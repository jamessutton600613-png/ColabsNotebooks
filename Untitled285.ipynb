# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessutton600613-png/GC/blob/main/Untitled285.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np

# -----------------------------
# Organism definition
# -----------------------------
class Organism:
    def __init__(self):
        # Genetic health: 0 (fragile) → 1 (robust)
        self.genetic_health = float(np.clip(random.gauss(0.7, 0.1), 0, 1))

        # Epigenetic bias: short-term modulation (small, can be +/-)
        self.epigenetic_bias = random.uniform(-0.05, 0.05)

        # Effort: training vs sloth (0 → 1)
        self.effort = random.uniform(0, 1)

    def effective_fitness(self) -> float:
        # Simple proxy: genetics + epigenetics + effort contribution
        return float(np.clip(self.genetic_health + self.epigenetic_bias + 0.2 * self.effort, 0, 1))


# -----------------------------
# Four "masters" as regime parameters
# -----------------------------
# Interpretations (kept minimal, but explicit):
# - Arrhenius: noise-driven threshold crossing; weak coupling to competence (low selection, high buffering)
# - Arrhenius–Marcus: better "cost accounting" via a fitness-modulated survival component (moderate selection/buffering)
# - Arrhenius–Warshel: strong infrastructure/protection; persistence decoupled from competence (very low selection, very high buffering)
# - GQR: selection-complete; tight coupling between competence and persistence (high selection, low buffering)
REGIMES = {
    "arrhenius": {
        "selection_strength": 0.2,
        "buffering": 0.8,
    },
    "arrhenius_marcus": {
        "selection_strength": 0.5,
        "buffering": 0.3,
    },
    "arrhenius_warshel": {
        "selection_strength": 0.1,
        "buffering": 0.9,
    },
    "gqr": {
        "selection_strength": 0.8,
        "buffering": 0.1,
    },
}


# -----------------------------
# Simulation step
# -----------------------------

def run_simulation(regime_name: str, generations: int = 200, initial_pop: int = 200, collapse_pop_threshold: int = 20):
    population = [Organism() for _ in range(initial_pop)]
    history = []

    MAX_POP = 2000  # start smaller for speed

    for gen in range(generations):
        population = simulate_generation(population, regime_name)

        # Cap AFTER the new generation is created
        if len(population) > MAX_POP:
            population = random.sample(population, MAX_POP)

        if len(population) == 0:
            history.append((gen, 0, 0.0))
            break

        avg_health = float(np.mean([o.genetic_health for o in population]))
        history.append((gen, len(population), avg_health))

        if len(population) < collapse_pop_threshold:
            break

    return history

# -----------------------------
# Run experiment
# -----------------------------
def run_simulation(regime_name: str, generations: int = 200, initial_pop: int = 200, collapse_pop_threshold: int = 20):
    population = [Organism() for _ in range(initial_pop)]
    history = []

    for gen in range(generations):
        population = simulate_generation(population, regime_name)

        if len(population) == 0:
            history.append((gen, 0, 0.0))
            break

        avg_health = float(np.mean([o.genetic_health for o in population]))
        history.append((gen, len(population), avg_health))

        if len(population) < collapse_pop_threshold:
            break

    return history


# -----------------------------
# Execute all regimes and print summary
# -----------------------------
results = {name: run_simulation(name) for name in REGIMES.keys()}

for name, hist in results.items():
    gen, pop, avg_health = hist[-1]
    print(f"{name:18s} | generations={gen:3d} | pop={pop:4d} | avg_health={avg_health:.3f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3351412434.py in <cell line: 0>()
#     104 # Execute all regimes and print summary
#     105 # -----------------------------
# --> 106 results = {name: run_simulation(name) for name in REGIMES.keys()}
#     107
#     108 for name, hist in results.items():
#
# /tmp/ipython-input-3351412434.py in run_simulation(regime_name, generations, initial_pop, collapse_pop_threshold)
#      86
#      87     for gen in range(generations):
# ---> 88         population = simulate_generation(population, regime_name)
#      89
#      90         if len(population) == 0:
#
# /tmp/ipython-input-3947384707.py in simulate_generation(population, regime_name)
#      69         # selection_strength * fitness = competence-linked survival
#      70         survival_prob = params["buffering"] + params["selection_strength"] * fitness
# ---> 71         survival_prob = float(np.clip(survival_prob, 0, 1))
#      72
#      73         if random.random() < survival_prob:
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2245
#    2246     """
# -> 2247     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2248
#    2249
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      44     # but this follows what was done before. TODO: revisit this.
#      45     arr, = conv.as_arrays(subok=False)
# ---> 46     result = getattr(arr, method)(*args, **kwds)
#      47
#      48     return conv.wrap(result, to_scalar=False)
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _clip(a, min, max, out, **kwargs)
#     106         return um.maximum(a, min, out=out, **kwargs)
#     107     else:
# --> 108         return um.clip(a, min, max, out=out, **kwargs)
#     109
#     110 def _mean(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#
# KeyboardInterrupt:

# %%
import random
import numpy as np

# -----------------------------
# Organism definition
# -----------------------------
class Organism:
    def __init__(self):
        self.genetic_health = float(np.clip(random.gauss(0.7, 0.1), 0, 1))
        self.epigenetic_bias = random.uniform(-0.05, 0.05)
        self.effort = random.uniform(0, 1)

    def effective_fitness(self) -> float:
        return float(np.clip(self.genetic_health + self.epigenetic_bias + 0.2 * self.effort, 0, 1))


# -----------------------------
# Four "masters" as regime parameters
# -----------------------------
REGIMES = {
    "arrhenius": {"selection_strength": 0.2, "buffering": 0.8},
    "arrhenius_marcus": {"selection_strength": 0.5, "buffering": 0.3},
    "arrhenius_warshel": {"selection_strength": 0.1, "buffering": 0.9},
    "gqr": {"selection_strength": 0.8, "buffering": 0.1},
}

# -----------------------------
# Simulation step
# -----------------------------
def simulate_generation(population, regime_name: str):
    params = REGIMES[regime_name]
    next_population = []

    for org in population:
        fitness = org.effective_fitness()

        survival_prob = params["buffering"] + params["selection_strength"] * fitness
        survival_prob = float(np.clip(survival_prob, 0, 1))

        if random.random() < survival_prob:
            reproduction_prob = float(np.clip(fitness, 0, 1))

            if random.random() < reproduction_prob:
                child = Organism()
                mutation = random.gauss(0, 0.05)
                child.genetic_health = float(np.clip(org.genetic_health + mutation, 0, 1))
                child.epigenetic_bias = 0.5 * org.epigenetic_bias
                next_population.append(child)

            next_population.append(org)

    return next_population


# -----------------------------
# Run experiment
# -----------------------------
def run_simulation(
    regime_name: str,
    generations: int = 200,
    initial_pop: int = 200,
    collapse_pop_threshold: int = 20,
    max_pop: int = 2000,
):
    population = [Organism() for _ in range(initial_pop)]
    history = []

    for gen in range(generations):
        population = simulate_generation(population, regime_name)

        # Cap AFTER the new generation is created
        if len(population) > max_pop:
            population = random.sample(population, max_pop)

        if len(population) == 0:
            history.append((gen, 0, 0.0))
            break

        avg_health = float(np.mean([o.genetic_health for o in population]))
        history.append((gen, len(population), avg_health))

        if len(population) < collapse_pop_threshold:
            break

    return history


# -----------------------------
# Execute all regimes and print summary
# -----------------------------
results = {name: run_simulation(name) for name in REGIMES.keys()}

for name, hist in results.items():
    gen, pop, avg_health = hist[-1]
    print(f"{name:18s} | generations={gen:3d} | pop={pop:4d} | avg_health={avg_health:.3f}")
# Out:
# arrhenius          | generations=199 | pop=2000 | avg_health=0.911
# arrhenius_marcus   | generations=199 | pop=2000 | avg_health=0.922
# arrhenius_warshel  | generations=199 | pop=2000 | avg_health=0.901
# gqr                | generations=199 | pop=2000 | avg_health=0.925

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# -----------------------------
# Four "masters" (regimes)
# -----------------------------
REGIMES = {
    "arrhenius": {"selection_strength": 0.2, "buffering": 0.8},
    "arrhenius_marcus": {"selection_strength": 0.5, "buffering": 0.3},
    "arrhenius_warshel": {"selection_strength": 0.1, "buffering": 0.9},
    "gqr": {"selection_strength": 0.8, "buffering": 0.1},
}

# Standard distinct colors (Matplotlib-like defaults)
COLORS = {
    "arrhenius": "#1f77b4",          # blue
    "arrhenius_marcus": "#ff7f0e",   # orange
    "arrhenius_warshel": "#2ca02c",  # green
    "gqr": "#d62728",                # red
}

# -----------------------------
# Population initialisation
# -----------------------------
def init_population(n, rng):
    genetic_health = np.clip(rng.normal(0.7, 0.1, size=n), 0, 1)
    epigenetic_bias = rng.uniform(-0.05, 0.05, size=n)
    effort = rng.uniform(0, 1, size=n)
    return genetic_health, epigenetic_bias, effort

# -----------------------------
# One generation (array-based, fast)
# -----------------------------
def simulate_generation(
    genetic_health,
    epigenetic_bias,
    effort,
    regime_name,
    rng,
    carrying_capacity=2000,
    base_mutation_sigma=0.03,
    extra_mutation_sigma=0.08,   # multiplied by buffering (gene-mangling channel)
    effort_benefit=0.2,
    effort_cost=0.1,             # makes training non-free
):
    sel = REGIMES[regime_name]["selection_strength"]
    buf = REGIMES[regime_name]["buffering"]

    # Fitness proxy (bounded)
    fitness = np.clip(genetic_health + epigenetic_bias + effort_benefit * effort - effort_cost * effort, 0, 1)

    # Survival probability (governance)
    survival_prob = np.clip(buf + sel * fitness, 0, 1)

    # Ecological (density) pressure: as pop approaches capacity, survival is penalised
    density = genetic_health.size / carrying_capacity
    survival_prob *= max(0.0, 1.0 - density)
    survival_prob = np.clip(survival_prob, 0, 1)

    survivors = rng.random(size=genetic_health.size) < survival_prob
    gh_s = genetic_health[survivors]
    eb_s = epigenetic_bias[survivors]
    ef_s = effort[survivors]
    fit_s = fitness[survivors]

    if gh_s.size == 0:
        return gh_s, eb_s, ef_s

    # Reproduction probability tied to fitness (simple)
    repro = rng.random(size=gh_s.size) < fit_s
    gh_p = gh_s[repro]
    eb_p = eb_s[repro]

    n_children = gh_p.size
    if n_children > 0:
        # Mutation load increases with buffering (civilisation "gene mangling")
        mutation_sigma = base_mutation_sigma + extra_mutation_sigma * buf
        mutation = rng.normal(0.0, mutation_sigma, size=n_children)

        child_gh = np.clip(gh_p + mutation, 0, 1)
        child_eb = 0.5 * eb_p               # weak epigenetic carryover
        child_ef = rng.uniform(0, 1, size=n_children)  # new effort each generation

        gh_next = np.concatenate([gh_s, child_gh])
        eb_next = np.concatenate([eb_s, child_eb])
        ef_next = np.concatenate([ef_s, child_ef])
    else:
        gh_next, eb_next, ef_next = gh_s, eb_s, ef_s

    return gh_next, eb_next, ef_next

# -----------------------------
# Run a regime with progress updates
# -----------------------------
def run_regime(
    regime_name,
    generations=100000,
    initial_pop=200,
    carrying_capacity=2000,
    collapse_threshold=20,
    seed=123,
    update_every=100,
):
    rng = np.random.default_rng(seed)
    gh, eb, ef = init_population(initial_pop, rng)

    gens = []
    pops = []
    avg_healths = []
    var_healths = []

    t0 = time.time()
    for gen in range(generations):
        gh, eb, ef = simulate_generation(
            gh, eb, ef, regime_name, rng, carrying_capacity=carrying_capacity
        )

        n = gh.size
        if n == 0:
            gens.append(gen)
            pops.append(0)
            avg_healths.append(0.0)
            var_healths.append(0.0)
            print(f"[{regime_name}] gen={gen:4d} pop=0 avg_health=0.000 (extinct)")
            break

        gens.append(gen)
        pops.append(int(n))
        avg_healths.append(float(gh.mean()))
        var_healths.append(float(gh.var()))

        if (gen % update_every) == 0 or gen == generations - 1:
            dt = time.time() - t0
            print(f"[{regime_name}] gen={gen:4d}/{generations-1} pop={n:4d} avg_health={avg_healths[-1]:.3f} var={var_healths[-1]:.4f} elapsed={dt:.1f}s")

        if n < collapse_threshold:
            print(f"[{regime_name}] gen={gen:4d} pop<{collapse_threshold} (collapse threshold reached)")
            break

    return np.array(gens), np.array(pops), np.array(avg_healths), np.array(var_healths)

# -----------------------------
# Run all four
# -----------------------------
generations = 100000
initial_pop = 200
carrying_capacity = 2000
update_every = 100

results = {}
for i, name in enumerate(REGIMES.keys(), start=1):
    print(f"\n=== Running {name} ({i}/{len(REGIMES)}) ===")
    results[name] = run_regime(
        name,
        generations=generations,
        initial_pop=initial_pop,
        carrying_capacity=carrying_capacity,
        seed=123,
        update_every=update_every,
    )

# -----------------------------
# Plot population
# -----------------------------
plt.figure()
for name, (g, p, h, v) in results.items():
    plt.plot(g, p, label=name, color=COLORS[name])
plt.xlabel("Generation")
plt.ylabel("Population size")
plt.title("Population size over generations (carrying capacity + buffering-linked mutation)")
plt.legend()
plt.show()

# -----------------------------
# Plot average genetic health
# -----------------------------
plt.figure()
for name, (g, p, h, v) in results.items():
    plt.plot(g, h, label=name, color=COLORS[name])
plt.xlabel("Generation")
plt.ylabel("Average genetic health")
plt.ylim(0, 1)
plt.title("Average genetic health over generations (carrying capacity + buffering-linked mutation)")
plt.legend()
plt.show()

# -----------------------------
# Plot variance (fragility indicator)
# -----------------------------
plt.figure()
for name, (g, p, h, v) in results.items():
    plt.plot(g, v, label=name, color=COLORS[name])
plt.xlabel("Generation")
plt.ylabel("Variance of genetic health")
plt.title("Variance of genetic health (fragility / diversity proxy)")
plt.legend()
plt.show()

# -----------------------------
# Final summary
# -----------------------------
print("\nFinal summary:")
for name, (g, p, h, v) in results.items():
    print(f"{name:18s} | gen={int(g[-1]):4d} | pop={int(p[-1]):4d} | avg_health={float(h[-1]):.3f} | var={float(v[-1]):.4f}")
# Out:
# === Running arrhenius (1/4) ===
# [arrhenius] gen=   0/99999 pop= 315 avg_health=0.713 var=0.0125 elapsed=0.0s
# [arrhenius] gen= 100/99999 pop= 941 avg_health=0.893 var=0.0126 elapsed=0.0s
# [arrhenius] gen= 200/99999 pop= 960 avg_health=0.891 var=0.0143 elapsed=0.1s
# [arrhenius] gen= 300/99999 pop= 933 avg_health=0.874 var=0.0184 elapsed=0.1s
# [arrhenius] gen= 400/99999 pop= 955 avg_health=0.891 var=0.0139 elapsed=0.1s
# [arrhenius] gen= 500/99999 pop= 945 avg_health=0.888 var=0.0152 elapsed=0.2s
# [arrhenius] gen= 600/99999 pop= 932 avg_health=0.889 var=0.0130 elapsed=0.2s
# [arrhenius] gen= 700/99999 pop= 949 avg_health=0.890 var=0.0138 elapsed=0.3s
# [arrhenius] gen= 800/99999 pop= 932 avg_health=0.886 var=0.0131 elapsed=0.4s
# [arrhenius] gen= 900/99999 pop= 925 avg_health=0.893 var=0.0137 elapsed=0.5s
# [arrhenius] gen=1000/99999 pop= 908 avg_health=0.894 var=0.0125 elapsed=0.5s
# [arrhenius] gen=1100/99999 pop= 936 avg_health=0.884 var=0.0149 elapsed=0.5s
# [arrhenius] gen=1200/99999 pop= 880 avg_health=0.876 var=0.0172 elapsed=0.5s
# [arrhenius] gen=1300/99999 pop= 938 avg_health=0.898 var=0.0120 elapsed=0.6s
# [arrhenius] gen=1400/99999 pop= 966 avg_health=0.894 var=0.0136 elapsed=0.6s
# [arrhenius] gen=1500/99999 pop= 921 avg_health=0.887 var=0.0122 elapsed=0.6s
# [arrhenius] gen=1600/99999 pop= 914 avg_health=0.894 var=0.0144 elapsed=0.6s
# [arrhenius] gen=1700/99999 pop= 899 avg_health=0.891 var=0.0115 elapsed=0.7s
# [arrhenius] gen=1800/99999 pop= 960 avg_health=0.888 var=0.0140 elapsed=0.7s
# [arrhenius] gen=1900/99999 pop= 940 avg_health=0.887 var=0.0150 elapsed=0.7s
# [arrhenius] gen=2000/99999 pop= 946 avg_health=0.889 var=0.0134 elapsed=0.7s
# [arrhenius] gen=2100/99999 pop= 952 avg_health=0.892 var=0.0144 elapsed=0.7s
# [arrhenius] gen=2200/99999 pop= 914 avg_health=0.873 var=0.0165 elapsed=0.8s
# [arrhenius] gen=2300/99999 pop= 943 avg_health=0.904 var=0.0119 elapsed=0.8s
# [arrhenius] gen=2400/99999 pop= 932 avg_health=0.884 var=0.0167 elapsed=0.8s
# [arrhenius] gen=2500/99999 pop= 995 avg_health=0.885 var=0.0143 elapsed=0.8s
# [arrhenius] gen=2600/99999 pop= 960 avg_health=0.887 var=0.0144 elapsed=0.8s
# [arrhenius] gen=2700/99999 pop= 980 avg_health=0.890 var=0.0141 elapsed=0.9s
# [arrhenius] gen=2800/99999 pop= 932 avg_health=0.892 var=0.0153 elapsed=0.9s
# [arrhenius] gen=2900/99999 pop= 902 avg_health=0.892 var=0.0128 elapsed=0.9s
# [arrhenius] gen=3000/99999 pop= 970 avg_health=0.895 var=0.0136 elapsed=0.9s
# [arrhenius] gen=3100/99999 pop= 894 avg_health=0.863 var=0.0167 elapsed=0.9s
# [arrhenius] gen=3200/99999 pop= 917 avg_health=0.895 var=0.0128 elapsed=0.9s
# [arrhenius] gen=3300/99999 pop= 993 avg_health=0.890 var=0.0126 elapsed=1.0s
# [arrhenius] gen=3400/99999 pop= 912 avg_health=0.882 var=0.0150 elapsed=1.0s
# [arrhenius] gen=3500/99999 pop=1010 avg_health=0.896 var=0.0131 elapsed=1.0s
# [arrhenius] gen=3600/99999 pop= 948 avg_health=0.885 var=0.0141 elapsed=1.0s
# [arrhenius] gen=3700/99999 pop= 991 avg_health=0.890 var=0.0141 elapsed=1.0s
# [arrhenius] gen=3800/99999 pop= 954 avg_health=0.882 var=0.0149 elapsed=1.1s
# [arrhenius] gen=3900/99999 pop= 964 avg_health=0.896 var=0.0135 elapsed=1.1s
# [arrhenius] gen=4000/99999 pop= 917 avg_health=0.886 var=0.0152 elapsed=1.1s
# [arrhenius] gen=4100/99999 pop= 945 avg_health=0.908 var=0.0098 elapsed=1.1s
# [arrhenius] gen=4200/99999 pop= 927 avg_health=0.879 var=0.0148 elapsed=1.1s
# [arrhenius] gen=4300/99999 pop= 918 avg_health=0.879 var=0.0161 elapsed=1.2s
# [arrhenius] gen=4400/99999 pop= 961 avg_health=0.893 var=0.0131 elapsed=1.2s
# [arrhenius] gen=4500/99999 pop= 988 avg_health=0.883 var=0.0138 elapsed=1.2s
# [arrhenius] gen=4600/99999 pop= 892 avg_health=0.877 var=0.0178 elapsed=1.2s
# [arrhenius] gen=4700/99999 pop= 968 avg_health=0.886 var=0.0166 elapsed=1.2s
# [arrhenius] gen=4800/99999 pop= 924 avg_health=0.888 var=0.0131 elapsed=1.2s
# [arrhenius] gen=4900/99999 pop= 981 avg_health=0.892 var=0.0133 elapsed=1.3s
# [arrhenius] gen=5000/99999 pop= 922 avg_health=0.883 var=0.0151 elapsed=1.3s
# [arrhenius] gen=5100/99999 pop= 966 avg_health=0.891 var=0.0146 elapsed=1.3s
# [arrhenius] gen=5200/99999 pop= 938 avg_health=0.888 var=0.0131 elapsed=1.3s
# [arrhenius] gen=5300/99999 pop= 890 avg_health=0.880 var=0.0152 elapsed=1.4s
# [arrhenius] gen=5400/99999 pop= 926 avg_health=0.897 var=0.0127 elapsed=1.4s
# [arrhenius] gen=5500/99999 pop= 934 avg_health=0.904 var=0.0126 elapsed=1.4s
# [arrhenius] gen=5600/99999 pop= 940 avg_health=0.879 var=0.0166 elapsed=1.4s
# [arrhenius] gen=5700/99999 pop= 915 avg_health=0.880 var=0.0161 elapsed=1.4s
# [arrhenius] gen=5800/99999 pop= 928 avg_health=0.883 var=0.0144 elapsed=1.4s
# [arrhenius] gen=5900/99999 pop= 938 avg_health=0.893 var=0.0146 elapsed=1.5s
# [arrhenius] gen=6000/99999 pop= 916 avg_health=0.880 var=0.0146 elapsed=1.5s
# [arrhenius] gen=6100/99999 pop= 887 avg_health=0.896 var=0.0128 elapsed=1.5s
# [arrhenius] gen=6200/99999 pop= 931 avg_health=0.897 var=0.0132 elapsed=1.5s
# [arrhenius] gen=6300/99999 pop= 913 avg_health=0.891 var=0.0146 elapsed=1.5s
# [arrhenius] gen=6400/99999 pop= 946 avg_health=0.889 var=0.0140 elapsed=1.6s
# [arrhenius] gen=6500/99999 pop= 880 avg_health=0.881 var=0.0155 elapsed=1.6s
# [arrhenius] gen=6600/99999 pop= 900 avg_health=0.896 var=0.0132 elapsed=1.6s
# [arrhenius] gen=6700/99999 pop= 901 avg_health=0.894 var=0.0131 elapsed=1.6s
# [arrhenius] gen=6800/99999 pop= 941 avg_health=0.893 var=0.0135 elapsed=1.6s
# [arrhenius] gen=6900/99999 pop= 948 avg_health=0.899 var=0.0139 elapsed=1.6s
# [arrhenius] gen=7000/99999 pop= 978 avg_health=0.887 var=0.0132 elapsed=1.7s
# [arrhenius] gen=7100/99999 pop= 949 avg_health=0.889 var=0.0130 elapsed=1.7s
# [arrhenius] gen=7200/99999 pop= 960 avg_health=0.883 var=0.0141 elapsed=1.7s
# [arrhenius] gen=7300/99999 pop= 915 avg_health=0.900 var=0.0126 elapsed=1.7s
# [arrhenius] gen=7400/99999 pop= 967 avg_health=0.890 var=0.0141 elapsed=1.7s
# [arrhenius] gen=7500/99999 pop= 936 avg_health=0.875 var=0.0172 elapsed=1.8s
# [arrhenius] gen=7600/99999 pop= 947 avg_health=0.896 var=0.0134 elapsed=1.8s
# [arrhenius] gen=7700/99999 pop= 887 avg_health=0.895 var=0.0120 elapsed=1.8s
# [arrhenius] gen=7800/99999 pop= 945 avg_health=0.897 var=0.0124 elapsed=1.8s
# [arrhenius] gen=7900/99999 pop= 925 avg_health=0.890 var=0.0139 elapsed=1.8s
# [arrhenius] gen=8000/99999 pop= 949 avg_health=0.890 var=0.0156 elapsed=1.9s
# [arrhenius] gen=8100/99999 pop= 925 avg_health=0.886 var=0.0135 elapsed=1.9s
# [arrhenius] gen=8200/99999 pop= 975 avg_health=0.888 var=0.0135 elapsed=1.9s
# [arrhenius] gen=8300/99999 pop= 897 avg_health=0.897 var=0.0143 elapsed=1.9s
# [arrhenius] gen=8400/99999 pop= 839 avg_health=0.893 var=0.0129 elapsed=1.9s
# [arrhenius] gen=8500/99999 pop= 935 avg_health=0.886 var=0.0137 elapsed=2.0s
# [arrhenius] gen=8600/99999 pop= 929 avg_health=0.901 var=0.0122 elapsed=2.0s
# [arrhenius] gen=8700/99999 pop= 950 avg_health=0.899 var=0.0124 elapsed=2.0s
# [arrhenius] gen=8800/99999 pop= 910 avg_health=0.888 var=0.0142 elapsed=2.0s
# [arrhenius] gen=8900/99999 pop= 955 avg_health=0.887 var=0.0136 elapsed=2.0s
# [arrhenius] gen=9000/99999 pop= 870 avg_health=0.895 var=0.0145 elapsed=2.1s
# [arrhenius] gen=9100/99999 pop= 951 avg_health=0.887 var=0.0137 elapsed=2.1s
# [arrhenius] gen=9200/99999 pop= 969 avg_health=0.896 var=0.0109 elapsed=2.1s
# [arrhenius] gen=9300/99999 pop= 922 avg_health=0.877 var=0.0151 elapsed=2.1s
# [arrhenius] gen=9400/99999 pop= 948 avg_health=0.895 var=0.0127 elapsed=2.1s
# [arrhenius] gen=9500/99999 pop=1019 avg_health=0.896 var=0.0131 elapsed=2.1s
# [arrhenius] gen=9600/99999 pop= 969 avg_health=0.888 var=0.0139 elapsed=2.2s
# [arrhenius] gen=9700/99999 pop= 912 avg_health=0.882 var=0.0142 elapsed=2.2s
# [arrhenius] gen=9800/99999 pop= 931 avg_health=0.893 var=0.0127 elapsed=2.2s
# [arrhenius] gen=9900/99999 pop= 963 avg_health=0.892 var=0.0130 elapsed=2.2s
# [arrhenius] gen=10000/99999 pop= 928 avg_health=0.887 var=0.0140 elapsed=2.2s
# [arrhenius] gen=10100/99999 pop= 975 avg_health=0.889 var=0.0147 elapsed=2.3s
# [arrhenius] gen=10200/99999 pop= 900 avg_health=0.900 var=0.0127 elapsed=2.3s
# [arrhenius] gen=10300/99999 pop= 938 avg_health=0.890 var=0.0140 elapsed=2.3s
# [arrhenius] gen=10400/99999 pop= 944 avg_health=0.886 var=0.0145 elapsed=2.3s
# [arrhenius] gen=10500/99999 pop= 925 avg_health=0.880 var=0.0149 elapsed=2.4s
# [arrhenius] gen=10600/99999 pop= 985 avg_health=0.885 var=0.0160 elapsed=2.4s
# [arrhenius] gen=10700/99999 pop= 938 avg_health=0.880 var=0.0162 elapsed=2.4s
# [arrhenius] gen=10800/99999 pop= 899 avg_health=0.879 var=0.0158 elapsed=2.4s
# [arrhenius] gen=10900/99999 pop= 994 avg_health=0.893 var=0.0140 elapsed=2.4s
# [arrhenius] gen=11000/99999 pop= 959 avg_health=0.891 var=0.0143 elapsed=2.5s
# [arrhenius] gen=11100/99999 pop= 934 avg_health=0.895 var=0.0124 elapsed=2.5s
# [arrhenius] gen=11200/99999 pop= 923 avg_health=0.875 var=0.0158 elapsed=2.5s
# [arrhenius] gen=11300/99999 pop= 946 avg_health=0.888 var=0.0149 elapsed=2.5s
# [arrhenius] gen=11400/99999 pop= 969 avg_health=0.885 var=0.0148 elapsed=2.5s
# [arrhenius] gen=11500/99999 pop= 958 avg_health=0.891 var=0.0144 elapsed=2.5s
# [arrhenius] gen=11600/99999 pop=1004 avg_health=0.899 var=0.0118 elapsed=2.6s
# [arrhenius] gen=11700/99999 pop= 952 avg_health=0.900 var=0.0121 elapsed=2.6s
# [arrhenius] gen=11800/99999 pop= 929 avg_health=0.890 var=0.0141 elapsed=2.6s
# [arrhenius] gen=11900/99999 pop= 938 avg_health=0.867 var=0.0180 elapsed=2.6s
# [arrhenius] gen=12000/99999 pop= 921 avg_health=0.883 var=0.0144 elapsed=2.6s
# [arrhenius] gen=12100/99999 pop= 938 avg_health=0.892 var=0.0130 elapsed=2.7s
# [arrhenius] gen=12200/99999 pop= 941 avg_health=0.885 var=0.0142 elapsed=2.7s
# [arrhenius] gen=12300/99999 pop= 959 avg_health=0.898 var=0.0144 elapsed=2.7s
# [arrhenius] gen=12400/99999 pop= 935 avg_health=0.889 var=0.0137 elapsed=2.7s
# [arrhenius] gen=12500/99999 pop= 963 avg_health=0.875 var=0.0150 elapsed=2.7s
# [arrhenius] gen=12600/99999 pop= 984 avg_health=0.884 var=0.0148 elapsed=2.8s
# [arrhenius] gen=12700/99999 pop= 924 avg_health=0.882 var=0.0138 elapsed=2.8s
# [arrhenius] gen=12800/99999 pop= 940 avg_health=0.902 var=0.0129 elapsed=2.8s
# [arrhenius] gen=12900/99999 pop= 927 avg_health=0.895 var=0.0138 elapsed=2.8s
# [arrhenius] gen=13000/99999 pop= 912 avg_health=0.894 var=0.0148 elapsed=2.8s
# [arrhenius] gen=13100/99999 pop= 930 avg_health=0.896 var=0.0133 elapsed=2.8s
# [arrhenius] gen=13200/99999 pop= 873 avg_health=0.887 var=0.0147 elapsed=2.9s
# [arrhenius] gen=13300/99999 pop= 982 avg_health=0.870 var=0.0165 elapsed=2.9s
# [arrhenius] gen=13400/99999 pop= 959 avg_health=0.892 var=0.0135 elapsed=2.9s
# [arrhenius] gen=13500/99999 pop= 943 avg_health=0.898 var=0.0144 elapsed=2.9s
# [arrhenius] gen=13600/99999 pop= 973 avg_health=0.893 var=0.0131 elapsed=2.9s
# [arrhenius] gen=13700/99999 pop= 861 avg_health=0.888 var=0.0144 elapsed=3.0s
# [arrhenius] gen=13800/99999 pop= 918 avg_health=0.888 var=0.0152 elapsed=3.0s
# [arrhenius] gen=13900/99999 pop= 983 avg_health=0.889 var=0.0143 elapsed=3.0s
# [arrhenius] gen=14000/99999 pop= 916 avg_health=0.898 var=0.0120 elapsed=3.0s
# [arrhenius] gen=14100/99999 pop= 970 avg_health=0.879 var=0.0153 elapsed=3.0s
# [arrhenius] gen=14200/99999 pop= 948 avg_health=0.893 var=0.0152 elapsed=3.1s
# [arrhenius] gen=14300/99999 pop= 890 avg_health=0.906 var=0.0106 elapsed=3.1s
# [arrhenius] gen=14400/99999 pop= 961 avg_health=0.886 var=0.0146 elapsed=3.1s
# [arrhenius] gen=14500/99999 pop= 877 avg_health=0.902 var=0.0120 elapsed=3.1s
# [arrhenius] gen=14600/99999 pop= 977 avg_health=0.888 var=0.0143 elapsed=3.1s
# [arrhenius] gen=14700/99999 pop= 944 avg_health=0.885 var=0.0137 elapsed=3.1s
# [arrhenius] gen=14800/99999 pop= 949 avg_health=0.886 var=0.0134 elapsed=3.2s
# [arrhenius] gen=14900/99999 pop= 919 avg_health=0.882 var=0.0156 elapsed=3.2s
# [arrhenius] gen=15000/99999 pop= 918 avg_health=0.867 var=0.0177 elapsed=3.2s
# [arrhenius] gen=15100/99999 pop= 945 avg_health=0.885 var=0.0142 elapsed=3.2s
# [arrhenius] gen=15200/99999 pop= 904 avg_health=0.871 var=0.0196 elapsed=3.2s
# [arrhenius] gen=15300/99999 pop= 925 avg_health=0.882 var=0.0162 elapsed=3.3s
# [arrhenius] gen=15400/99999 pop= 908 avg_health=0.878 var=0.0152 elapsed=3.3s
# [arrhenius] gen=15500/99999 pop= 954 avg_health=0.891 var=0.0129 elapsed=3.3s
# [arrhenius] gen=15600/99999 pop= 981 avg_health=0.885 var=0.0153 elapsed=3.3s
# [arrhenius] gen=15700/99999 pop= 932 avg_health=0.892 var=0.0136 elapsed=3.3s
# [arrhenius] gen=15800/99999 pop= 905 avg_health=0.888 var=0.0135 elapsed=3.4s
# [arrhenius] gen=15900/99999 pop= 912 avg_health=0.895 var=0.0113 elapsed=3.4s
# [arrhenius] gen=16000/99999 pop= 960 avg_health=0.891 var=0.0143 elapsed=3.4s
# [arrhenius] gen=16100/99999 pop= 933 avg_health=0.902 var=0.0109 elapsed=3.4s
# [arrhenius] gen=16200/99999 pop= 933 avg_health=0.896 var=0.0124 elapsed=3.4s
# [arrhenius] gen=16300/99999 pop= 923 avg_health=0.893 var=0.0138 elapsed=3.5s
# [arrhenius] gen=16400/99999 pop= 994 avg_health=0.901 var=0.0120 elapsed=3.5s
# [arrhenius] gen=16500/99999 pop= 982 avg_health=0.905 var=0.0111 elapsed=3.5s
# [arrhenius] gen=16600/99999 pop= 927 avg_health=0.879 var=0.0149 elapsed=3.5s
# [arrhenius] gen=16700/99999 pop= 962 avg_health=0.895 var=0.0136 elapsed=3.5s
# [arrhenius] gen=16800/99999 pop= 957 avg_health=0.889 var=0.0137 elapsed=3.5s
# [arrhenius] gen=16900/99999 pop= 954 avg_health=0.886 var=0.0139 elapsed=3.6s
# [arrhenius] gen=17000/99999 pop= 926 avg_health=0.887 var=0.0135 elapsed=3.6s
# [arrhenius] gen=17100/99999 pop= 891 avg_health=0.898 var=0.0115 elapsed=3.6s
# [arrhenius] gen=17200/99999 pop= 904 avg_health=0.890 var=0.0143 elapsed=3.6s
# [arrhenius] gen=17300/99999 pop= 936 avg_health=0.900 var=0.0129 elapsed=3.6s
# [arrhenius] gen=17400/99999 pop= 927 avg_health=0.882 var=0.0147 elapsed=3.7s
# [arrhenius] gen=17500/99999 pop= 928 avg_health=0.895 var=0.0134 elapsed=3.7s
# [arrhenius] gen=17600/99999 pop= 908 avg_health=0.877 var=0.0174 elapsed=3.7s
# [arrhenius] gen=17700/99999 pop= 959 avg_health=0.899 var=0.0106 elapsed=3.7s
# [arrhenius] gen=17800/99999 pop= 967 avg_health=0.900 var=0.0114 elapsed=3.7s
# [arrhenius] gen=17900/99999 pop= 956 avg_health=0.883 var=0.0176 elapsed=3.8s
# [arrhenius] gen=18000/99999 pop= 951 avg_health=0.888 var=0.0143 elapsed=3.8s
# [arrhenius] gen=18100/99999 pop= 990 avg_health=0.892 var=0.0143 elapsed=3.8s
# [arrhenius] gen=18200/99999 pop= 911 avg_health=0.890 var=0.0138 elapsed=3.8s
# [arrhenius] gen=18300/99999 pop= 931 avg_health=0.884 var=0.0134 elapsed=3.8s
# [arrhenius] gen=18400/99999 pop= 970 avg_health=0.895 var=0.0152 elapsed=3.9s
# [arrhenius] gen=18500/99999 pop= 958 avg_health=0.908 var=0.0113 elapsed=3.9s
# [arrhenius] gen=18600/99999 pop= 916 avg_health=0.892 var=0.0119 elapsed=3.9s
# [arrhenius] gen=18700/99999 pop= 951 avg_health=0.889 var=0.0155 elapsed=3.9s
# [arrhenius] gen=18800/99999 pop= 880 avg_health=0.893 var=0.0140 elapsed=3.9s
# [arrhenius] gen=18900/99999 pop= 969 avg_health=0.876 var=0.0140 elapsed=4.0s
# [arrhenius] gen=19000/99999 pop= 899 avg_health=0.882 var=0.0166 elapsed=4.0s
# [arrhenius] gen=19100/99999 pop= 969 avg_health=0.901 var=0.0124 elapsed=4.0s
# [arrhenius] gen=19200/99999 pop= 973 avg_health=0.892 var=0.0131 elapsed=4.0s
# [arrhenius] gen=19300/99999 pop= 956 avg_health=0.886 var=0.0140 elapsed=4.0s
# [arrhenius] gen=19400/99999 pop= 956 avg_health=0.886 var=0.0138 elapsed=4.1s
# [arrhenius] gen=19500/99999 pop= 902 avg_health=0.889 var=0.0152 elapsed=4.1s
# [arrhenius] gen=19600/99999 pop= 950 avg_health=0.880 var=0.0157 elapsed=4.1s
# [arrhenius] gen=19700/99999 pop= 961 avg_health=0.902 var=0.0122 elapsed=4.1s
# [arrhenius] gen=19800/99999 pop= 943 avg_health=0.891 var=0.0141 elapsed=4.2s
# [arrhenius] gen=19900/99999 pop= 922 avg_health=0.885 var=0.0142 elapsed=4.2s
# [arrhenius] gen=20000/99999 pop= 952 avg_health=0.894 var=0.0129 elapsed=4.2s
# [arrhenius] gen=20100/99999 pop= 985 avg_health=0.900 var=0.0119 elapsed=4.3s
# [arrhenius] gen=20200/99999 pop= 902 avg_health=0.868 var=0.0150 elapsed=4.3s
# [arrhenius] gen=20300/99999 pop= 964 avg_health=0.887 var=0.0146 elapsed=4.3s
# [arrhenius] gen=20400/99999 pop=1020 avg_health=0.896 var=0.0137 elapsed=4.3s
# [arrhenius] gen=20500/99999 pop= 990 avg_health=0.906 var=0.0119 elapsed=4.4s
# [arrhenius] gen=20600/99999 pop= 941 avg_health=0.883 var=0.0160 elapsed=4.4s
# [arrhenius] gen=20700/99999 pop= 916 avg_health=0.893 var=0.0131 elapsed=4.4s
# [arrhenius] gen=20800/99999 pop= 927 avg_health=0.905 var=0.0109 elapsed=4.4s
# [arrhenius] gen=20900/99999 pop= 909 avg_health=0.881 var=0.0166 elapsed=4.5s
# [arrhenius] gen=21000/99999 pop= 889 avg_health=0.883 var=0.0163 elapsed=4.5s
# [arrhenius] gen=21100/99999 pop= 980 avg_health=0.889 var=0.0134 elapsed=4.5s
# [arrhenius] gen=21200/99999 pop= 891 avg_health=0.896 var=0.0127 elapsed=4.6s
# [arrhenius] gen=21300/99999 pop= 943 avg_health=0.897 var=0.0124 elapsed=4.6s
# [arrhenius] gen=21400/99999 pop= 947 avg_health=0.888 var=0.0143 elapsed=4.6s
# [arrhenius] gen=21500/99999 pop= 901 avg_health=0.888 var=0.0147 elapsed=4.6s
# [arrhenius] gen=21600/99999 pop= 964 avg_health=0.873 var=0.0150 elapsed=4.7s
# [arrhenius] gen=21700/99999 pop= 919 avg_health=0.871 var=0.0167 elapsed=4.7s
# [arrhenius] gen=21800/99999 pop= 937 avg_health=0.876 var=0.0161 elapsed=4.7s
# [arrhenius] gen=21900/99999 pop= 920 avg_health=0.894 var=0.0122 elapsed=4.7s
# [arrhenius] gen=22000/99999 pop= 962 avg_health=0.878 var=0.0149 elapsed=4.8s
# [arrhenius] gen=22100/99999 pop= 963 avg_health=0.895 var=0.0114 elapsed=4.8s
# [arrhenius] gen=22200/99999 pop= 944 avg_health=0.877 var=0.0162 elapsed=4.8s
# [arrhenius] gen=22300/99999 pop= 959 avg_health=0.879 var=0.0166 elapsed=4.8s
# [arrhenius] gen=22400/99999 pop= 958 avg_health=0.875 var=0.0157 elapsed=4.9s
# [arrhenius] gen=22500/99999 pop= 939 avg_health=0.907 var=0.0130 elapsed=4.9s
# [arrhenius] gen=22600/99999 pop= 963 avg_health=0.894 var=0.0139 elapsed=4.9s
# [arrhenius] gen=22700/99999 pop= 978 avg_health=0.898 var=0.0124 elapsed=5.0s
# [arrhenius] gen=22800/99999 pop= 921 avg_health=0.892 var=0.0132 elapsed=5.0s
# [arrhenius] gen=22900/99999 pop= 943 avg_health=0.885 var=0.0136 elapsed=5.0s
# [arrhenius] gen=23000/99999 pop= 925 avg_health=0.885 var=0.0143 elapsed=5.0s
# [arrhenius] gen=23100/99999 pop= 917 avg_health=0.880 var=0.0157 elapsed=5.1s
# [arrhenius] gen=23200/99999 pop= 958 avg_health=0.897 var=0.0130 elapsed=5.1s
# [arrhenius] gen=23300/99999 pop= 916 avg_health=0.892 var=0.0140 elapsed=5.1s
# [arrhenius] gen=23400/99999 pop= 936 avg_health=0.886 var=0.0137 elapsed=5.1s
# [arrhenius] gen=23500/99999 pop= 984 avg_health=0.897 var=0.0120 elapsed=5.2s
# [arrhenius] gen=23600/99999 pop= 882 avg_health=0.895 var=0.0143 elapsed=5.2s
# [arrhenius] gen=23700/99999 pop= 948 avg_health=0.884 var=0.0146 elapsed=5.2s
# [arrhenius] gen=23800/99999 pop= 965 avg_health=0.891 var=0.0131 elapsed=5.2s
# [arrhenius] gen=23900/99999 pop= 888 avg_health=0.894 var=0.0143 elapsed=5.3s
# [arrhenius] gen=24000/99999 pop= 944 avg_health=0.891 var=0.0161 elapsed=5.3s
# [arrhenius] gen=24100/99999 pop= 972 avg_health=0.893 var=0.0126 elapsed=5.3s
# [arrhenius] gen=24200/99999 pop= 966 avg_health=0.892 var=0.0139 elapsed=5.4s
# [arrhenius] gen=24300/99999 pop= 959 avg_health=0.884 var=0.0135 elapsed=5.4s
# [arrhenius] gen=24400/99999 pop= 943 avg_health=0.892 var=0.0142 elapsed=5.4s
# [arrhenius] gen=24500/99999 pop= 956 avg_health=0.877 var=0.0169 elapsed=5.4s
# [arrhenius] gen=24600/99999 pop= 976 avg_health=0.892 var=0.0128 elapsed=5.5s
# [arrhenius] gen=24700/99999 pop=1030 avg_health=0.896 var=0.0127 elapsed=5.5s
# [arrhenius] gen=24800/99999 pop=1060 avg_health=0.900 var=0.0123 elapsed=5.5s
# [arrhenius] gen=24900/99999 pop= 928 avg_health=0.889 var=0.0143 elapsed=5.5s
# [arrhenius] gen=25000/99999 pop= 944 avg_health=0.881 var=0.0148 elapsed=5.6s
# [arrhenius] gen=25100/99999 pop= 904 avg_health=0.894 var=0.0140 elapsed=5.6s
# [arrhenius] gen=25200/99999 pop= 948 avg_health=0.898 var=0.0133 elapsed=5.6s
# [arrhenius] gen=25300/99999 pop= 964 avg_health=0.887 var=0.0141 elapsed=5.6s
# [arrhenius] gen=25400/99999 pop= 945 avg_health=0.891 var=0.0153 elapsed=5.7s
# [arrhenius] gen=25500/99999 pop= 926 avg_health=0.876 var=0.0161 elapsed=5.7s
# [arrhenius] gen=25600/99999 pop= 966 avg_health=0.894 var=0.0134 elapsed=5.7s
# [arrhenius] gen=25700/99999 pop= 999 avg_health=0.896 var=0.0124 elapsed=5.7s
# [arrhenius] gen=25800/99999 pop= 882 avg_health=0.879 var=0.0158 elapsed=5.8s
# [arrhenius] gen=25900/99999 pop= 899 avg_health=0.885 var=0.0158 elapsed=5.8s
# [arrhenius] gen=26000/99999 pop= 902 avg_health=0.888 var=0.0140 elapsed=5.8s
# [arrhenius] gen=26100/99999 pop= 966 avg_health=0.889 var=0.0133 elapsed=5.8s
# [arrhenius] gen=26200/99999 pop= 950 avg_health=0.901 var=0.0105 elapsed=5.9s
# [arrhenius] gen=26300/99999 pop= 941 avg_health=0.893 var=0.0159 elapsed=5.9s
# [arrhenius] gen=26400/99999 pop= 944 avg_health=0.889 var=0.0149 elapsed=5.9s
# [arrhenius] gen=26500/99999 pop= 884 avg_health=0.883 var=0.0139 elapsed=5.9s
# [arrhenius] gen=26600/99999 pop= 951 avg_health=0.889 var=0.0132 elapsed=6.0s
# [arrhenius] gen=26700/99999 pop= 941 avg_health=0.895 var=0.0127 elapsed=6.0s
# [arrhenius] gen=26800/99999 pop= 982 avg_health=0.880 var=0.0151 elapsed=6.0s
# [arrhenius] gen=26900/99999 pop= 931 avg_health=0.892 var=0.0145 elapsed=6.1s
# [arrhenius] gen=27000/99999 pop= 923 avg_health=0.887 var=0.0153 elapsed=6.1s
# [arrhenius] gen=27100/99999 pop= 912 avg_health=0.899 var=0.0128 elapsed=6.1s
# [arrhenius] gen=27200/99999 pop= 939 avg_health=0.892 var=0.0131 elapsed=6.2s
# [arrhenius] gen=27300/99999 pop= 948 avg_health=0.889 var=0.0120 elapsed=6.2s
# [arrhenius] gen=27400/99999 pop= 932 avg_health=0.889 var=0.0151 elapsed=6.2s
# [arrhenius] gen=27500/99999 pop= 961 avg_health=0.881 var=0.0156 elapsed=6.2s
# [arrhenius] gen=27600/99999 pop= 987 avg_health=0.901 var=0.0133 elapsed=6.3s
# [arrhenius] gen=27700/99999 pop= 925 avg_health=0.892 var=0.0139 elapsed=6.3s
# [arrhenius] gen=27800/99999 pop= 958 avg_health=0.901 var=0.0129 elapsed=6.3s
# [arrhenius] gen=27900/99999 pop= 930 avg_health=0.891 var=0.0140 elapsed=6.3s
# [arrhenius] gen=28000/99999 pop= 974 avg_health=0.886 var=0.0141 elapsed=6.4s
# [arrhenius] gen=28100/99999 pop= 999 avg_health=0.887 var=0.0139 elapsed=6.4s
# [arrhenius] gen=28200/99999 pop= 955 avg_health=0.888 var=0.0122 elapsed=6.4s
# [arrhenius] gen=28300/99999 pop= 896 avg_health=0.880 var=0.0156 elapsed=6.5s
# [arrhenius] gen=28400/99999 pop= 934 avg_health=0.890 var=0.0145 elapsed=6.5s
# [arrhenius] gen=28500/99999 pop=1002 avg_health=0.887 var=0.0146 elapsed=6.5s
# [arrhenius] gen=28600/99999 pop= 933 avg_health=0.884 var=0.0142 elapsed=6.5s
# [arrhenius] gen=28700/99999 pop= 965 avg_health=0.884 var=0.0169 elapsed=6.6s
# [arrhenius] gen=28800/99999 pop= 898 avg_health=0.886 var=0.0135 elapsed=6.6s
# [arrhenius] gen=28900/99999 pop= 954 avg_health=0.872 var=0.0162 elapsed=6.6s
# [arrhenius] gen=29000/99999 pop= 916 avg_health=0.893 var=0.0128 elapsed=6.7s
# [arrhenius] gen=29100/99999 pop= 978 avg_health=0.895 var=0.0133 elapsed=6.7s
# [arrhenius] gen=29200/99999 pop= 969 avg_health=0.890 var=0.0134 elapsed=6.7s
# [arrhenius] gen=29300/99999 pop= 915 avg_health=0.888 var=0.0148 elapsed=6.8s
# [arrhenius] gen=29400/99999 pop= 901 avg_health=0.896 var=0.0131 elapsed=6.8s
# [arrhenius] gen=29500/99999 pop= 939 avg_health=0.871 var=0.0172 elapsed=6.8s
# [arrhenius] gen=29600/99999 pop= 948 avg_health=0.885 var=0.0147 elapsed=6.8s
# [arrhenius] gen=29700/99999 pop= 960 avg_health=0.883 var=0.0151 elapsed=6.9s
# [arrhenius] gen=29800/99999 pop= 982 avg_health=0.888 var=0.0128 elapsed=6.9s
# [arrhenius] gen=29900/99999 pop= 950 avg_health=0.899 var=0.0116 elapsed=6.9s
# [arrhenius] gen=30000/99999 pop= 921 avg_health=0.894 var=0.0132 elapsed=6.9s
# [arrhenius] gen=30100/99999 pop= 940 avg_health=0.885 var=0.0145 elapsed=7.0s
# [arrhenius] gen=30200/99999 pop= 956 avg_health=0.886 var=0.0139 elapsed=7.0s
# [arrhenius] gen=30300/99999 pop= 945 avg_health=0.894 var=0.0138 elapsed=7.0s
# [arrhenius] gen=30400/99999 pop= 869 avg_health=0.883 var=0.0149 elapsed=7.0s
# [arrhenius] gen=30500/99999 pop= 927 avg_health=0.887 var=0.0151 elapsed=7.0s
# [arrhenius] gen=30600/99999 pop= 918 avg_health=0.907 var=0.0112 elapsed=7.1s
# [arrhenius] gen=30700/99999 pop= 941 avg_health=0.897 var=0.0135 elapsed=7.1s
# [arrhenius] gen=30800/99999 pop= 927 avg_health=0.881 var=0.0164 elapsed=7.1s
# [arrhenius] gen=30900/99999 pop= 954 avg_health=0.897 var=0.0133 elapsed=7.1s
# [arrhenius] gen=31000/99999 pop= 931 avg_health=0.885 var=0.0138 elapsed=7.1s
# [arrhenius] gen=31100/99999 pop= 922 avg_health=0.891 var=0.0137 elapsed=7.2s
# [arrhenius] gen=31200/99999 pop= 895 avg_health=0.890 var=0.0144 elapsed=7.2s
# [arrhenius] gen=31300/99999 pop= 931 avg_health=0.900 var=0.0145 elapsed=7.2s
# [arrhenius] gen=31400/99999 pop= 934 avg_health=0.879 var=0.0150 elapsed=7.2s
# [arrhenius] gen=31500/99999 pop= 952 avg_health=0.899 var=0.0140 elapsed=7.2s
# [arrhenius] gen=31600/99999 pop= 971 avg_health=0.891 var=0.0123 elapsed=7.2s
# [arrhenius] gen=31700/99999 pop= 972 avg_health=0.902 var=0.0113 elapsed=7.3s
# [arrhenius] gen=31800/99999 pop= 915 avg_health=0.888 var=0.0141 elapsed=7.3s
# [arrhenius] gen=31900/99999 pop=1017 avg_health=0.898 var=0.0111 elapsed=7.3s
# [arrhenius] gen=32000/99999 pop= 890 avg_health=0.889 var=0.0146 elapsed=7.3s
# [arrhenius] gen=32100/99999 pop= 921 avg_health=0.902 var=0.0130 elapsed=7.3s
# [arrhenius] gen=32200/99999 pop= 912 avg_health=0.895 var=0.0125 elapsed=7.4s
# [arrhenius] gen=32300/99999 pop= 994 avg_health=0.889 var=0.0117 elapsed=7.4s
# [arrhenius] gen=32400/99999 pop= 986 avg_health=0.893 var=0.0141 elapsed=7.4s
# [arrhenius] gen=32500/99999 pop= 965 avg_health=0.885 var=0.0162 elapsed=7.4s
# [arrhenius] gen=32600/99999 pop= 983 avg_health=0.896 var=0.0121 elapsed=7.4s
# [arrhenius] gen=32700/99999 pop= 911 avg_health=0.884 var=0.0154 elapsed=7.5s
# [arrhenius] gen=32800/99999 pop= 910 avg_health=0.882 var=0.0138 elapsed=7.5s
# [arrhenius] gen=32900/99999 pop= 930 avg_health=0.886 var=0.0148 elapsed=7.5s
# [arrhenius] gen=33000/99999 pop= 987 avg_health=0.884 var=0.0145 elapsed=7.5s
# [arrhenius] gen=33100/99999 pop= 943 avg_health=0.897 var=0.0123 elapsed=7.5s
# [arrhenius] gen=33200/99999 pop= 918 avg_health=0.893 var=0.0147 elapsed=7.6s
# [arrhenius] gen=33300/99999 pop= 960 avg_health=0.892 var=0.0130 elapsed=7.6s
# [arrhenius] gen=33400/99999 pop= 928 avg_health=0.887 var=0.0149 elapsed=7.6s
# [arrhenius] gen=33500/99999 pop= 979 avg_health=0.902 var=0.0133 elapsed=7.6s
# [arrhenius] gen=33600/99999 pop= 949 avg_health=0.884 var=0.0153 elapsed=7.6s
# [arrhenius] gen=33700/99999 pop= 935 avg_health=0.887 var=0.0148 elapsed=7.6s
# [arrhenius] gen=33800/99999 pop= 934 avg_health=0.891 var=0.0140 elapsed=7.7s
# [arrhenius] gen=33900/99999 pop= 948 avg_health=0.882 var=0.0146 elapsed=7.7s
# [arrhenius] gen=34000/99999 pop= 967 avg_health=0.886 var=0.0164 elapsed=7.7s
# [arrhenius] gen=34100/99999 pop= 966 avg_health=0.901 var=0.0127 elapsed=7.7s
# [arrhenius] gen=34200/99999 pop= 960 avg_health=0.885 var=0.0144 elapsed=7.8s
# [arrhenius] gen=34300/99999 pop= 906 avg_health=0.872 var=0.0147 elapsed=7.8s
# [arrhenius] gen=34400/99999 pop= 950 avg_health=0.895 var=0.0133 elapsed=7.8s
# [arrhenius] gen=34500/99999 pop= 931 avg_health=0.892 var=0.0127 elapsed=7.8s
# [arrhenius] gen=34600/99999 pop= 899 avg_health=0.902 var=0.0120 elapsed=7.8s
# [arrhenius] gen=34700/99999 pop= 921 avg_health=0.877 var=0.0149 elapsed=7.9s
# [arrhenius] gen=34800/99999 pop= 940 avg_health=0.891 var=0.0149 elapsed=7.9s
# [arrhenius] gen=34900/99999 pop= 928 avg_health=0.881 var=0.0155 elapsed=7.9s
# [arrhenius] gen=35000/99999 pop=1003 avg_health=0.896 var=0.0130 elapsed=7.9s
# [arrhenius] gen=35100/99999 pop= 966 avg_health=0.895 var=0.0117 elapsed=7.9s
# [arrhenius] gen=35200/99999 pop= 931 avg_health=0.899 var=0.0124 elapsed=8.0s
# [arrhenius] gen=35300/99999 pop= 950 avg_health=0.894 var=0.0136 elapsed=8.0s
# [arrhenius] gen=35400/99999 pop= 951 avg_health=0.877 var=0.0154 elapsed=8.0s
# [arrhenius] gen=35500/99999 pop= 944 avg_health=0.895 var=0.0126 elapsed=8.0s
# [arrhenius] gen=35600/99999 pop= 951 avg_health=0.885 var=0.0140 elapsed=8.0s
# [arrhenius] gen=35700/99999 pop= 966 avg_health=0.893 var=0.0132 elapsed=8.0s
# [arrhenius] gen=35800/99999 pop= 941 avg_health=0.887 var=0.0135 elapsed=8.1s
# [arrhenius] gen=35900/99999 pop= 972 avg_health=0.885 var=0.0129 elapsed=8.1s
# [arrhenius] gen=36000/99999 pop= 920 avg_health=0.882 var=0.0134 elapsed=8.1s
# [arrhenius] gen=36100/99999 pop= 933 avg_health=0.890 var=0.0129 elapsed=8.1s
# [arrhenius] gen=36200/99999 pop= 953 avg_health=0.895 var=0.0125 elapsed=8.1s
# [arrhenius] gen=36300/99999 pop= 905 avg_health=0.890 var=0.0142 elapsed=8.2s
# [arrhenius] gen=36400/99999 pop= 932 avg_health=0.875 var=0.0146 elapsed=8.2s
# [arrhenius] gen=36500/99999 pop= 947 avg_health=0.898 var=0.0131 elapsed=8.2s
# [arrhenius] gen=36600/99999 pop= 929 avg_health=0.883 var=0.0138 elapsed=8.2s
# [arrhenius] gen=36700/99999 pop= 970 avg_health=0.879 var=0.0165 elapsed=8.2s
# [arrhenius] gen=36800/99999 pop= 930 avg_health=0.892 var=0.0138 elapsed=8.3s
# [arrhenius] gen=36900/99999 pop= 916 avg_health=0.905 var=0.0110 elapsed=8.3s
# [arrhenius] gen=37000/99999 pop= 980 avg_health=0.892 var=0.0145 elapsed=8.3s
# [arrhenius] gen=37100/99999 pop= 916 avg_health=0.888 var=0.0144 elapsed=8.3s
# [arrhenius] gen=37200/99999 pop= 966 avg_health=0.898 var=0.0141 elapsed=8.3s
# [arrhenius] gen=37300/99999 pop= 923 avg_health=0.894 var=0.0154 elapsed=8.4s
# [arrhenius] gen=37400/99999 pop= 961 avg_health=0.868 var=0.0163 elapsed=8.4s
# [arrhenius] gen=37500/99999 pop= 999 avg_health=0.891 var=0.0145 elapsed=8.4s
# [arrhenius] gen=37600/99999 pop= 881 avg_health=0.884 var=0.0134 elapsed=8.4s
# [arrhenius] gen=37700/99999 pop= 953 avg_health=0.897 var=0.0124 elapsed=8.4s
# [arrhenius] gen=37800/99999 pop= 953 avg_health=0.876 var=0.0180 elapsed=8.4s
# [arrhenius] gen=37900/99999 pop= 941 avg_health=0.885 var=0.0170 elapsed=8.5s
# [arrhenius] gen=38000/99999 pop= 960 avg_health=0.894 var=0.0137 elapsed=8.5s
# [arrhenius] gen=38100/99999 pop= 961 avg_health=0.901 var=0.0128 elapsed=8.5s
# [arrhenius] gen=38200/99999 pop= 938 avg_health=0.883 var=0.0138 elapsed=8.5s
# [arrhenius] gen=38300/99999 pop= 983 avg_health=0.887 var=0.0152 elapsed=8.5s
# [arrhenius] gen=38400/99999 pop= 907 avg_health=0.887 var=0.0148 elapsed=8.5s
# [arrhenius] gen=38500/99999 pop=1006 avg_health=0.895 var=0.0143 elapsed=8.6s
# [arrhenius] gen=38600/99999 pop= 932 avg_health=0.891 var=0.0134 elapsed=8.6s
# [arrhenius] gen=38700/99999 pop= 952 avg_health=0.888 var=0.0142 elapsed=8.6s
# [arrhenius] gen=38800/99999 pop= 992 avg_health=0.897 var=0.0117 elapsed=8.6s
# [arrhenius] gen=38900/99999 pop= 916 avg_health=0.891 var=0.0144 elapsed=8.6s
# [arrhenius] gen=39000/99999 pop= 935 avg_health=0.885 var=0.0154 elapsed=8.7s
# [arrhenius] gen=39100/99999 pop= 959 avg_health=0.876 var=0.0153 elapsed=8.7s
# [arrhenius] gen=39200/99999 pop= 902 avg_health=0.882 var=0.0149 elapsed=8.7s
# [arrhenius] gen=39300/99999 pop= 968 avg_health=0.888 var=0.0144 elapsed=8.7s
# [arrhenius] gen=39400/99999 pop= 910 avg_health=0.889 var=0.0146 elapsed=8.7s
# [arrhenius] gen=39500/99999 pop= 926 avg_health=0.893 var=0.0129 elapsed=8.8s
# [arrhenius] gen=39600/99999 pop= 913 avg_health=0.900 var=0.0125 elapsed=8.8s
# [arrhenius] gen=39700/99999 pop= 899 avg_health=0.884 var=0.0139 elapsed=8.8s
# [arrhenius] gen=39800/99999 pop= 922 avg_health=0.895 var=0.0127 elapsed=8.8s
# [arrhenius] gen=39900/99999 pop= 946 avg_health=0.880 var=0.0168 elapsed=8.9s
# [arrhenius] gen=40000/99999 pop= 966 avg_health=0.892 var=0.0146 elapsed=8.9s
# [arrhenius] gen=40100/99999 pop= 961 avg_health=0.891 var=0.0146 elapsed=8.9s
# [arrhenius] gen=40200/99999 pop= 911 avg_health=0.894 var=0.0131 elapsed=8.9s
# [arrhenius] gen=40300/99999 pop= 942 avg_health=0.873 var=0.0141 elapsed=8.9s
# [arrhenius] gen=40400/99999 pop= 920 avg_health=0.892 var=0.0132 elapsed=8.9s
# [arrhenius] gen=40500/99999 pop= 981 avg_health=0.900 var=0.0123 elapsed=9.0s
# [arrhenius] gen=40600/99999 pop= 969 avg_health=0.892 var=0.0126 elapsed=9.0s
# [arrhenius] gen=40700/99999 pop= 943 avg_health=0.888 var=0.0132 elapsed=9.0s
# [arrhenius] gen=40800/99999 pop= 952 avg_health=0.891 var=0.0145 elapsed=9.0s
# [arrhenius] gen=40900/99999 pop=1004 avg_health=0.890 var=0.0123 elapsed=9.0s
# [arrhenius] gen=41000/99999 pop= 939 avg_health=0.889 var=0.0129 elapsed=9.1s
# [arrhenius] gen=41100/99999 pop= 946 avg_health=0.888 var=0.0146 elapsed=9.1s
# [arrhenius] gen=41200/99999 pop= 959 avg_health=0.892 var=0.0137 elapsed=9.1s
# [arrhenius] gen=41300/99999 pop= 950 avg_health=0.897 var=0.0145 elapsed=9.1s
# [arrhenius] gen=41400/99999 pop= 856 avg_health=0.878 var=0.0180 elapsed=9.1s
# [arrhenius] gen=41500/99999 pop= 940 avg_health=0.885 var=0.0152 elapsed=9.1s
# [arrhenius] gen=41600/99999 pop= 913 avg_health=0.893 var=0.0137 elapsed=9.2s
# [arrhenius] gen=41700/99999 pop= 948 avg_health=0.890 var=0.0145 elapsed=9.2s
# [arrhenius] gen=41800/99999 pop= 968 avg_health=0.885 var=0.0142 elapsed=9.2s
# [arrhenius] gen=41900/99999 pop= 937 avg_health=0.893 var=0.0128 elapsed=9.2s
# [arrhenius] gen=42000/99999 pop= 926 avg_health=0.896 var=0.0137 elapsed=9.2s
# [arrhenius] gen=42100/99999 pop= 870 avg_health=0.883 var=0.0142 elapsed=9.3s
# [arrhenius] gen=42200/99999 pop= 986 avg_health=0.885 var=0.0143 elapsed=9.3s
# [arrhenius] gen=42300/99999 pop= 966 avg_health=0.890 var=0.0163 elapsed=9.3s
# [arrhenius] gen=42400/99999 pop= 950 avg_health=0.902 var=0.0109 elapsed=9.3s
# [arrhenius] gen=42500/99999 pop= 921 avg_health=0.888 var=0.0137 elapsed=9.3s
# [arrhenius] gen=42600/99999 pop= 924 avg_health=0.888 var=0.0137 elapsed=9.4s
# [arrhenius] gen=42700/99999 pop= 957 avg_health=0.884 var=0.0150 elapsed=9.4s
# [arrhenius] gen=42800/99999 pop= 908 avg_health=0.890 var=0.0150 elapsed=9.4s
# [arrhenius] gen=42900/99999 pop= 902 avg_health=0.879 var=0.0144 elapsed=9.4s
# [arrhenius] gen=43000/99999 pop= 959 avg_health=0.885 var=0.0157 elapsed=9.4s
# [arrhenius] gen=43100/99999 pop= 954 avg_health=0.882 var=0.0154 elapsed=9.4s
# [arrhenius] gen=43200/99999 pop= 954 avg_health=0.887 var=0.0134 elapsed=9.5s
# [arrhenius] gen=43300/99999 pop= 916 avg_health=0.893 var=0.0137 elapsed=9.5s
# [arrhenius] gen=43400/99999 pop= 944 avg_health=0.892 var=0.0137 elapsed=9.5s
# [arrhenius] gen=43500/99999 pop= 939 avg_health=0.883 var=0.0142 elapsed=9.5s
# [arrhenius] gen=43600/99999 pop= 921 avg_health=0.884 var=0.0145 elapsed=9.5s
# [arrhenius] gen=43700/99999 pop= 975 avg_health=0.872 var=0.0166 elapsed=9.6s
# [arrhenius] gen=43800/99999 pop= 951 avg_health=0.899 var=0.0122 elapsed=9.6s
# [arrhenius] gen=43900/99999 pop= 954 avg_health=0.897 var=0.0122 elapsed=9.6s
# [arrhenius] gen=44000/99999 pop= 922 avg_health=0.889 var=0.0151 elapsed=9.6s
# [arrhenius] gen=44100/99999 pop= 934 avg_health=0.881 var=0.0154 elapsed=9.6s
# [arrhenius] gen=44200/99999 pop= 948 avg_health=0.884 var=0.0157 elapsed=9.6s
# [arrhenius] gen=44300/99999 pop= 957 avg_health=0.894 var=0.0124 elapsed=9.7s
# [arrhenius] gen=44400/99999 pop= 937 avg_health=0.893 var=0.0136 elapsed=9.7s
# [arrhenius] gen=44500/99999 pop= 955 avg_health=0.898 var=0.0136 elapsed=9.7s
# [arrhenius] gen=44600/99999 pop= 962 avg_health=0.887 var=0.0129 elapsed=9.7s
# [arrhenius] gen=44700/99999 pop= 948 avg_health=0.884 var=0.0138 elapsed=9.7s
# [arrhenius] gen=44800/99999 pop= 921 avg_health=0.887 var=0.0132 elapsed=9.8s
# [arrhenius] gen=44900/99999 pop= 911 avg_health=0.893 var=0.0125 elapsed=9.8s
# [arrhenius] gen=45000/99999 pop= 921 avg_health=0.896 var=0.0137 elapsed=9.8s
# [arrhenius] gen=45100/99999 pop= 958 avg_health=0.874 var=0.0155 elapsed=9.8s
# [arrhenius] gen=45200/99999 pop= 960 avg_health=0.890 var=0.0134 elapsed=9.8s
# [arrhenius] gen=45300/99999 pop= 981 avg_health=0.882 var=0.0156 elapsed=9.9s
# [arrhenius] gen=45400/99999 pop= 936 avg_health=0.884 var=0.0152 elapsed=9.9s
# [arrhenius] gen=45500/99999 pop= 954 avg_health=0.890 var=0.0134 elapsed=9.9s
# [arrhenius] gen=45600/99999 pop= 948 avg_health=0.883 var=0.0133 elapsed=9.9s
# [arrhenius] gen=45700/99999 pop= 916 avg_health=0.889 var=0.0145 elapsed=9.9s
# [arrhenius] gen=45800/99999 pop= 950 avg_health=0.881 var=0.0129 elapsed=10.0s
# [arrhenius] gen=45900/99999 pop= 927 avg_health=0.882 var=0.0140 elapsed=10.0s
# [arrhenius] gen=46000/99999 pop= 926 avg_health=0.879 var=0.0167 elapsed=10.0s
# [arrhenius] gen=46100/99999 pop= 964 avg_health=0.895 var=0.0126 elapsed=10.0s
# [arrhenius] gen=46200/99999 pop= 929 avg_health=0.900 var=0.0134 elapsed=10.0s
# [arrhenius] gen=46300/99999 pop= 950 avg_health=0.890 var=0.0137 elapsed=10.1s
# [arrhenius] gen=46400/99999 pop= 973 avg_health=0.893 var=0.0119 elapsed=10.1s
# [arrhenius] gen=46500/99999 pop= 875 avg_health=0.880 var=0.0166 elapsed=10.1s
# [arrhenius] gen=46600/99999 pop= 944 avg_health=0.876 var=0.0146 elapsed=10.1s
# [arrhenius] gen=46700/99999 pop= 930 avg_health=0.879 var=0.0147 elapsed=10.1s
# [arrhenius] gen=46800/99999 pop= 923 avg_health=0.885 var=0.0134 elapsed=10.1s
# [arrhenius] gen=46900/99999 pop= 932 avg_health=0.887 var=0.0136 elapsed=10.2s
# [arrhenius] gen=47000/99999 pop= 960 avg_health=0.892 var=0.0122 elapsed=10.2s
# [arrhenius] gen=47100/99999 pop= 950 avg_health=0.900 var=0.0128 elapsed=10.2s
# [arrhenius] gen=47200/99999 pop= 927 avg_health=0.906 var=0.0104 elapsed=10.2s
# [arrhenius] gen=47300/99999 pop= 960 avg_health=0.885 var=0.0144 elapsed=10.2s
# [arrhenius] gen=47400/99999 pop= 985 avg_health=0.893 var=0.0142 elapsed=10.3s
# [arrhenius] gen=47500/99999 pop= 945 avg_health=0.881 var=0.0156 elapsed=10.3s
# [arrhenius] gen=47600/99999 pop= 925 avg_health=0.886 var=0.0152 elapsed=10.3s
# [arrhenius] gen=47700/99999 pop= 999 avg_health=0.881 var=0.0140 elapsed=10.3s
# [arrhenius] gen=47800/99999 pop= 996 avg_health=0.884 var=0.0139 elapsed=10.3s
# [arrhenius] gen=47900/99999 pop= 959 avg_health=0.884 var=0.0152 elapsed=10.3s
# [arrhenius] gen=48000/99999 pop= 928 avg_health=0.894 var=0.0141 elapsed=10.4s
# [arrhenius] gen=48100/99999 pop= 961 avg_health=0.884 var=0.0135 elapsed=10.4s
# [arrhenius] gen=48200/99999 pop= 954 avg_health=0.887 var=0.0132 elapsed=10.4s
# [arrhenius] gen=48300/99999 pop= 944 avg_health=0.890 var=0.0134 elapsed=10.4s
# [arrhenius] gen=48400/99999 pop= 871 avg_health=0.887 var=0.0139 elapsed=10.4s
# [arrhenius] gen=48500/99999 pop= 963 avg_health=0.895 var=0.0139 elapsed=10.5s
# [arrhenius] gen=48600/99999 pop= 906 avg_health=0.891 var=0.0131 elapsed=10.5s
# [arrhenius] gen=48700/99999 pop= 968 avg_health=0.883 var=0.0144 elapsed=10.5s
# [arrhenius] gen=48800/99999 pop= 966 avg_health=0.893 var=0.0138 elapsed=10.5s
# [arrhenius] gen=48900/99999 pop= 937 avg_health=0.888 var=0.0122 elapsed=10.5s
# [arrhenius] gen=49000/99999 pop= 943 avg_health=0.889 var=0.0141 elapsed=10.5s
# [arrhenius] gen=49100/99999 pop= 909 avg_health=0.880 var=0.0165 elapsed=10.6s
# [arrhenius] gen=49200/99999 pop= 955 avg_health=0.904 var=0.0105 elapsed=10.6s
# [arrhenius] gen=49300/99999 pop= 970 avg_health=0.893 var=0.0134 elapsed=10.6s
# [arrhenius] gen=49400/99999 pop= 966 avg_health=0.886 var=0.0129 elapsed=10.6s
# [arrhenius] gen=49500/99999 pop= 921 avg_health=0.897 var=0.0122 elapsed=10.6s
# [arrhenius] gen=49600/99999 pop= 931 avg_health=0.893 var=0.0139 elapsed=10.7s
# [arrhenius] gen=49700/99999 pop= 938 avg_health=0.888 var=0.0138 elapsed=10.7s
# [arrhenius] gen=49800/99999 pop= 973 avg_health=0.884 var=0.0143 elapsed=10.7s
# [arrhenius] gen=49900/99999 pop= 937 avg_health=0.875 var=0.0181 elapsed=10.7s
# [arrhenius] gen=50000/99999 pop= 909 avg_health=0.896 var=0.0114 elapsed=10.7s
# [arrhenius] gen=50100/99999 pop= 936 avg_health=0.877 var=0.0175 elapsed=10.8s
# [arrhenius] gen=50200/99999 pop= 915 avg_health=0.885 var=0.0141 elapsed=10.8s
# [arrhenius] gen=50300/99999 pop= 961 avg_health=0.889 var=0.0143 elapsed=10.8s
# [arrhenius] gen=50400/99999 pop=1006 avg_health=0.897 var=0.0131 elapsed=10.8s
# [arrhenius] gen=50500/99999 pop= 984 avg_health=0.894 var=0.0138 elapsed=10.9s
# [arrhenius] gen=50600/99999 pop= 962 avg_health=0.894 var=0.0141 elapsed=10.9s
# [arrhenius] gen=50700/99999 pop= 947 avg_health=0.887 var=0.0135 elapsed=10.9s
# [arrhenius] gen=50800/99999 pop= 957 avg_health=0.878 var=0.0165 elapsed=10.9s
# [arrhenius] gen=50900/99999 pop= 964 avg_health=0.883 var=0.0154 elapsed=11.0s
# [arrhenius] gen=51000/99999 pop= 918 avg_health=0.897 var=0.0131 elapsed=11.0s
# [arrhenius] gen=51100/99999 pop= 946 avg_health=0.886 var=0.0140 elapsed=11.0s
# [arrhenius] gen=51200/99999 pop= 971 avg_health=0.888 var=0.0152 elapsed=11.0s
# [arrhenius] gen=51300/99999 pop= 910 avg_health=0.886 var=0.0161 elapsed=11.0s
# [arrhenius] gen=51400/99999 pop= 970 avg_health=0.883 var=0.0162 elapsed=11.0s
# [arrhenius] gen=51500/99999 pop= 961 avg_health=0.893 var=0.0137 elapsed=11.1s
# [arrhenius] gen=51600/99999 pop= 945 avg_health=0.885 var=0.0139 elapsed=11.1s
# [arrhenius] gen=51700/99999 pop= 949 avg_health=0.877 var=0.0166 elapsed=11.1s
# [arrhenius] gen=51800/99999 pop= 942 avg_health=0.885 var=0.0160 elapsed=11.1s
# [arrhenius] gen=51900/99999 pop= 945 avg_health=0.876 var=0.0165 elapsed=11.1s
# [arrhenius] gen=52000/99999 pop= 964 avg_health=0.887 var=0.0136 elapsed=11.2s
# [arrhenius] gen=52100/99999 pop= 999 avg_health=0.899 var=0.0113 elapsed=11.2s
# [arrhenius] gen=52200/99999 pop= 901 avg_health=0.879 var=0.0158 elapsed=11.2s
# [arrhenius] gen=52300/99999 pop= 979 avg_health=0.895 var=0.0140 elapsed=11.2s
# [arrhenius] gen=52400/99999 pop= 954 avg_health=0.891 var=0.0141 elapsed=11.2s
# [arrhenius] gen=52500/99999 pop= 929 avg_health=0.890 var=0.0129 elapsed=11.2s
# [arrhenius] gen=52600/99999 pop= 909 avg_health=0.883 var=0.0147 elapsed=11.3s
# [arrhenius] gen=52700/99999 pop= 857 avg_health=0.889 var=0.0149 elapsed=11.3s
# [arrhenius] gen=52800/99999 pop= 940 avg_health=0.890 var=0.0158 elapsed=11.3s
# [arrhenius] gen=52900/99999 pop= 920 avg_health=0.897 var=0.0136 elapsed=11.3s
# [arrhenius] gen=53000/99999 pop= 909 avg_health=0.886 var=0.0138 elapsed=11.3s
# [arrhenius] gen=53100/99999 pop= 946 avg_health=0.892 var=0.0145 elapsed=11.4s
# [arrhenius] gen=53200/99999 pop= 888 avg_health=0.883 var=0.0150 elapsed=11.4s
# [arrhenius] gen=53300/99999 pop= 938 avg_health=0.906 var=0.0120 elapsed=11.4s
# [arrhenius] gen=53400/99999 pop= 942 avg_health=0.894 var=0.0146 elapsed=11.4s
# [arrhenius] gen=53500/99999 pop= 946 avg_health=0.902 var=0.0118 elapsed=11.4s
# [arrhenius] gen=53600/99999 pop= 991 avg_health=0.901 var=0.0121 elapsed=11.5s
# [arrhenius] gen=53700/99999 pop= 916 avg_health=0.884 var=0.0147 elapsed=11.5s
# [arrhenius] gen=53800/99999 pop= 941 avg_health=0.889 var=0.0151 elapsed=11.5s
# [arrhenius] gen=53900/99999 pop= 956 avg_health=0.891 var=0.0143 elapsed=11.5s
# [arrhenius] gen=54000/99999 pop= 929 avg_health=0.886 var=0.0159 elapsed=11.5s
# [arrhenius] gen=54100/99999 pop= 990 avg_health=0.890 var=0.0133 elapsed=11.6s
# [arrhenius] gen=54200/99999 pop= 918 avg_health=0.888 var=0.0144 elapsed=11.6s
# [arrhenius] gen=54300/99999 pop= 990 avg_health=0.873 var=0.0156 elapsed=11.6s
# [arrhenius] gen=54400/99999 pop= 951 avg_health=0.887 var=0.0134 elapsed=11.6s
# [arrhenius] gen=54500/99999 pop= 954 avg_health=0.880 var=0.0160 elapsed=11.6s
# [arrhenius] gen=54600/99999 pop= 928 avg_health=0.885 var=0.0147 elapsed=11.6s
# [arrhenius] gen=54700/99999 pop= 964 avg_health=0.886 var=0.0159 elapsed=11.7s
# [arrhenius] gen=54800/99999 pop= 866 avg_health=0.893 var=0.0129 elapsed=11.7s
# [arrhenius] gen=54900/99999 pop= 932 avg_health=0.867 var=0.0191 elapsed=11.7s
# [arrhenius] gen=55000/99999 pop= 890 avg_health=0.893 var=0.0144 elapsed=11.7s
# [arrhenius] gen=55100/99999 pop= 979 avg_health=0.889 var=0.0137 elapsed=11.7s
# [arrhenius] gen=55200/99999 pop= 906 avg_health=0.892 var=0.0151 elapsed=11.7s
# [arrhenius] gen=55300/99999 pop= 944 avg_health=0.888 var=0.0154 elapsed=11.8s
# [arrhenius] gen=55400/99999 pop= 971 avg_health=0.888 var=0.0135 elapsed=11.8s
# [arrhenius] gen=55500/99999 pop= 921 avg_health=0.890 var=0.0144 elapsed=11.8s
# [arrhenius] gen=55600/99999 pop= 972 avg_health=0.880 var=0.0142 elapsed=11.8s
# [arrhenius] gen=55700/99999 pop= 975 avg_health=0.895 var=0.0139 elapsed=11.8s
# [arrhenius] gen=55800/99999 pop= 933 avg_health=0.887 var=0.0151 elapsed=11.9s
# [arrhenius] gen=55900/99999 pop= 970 avg_health=0.880 var=0.0150 elapsed=11.9s
# [arrhenius] gen=56000/99999 pop= 947 avg_health=0.896 var=0.0132 elapsed=11.9s
# [arrhenius] gen=56100/99999 pop= 932 avg_health=0.882 var=0.0159 elapsed=11.9s
# [arrhenius] gen=56200/99999 pop= 995 avg_health=0.887 var=0.0134 elapsed=11.9s
# [arrhenius] gen=56300/99999 pop= 884 avg_health=0.883 var=0.0147 elapsed=12.0s
# [arrhenius] gen=56400/99999 pop= 941 avg_health=0.879 var=0.0161 elapsed=12.0s
# [arrhenius] gen=56500/99999 pop= 943 avg_health=0.895 var=0.0133 elapsed=12.0s
# [arrhenius] gen=56600/99999 pop= 930 avg_health=0.891 var=0.0123 elapsed=12.0s
# [arrhenius] gen=56700/99999 pop= 931 avg_health=0.895 var=0.0131 elapsed=12.0s
# [arrhenius] gen=56800/99999 pop= 925 avg_health=0.881 var=0.0154 elapsed=12.1s
# [arrhenius] gen=56900/99999 pop= 943 avg_health=0.887 var=0.0128 elapsed=12.1s
# [arrhenius] gen=57000/99999 pop= 910 avg_health=0.887 var=0.0135 elapsed=12.1s
# [arrhenius] gen=57100/99999 pop= 926 avg_health=0.863 var=0.0191 elapsed=12.1s
# [arrhenius] gen=57200/99999 pop= 902 avg_health=0.905 var=0.0138 elapsed=12.1s
# [arrhenius] gen=57300/99999 pop= 909 avg_health=0.884 var=0.0140 elapsed=12.2s
# [arrhenius] gen=57400/99999 pop= 911 avg_health=0.892 var=0.0146 elapsed=12.2s
# [arrhenius] gen=57500/99999 pop= 966 avg_health=0.900 var=0.0111 elapsed=12.2s
# [arrhenius] gen=57600/99999 pop= 945 avg_health=0.893 var=0.0127 elapsed=12.2s
# [arrhenius] gen=57700/99999 pop= 951 avg_health=0.890 var=0.0149 elapsed=12.3s
# [arrhenius] gen=57800/99999 pop= 908 avg_health=0.899 var=0.0132 elapsed=12.3s
# [arrhenius] gen=57900/99999 pop= 878 avg_health=0.882 var=0.0159 elapsed=12.3s
# [arrhenius] gen=58000/99999 pop= 980 avg_health=0.899 var=0.0131 elapsed=12.3s
# [arrhenius] gen=58100/99999 pop= 898 avg_health=0.889 var=0.0137 elapsed=12.4s
# [arrhenius] gen=58200/99999 pop= 911 avg_health=0.878 var=0.0158 elapsed=12.4s
# [arrhenius] gen=58300/99999 pop= 924 avg_health=0.889 var=0.0145 elapsed=12.4s
# [arrhenius] gen=58400/99999 pop= 945 avg_health=0.892 var=0.0153 elapsed=12.4s
# [arrhenius] gen=58500/99999 pop= 957 avg_health=0.889 var=0.0138 elapsed=12.4s
# [arrhenius] gen=58600/99999 pop= 965 avg_health=0.898 var=0.0125 elapsed=12.4s
# [arrhenius] gen=58700/99999 pop= 949 avg_health=0.891 var=0.0141 elapsed=12.5s
# [arrhenius] gen=58800/99999 pop= 949 avg_health=0.886 var=0.0157 elapsed=12.5s
# [arrhenius] gen=58900/99999 pop= 906 avg_health=0.884 var=0.0151 elapsed=12.5s
# [arrhenius] gen=59000/99999 pop= 982 avg_health=0.897 var=0.0124 elapsed=12.5s
# [arrhenius] gen=59100/99999 pop= 902 avg_health=0.881 var=0.0136 elapsed=12.5s
# [arrhenius] gen=59200/99999 pop= 888 avg_health=0.884 var=0.0131 elapsed=12.6s
# [arrhenius] gen=59300/99999 pop= 917 avg_health=0.888 var=0.0133 elapsed=12.6s
# [arrhenius] gen=59400/99999 pop= 918 avg_health=0.887 var=0.0141 elapsed=12.6s
# [arrhenius] gen=59500/99999 pop= 941 avg_health=0.900 var=0.0124 elapsed=12.6s
# [arrhenius] gen=59600/99999 pop= 964 avg_health=0.891 var=0.0145 elapsed=12.6s
# [arrhenius] gen=59700/99999 pop= 976 avg_health=0.886 var=0.0139 elapsed=12.7s
# [arrhenius] gen=59800/99999 pop= 914 avg_health=0.895 var=0.0142 elapsed=12.7s
# [arrhenius] gen=59900/99999 pop= 892 avg_health=0.879 var=0.0166 elapsed=12.7s
# [arrhenius] gen=60000/99999 pop= 997 avg_health=0.890 var=0.0132 elapsed=12.7s
# [arrhenius] gen=60100/99999 pop= 937 avg_health=0.871 var=0.0157 elapsed=12.7s
# [arrhenius] gen=60200/99999 pop= 930 avg_health=0.890 var=0.0147 elapsed=12.8s
# [arrhenius] gen=60300/99999 pop= 968 avg_health=0.879 var=0.0131 elapsed=12.8s
# [arrhenius] gen=60400/99999 pop= 877 avg_health=0.883 var=0.0158 elapsed=12.8s
# [arrhenius] gen=60500/99999 pop= 897 avg_health=0.909 var=0.0104 elapsed=12.8s
# [arrhenius] gen=60600/99999 pop= 972 avg_health=0.893 var=0.0134 elapsed=12.8s
# [arrhenius] gen=60700/99999 pop= 909 avg_health=0.872 var=0.0143 elapsed=12.8s
# [arrhenius] gen=60800/99999 pop= 936 avg_health=0.899 var=0.0120 elapsed=12.9s
# [arrhenius] gen=60900/99999 pop= 921 avg_health=0.877 var=0.0143 elapsed=12.9s
# [arrhenius] gen=61000/99999 pop= 995 avg_health=0.892 var=0.0141 elapsed=12.9s
# [arrhenius] gen=61100/99999 pop= 963 avg_health=0.894 var=0.0131 elapsed=12.9s
# [arrhenius] gen=61200/99999 pop= 939 avg_health=0.905 var=0.0123 elapsed=12.9s
# [arrhenius] gen=61300/99999 pop= 962 avg_health=0.907 var=0.0099 elapsed=13.0s
# ...
# [gqr] gen=78700/99999 pop= 905 avg_health=0.946 var=0.0032 elapsed=16.9s
# [gqr] gen=78800/99999 pop= 854 avg_health=0.946 var=0.0032 elapsed=17.0s
# [gqr] gen=78900/99999 pop= 845 avg_health=0.943 var=0.0030 elapsed=17.0s
# [gqr] gen=79000/99999 pop= 837 avg_health=0.949 var=0.0027 elapsed=17.0s
# [gqr] gen=79100/99999 pop= 864 avg_health=0.945 var=0.0029 elapsed=17.0s
# [gqr] gen=79200/99999 pop= 810 avg_health=0.945 var=0.0030 elapsed=17.0s
# [gqr] gen=79300/99999 pop= 843 avg_health=0.944 var=0.0029 elapsed=17.1s
# [gqr] gen=79400/99999 pop= 883 avg_health=0.942 var=0.0029 elapsed=17.1s
# [gqr] gen=79500/99999 pop= 923 avg_health=0.948 var=0.0030 elapsed=17.1s
# [gqr] gen=79600/99999 pop= 864 avg_health=0.947 var=0.0030 elapsed=17.1s
# [gqr] gen=79700/99999 pop= 893 avg_health=0.942 var=0.0034 elapsed=17.1s
# [gqr] gen=79800/99999 pop= 850 avg_health=0.953 var=0.0027 elapsed=17.1s
# [gqr] gen=79900/99999 pop= 855 avg_health=0.955 var=0.0023 elapsed=17.2s
# [gqr] gen=80000/99999 pop= 863 avg_health=0.944 var=0.0026 elapsed=17.2s
# [gqr] gen=80100/99999 pop= 832 avg_health=0.945 var=0.0029 elapsed=17.2s
# [gqr] gen=80200/99999 pop= 842 avg_health=0.945 var=0.0030 elapsed=17.2s
# [gqr] gen=80300/99999 pop= 840 avg_health=0.951 var=0.0024 elapsed=17.3s
# [gqr] gen=80400/99999 pop= 886 avg_health=0.946 var=0.0024 elapsed=17.3s
# [gqr] gen=80500/99999 pop= 843 avg_health=0.947 var=0.0028 elapsed=17.3s
# [gqr] gen=80600/99999 pop= 828 avg_health=0.938 var=0.0037 elapsed=17.3s
# [gqr] gen=80700/99999 pop= 838 avg_health=0.948 var=0.0029 elapsed=17.4s
# [gqr] gen=80800/99999 pop= 888 avg_health=0.946 var=0.0032 elapsed=17.4s
# [gqr] gen=80900/99999 pop= 817 avg_health=0.942 var=0.0033 elapsed=17.4s
# [gqr] gen=81000/99999 pop= 811 avg_health=0.949 var=0.0029 elapsed=17.4s
# [gqr] gen=81100/99999 pop= 859 avg_health=0.948 var=0.0029 elapsed=17.4s
# [gqr] gen=81200/99999 pop= 852 avg_health=0.945 var=0.0033 elapsed=17.4s
# [gqr] gen=81300/99999 pop= 777 avg_health=0.947 var=0.0029 elapsed=17.5s
# [gqr] gen=81400/99999 pop= 841 avg_health=0.937 var=0.0039 elapsed=17.5s
# [gqr] gen=81500/99999 pop= 870 avg_health=0.946 var=0.0031 elapsed=17.5s
# [gqr] gen=81600/99999 pop= 848 avg_health=0.947 var=0.0027 elapsed=17.5s
# [gqr] gen=81700/99999 pop= 835 avg_health=0.941 var=0.0036 elapsed=17.5s
# [gqr] gen=81800/99999 pop= 831 avg_health=0.943 var=0.0033 elapsed=17.6s
# [gqr] gen=81900/99999 pop= 816 avg_health=0.946 var=0.0034 elapsed=17.6s
# [gqr] gen=82000/99999 pop= 793 avg_health=0.945 var=0.0035 elapsed=17.6s
# [gqr] gen=82100/99999 pop= 838 avg_health=0.943 var=0.0031 elapsed=17.6s
# [gqr] gen=82200/99999 pop= 851 avg_health=0.942 var=0.0033 elapsed=17.6s
# [gqr] gen=82300/99999 pop= 845 avg_health=0.943 var=0.0034 elapsed=17.6s
# [gqr] gen=82400/99999 pop= 834 avg_health=0.952 var=0.0026 elapsed=17.7s
# [gqr] gen=82500/99999 pop= 862 avg_health=0.944 var=0.0028 elapsed=17.7s
# [gqr] gen=82600/99999 pop= 880 avg_health=0.944 var=0.0034 elapsed=17.7s
# [gqr] gen=82700/99999 pop= 809 avg_health=0.945 var=0.0032 elapsed=17.7s
# [gqr] gen=82800/99999 pop= 896 avg_health=0.946 var=0.0032 elapsed=17.7s
# [gqr] gen=82900/99999 pop= 852 avg_health=0.947 var=0.0027 elapsed=17.8s
# [gqr] gen=83000/99999 pop= 865 avg_health=0.946 var=0.0031 elapsed=17.8s
# [gqr] gen=83100/99999 pop= 869 avg_health=0.944 var=0.0035 elapsed=17.8s
# [gqr] gen=83200/99999 pop= 826 avg_health=0.948 var=0.0029 elapsed=17.8s
# [gqr] gen=83300/99999 pop= 837 avg_health=0.947 var=0.0028 elapsed=17.8s
# [gqr] gen=83400/99999 pop= 841 avg_health=0.944 var=0.0029 elapsed=17.8s
# [gqr] gen=83500/99999 pop= 818 avg_health=0.939 var=0.0032 elapsed=17.9s
# [gqr] gen=83600/99999 pop= 800 avg_health=0.944 var=0.0033 elapsed=17.9s
# [gqr] gen=83700/99999 pop= 768 avg_health=0.939 var=0.0031 elapsed=17.9s
# [gqr] gen=83800/99999 pop= 870 avg_health=0.946 var=0.0034 elapsed=17.9s
# [gqr] gen=83900/99999 pop= 834 avg_health=0.941 var=0.0029 elapsed=17.9s
# [gqr] gen=84000/99999 pop= 847 avg_health=0.942 var=0.0038 elapsed=17.9s
# [gqr] gen=84100/99999 pop= 908 avg_health=0.941 var=0.0033 elapsed=18.0s
# [gqr] gen=84200/99999 pop= 862 avg_health=0.944 var=0.0032 elapsed=18.0s
# [gqr] gen=84300/99999 pop= 799 avg_health=0.947 var=0.0029 elapsed=18.0s
# [gqr] gen=84400/99999 pop= 817 avg_health=0.943 var=0.0033 elapsed=18.0s
# [gqr] gen=84500/99999 pop= 756 avg_health=0.940 var=0.0031 elapsed=18.0s
# [gqr] gen=84600/99999 pop= 883 avg_health=0.943 var=0.0039 elapsed=18.1s
# [gqr] gen=84700/99999 pop= 845 avg_health=0.947 var=0.0027 elapsed=18.1s
# [gqr] gen=84800/99999 pop= 896 avg_health=0.934 var=0.0037 elapsed=18.1s
# [gqr] gen=84900/99999 pop= 877 avg_health=0.947 var=0.0029 elapsed=18.1s
# [gqr] gen=85000/99999 pop= 867 avg_health=0.943 var=0.0033 elapsed=18.1s
# [gqr] gen=85100/99999 pop= 836 avg_health=0.949 var=0.0029 elapsed=18.1s
# [gqr] gen=85200/99999 pop= 852 avg_health=0.951 var=0.0031 elapsed=18.2s
# [gqr] gen=85300/99999 pop= 853 avg_health=0.935 var=0.0034 elapsed=18.2s
# [gqr] gen=85400/99999 pop= 868 avg_health=0.939 var=0.0035 elapsed=18.2s
# [gqr] gen=85500/99999 pop= 793 avg_health=0.936 var=0.0033 elapsed=18.2s
# [gqr] gen=85600/99999 pop= 841 avg_health=0.938 var=0.0037 elapsed=18.2s
# [gqr] gen=85700/99999 pop= 823 avg_health=0.945 var=0.0028 elapsed=18.2s
# [gqr] gen=85800/99999 pop= 847 avg_health=0.953 var=0.0026 elapsed=18.3s
# [gqr] gen=85900/99999 pop= 809 avg_health=0.951 var=0.0032 elapsed=18.3s
# [gqr] gen=86000/99999 pop= 876 avg_health=0.947 var=0.0028 elapsed=18.3s
# [gqr] gen=86100/99999 pop= 812 avg_health=0.946 var=0.0031 elapsed=18.3s
# [gqr] gen=86200/99999 pop= 868 avg_health=0.950 var=0.0029 elapsed=18.4s
# [gqr] gen=86300/99999 pop= 821 avg_health=0.941 var=0.0036 elapsed=18.4s
# [gqr] gen=86400/99999 pop= 909 avg_health=0.946 var=0.0030 elapsed=18.4s
# [gqr] gen=86500/99999 pop= 877 avg_health=0.942 var=0.0033 elapsed=18.4s
# [gqr] gen=86600/99999 pop= 826 avg_health=0.952 var=0.0031 elapsed=18.4s
# [gqr] gen=86700/99999 pop= 833 avg_health=0.950 var=0.0029 elapsed=18.4s
# [gqr] gen=86800/99999 pop= 839 avg_health=0.946 var=0.0035 elapsed=18.5s
# [gqr] gen=86900/99999 pop= 830 avg_health=0.948 var=0.0029 elapsed=18.5s
# [gqr] gen=87000/99999 pop= 874 avg_health=0.935 var=0.0039 elapsed=18.5s
# [gqr] gen=87100/99999 pop= 875 avg_health=0.947 var=0.0030 elapsed=18.5s
# [gqr] gen=87200/99999 pop= 937 avg_health=0.949 var=0.0029 elapsed=18.5s
# [gqr] gen=87300/99999 pop= 882 avg_health=0.944 var=0.0032 elapsed=18.6s
# [gqr] gen=87400/99999 pop= 836 avg_health=0.936 var=0.0039 elapsed=18.6s
# [gqr] gen=87500/99999 pop= 848 avg_health=0.951 var=0.0029 elapsed=18.6s
# [gqr] gen=87600/99999 pop= 889 avg_health=0.946 var=0.0029 elapsed=18.6s
# [gqr] gen=87700/99999 pop= 847 avg_health=0.952 var=0.0026 elapsed=18.6s
# [gqr] gen=87800/99999 pop= 897 avg_health=0.949 var=0.0030 elapsed=18.6s
# [gqr] gen=87900/99999 pop= 846 avg_health=0.939 var=0.0037 elapsed=18.7s
# [gqr] gen=88000/99999 pop= 826 avg_health=0.948 var=0.0029 elapsed=18.7s
# [gqr] gen=88100/99999 pop= 866 avg_health=0.943 var=0.0035 elapsed=18.7s
# [gqr] gen=88200/99999 pop= 866 avg_health=0.947 var=0.0031 elapsed=18.7s
# [gqr] gen=88300/99999 pop= 833 avg_health=0.941 var=0.0036 elapsed=18.7s
# [gqr] gen=88400/99999 pop= 850 avg_health=0.946 var=0.0030 elapsed=18.8s
# [gqr] gen=88500/99999 pop= 859 avg_health=0.940 var=0.0031 elapsed=18.8s
# [gqr] gen=88600/99999 pop= 854 avg_health=0.948 var=0.0030 elapsed=18.8s
# [gqr] gen=88700/99999 pop= 852 avg_health=0.944 var=0.0031 elapsed=18.8s
# [gqr] gen=88800/99999 pop= 837 avg_health=0.941 var=0.0035 elapsed=18.8s
# [gqr] gen=88900/99999 pop= 865 avg_health=0.943 var=0.0033 elapsed=18.8s
# [gqr] gen=89000/99999 pop= 838 avg_health=0.948 var=0.0029 elapsed=18.9s
# [gqr] gen=89100/99999 pop= 849 avg_health=0.941 var=0.0033 elapsed=18.9s
# [gqr] gen=89200/99999 pop= 805 avg_health=0.949 var=0.0029 elapsed=18.9s
# [gqr] gen=89300/99999 pop= 852 avg_health=0.940 var=0.0033 elapsed=18.9s
# [gqr] gen=89400/99999 pop= 871 avg_health=0.951 var=0.0028 elapsed=18.9s
# [gqr] gen=89500/99999 pop= 843 avg_health=0.941 var=0.0033 elapsed=18.9s
# [gqr] gen=89600/99999 pop= 867 avg_health=0.941 var=0.0031 elapsed=19.0s
# [gqr] gen=89700/99999 pop= 832 avg_health=0.950 var=0.0031 elapsed=19.0s
# [gqr] gen=89800/99999 pop= 846 avg_health=0.942 var=0.0031 elapsed=19.0s
# [gqr] gen=89900/99999 pop= 852 avg_health=0.949 var=0.0032 elapsed=19.0s
# [gqr] gen=90000/99999 pop= 827 avg_health=0.950 var=0.0029 elapsed=19.0s
# [gqr] gen=90100/99999 pop= 863 avg_health=0.951 var=0.0024 elapsed=19.1s
# [gqr] gen=90200/99999 pop= 781 avg_health=0.948 var=0.0032 elapsed=19.1s
# [gqr] gen=90300/99999 pop= 877 avg_health=0.947 var=0.0032 elapsed=19.1s
# [gqr] gen=90400/99999 pop= 864 avg_health=0.946 var=0.0025 elapsed=19.1s
# [gqr] gen=90500/99999 pop= 915 avg_health=0.941 var=0.0033 elapsed=19.1s
# [gqr] gen=90600/99999 pop= 811 avg_health=0.941 var=0.0033 elapsed=19.1s
# [gqr] gen=90700/99999 pop= 884 avg_health=0.937 var=0.0034 elapsed=19.2s
# [gqr] gen=90800/99999 pop= 812 avg_health=0.951 var=0.0027 elapsed=19.2s
# [gqr] gen=90900/99999 pop= 800 avg_health=0.940 var=0.0031 elapsed=19.2s
# [gqr] gen=91000/99999 pop= 843 avg_health=0.946 var=0.0031 elapsed=19.2s
# [gqr] gen=91100/99999 pop= 874 avg_health=0.950 var=0.0025 elapsed=19.2s
# [gqr] gen=91200/99999 pop= 853 avg_health=0.943 var=0.0031 elapsed=19.2s
# [gqr] gen=91300/99999 pop= 835 avg_health=0.945 var=0.0031 elapsed=19.3s
# [gqr] gen=91400/99999 pop= 889 avg_health=0.948 var=0.0029 elapsed=19.3s
# [gqr] gen=91500/99999 pop= 897 avg_health=0.946 var=0.0026 elapsed=19.3s
# [gqr] gen=91600/99999 pop= 848 avg_health=0.944 var=0.0034 elapsed=19.3s
# [gqr] gen=91700/99999 pop= 786 avg_health=0.943 var=0.0031 elapsed=19.3s
# [gqr] gen=91800/99999 pop= 814 avg_health=0.946 var=0.0030 elapsed=19.4s
# [gqr] gen=91900/99999 pop= 889 avg_health=0.942 var=0.0034 elapsed=19.4s
# [gqr] gen=92000/99999 pop= 846 avg_health=0.941 var=0.0032 elapsed=19.4s
# [gqr] gen=92100/99999 pop= 807 avg_health=0.947 var=0.0032 elapsed=19.4s
# [gqr] gen=92200/99999 pop= 788 avg_health=0.937 var=0.0040 elapsed=19.4s
# [gqr] gen=92300/99999 pop= 848 avg_health=0.945 var=0.0031 elapsed=19.5s
# [gqr] gen=92400/99999 pop= 859 avg_health=0.949 var=0.0024 elapsed=19.5s
# [gqr] gen=92500/99999 pop= 884 avg_health=0.942 var=0.0031 elapsed=19.5s
# [gqr] gen=92600/99999 pop= 845 avg_health=0.952 var=0.0025 elapsed=19.5s
# [gqr] gen=92700/99999 pop= 873 avg_health=0.939 var=0.0031 elapsed=19.5s
# [gqr] gen=92800/99999 pop= 841 avg_health=0.944 var=0.0034 elapsed=19.5s
# [gqr] gen=92900/99999 pop= 874 avg_health=0.951 var=0.0023 elapsed=19.6s
# [gqr] gen=93000/99999 pop= 896 avg_health=0.943 var=0.0030 elapsed=19.6s
# [gqr] gen=93100/99999 pop= 843 avg_health=0.945 var=0.0027 elapsed=19.6s
# [gqr] gen=93200/99999 pop= 845 avg_health=0.956 var=0.0022 elapsed=19.6s
# [gqr] gen=93300/99999 pop= 853 avg_health=0.942 var=0.0032 elapsed=19.6s
# [gqr] gen=93400/99999 pop= 756 avg_health=0.944 var=0.0036 elapsed=19.7s
# [gqr] gen=93500/99999 pop= 847 avg_health=0.945 var=0.0031 elapsed=19.7s
# [gqr] gen=93600/99999 pop= 788 avg_health=0.955 var=0.0022 elapsed=19.7s
# [gqr] gen=93700/99999 pop= 816 avg_health=0.941 var=0.0033 elapsed=19.7s
# [gqr] gen=93800/99999 pop= 789 avg_health=0.947 var=0.0029 elapsed=19.7s
# [gqr] gen=93900/99999 pop= 850 avg_health=0.935 var=0.0036 elapsed=19.7s
# [gqr] gen=94000/99999 pop= 798 avg_health=0.949 var=0.0026 elapsed=19.8s
# [gqr] gen=94100/99999 pop= 870 avg_health=0.947 var=0.0027 elapsed=19.8s
# [gqr] gen=94200/99999 pop= 860 avg_health=0.943 var=0.0029 elapsed=19.8s
# [gqr] gen=94300/99999 pop= 818 avg_health=0.942 var=0.0028 elapsed=19.8s
# [gqr] gen=94400/99999 pop= 940 avg_health=0.947 var=0.0027 elapsed=19.8s
# [gqr] gen=94500/99999 pop= 854 avg_health=0.942 var=0.0032 elapsed=19.9s
# [gqr] gen=94600/99999 pop= 835 avg_health=0.940 var=0.0038 elapsed=19.9s
# [gqr] gen=94700/99999 pop= 812 avg_health=0.949 var=0.0029 elapsed=19.9s
# [gqr] gen=94800/99999 pop= 880 avg_health=0.944 var=0.0028 elapsed=19.9s
# [gqr] gen=94900/99999 pop= 834 avg_health=0.948 var=0.0028 elapsed=19.9s
# [gqr] gen=95000/99999 pop= 899 avg_health=0.946 var=0.0031 elapsed=19.9s
# [gqr] gen=95100/99999 pop= 882 avg_health=0.938 var=0.0034 elapsed=20.0s
# [gqr] gen=95200/99999 pop= 863 avg_health=0.948 var=0.0029 elapsed=20.0s
# [gqr] gen=95300/99999 pop= 841 avg_health=0.943 var=0.0032 elapsed=20.0s
# [gqr] gen=95400/99999 pop= 826 avg_health=0.943 var=0.0032 elapsed=20.0s
# [gqr] gen=95500/99999 pop= 824 avg_health=0.941 var=0.0034 elapsed=20.0s
# [gqr] gen=95600/99999 pop= 881 avg_health=0.949 var=0.0030 elapsed=20.1s
# [gqr] gen=95700/99999 pop= 883 avg_health=0.945 var=0.0032 elapsed=20.1s
# [gqr] gen=95800/99999 pop= 915 avg_health=0.949 var=0.0029 elapsed=20.1s
# [gqr] gen=95900/99999 pop= 900 avg_health=0.943 var=0.0034 elapsed=20.1s
# [gqr] gen=96000/99999 pop= 876 avg_health=0.948 var=0.0028 elapsed=20.1s
# [gqr] gen=96100/99999 pop= 868 avg_health=0.945 var=0.0028 elapsed=20.1s
# [gqr] gen=96200/99999 pop= 909 avg_health=0.942 var=0.0033 elapsed=20.2s
# [gqr] gen=96300/99999 pop= 837 avg_health=0.941 var=0.0032 elapsed=20.2s
# [gqr] gen=96400/99999 pop= 882 avg_health=0.942 var=0.0028 elapsed=20.2s
# [gqr] gen=96500/99999 pop= 929 avg_health=0.949 var=0.0030 elapsed=20.2s
# [gqr] gen=96600/99999 pop= 808 avg_health=0.946 var=0.0030 elapsed=20.2s
# [gqr] gen=96700/99999 pop= 846 avg_health=0.936 var=0.0038 elapsed=20.2s
# [gqr] gen=96800/99999 pop= 826 avg_health=0.945 var=0.0031 elapsed=20.3s
# [gqr] gen=96900/99999 pop= 815 avg_health=0.946 var=0.0033 elapsed=20.3s
# [gqr] gen=97000/99999 pop= 867 avg_health=0.940 var=0.0033 elapsed=20.3s
# [gqr] gen=97100/99999 pop= 862 avg_health=0.936 var=0.0039 elapsed=20.3s
# [gqr] gen=97200/99999 pop= 876 avg_health=0.945 var=0.0033 elapsed=20.3s
# [gqr] gen=97300/99999 pop= 866 avg_health=0.943 var=0.0034 elapsed=20.4s
# [gqr] gen=97400/99999 pop= 845 avg_health=0.947 var=0.0028 elapsed=20.4s
# [gqr] gen=97500/99999 pop= 823 avg_health=0.947 var=0.0032 elapsed=20.4s
# [gqr] gen=97600/99999 pop= 795 avg_health=0.940 var=0.0029 elapsed=20.5s
# [gqr] gen=97700/99999 pop= 867 avg_health=0.946 var=0.0032 elapsed=20.5s
# [gqr] gen=97800/99999 pop= 811 avg_health=0.942 var=0.0034 elapsed=20.5s
# [gqr] gen=97900/99999 pop= 846 avg_health=0.942 var=0.0032 elapsed=20.5s
# [gqr] gen=98000/99999 pop= 845 avg_health=0.942 var=0.0031 elapsed=20.5s
# [gqr] gen=98100/99999 pop= 806 avg_health=0.946 var=0.0032 elapsed=20.6s
# [gqr] gen=98200/99999 pop= 804 avg_health=0.948 var=0.0031 elapsed=20.6s
# [gqr] gen=98300/99999 pop= 869 avg_health=0.947 var=0.0031 elapsed=20.6s
# [gqr] gen=98400/99999 pop= 860 avg_health=0.945 var=0.0031 elapsed=20.6s
# [gqr] gen=98500/99999 pop= 871 avg_health=0.946 var=0.0030 elapsed=20.6s
# [gqr] gen=98600/99999 pop= 852 avg_health=0.946 var=0.0029 elapsed=20.7s
# [gqr] gen=98700/99999 pop= 873 avg_health=0.938 var=0.0037 elapsed=20.7s
# [gqr] gen=98800/99999 pop= 901 avg_health=0.946 var=0.0034 elapsed=20.7s
# [gqr] gen=98900/99999 pop= 786 avg_health=0.945 var=0.0029 elapsed=20.7s
# [gqr] gen=99000/99999 pop= 874 avg_health=0.948 var=0.0024 elapsed=20.8s
# [gqr] gen=99100/99999 pop= 871 avg_health=0.943 var=0.0033 elapsed=20.8s
# [gqr] gen=99200/99999 pop= 835 avg_health=0.946 var=0.0030 elapsed=20.8s
# [gqr] gen=99300/99999 pop= 875 avg_health=0.949 var=0.0027 elapsed=20.8s
# [gqr] gen=99400/99999 pop= 826 avg_health=0.948 var=0.0029 elapsed=20.9s
# [gqr] gen=99500/99999 pop= 826 avg_health=0.945 var=0.0030 elapsed=20.9s
# [gqr] gen=99600/99999 pop= 881 avg_health=0.940 var=0.0035 elapsed=20.9s
# [gqr] gen=99700/99999 pop= 813 avg_health=0.945 var=0.0030 elapsed=20.9s
# [gqr] gen=99800/99999 pop= 804 avg_health=0.948 var=0.0029 elapsed=21.0s
# [gqr] gen=99900/99999 pop= 865 avg_health=0.948 var=0.0031 elapsed=21.0s
# [gqr] gen=99999/99999 pop= 917 avg_health=0.943 var=0.0030 elapsed=21.0s
# Final summary:
# arrhenius          | gen=99999 | pop= 963 | avg_health=0.896 | var=0.0122
# arrhenius_marcus   | gen=99999 | pop= 654 | avg_health=0.920 | var=0.0062
# arrhenius_warshel  | gen=99999 | pop= 889 | avg_health=0.877 | var=0.0160
# gqr                | gen=99999 | pop= 917 | avg_health=0.943 | var=0.0030

# %%
import numpy as np

# Save results to NPZ
np.savez(
    "gqr_civilisation_simulation_100k.npz",
    **{
        f"{name}_gens": g,
        f"{name}_pop": p,
        f"{name}_avg_health": h,
        f"{name}_var_health": v
        for name, (g, p, h, v) in results.items()
    }
)

print("Saved: gqr_civilisation_simulation_100k.npz")
# Out:
#   File "/tmp/ipython-input-2868682775.py", line 11
#     for name, (g, p, h, v) in results.items()
#     ^
# SyntaxError: invalid syntax

# %%
save_dict = {}

for name, (g, p, h, v) in results.items():
    save_dict[f"{name}_gens"] = g
    save_dict[f"{name}_pop"] = p
    save_dict[f"{name}_avg_health"] = h
    save_dict[f"{name}_var_health"] = v

# %%
np.savez("gqr_civilisation_simulation_100k.npz", **save_dict)
print("Saved: gqr_civilisation_simulation_100k.npz")
# Out:
# Saved: gqr_civilisation_simulation_100k.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import os

# =============================
# Settings (time mapping)
# =============================
YEARS_PER_GEN = 20
YEAR0 = 1800

GENERATIONS = 80              # 80 gens = 1600 years (tune to 20-60 for "industrial era")
PRINT_EVERY = 1               # 1 = every generation (your request); set to 2/5/10 if you want less spam
AUTOSAVE_EVERY = 5            # autosave every N generations to /content
OUTFILE = "/content/gqr_4masters_competition_autosave.npz"

# Industrial shock timing (e.g., gen 10 ~ year 2000 if YEAR0=1800)
INDUSTRIAL_SHOCK_GEN = 10

# Shared carrying capacity (competition happens via total population)
K_TOTAL = 8000

# Initial population per regime
N0 = 400

# Mutation model: base + (buffering * extra) + (industrial exposure extra after shock)
BASE_MUT_SIGMA = 0.02
BUFFER_MUT_EXTRA = 0.06
INDUSTRIAL_MUT_EXTRA = 0.06   # added after shock (can tune)

# Effort model
EFFORT_BENEFIT = 0.20
EFFORT_COST = 0.10

SEED = 123
rng = np.random.default_rng(SEED)

# =============================
# Regimes ("four masters")
# =============================
REGIMES = {
    "arrhenius":         {"selection_strength": 0.20, "buffering": 0.80},
    "arrhenius_marcus":  {"selection_strength": 0.50, "buffering": 0.30},
    "arrhenius_warshel": {"selection_strength": 0.10, "buffering": 0.90},
    "gqr":               {"selection_strength": 0.80, "buffering": 0.10},
}

# Standard distinct colours
COLORS = {
    "arrhenius": "#1f77b4",          # blue
    "arrhenius_marcus": "#ff7f0e",   # orange
    "arrhenius_warshel": "#2ca02c",  # green
    "gqr": "#d62728",                # red
}

ORDER = list(REGIMES.keys())

# =============================
# Population representation (arrays per regime)
# Each regime holds: genetic_health, epigenetic_bias, effort
# =============================
def init_pop(n):
    gh = np.clip(rng.normal(0.70, 0.10, size=n), 0, 1)
    eb = rng.uniform(-0.05, 0.05, size=n)
    ef = rng.uniform(0, 1, size=n)
    return gh, eb, ef

pops = {name: init_pop(N0) for name in ORDER}

# =============================
# One generation step for one regime, but with COMPETITION
# competition is applied via total density (total_pop / K_TOTAL)
# =============================
def step_regime(gh, eb, ef, regime_name, total_density, industrial_on):
    sel = REGIMES[regime_name]["selection_strength"]
    buf = REGIMES[regime_name]["buffering"]

    # Fitness proxy
    fitness = np.clip(gh + eb + EFFORT_BENEFIT * ef - EFFORT_COST * ef, 0, 1)

    # Survival governance
    survival_prob = np.clip(buf + sel * fitness, 0, 1)

    # Competition / shared ecology: everyone pays as total density rises
    survival_prob *= max(0.0, 1.0 - total_density)
    survival_prob = np.clip(survival_prob, 0, 1)

    survivors = rng.random(size=gh.size) < survival_prob
    gh_s = gh[survivors]
    eb_s = eb[survivors]
    ef_s = ef[survivors]
    fit_s = fitness[survivors]

    if gh_s.size == 0:
        return gh_s, eb_s, ef_s

    # Reproduction probability (fitness-tied)
    repro = rng.random(size=gh_s.size) < fit_s
    gh_p = gh_s[repro]
    eb_p = eb_s[repro]
    n_children = gh_p.size

    if n_children > 0:
        mut_sigma = BASE_MUT_SIGMA + BUFFER_MUT_EXTRA * buf + (INDUSTRIAL_MUT_EXTRA if industrial_on else 0.0)
        mutation = rng.normal(0.0, mut_sigma, size=n_children)

        child_gh = np.clip(gh_p + mutation, 0, 1)
        child_eb = 0.5 * eb_p
        child_ef = rng.uniform(0, 1, size=n_children)

        gh_next = np.concatenate([gh_s, child_gh])
        eb_next = np.concatenate([eb_s, child_eb])
        ef_next = np.concatenate([ef_s, child_ef])
    else:
        gh_next, eb_next, ef_next = gh_s, eb_s, ef_s

    return gh_next, eb_next, ef_next

# =============================
# History (NOT big): store every generation (80 gens is tiny)
# =============================
hist_year = []
hist_pop = {name: [] for name in ORDER}
hist_health = {name: [] for name in ORDER}
hist_var = {name: [] for name in ORDER}

def autosave(gen):
    save = {
        "year": np.array(hist_year, dtype=int),
        "order": np.array(ORDER),
        "generations_ran": gen,
        "years_per_gen": YEARS_PER_GEN,
        "year0": YEAR0,
        "industrial_shock_gen": INDUSTRIAL_SHOCK_GEN,
        "k_total": K_TOTAL,
    }
    for name in ORDER:
        save[f"{name}_pop"] = np.array(hist_pop[name], dtype=int)
        save[f"{name}_avg_health"] = np.array(hist_health[name], dtype=float)
        save[f"{name}_var_health"] = np.array(hist_var[name], dtype=float)
    np.savez(OUTFILE, **save)

# =============================
# Run
# =============================
t0 = time.time()
print("gen  year  " + "  ".join([f"{n:>16s}" for n in ORDER]) + "   | " + "  ".join([f"{n:>16s}" for n in ORDER]))

for gen in range(GENERATIONS):
    year = YEAR0 + gen * YEARS_PER_GEN
    industrial_on = gen >= INDUSTRIAL_SHOCK_GEN

    # total density = total_pop / K_TOTAL
    total_pop = sum(pops[name][0].size for name in ORDER)
    total_density = total_pop / K_TOTAL

    # step each regime under the same total density (competition)
    new_pops = {}
    for name in ORDER:
        gh, eb, ef = pops[name]
        new_pops[name] = step_regime(gh, eb, ef, name, total_density, industrial_on)
    pops = new_pops

    # record
    hist_year.append(year)
    for name in ORDER:
        gh, eb, ef = pops[name]
        n = gh.size
        hist_pop[name].append(n)
        hist_health[name].append(float(gh.mean()) if n > 0 else 0.0)
        hist_var[name].append(float(gh.var()) if n > 1 else 0.0)

    # one-line progress
    if (gen % PRINT_EVERY) == 0:
        pop_str = "  ".join([f"{hist_pop[n][-1]:16d}" for n in ORDER])
        health_str = "  ".join([f"{hist_health[n][-1]:16.3f}" for n in ORDER])
        print(f"{gen:3d}  {year:4d}  {pop_str}   | {health_str}")

    # autosave
    if (gen % AUTOSAVE_EVERY) == 0 or gen == GENERATIONS - 1:
        autosave(gen)

dt = time.time() - t0
print(f"\nDone in {dt:.2f}s. Autosaved to: {OUTFILE}")

# =============================
# Charts
# =============================
x = np.array(hist_year)

plt.figure()
for name in ORDER:
    plt.plot(x, hist_pop[name], label=name, color=COLORS[name])
plt.axvline(YEAR0 + INDUSTRIAL_SHOCK_GEN * YEARS_PER_GEN, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Population size")
plt.title("Population (competing regimes; shared carrying capacity)")
plt.legend()
plt.show()

plt.figure()
for name in ORDER:
    plt.plot(x, hist_health[name], label=name, color=COLORS[name])
plt.axvline(YEAR0 + INDUSTRIAL_SHOCK_GEN * YEARS_PER_GEN, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Average genetic health")
plt.ylim(0, 1)
plt.title("Average genetic health (industrial shock marked)")
plt.legend()
plt.show()

plt.figure()
for name in ORDER:
    plt.plot(x, hist_var[name], label=name, color=COLORS[name])
plt.axvline(YEAR0 + INDUSTRIAL_SHOCK_GEN * YEARS_PER_GEN, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Variance of genetic health")
plt.title("Variance (diversity / fragility proxy; industrial shock marked)")
plt.legend()
plt.show()
# Out:
# gen  year         arrhenius  arrhenius_marcus  arrhenius_warshel               gqr   |        arrhenius  arrhenius_marcus  arrhenius_warshel               gqr
#   0  1800               542               388               540               409   |            0.712             0.718             0.697             0.718
#   1  1820               701               336               693               422   |            0.719             0.730             0.703             0.733
#   2  1840               913               305               889               414   |            0.735             0.751             0.709             0.754
#   3  1860              1092               290              1023               398   |            0.743             0.766             0.721             0.773
#   4  1880              1246               262              1095               375   |            0.751             0.774             0.727             0.790
#   5  1900              1347               188              1187               340   |            0.764             0.807             0.742             0.799
#   6  1920              1404               153              1356               291   |            0.773             0.830             0.755             0.816
#   7  1940              1500               116              1414               236   |            0.785             0.843             0.767             0.823
#   8  1960              1583                64              1478               204   |            0.799             0.862             0.775             0.851
#   9  1980              1648                53              1483               205   |            0.813             0.886             0.788             0.869
#  10  2000              1735                48              1540               220   |            0.818             0.905             0.793             0.886
#  11  2020              1721                42              1518               197   |            0.825             0.911             0.797             0.885
#  12  2040              1742                35              1517               184   |            0.831             0.904             0.804             0.893
#  13  2060              1891                34              1586               151   |            0.838             0.898             0.810             0.892
#  14  2080              1837                30              1633               129   |            0.847             0.898             0.817             0.882
#  15  2100              1921                36              1615               126   |            0.848             0.884             0.821             0.872
#  16  2120              1866                33              1573                95   |            0.852             0.887             0.828             0.905
#  17  2140              1888                31              1592                88   |            0.856             0.856             0.836             0.904
#  18  2160              1854                23              1564                62   |            0.860             0.853             0.837             0.936
#  19  2180              1955                26              1618                57   |            0.862             0.860             0.845             0.931
#  20  2200              1979                22              1587                47   |            0.865             0.890             0.842             0.939
#  21  2220              2064                16              1554                40   |            0.860             0.900             0.858             0.942
#  22  2240              2138                 9              1577                46   |            0.860             0.797             0.857             0.948
#  23  2260              2132                 8              1546                39   |            0.866             0.760             0.857             0.948
#  24  2280              2110                 3              1588                32   |            0.873             0.718             0.854             0.945
#  25  2300              2076                 3              1536                30   |            0.869             0.681             0.856             0.919
#  26  2320              2082                 1              1553                30   |            0.870             0.778             0.856             0.950
#  27  2340              2191                 1              1559                28   |            0.868             0.778             0.856             0.958
#  28  2360              2128                 0              1443                24   |            0.869             0.000             0.854             0.928
#  29  2380              2161                 0              1519                35   |            0.870             0.000             0.856             0.922
#  30  2400              2192                 0              1558                32   |            0.870             0.000             0.858             0.937
#  31  2420              2169                 0              1527                36   |            0.868             0.000             0.856             0.918
#  32  2440              2155                 0              1511                24   |            0.867             0.000             0.855             0.952
#  33  2460              2257                 0              1614                23   |            0.865             0.000             0.854             0.948
#  34  2480              2178                 0              1538                28   |            0.867             0.000             0.856             0.943
#  35  2500              2126                 0              1497                20   |            0.867             0.000             0.857             0.952
#  36  2520              2219                 0              1502                23   |            0.867             0.000             0.857             0.961
#  37  2540              2203                 0              1526                18   |            0.867             0.000             0.857             0.926
#  38  2560              2170                 0              1457                20   |            0.863             0.000             0.860             0.973
#  39  2580              2246                 0              1426                14   |            0.862             0.000             0.857             0.984
#  40  2600              2232                 0              1445                18   |            0.863             0.000             0.860             0.957
#  41  2620              2258                 0              1471                16   |            0.864             0.000             0.859             0.932
#  42  2640              2283                 0              1504                12   |            0.867             0.000             0.863             0.921
#  43  2660              2223                 0              1517                 7   |            0.872             0.000             0.869             0.971
#  44  2680              2161                 0              1582                10   |            0.870             0.000             0.868             0.930
#  45  2700              2171                 0              1567                10   |            0.872             0.000             0.865             0.929
#  46  2720              2243                 0              1613                 8   |            0.875             0.000             0.861             0.920
#  47  2740              2218                 0              1462                 4   |            0.873             0.000             0.855             0.959
#  48  2760              2225                 0              1564                 0   |            0.873             0.000             0.854             0.000
#  49  2780              2211                 0              1545                 0   |            0.873             0.000             0.846             0.000
#  50  2800              2214                 0              1472                 0   |            0.873             0.000             0.846             0.000
#  51  2820              2171                 0              1455                 0   |            0.871             0.000             0.845             0.000
#  52  2840              2258                 0              1441                 0   |            0.870             0.000             0.849             0.000
#  53  2860              2321                 0              1407                 0   |            0.875             0.000             0.847             0.000
#  54  2880              2302                 0              1388                 0   |            0.876             0.000             0.851             0.000
#  55  2900              2256                 0              1431                 0   |            0.876             0.000             0.851             0.000
#  56  2920              2281                 0              1406                 0   |            0.880             0.000             0.856             0.000
#  57  2940              2198                 0              1459                 0   |            0.878             0.000             0.862             0.000
#  58  2960              2328                 0              1497                 0   |            0.879             0.000             0.861             0.000
#  59  2980              2251                 0              1472                 0   |            0.884             0.000             0.861             0.000
#  60  3000              2228                 0              1508                 0   |            0.888             0.000             0.862             0.000
#  61  3020              2213                 0              1535                 0   |            0.880             0.000             0.857             0.000
#  62  3040              2241                 0              1493                 0   |            0.883             0.000             0.855             0.000
#  63  3060              2251                 0              1564                 0   |            0.879             0.000             0.859             0.000
#  64  3080              2204                 0              1561                 0   |            0.878             0.000             0.860             0.000
#  65  3100              2157                 0              1557                 0   |            0.879             0.000             0.859             0.000
#  66  3120              2122                 0              1563                 0   |            0.878             0.000             0.860             0.000
#  67  3140              2132                 0              1618                 0   |            0.874             0.000             0.863             0.000
#  68  3160              2070                 0              1626                 0   |            0.873             0.000             0.867             0.000
#  69  3180              2146                 0              1676                 0   |            0.877             0.000             0.874             0.000
#  70  3200              2061                 0              1635                 0   |            0.872             0.000             0.869             0.000
#  71  3220              2083                 0              1698                 0   |            0.875             0.000             0.875             0.000
#  72  3240              2017                 0              1692                 0   |            0.872             0.000             0.869             0.000
#  73  3260              2061                 0              1741                 0   |            0.864             0.000             0.866             0.000
#  74  3280              2069                 0              1696                 0   |            0.869             0.000             0.866             0.000
#  75  3300              2036                 0              1702                 0   |            0.867             0.000             0.864             0.000
#  76  3320              1980                 0              1656                 0   |            0.866             0.000             0.860             0.000
#  77  3340              1959                 0              1639                 0   |            0.869             0.000             0.857             0.000
#  78  3360              2036                 0              1731                 0   |            0.866             0.000             0.861             0.000
#  79  3380              2043                 0              1768                 0   |            0.869             0.000             0.864             0.000
#
# Done in 0.24s. Autosaved to: /content/gqr_4masters_competition_autosave.npz

# %%
# --- GQR adaptive variance knobs ---
GQR_VAR_FLOOR = 0.004          # if GQR var drops below this, enable plasticity
GQR_EXPLORATION_BOOST = 0.06   # adds to mutation sigma when plasticity on
GQR_BUFFER_BOOST = 0.15        # temporary extra buffering (survival baseline) when plasticity on

def step_regime(gh, eb, ef, regime_name, total_density, industrial_on):
    sel = REGIMES[regime_name]["selection_strength"]
    buf = REGIMES[regime_name]["buffering"]

    # Fitness proxy
    fitness = np.clip(gh + eb + EFFORT_BENEFIT * ef - EFFORT_COST * ef, 0, 1)

    # ---- Adaptive variance mode (GQR only) ----
    plasticity_on = False
    if regime_name == "gqr" and gh.size > 10:
        current_var = float(gh.var())
        # Turn on plasticity if variance is too low AND we're in a stressful epoch
        if current_var < GQR_VAR_FLOOR and (industrial_on or total_density > 0.6):
            plasticity_on = True

    # Option A: temporary buffering boost (prevents extinction under shock)
    if plasticity_on:
        buf_eff = min(1.0, buf + GQR_BUFFER_BOOST)
        sel_eff = sel  # keep selection strength, or reduce slightly if you want
    else:
        buf_eff = buf
        sel_eff = sel

    # Survival governance
    survival_prob = np.clip(buf_eff + sel_eff * fitness, 0, 1)

    # Competition / shared ecology: everyone pays as total density rises
    survival_prob *= max(0.0, 1.0 - total_density)
    survival_prob = np.clip(survival_prob, 0, 1)

    survivors = rng.random(size=gh.size) < survival_prob
    gh_s = gh[survivors]
    eb_s = eb[survivors]
    ef_s = ef[survivors]
    fit_s = fitness[survivors]

    if gh_s.size == 0:
        return gh_s, eb_s, ef_s

    # Reproduction probability (fitness-tied)
    repro = rng.random(size=gh_s.size) < fit_s
    gh_p = gh_s[repro]
    eb_p = eb_s[repro]
    n_children = gh_p.size

    if n_children > 0:
        # Baseline mutation load: base + buffering channel + industrial channel
        mut_sigma = BASE_MUT_SIGMA + BUFFER_MUT_EXTRA * buf_eff + (INDUSTRIAL_MUT_EXTRA if industrial_on else 0.0)

        # Option B: controlled exploration boost (inject variance, children-only)
        if plasticity_on:
            mut_sigma += GQR_EXPLORATION_BOOST

        mutation = rng.normal(0.0, mut_sigma, size=n_children)

        child_gh = np.clip(gh_p + mutation, 0, 1)
        child_eb = 0.5 * eb_p
        child_ef = rng.uniform(0, 1, size=n_children)

        gh_next = np.concatenate([gh_s, child_gh])
        eb_next = np.concatenate([eb_s, child_eb])
        ef_next = np.concatenate([ef_s, child_ef])
    else:
        gh_next, eb_next, ef_next = gh_s, eb_s, ef_s

    return gh_next, eb_next, ef_next

# %%
# =============================
# ONE-CELL PATCH: 4 masters compete + industrial shock + autosave + charts
# with GQR adaptive variance ("plasticity mode")
# Paste this into ONE Colab cell and run.
# It saves: /content/gqr_4masters_competition_autosave.npz
# =============================

import numpy as np
import matplotlib.pyplot as plt
import time

# =============================
# Settings (time mapping)
# =============================
YEARS_PER_GEN = 20
YEAR0 = 1800

GENERATIONS = 80               # 80 gens = 1600 years (tune to 20–120)
PRINT_EVERY = 1                # one-line update every generation (set higher to reduce output)
AUTOSAVE_EVERY = 5             # autosave every N generations to /content
OUTFILE = "/content/gqr_4masters_competition_autosave.npz"

# Industrial shock timing (gen 10 ~ year 2000 if YEAR0=1800)
INDUSTRIAL_SHOCK_GEN = 10

# Shared carrying capacity (competition happens via total density)
K_TOTAL = 8000

# Initial population per regime
N0 = 400

# Mutation model: base + (buffering * extra) + (industrial exposure extra after shock)
BASE_MUT_SIGMA = 0.02
BUFFER_MUT_EXTRA = 0.06
INDUSTRIAL_MUT_EXTRA = 0.06    # added after shock (tune)

# Effort model
EFFORT_BENEFIT = 0.20
EFFORT_COST = 0.10

SEED = 123
rng = np.random.default_rng(SEED)

# =============================
# Regimes ("four masters")
# =============================
REGIMES = {
    "arrhenius":         {"selection_strength": 0.20, "buffering": 0.80},
    "arrhenius_marcus":  {"selection_strength": 0.50, "buffering": 0.30},
    "arrhenius_warshel": {"selection_strength": 0.10, "buffering": 0.90},
    "gqr":               {"selection_strength": 0.80, "buffering": 0.10},
}

# Standard distinct colours
COLORS = {
    "arrhenius": "#1f77b4",          # blue
    "arrhenius_marcus": "#ff7f0e",   # orange
    "arrhenius_warshel": "#2ca02c",  # green
    "gqr": "#d62728",                # red
}

ORDER = list(REGIMES.keys())

# =============================
# GQR adaptive variance knobs
# =============================
GQR_VAR_FLOOR = 0.004           # if GQR var drops below this, enable plasticity
GQR_EXPLORATION_BOOST = 0.06    # adds to mutation sigma when plasticity on (children only)
GQR_BUFFER_BOOST = 0.15         # temporary extra buffering when plasticity on

# =============================
# Population initialisation
# =============================
def init_pop(n):
    gh = np.clip(rng.normal(0.70, 0.10, size=n), 0, 1)
    eb = rng.uniform(-0.05, 0.05, size=n)
    ef = rng.uniform(0, 1, size=n)
    return gh, eb, ef

pops = {name: init_pop(N0) for name in ORDER}

# =============================
# One generation step for one regime under COMPETITION + SHOCK
# (includes GQR plasticity mode)
# =============================
def step_regime(gh, eb, ef, regime_name, total_density, industrial_on):
    sel = REGIMES[regime_name]["selection_strength"]
    buf = REGIMES[regime_name]["buffering"]

    # Fitness proxy
    fitness = np.clip(gh + eb + EFFORT_BENEFIT * ef - EFFORT_COST * ef, 0, 1)

    # ---- GQR adaptive variance mode ("plasticity") ----
    plasticity_on = False
    if regime_name == "gqr" and gh.size > 10:
        current_var = float(gh.var())
        if current_var < GQR_VAR_FLOOR and (industrial_on or total_density > 0.6):
            plasticity_on = True

    # Temporary buffering boost to prevent brittle extinction under stress
    if plasticity_on:
        buf_eff = min(1.0, buf + GQR_BUFFER_BOOST)
        sel_eff = sel
    else:
        buf_eff = buf
        sel_eff = sel

    # Survival governance
    survival_prob = np.clip(buf_eff + sel_eff * fitness, 0, 1)

    # Competition / shared ecology: everyone pays as total density rises
    survival_prob *= max(0.0, 1.0 - total_density)
    survival_prob = np.clip(survival_prob, 0, 1)

    survivors = rng.random(size=gh.size) < survival_prob
    gh_s = gh[survivors]
    eb_s = eb[survivors]
    ef_s = ef[survivors]
    fit_s = fitness[survivors]

    if gh_s.size == 0:
        return gh_s, eb_s, ef_s, plasticity_on

    # Reproduction probability (fitness-tied)
    repro = rng.random(size=gh_s.size) < fit_s
    gh_p = gh_s[repro]
    eb_p = eb_s[repro]
    n_children = gh_p.size

    if n_children > 0:
        # Baseline mutation load: base + buffering channel + industrial channel
        mut_sigma = BASE_MUT_SIGMA + BUFFER_MUT_EXTRA * buf_eff + (INDUSTRIAL_MUT_EXTRA if industrial_on else 0.0)

        # Controlled exploration boost (inject variance, children-only)
        if plasticity_on:
            mut_sigma += GQR_EXPLORATION_BOOST

        mutation = rng.normal(0.0, mut_sigma, size=n_children)

        child_gh = np.clip(gh_p + mutation, 0, 1)
        child_eb = 0.5 * eb_p
        child_ef = rng.uniform(0, 1, size=n_children)

        gh_next = np.concatenate([gh_s, child_gh])
        eb_next = np.concatenate([eb_s, child_eb])
        ef_next = np.concatenate([ef_s, child_ef])
    else:
        gh_next, eb_next, ef_next = gh_s, eb_s, ef_s

    return gh_next, eb_next, ef_next, plasticity_on

# =============================
# History (small)
# =============================
hist_year = []
hist_pop = {name: [] for name in ORDER}
hist_health = {name: [] for name in ORDER}
hist_var = {name: [] for name in ORDER}
hist_gqr_plastic = []  # 1 if plasticity on that gen, else 0

def autosave(gen):
    save = {
        "year": np.array(hist_year, dtype=int),
        "order": np.array(ORDER),
        "generations_ran": int(gen),
        "years_per_gen": int(YEARS_PER_GEN),
        "year0": int(YEAR0),
        "industrial_shock_gen": int(INDUSTRIAL_SHOCK_GEN),
        "k_total": int(K_TOTAL),
        "gqr_plasticity": np.array(hist_gqr_plastic, dtype=int),
        "seed": int(SEED),
        "gqr_var_floor": float(GQR_VAR_FLOOR),
        "gqr_exploration_boost": float(GQR_EXPLORATION_BOOST),
        "gqr_buffer_boost": float(GQR_BUFFER_BOOST),
    }
    for name in ORDER:
        save[f"{name}_pop"] = np.array(hist_pop[name], dtype=int)
        save[f"{name}_avg_health"] = np.array(hist_health[name], dtype=float)
        save[f"{name}_var_health"] = np.array(hist_var[name], dtype=float)
    np.savez(OUTFILE, **save)

# =============================
# Run
# =============================
t0 = time.time()

print("gen  year  " + "  ".join([f"{n:>16s}" for n in ORDER]) + "   | " + "  ".join([f"{n:>16s}" for n in ORDER]) + "   | gqr_plastic")

shock_year = YEAR0 + INDUSTRIAL_SHOCK_GEN * YEARS_PER_GEN

for gen in range(GENERATIONS):
    year = YEAR0 + gen * YEARS_PER_GEN
    industrial_on = gen >= INDUSTRIAL_SHOCK_GEN

    total_pop = sum(pops[name][0].size for name in ORDER)
    total_density = total_pop / K_TOTAL

    new_pops = {}
    gqr_plastic_now = 0

    for name in ORDER:
        gh, eb, ef = pops[name]
        gh2, eb2, ef2, plast = step_regime(gh, eb, ef, name, total_density, industrial_on)
        new_pops[name] = (gh2, eb2, ef2)
        if name == "gqr":
            gqr_plastic_now = 1 if plast else 0

    pops = new_pops

    # record
    hist_year.append(year)
    hist_gqr_plastic.append(gqr_plastic_now)

    for name in ORDER:
        gh, eb, ef = pops[name]
        n = gh.size
        hist_pop[name].append(n)
        hist_health[name].append(float(gh.mean()) if n > 0 else 0.0)
        hist_var[name].append(float(gh.var()) if n > 1 else 0.0)

    # one-line progress
    if (gen % PRINT_EVERY) == 0:
        pop_str = "  ".join([f"{hist_pop[n][-1]:16d}" for n in ORDER])
        health_str = "  ".join([f"{hist_health[n][-1]:16.3f}" for n in ORDER])
        marker = "P" if gqr_plastic_now else "-"
        print(f"{gen:3d}  {year:4d}  {pop_str}   | {health_str}   | {marker}")

    # autosave
    if (gen % AUTOSAVE_EVERY) == 0 or gen == GENERATIONS - 1:
        autosave(gen)

dt = time.time() - t0
print(f"\nDone in {dt:.2f}s. Autosaved to: {OUTFILE}")

# =============================
# Charts
# =============================
x = np.array(hist_year)

plt.figure()
for name in ORDER:
    plt.plot(x, hist_pop[name], label=name, color=COLORS[name])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Population size")
plt.title("Population (competing regimes; shared carrying capacity)")
plt.legend()
plt.show()

plt.figure()
for name in ORDER:
    plt.plot(x, hist_health[name], label=name, color=COLORS[name])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Average genetic health")
plt.ylim(0, 1)
plt.title("Average genetic health (industrial shock marked)")
plt.legend()
plt.show()

plt.figure()
for name in ORDER:
    plt.plot(x, hist_var[name], label=name, color=COLORS[name])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Variance of genetic health")
plt.title("Variance (diversity / fragility proxy; industrial shock marked)")
plt.legend()
plt.show()

plt.figure()
plt.plot(x, hist_gqr_plastic, color=COLORS["gqr"])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("GQR plasticity (0/1)")
plt.title("GQR adaptive variance mode activation")
plt.ylim(-0.1, 1.1)
plt.show()
# Out:
# gen  year         arrhenius  arrhenius_marcus  arrhenius_warshel               gqr   |        arrhenius  arrhenius_marcus  arrhenius_warshel               gqr   | gqr_plastic
#   0  1800               542               388               540               409   |            0.712             0.718             0.697             0.718   | -
#   1  1820               701               336               693               422   |            0.719             0.730             0.703             0.733   | -
#   2  1840               913               305               889               414   |            0.735             0.751             0.709             0.754   | -
#   3  1860              1092               290              1023               398   |            0.743             0.766             0.721             0.773   | -
#   4  1880              1246               262              1095               375   |            0.751             0.774             0.727             0.790   | -
#   5  1900              1347               188              1187               340   |            0.764             0.807             0.742             0.799   | -
#   6  1920              1404               153              1356               291   |            0.773             0.830             0.755             0.816   | -
#   7  1940              1500               116              1414               236   |            0.785             0.843             0.767             0.823   | -
#   8  1960              1583                64              1478               204   |            0.799             0.862             0.775             0.851   | -
#   9  1980              1648                53              1483               205   |            0.813             0.886             0.788             0.869   | -
#  10  2000              1735                48              1540               220   |            0.818             0.905             0.793             0.886   | -
#  11  2020              1721                42              1518               197   |            0.825             0.911             0.797             0.885   | -
#  12  2040              1742                35              1517               184   |            0.831             0.904             0.804             0.893   | -
#  13  2060              1891                34              1586               151   |            0.838             0.898             0.810             0.892   | -
#  14  2080              1837                30              1633               129   |            0.847             0.898             0.817             0.882   | -
#  15  2100              1921                36              1615               126   |            0.848             0.884             0.821             0.872   | -
#  16  2120              1866                33              1573                95   |            0.852             0.887             0.828             0.905   | -
#  17  2140              1888                31              1592                88   |            0.856             0.856             0.836             0.904   | -
#  18  2160              1854                23              1564                62   |            0.860             0.853             0.837             0.936   | -
#  19  2180              1955                26              1618                57   |            0.862             0.860             0.845             0.931   | -
#  20  2200              1979                22              1587                47   |            0.865             0.890             0.842             0.939   | -
#  21  2220              2064                16              1554                40   |            0.860             0.900             0.858             0.942   | -
#  22  2240              2138                 9              1577                53   |            0.860             0.797             0.857             0.933   | P
#  23  2260              2151                 7              1536                38   |            0.863             0.820             0.853             0.906   | -
#  24  2280              2107                 2              1571                31   |            0.870             0.907             0.854             0.919   | -
#  25  2300              2080                 0              1535                29   |            0.872             0.000             0.859             0.916   | -
#  26  2320              2078                 0              1563                31   |            0.878             0.000             0.858             0.938   | -
#  27  2340              2193                 0              1585                32   |            0.878             0.000             0.866             0.928   | -
#  28  2360              2133                 0              1459                28   |            0.876             0.000             0.868             0.928   | -
#  29  2380              2170                 0              1527                24   |            0.875             0.000             0.868             0.940   | -
#  30  2400              2167                 0              1579                24   |            0.876             0.000             0.862             0.938   | -
#  31  2420              2160                 0              1539                15   |            0.874             0.000             0.863             0.935   | -
#  32  2440              2165                 0              1529                12   |            0.873             0.000             0.865             0.913   | -
#  33  2460              2239                 0              1618                10   |            0.870             0.000             0.864             0.889   | -
#  34  2480              2170                 0              1574                 8   |            0.874             0.000             0.869             0.831   | -
#  35  2500              2110                 0              1533                 8   |            0.876             0.000             0.864             0.839   | -
#  36  2520              2220                 0              1555                10   |            0.869             0.000             0.864             0.918   | -
#  37  2540              2218                 0              1544                 7   |            0.868             0.000             0.866             0.921   | -
#  38  2560              2168                 0              1473                 6   |            0.870             0.000             0.858             0.982   | -
#  39  2580              2243                 0              1440                 4   |            0.873             0.000             0.854             0.942   | -
#  40  2600              2271                 0              1497                 8   |            0.873             0.000             0.852             0.935   | -
#  41  2620              2221                 0              1482                 2   |            0.875             0.000             0.856             0.975   | -
#  42  2640              2322                 0              1524                 2   |            0.873             0.000             0.862             0.972   | -
#  43  2660              2190                 0              1477                 2   |            0.876             0.000             0.868             0.976   | -
#  44  2680              2189                 0              1563                 2   |            0.875             0.000             0.859             0.996   | -
#  45  2700              2164                 0              1505                 4   |            0.868             0.000             0.861             0.962   | -
#  46  2720              2226                 0              1572                 8   |            0.865             0.000             0.855             0.932   | -
#  47  2740              2191                 0              1435                 4   |            0.864             0.000             0.860             0.881   | -
#  48  2760              2199                 0              1518                 6   |            0.865             0.000             0.865             0.894   | -
#  49  2780              2174                 0              1552                 4   |            0.866             0.000             0.866             0.923   | -
#  50  2800              2190                 0              1504                 6   |            0.866             0.000             0.865             0.881   | -
#  51  2820              2160                 0              1494                 6   |            0.868             0.000             0.867             0.797   | -
#  52  2840              2244                 0              1475                 5   |            0.863             0.000             0.865             0.777   | -
#  53  2860              2274                 0              1474                 2   |            0.863             0.000             0.856             0.842   | -
#  54  2880              2221                 0              1423                 0   |            0.861             0.000             0.854             0.000   | -
#  55  2900              2218                 0              1459                 0   |            0.864             0.000             0.861             0.000   | -
#  56  2920              2240                 0              1446                 0   |            0.867             0.000             0.863             0.000   | -
#  57  2940              2149                 0              1514                 0   |            0.871             0.000             0.866             0.000   | -
#  58  2960              2272                 0              1555                 0   |            0.876             0.000             0.861             0.000   | -
#  59  2980              2156                 0              1527                 0   |            0.874             0.000             0.867             0.000   | -
#  60  3000              2172                 0              1580                 0   |            0.871             0.000             0.861             0.000   | -
#  61  3020              2149                 0              1580                 0   |            0.869             0.000             0.858             0.000   | -
#  62  3040              2170                 0              1521                 0   |            0.867             0.000             0.859             0.000   | -
#  63  3060              2145                 0              1552                 0   |            0.870             0.000             0.860             0.000   | -
#  64  3080              2126                 0              1594                 0   |            0.869             0.000             0.855             0.000   | -
#  65  3100              2061                 0              1615                 0   |            0.863             0.000             0.850             0.000   | -
#  66  3120              2051                 0              1643                 0   |            0.867             0.000             0.854             0.000   | -
#  67  3140              2082                 0              1689                 0   |            0.866             0.000             0.859             0.000   | -
#  68  3160              2024                 0              1662                 0   |            0.867             0.000             0.862             0.000   | -
#  69  3180              2018                 0              1713                 0   |            0.867             0.000             0.861             0.000   | -
#  70  3200              2001                 0              1675                 0   |            0.867             0.000             0.860             0.000   | -
#  71  3220              2018                 0              1712                 0   |            0.870             0.000             0.859             0.000   | -
#  72  3240              2038                 0              1725                 0   |            0.870             0.000             0.853             0.000   | -
#  73  3260              1986                 0              1715                 0   |            0.871             0.000             0.854             0.000   | -
#  74  3280              2029                 0              1687                 0   |            0.874             0.000             0.858             0.000   | -
#  75  3300              1969                 0              1736                 0   |            0.878             0.000             0.858             0.000   | -
#  76  3320              1930                 0              1696                 0   |            0.879             0.000             0.861             0.000   | -
#  77  3340              1922                 0              1775                 0   |            0.882             0.000             0.862             0.000   | -
#  78  3360              2020                 0              1770                 0   |            0.883             0.000             0.859             0.000   | -
#  79  3380              1946                 0              1836                 0   |            0.877             0.000             0.854             0.000   | -
#
# Done in 0.11s. Autosaved to: /content/gqr_4masters_competition_autosave.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# =============================
# Time mapping / run controls
# =============================
YEARS_PER_GEN = 20
YEAR0 = 1800
GENERATIONS = 120          # 120 gens = 2400 years; set 30–80 for industrial-era focus
PRINT_EVERY = 1            # one-line update each gen (set to 2/5/10 to reduce output)
AUTOSAVE_EVERY = 5
OUTFILE = "/content/rights_game_4masters_autosave.npz"
SEED = 123
rng = np.random.default_rng(SEED)

# Industrial shock
INDUSTRIAL_SHOCK_GEN = 10  # gen 10 ~ year 2000 if YEAR0=1800
INDUSTRIAL_MUT_EXTRA = 0.05
INDUSTRIAL_BUDGET_DRAIN_EXTRA = 0.08   # extra maintenance burden after industrialisation
SHOCK_STRESS_LEVEL = 0.35              # used by GQR jurisdiction switching

# Shared ecology (competition)
K_TOTAL = 9000  # shared carrying capacity scale

# Initial population per regime
N0 = 500

# Fitness model
EFFORT_BENEFIT = 0.20
EFFORT_COST = 0.12  # makes training non-free

# Mutation model
BASE_MUT_SIGMA = 0.02
BUFFER_MUT_EXTRA = 0.05  # "gene mangling" channel: buffering increases mutation load

# Budget / maintenance model
# Budget is a proxy for energy/infrastructure/complexity that keeps buffering running.
BUDGET0 = 1.0
BUDGET_MIN = -2.0
BUDGET_MAX = 4.0

# How budgets change each gen:
# - Earned by productive competence (fitness * population)
# - Spent by buffering (buffering_eff * population), plus baseline overhead
BUDGET_EARN_SCALE = 0.00035
BUDGET_SPEND_SCALE = 0.00055
BUDGET_BASE_OVERHEAD = 0.010

# When budget is low, buffering effectiveness collapses (debt comes due)
def buffering_effect_from_budget(buffering, budget):
    # Smooth clamp: if budget below 0, effective buffering drops
    if budget >= 0:
        return buffering
    # linear drop to zero by BUDGET_MIN
    frac = max(0.0, (budget - BUDGET_MIN) / (0.0 - BUDGET_MIN))
    return buffering * frac

# =============================
# Regimes: constitutional parameters
# =============================
# selection_strength = coupling between competence and survival
# buffering = baseline survival decoupled from competence
REGIMES = {
    "arrhenius": {
        "selection_strength": 0.25,
        "buffering": 0.55,
        "coherence": 0.10,  # mostly irrelevant here (used for symmetry / plotting)
    },
    "arrhenius_marcus": {
        "selection_strength": 0.50,
        "buffering": 0.25,
        "coherence": 0.15,
    },
    "arrhenius_warshel": {
        "selection_strength": 0.18,
        "buffering": 0.70,
        "coherence": 0.20,
    },
    "gqr": {
        "selection_strength": 0.75,
        "buffering": 0.12,
        "coherence": 0.70,  # interpreted as capability for structured option management
    },
}

COLORS = {
    "arrhenius": "#1f77b4",
    "arrhenius_marcus": "#ff7f0e",
    "arrhenius_warshel": "#2ca02c",
    "gqr": "#d62728",
}

ORDER = list(REGIMES.keys())

# =============================
# Population representation: arrays per regime
# gh = genetic health in [0,1]
# eb = epigenetic bias (small +/-)
# ef = effort in [0,1]
# =============================
def init_pop(n):
    gh = np.clip(rng.normal(0.70, 0.10, size=n), 0, 1)
    eb = rng.uniform(-0.05, 0.05, size=n)
    ef = rng.uniform(0, 1, size=n)
    return gh, eb, ef

pops = {name: init_pop(N0) for name in ORDER}
budgets = {name: float(BUDGET0) for name in ORDER}

# =============================
# GQR jurisdiction switching ("phase-dependent governance")
# =============================
# GQR has two modes:
# - "coherent" mode: high selection, low buffering, low exploration (tight)
# - "plastic" mode: relax selection a bit, increase buffering a bit, increase exploration (variance-preserving)
GQR_VAR_FLOOR = 0.004
GQR_PLASTIC_BUFFER_BOOST = 0.20
GQR_PLASTIC_SELECTION_MULT = 0.70
GQR_PLASTIC_MUT_BOOST = 0.05

def gqr_mode(gh, total_density, shock_level, budget):
    # Turn plastic if variance too low under stress, OR budget is stressed, OR shock high
    var = float(gh.var()) if gh.size > 20 else 0.0
    if shock_level > SHOCK_STRESS_LEVEL:
        return "plastic"
    if var < GQR_VAR_FLOOR and total_density > 0.55:
        return "plastic"
    if budget < 0.0:
        return "plastic"
    return "coherent"

# =============================
# One-generation step for one regime
# =============================
def step_regime(name, gh, eb, ef, budget, total_density, industrial_on, shock_level):
    params = REGIMES[name]
    sel = params["selection_strength"]
    buf = params["buffering"]

    # GQR: phase-dependent governance
    mode = "-"
    if name == "gqr":
        mode = gqr_mode(gh, total_density, shock_level, budget)
        if mode == "plastic":
            sel = sel * GQR_PLASTIC_SELECTION_MULT
            buf = min(1.0, buf + GQR_PLASTIC_BUFFER_BOOST)

    # Budget affects buffering effectiveness (debt clause)
    buf_eff = buffering_effect_from_budget(buf, budget)

    # Fitness proxy
    fitness = np.clip(gh + eb + EFFORT_BENEFIT * ef - EFFORT_COST * ef, 0, 1)

    # Survival probability: selection + buffering
    survival_prob = np.clip(buf_eff + sel * fitness, 0, 1)

    # Shared ecological competition: survival penalised by total density
    survival_prob *= max(0.0, 1.0 - total_density)
    survival_prob = np.clip(survival_prob, 0, 1)

    survivors = rng.random(size=gh.size) < survival_prob
    gh_s = gh[survivors]
    eb_s = eb[survivors]
    ef_s = ef[survivors]
    fit_s = fitness[survivors]

    if gh_s.size == 0:
        # still update budget (it will decay)
        earned = 0.0
        spent = BUDGET_BASE_OVERHEAD
        if industrial_on:
            spent += INDUSTRIAL_BUDGET_DRAIN_EXTRA
        budget_next = float(np.clip(budget + earned - spent, BUDGET_MIN, BUDGET_MAX))
        return gh_s, eb_s, ef_s, budget_next, mode, buf_eff

    # Reproduction probability tied to fitness
    repro = rng.random(size=gh_s.size) < fit_s
    gh_p = gh_s[repro]
    eb_p = eb_s[repro]
    n_children = gh_p.size

    # Mutation sigma: base + buffering channel + industrial exposure channel (+ GQR plastic exploration)
    mut_sigma = BASE_MUT_SIGMA + BUFFER_MUT_EXTRA * buf_eff + (INDUSTRIAL_MUT_EXTRA if industrial_on else 0.0)
    if name == "gqr" and mode == "plastic":
        mut_sigma += GQR_PLASTIC_MUT_BOOST

    if n_children > 0:
        mutation = rng.normal(0.0, mut_sigma, size=n_children)
        child_gh = np.clip(gh_p + mutation, 0, 1)
        child_eb = 0.5 * eb_p
        child_ef = rng.uniform(0, 1, size=n_children)

        gh_next = np.concatenate([gh_s, child_gh])
        eb_next = np.concatenate([eb_s, child_eb])
        ef_next = np.concatenate([ef_s, child_ef])
    else:
        gh_next, eb_next, ef_next = gh_s, eb_s, ef_s

    # Budget update: earn from productive competence, spend for buffering + overhead (+ industrial burden)
    avg_fit = float(fit_s.mean()) if fit_s.size > 0 else 0.0
    earned = BUDGET_EARN_SCALE * avg_fit * gh_s.size
    spent = BUDGET_BASE_OVERHEAD + BUDGET_SPEND_SCALE * buf_eff * gh_s.size
    if industrial_on:
        spent += INDUSTRIAL_BUDGET_DRAIN_EXTRA

    budget_next = float(np.clip(budget + earned - spent, BUDGET_MIN, BUDGET_MAX))
    return gh_next, eb_next, ef_next, budget_next, mode, buf_eff

# =============================
# Histories (small; autosaved)
# =============================
hist_year = []
hist_total_pop = []
hist_shock = []

hist_pop = {n: [] for n in ORDER}
hist_avg = {n: [] for n in ORDER}
hist_var = {n: [] for n in ORDER}
hist_budget = {n: [] for n in ORDER}
hist_bufeff = {n: [] for n in ORDER}
hist_gqr_mode = []  # 0 coherent, 1 plastic, -1 extinct

def autosave(gen):
    save = {
        "year": np.array(hist_year, dtype=int),
        "total_pop": np.array(hist_total_pop, dtype=int),
        "shock_level": np.array(hist_shock, dtype=float),
        "order": np.array(ORDER),
        "generations_ran": int(gen),
        "years_per_gen": int(YEARS_PER_GEN),
        "year0": int(YEAR0),
        "industrial_shock_gen": int(INDUSTRIAL_SHOCK_GEN),
        "k_total": int(K_TOTAL),
        "seed": int(SEED),
        "params": np.array([0]),  # placeholder for easy loading
        "gqr_mode": np.array(hist_gqr_mode, dtype=int),
    }
    for n in ORDER:
        save[f"{n}_pop"] = np.array(hist_pop[n], dtype=int)
        save[f"{n}_avg_health"] = np.array(hist_avg[n], dtype=float)
        save[f"{n}_var_health"] = np.array(hist_var[n], dtype=float)
        save[f"{n}_budget"] = np.array(hist_budget[n], dtype=float)
        save[f"{n}_buffering_eff"] = np.array(hist_bufeff[n], dtype=float)
    np.savez(OUTFILE, **save)

# =============================
# Run
# =============================
t0 = time.time()
shock_year = YEAR0 + INDUSTRIAL_SHOCK_GEN * YEARS_PER_GEN

print("gen year | " + " ".join([f"{n:>9s}" for n in ORDER]) +
      " | " + " ".join([f"{n:>9s}" for n in ORDER]) +
      " | " + " ".join([f"{n:>6s}" for n in ORDER]) +
      " | gqr")

for gen in range(GENERATIONS):
    year = YEAR0 + gen * YEARS_PER_GEN
    industrial_on = gen >= INDUSTRIAL_SHOCK_GEN

    # Define "shock level" as a simple piecewise: 0 pre-industrial, 1 post-industrial
    # (You can replace this later with a varying signal)
    shock_level = 1.0 if industrial_on else 0.0

    # Competition: total density from current total population
    total_pop = sum(pops[n][0].size for n in ORDER)
    total_density = total_pop / K_TOTAL

    # Step each regime under the same total density and shock level
    new_pops = {}
    new_budgets = {}
    modes = {}
    bufeffs = {}

    for n in ORDER:
        gh, eb, ef = pops[n]
        gh2, eb2, ef2, bud2, mode, buf_eff = step_regime(n, gh, eb, ef, budgets[n], total_density, industrial_on, shock_level)
        new_pops[n] = (gh2, eb2, ef2)
        new_budgets[n] = bud2
        modes[n] = mode
        bufeffs[n] = buf_eff

    pops = new_pops
    budgets = new_budgets

    # Record
    hist_year.append(year)
    hist_total_pop.append(sum(pops[n][0].size for n in ORDER))
    hist_shock.append(shock_level)

    for n in ORDER:
        gh, eb, ef = pops[n]
        nn = gh.size
        hist_pop[n].append(int(nn))
        hist_avg[n].append(float(gh.mean()) if nn > 0 else 0.0)
        hist_var[n].append(float(gh.var()) if nn > 1 else 0.0)
        hist_budget[n].append(float(budgets[n]))
        hist_bufeff[n].append(float(bufeffs[n]))

    # GQR mode series
    if pops["gqr"][0].size == 0:
        hist_gqr_mode.append(-1)
    else:
        hist_gqr_mode.append(1 if modes["gqr"] == "plastic" else 0)

    # One-line progress
    if gen % PRINT_EVERY == 0:
        pop_str = " ".join([f"{hist_pop[n][-1]:9d}" for n in ORDER])
        avg_str = " ".join([f"{hist_avg[n][-1]:9.3f}" for n in ORDER])
        bud_str = " ".join([f"{hist_budget[n][-1]:6.2f}" for n in ORDER])
        gqr_mark = "P" if hist_gqr_mode[-1] == 1 else ("X" if hist_gqr_mode[-1] == -1 else "-")
        print(f"{gen:3d} {year:4d} | {pop_str} | {avg_str} | {bud_str} | {gqr_mark}")

    # Autosave
    if gen % AUTOSAVE_EVERY == 0 or gen == GENERATIONS - 1:
        autosave(gen)

dt = time.time() - t0
print(f"\nDone in {dt:.2f}s. Autosaved to: {OUTFILE}")

# =============================
# Plots
# =============================
x = np.array(hist_year)

plt.figure()
for n in ORDER:
    plt.plot(x, hist_pop[n], label=n, color=COLORS[n])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("Population (shared ecology + maintenance budgets; industrial shock marked)")
plt.legend()
plt.show()

plt.figure()
for n in ORDER:
    plt.plot(x, hist_avg[n], label=n, color=COLORS[n])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Avg genetic health")
plt.ylim(0, 1)
plt.title("Avg genetic health (industrial shock marked)")
plt.legend()
plt.show()

plt.figure()
for n in ORDER:
    plt.plot(x, hist_var[n], label=n, color=COLORS[n])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Variance of genetic health")
plt.title("Variance (diversity / fragility proxy)")
plt.legend()
plt.show()

plt.figure()
for n in ORDER:
    plt.plot(x, hist_budget[n], label=n, color=COLORS[n])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Maintenance budget (debt proxy)")
plt.title("Maintenance budget (buffering is not free)")
plt.legend()
plt.show()

plt.figure()
plt.plot(x, np.array(hist_gqr_mode), color=COLORS["gqr"])
plt.axvline(shock_year, linestyle="--")
plt.xlabel("Year")
plt.ylabel("GQR mode (-1 extinct, 0 coherent, 1 plastic)")
plt.title("GQR jurisdiction switching over time")
plt.ylim(-1.2, 1.2)
plt.show()
# Out:
# gen year | arrhenius arrhenius_marcus arrhenius_warshel       gqr | arrhenius arrhenius_marcus arrhenius_warshel       gqr | arrhenius arrhenius_marcus arrhenius_warshel    gqr | gqr
#   0 1800 |       511       398       565       472 |     0.709     0.717     0.709     0.725 |   0.98   1.02   0.95   1.04 | -
#   1 1820 |       510       318       683       439 |     0.721     0.728     0.720     0.738 |   0.96   1.03   0.89   1.08 | -
#   2 1840 |       524       313       823       423 |     0.735     0.739     0.729     0.748 |   0.94   1.05   0.83   1.12 | -
#   3 1860 |       540       298       977       390 |     0.747     0.759     0.736     0.768 |   0.92   1.06   0.75   1.16 | -
#   4 1880 |       557       278      1092       356 |     0.760     0.775     0.745     0.787 |   0.90   1.07   0.68   1.20 | -
#   5 1900 |       585       271      1225       396 |     0.776     0.792     0.758     0.799 |   0.89   1.08   0.59   1.23 | -
#   6 1920 |       606       212      1319       379 |     0.789     0.809     0.770     0.818 |   0.87   1.09   0.50   1.27 | -
#   7 1940 |       616       225      1447       406 |     0.799     0.811     0.784     0.834 |   0.86   1.10   0.42   1.31 | -
#   8 1960 |       617       221      1524       442 |     0.817     0.815     0.793     0.851 |   0.84   1.11   0.32   1.36 | -
#   9 1980 |       644       181      1580       437 |     0.827     0.844     0.799     0.867 |   0.83   1.12   0.23   1.41 | -
#  10 2000 |       612       148      1700       427 |     0.834     0.850     0.805     0.869 |   0.74   1.04   0.05   1.35 | P
#  11 2020 |       567       136      1838       442 |     0.855     0.861     0.815     0.862 |   0.66   0.96  -0.12   1.29 | P
#  12 2040 |       601       127      1850       419 |     0.864     0.888     0.820     0.865 |   0.57   0.89  -0.28   1.23 | P
#  13 2060 |       576       109      1655       444 |     0.867     0.892     0.829     0.875 |   0.48   0.81  -0.40   1.17 | P
#  14 2080 |       565       116      1517       484 |     0.870     0.898     0.834     0.888 |   0.40   0.73  -0.49   1.12 | P
#  15 2100 |       599       128      1340       566 |     0.873     0.901     0.841     0.888 |   0.31   0.65  -0.57   1.07 | P
#  16 2120 |       625       117      1134       615 |     0.868     0.899     0.853     0.891 |   0.22   0.57  -0.64   1.03 | P
#  17 2140 |       666       111       992       638 |     0.872     0.892     0.863     0.890 |   0.14   0.49  -0.71   0.99 | P
#  18 2160 |       771       101       806       680 |     0.878     0.879     0.874     0.893 |   0.06   0.41  -0.77   0.95 | P
#  19 2180 |       861        91       681       721 |     0.882     0.874     0.869     0.891 |  -0.03   0.33  -0.83   0.92 | P
#  20 2200 |       955        83       542       832 |     0.886     0.885     0.876     0.889 |  -0.11   0.25  -0.89   0.89 | P
#  21 2220 |       985        79       403       947 |     0.884     0.897     0.882     0.896 |  -0.18   0.17  -0.96   0.88 | P
#  22 2240 |      1016        82       285      1019 |     0.891     0.920     0.888     0.895 |  -0.25   0.08  -1.03   0.86 | P
#  23 2260 |      1001        81       176      1161 |     0.895     0.897     0.890     0.899 |  -0.31   0.00  -1.11   0.87 | P
#  24 2280 |       976        91       114      1361 |     0.895     0.900     0.894     0.900 |  -0.36  -0.08  -1.19   0.88 | P
#  25 2300 |       935        93        89      1535 |     0.900     0.899     0.872     0.896 |  -0.41  -0.16  -1.27   0.91 | P
#  26 2320 |       778        77        36      1678 |     0.907     0.913     0.896     0.896 |  -0.47  -0.24  -1.36   0.95 | P
#  27 2340 |       690        77        27      1807 |     0.902     0.929     0.903     0.898 |  -0.53  -0.32  -1.45   1.00 | P
#  28 2360 |       599        66         9      2095 |     0.899     0.929     0.847     0.899 |  -0.58  -0.41  -1.54   1.07 | P
#  29 2380 |       492        59         4      2327 |     0.896     0.924     0.791     0.897 |  -0.65  -0.49  -1.63   1.16 | P
#  30 2400 |       411        49         1      2391 |     0.898     0.928     0.549     0.897 |  -0.71  -0.57  -1.72   1.26 | P
#  31 2420 |       343        47         0      2584 |     0.901     0.932     0.000     0.899 |  -0.78  -0.66  -1.81   1.37 | P
#  32 2440 |       245        31         0      2670 |     0.899     0.936     0.000     0.898 |  -0.85  -0.74  -1.90   1.48 | P
#  33 2460 |       164        28         0      2732 |     0.897     0.925     0.000     0.898 |  -0.93  -0.83  -1.99   1.61 | P
#  34 2480 |       121        14         0      2894 |     0.891     0.938     0.000     0.900 |  -1.01  -0.92  -2.00   1.74 | P
#  35 2500 |        72         9         0      2990 |     0.912     0.961     0.000     0.899 |  -1.09  -1.01  -2.00   1.88 | P
#  36 2520 |        42         6         0      3054 |     0.904     0.947     0.000     0.893 |  -1.18  -1.10  -2.00   2.03 | P
#  37 2540 |        37         8         0      3088 |     0.940     0.940     0.000     0.896 |  -1.26  -1.19  -2.00   2.18 | P
#  38 2560 |        28        10         0      3153 |     0.931     0.910     0.000     0.893 |  -1.35  -1.27  -2.00   2.33 | P
#  39 2580 |        14        12         0      3165 |     0.873     0.910     0.000     0.893 |  -1.44  -1.36  -2.00   2.49 | P
#  40 2600 |         4         8         0      3139 |     0.895     0.932     0.000     0.889 |  -1.53  -1.45  -2.00   2.64 | P
#  41 2620 |         4         8         0      3160 |     0.862     0.954     0.000     0.894 |  -1.62  -1.54  -2.00   2.79 | P
#  42 2640 |         0         8         0      3206 |     0.000     0.956     0.000     0.892 |  -1.71  -1.63  -2.00   2.94 | P
#  43 2660 |         0         8         0      3152 |     0.000     0.976     0.000     0.892 |  -1.80  -1.72  -2.00   3.09 | P
#  44 2680 |         0        10         0      3078 |     0.000     0.965     0.000     0.893 |  -1.89  -1.81  -2.00   3.24 | P
#  45 2700 |         0         6         0      3219 |     0.000     0.998     0.000     0.896 |  -1.98  -1.90  -2.00   3.40 | P
#  46 2720 |         0         6         0      3291 |     0.000     0.998     0.000     0.898 |  -2.00  -1.98  -2.00   3.56 | P
#  47 2740 |         0         2         0      3262 |     0.000     0.960     0.000     0.894 |  -2.00  -2.00  -2.00   3.72 | P
#  48 2760 |         0         2         0      3165 |     0.000     0.958     0.000     0.893 |  -2.00  -2.00  -2.00   3.88 | P
#  49 2780 |         0         2         0      3063 |     0.000     0.988     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
#  50 2800 |         0         0         0      3173 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
#  51 2820 |         0         0         0      3132 |     0.000     0.000     0.000     0.891 |  -2.00  -2.00  -2.00   4.00 | P
#  52 2840 |         0         0         0      3216 |     0.000     0.000     0.000     0.888 |  -2.00  -2.00  -2.00   4.00 | P
#  53 2860 |         0         0         0      3202 |     0.000     0.000     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
#  54 2880 |         0         0         0      3254 |     0.000     0.000     0.000     0.891 |  -2.00  -2.00  -2.00   4.00 | P
#  55 2900 |         0         0         0      3217 |     0.000     0.000     0.000     0.891 |  -2.00  -2.00  -2.00   4.00 | P
#  56 2920 |         0         0         0      3191 |     0.000     0.000     0.000     0.889 |  -2.00  -2.00  -2.00   4.00 | P
#  57 2940 |         0         0         0      3224 |     0.000     0.000     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
#  58 2960 |         0         0         0      3225 |     0.000     0.000     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
#  59 2980 |         0         0         0      3141 |     0.000     0.000     0.000     0.894 |  -2.00  -2.00  -2.00   4.00 | P
#  60 3000 |         0         0         0      3146 |     0.000     0.000     0.000     0.895 |  -2.00  -2.00  -2.00   4.00 | P
#  61 3020 |         0         0         0      3132 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  62 3040 |         0         0         0      3081 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
#  63 3060 |         0         0         0      3238 |     0.000     0.000     0.000     0.890 |  -2.00  -2.00  -2.00   4.00 | P
#  64 3080 |         0         0         0      3218 |     0.000     0.000     0.000     0.890 |  -2.00  -2.00  -2.00   4.00 | P
#  65 3100 |         0         0         0      3123 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  66 3120 |         0         0         0      3067 |     0.000     0.000     0.000     0.895 |  -2.00  -2.00  -2.00   4.00 | P
#  67 3140 |         0         0         0      3141 |     0.000     0.000     0.000     0.900 |  -2.00  -2.00  -2.00   4.00 | P
#  68 3160 |         0         0         0      3204 |     0.000     0.000     0.000     0.898 |  -2.00  -2.00  -2.00   4.00 | P
#  69 3180 |         0         0         0      3119 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  70 3200 |         0         0         0      3084 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  71 3220 |         0         0         0      3204 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  72 3240 |         0         0         0      3186 |     0.000     0.000     0.000     0.895 |  -2.00  -2.00  -2.00   4.00 | P
#  73 3260 |         0         0         0      3140 |     0.000     0.000     0.000     0.899 |  -2.00  -2.00  -2.00   4.00 | P
#  74 3280 |         0         0         0      3192 |     0.000     0.000     0.000     0.898 |  -2.00  -2.00  -2.00   4.00 | P
#  75 3300 |         0         0         0      3215 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  76 3320 |         0         0         0      3131 |     0.000     0.000     0.000     0.899 |  -2.00  -2.00  -2.00   4.00 | P
#  77 3340 |         0         0         0      3141 |     0.000     0.000     0.000     0.903 |  -2.00  -2.00  -2.00   4.00 | P
#  78 3360 |         0         0         0      3111 |     0.000     0.000     0.000     0.899 |  -2.00  -2.00  -2.00   4.00 | P
#  79 3380 |         0         0         0      3131 |     0.000     0.000     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
#  80 3400 |         0         0         0      3138 |     0.000     0.000     0.000     0.895 |  -2.00  -2.00  -2.00   4.00 | P
#  81 3420 |         0         0         0      3176 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  82 3440 |         0         0         0      3233 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  83 3460 |         0         0         0      3202 |     0.000     0.000     0.000     0.894 |  -2.00  -2.00  -2.00   4.00 | P
#  84 3480 |         0         0         0      3229 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  85 3500 |         0         0         0      3192 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  86 3520 |         0         0         0      3203 |     0.000     0.000     0.000     0.894 |  -2.00  -2.00  -2.00   4.00 | P
#  87 3540 |         0         0         0      3237 |     0.000     0.000     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
#  88 3560 |         0         0         0      3116 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
#  89 3580 |         0         0         0      3164 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
#  90 3600 |         0         0         0      3144 |     0.000     0.000     0.000     0.894 |  -2.00  -2.00  -2.00   4.00 | P
#  91 3620 |         0         0         0      3187 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
#  92 3640 |         0         0         0      3242 |     0.000     0.000     0.000     0.894 |  -2.00  -2.00  -2.00   4.00 | P
#  93 3660 |         0         0         0      3120 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  94 3680 |         0         0         0      3231 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  95 3700 |         0         0         0      3166 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  96 3720 |         0         0         0      3272 |     0.000     0.000     0.000     0.898 |  -2.00  -2.00  -2.00   4.00 | P
#  97 3740 |         0         0         0      3268 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
#  98 3760 |         0         0         0      3316 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
#  99 3780 |         0         0         0      3206 |     0.000     0.000     0.000     0.893 |  -2.00  -2.00  -2.00   4.00 | P
# 100 3800 |         0         0         0      3233 |     0.000     0.000     0.000     0.891 |  -2.00  -2.00  -2.00   4.00 | P
# 101 3820 |         0         0         0      3093 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
# 102 3840 |         0         0         0      3088 |     0.000     0.000     0.000     0.895 |  -2.00  -2.00  -2.00   4.00 | P
# 103 3860 |         0         0         0      3139 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
# 104 3880 |         0         0         0      3115 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
# 105 3900 |         0         0         0      3224 |     0.000     0.000     0.000     0.899 |  -2.00  -2.00  -2.00   4.00 | P
# 106 3920 |         0         0         0      3198 |     0.000     0.000     0.000     0.900 |  -2.00  -2.00  -2.00   4.00 | P
# 107 3940 |         0         0         0      3187 |     0.000     0.000     0.000     0.895 |  -2.00  -2.00  -2.00   4.00 | P
# 108 3960 |         0         0         0      3104 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
# 109 3980 |         0         0         0      3231 |     0.000     0.000     0.000     0.896 |  -2.00  -2.00  -2.00   4.00 | P
# 110 4000 |         0         0         0      3201 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
# 111 4020 |         0         0         0      3249 |     0.000     0.000     0.000     0.897 |  -2.00  -2.00  -2.00   4.00 | P
# 112 4040 |         0         0         0      3201 |     0.000     0.000     0.000     0.894 |  -2.00  -2.00  -2.00   4.00 | P
# 113 4060 |         0         0         0      3238 |     0.000     0.000     0.000     0.889 |  -2.00  -2.00  -2.00   4.00 | P
# 114 4080 |         0         0         0      3180 |     0.000     0.000     0.000     0.890 |  -2.00  -2.00  -2.00   4.00 | P
# 115 4100 |         0         0         0      3134 |     0.000     0.000     0.000     0.888 |  -2.00  -2.00  -2.00   4.00 | P
# 116 4120 |         0         0         0      3155 |     0.000     0.000     0.000     0.888 |  -2.00  -2.00  -2.00   4.00 | P
# 117 4140 |         0         0         0      3232 |     0.000     0.000     0.000     0.891 |  -2.00  -2.00  -2.00   4.00 | P
# 118 4160 |         0         0         0      3163 |     0.000     0.000     0.000     0.890 |  -2.00  -2.00  -2.00   4.00 | P
# 119 4180 |         0         0         0      3062 |     0.000     0.000     0.000     0.892 |  -2.00  -2.00  -2.00   4.00 | P
#
# Done in 0.15s. Autosaved to: /content/rights_game_4masters_autosave.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# =============================
# Config
# =============================
SEED = 123
rng = np.random.default_rng(SEED)

N_PATHS = 50
PRODUCT_IDX = 0
EVENTS = 200_000

PRINT_EVERY = 10_000            # one-line progress cadence
AUTOSAVE_EVERY = 20_000
OUTFILE = "/content/enz_rights_game_autosave.npz"

# Two disorder shocks (increase "disorder", which harms GQR filtering)
SHOCK1 = int(0.25 * EVENTS)
SHOCK2 = int(0.60 * EVENTS)
SHOCK_DISORDER_JUMP = 0.30

# Thermodynamic scale (dimensionless)
BETA = 2.2  # higher -> more barrier-sensitive (like lower temperature)

# =============================
# Path landscape (shared across regimes)
# =============================
# Barriers: productive path is modestly favourable; wastes distributed a bit worse on average
base_barriers = np.clip(rng.normal(loc=1.2, scale=0.25, size=N_PATHS), 0.3, 2.2)
base_barriers[PRODUCT_IDX] = 0.95

# Reorganisation-like penalties (Marcus): wastes tend to have higher reorg "friction"
reorg = np.clip(rng.normal(loc=0.35, scale=0.10, size=N_PATHS), 0.05, 0.8)
reorg[PRODUCT_IDX] = 0.20

# Dissipation costs (entropy/heat per event) — wastes often more dissipative
dissipation = np.clip(rng.normal(loc=1.0, scale=0.25, size=N_PATHS), 0.2, 2.0)
dissipation[PRODUCT_IDX] = 0.75

# Reward: productive yields 1 product unit, wastes yield 0
reward = np.zeros(N_PATHS, dtype=float)
reward[PRODUCT_IDX] = 1.0

# =============================
# Regimes ("four masters") as control styles
# =============================
REGIMES = ["arrhenius", "arrhenius_marcus", "arrhenius_warshel", "gqr"]
COLORS = {
    "arrhenius": "#1f77b4",
    "arrhenius_marcus": "#ff7f0e",
    "arrhenius_warshel": "#2ca02c",
    "gqr": "#d62728",
}

# Warshel: barrier shaping parameters
WARSHEL_LOWER_PRODUCT = 0.25        # lower productive barrier
WARSHEL_RAISE_WASTE = 0.05          # slight waste penalty (better preorganisation)
WARSHEL_DISSIPATION_REDUCE = 0.05   # slightly less dissipation from better organisation

# GQR: filter + budget model
GQR_FILTER_BASE = 0.90          # 0..1 : higher -> stronger suppression of waste paths
GQR_FILTER_COST = 0.0008        # budget cost per event per unit filter strength
GQR_BUDGET0 = 1.0
GQR_BUDGET_MIN = -2.0
GQR_BUDGET_MAX = 4.0

# GQR earns budget from "useful work": product yield with low dissipation
GQR_EARN_SCALE = 0.050

# When disorder rises, filter effectiveness drops.
# Also, when budget is negative, filter collapses.
def gqr_effective_filter(filter_setting, disorder, budget):
    # disorder reduces filter linearly; budget<0 reduces further
    eff = filter_setting * max(0.0, 1.0 - disorder)
    if budget < 0:
        # linearly reduce to 0 by BUDGET_MIN
        frac = max(0.0, (budget - GQR_BUDGET_MIN) / (0.0 - GQR_BUDGET_MIN))
        eff *= frac
    return float(np.clip(eff, 0.0, 1.0))

# =============================
# Weight functions per regime (path selection)
# =============================
def weights_arrhenius(barriers):
    # thermal choice ~ exp(-beta * barrier)
    w = np.exp(-BETA * barriers)
    return w / w.sum()

def weights_arrhenius_marcus(barriers, reorg):
    # crude Marcus-like: barrier + reorg penalty
    w = np.exp(-BETA * (barriers + reorg))
    return w / w.sum()

def weights_arrhenius_warshel(barriers, dissipation):
    # protein reshapes barriers: lowers productive, slightly raises wastes
    b = barriers.copy()
    b[PRODUCT_IDX] = max(0.0, b[PRODUCT_IDX] - WARSHEL_LOWER_PRODUCT)
    b[1:] = b[1:] + WARSHEL_RAISE_WASTE
    w = np.exp(-BETA * b)
    return w / w.sum()

def weights_gqr(barriers, filter_eff):
    # GQR pre-collapse filtering suppresses waste weights multiplicatively
    w = np.exp(-BETA * barriers)
    # apply suppression: waste weights multiplied by (1 - filter_eff)
    w2 = w.copy()
    w2[1:] *= (1.0 - filter_eff)
    # productive path remains unsuppressed
    s = w2.sum()
    if s <= 0:
        # fallback (shouldn't happen)
        w2 = np.ones_like(w2) / len(w2)
        return w2
    return w2 / s

# =============================
# Simulation loop
# =============================
def run_regime(name):
    disorder = 0.0
    budget = GQR_BUDGET0 if name == "gqr" else 0.0

    cum_product = 0.0
    cum_waste = 0.0
    cum_diss = 0.0

    # time series (downsampled)
    t = []
    yield_frac = []
    throughput = []
    diss_per_prod = []
    gqr_budget = []
    gqr_filter_eff_series = []
    disorder_series = []

    t0 = time.time()

    # precompute static weights for regimes that don't change over time
    if name == "arrhenius":
        base_w = weights_arrhenius(base_barriers)
    elif name == "arrhenius_marcus":
        base_w = weights_arrhenius_marcus(base_barriers, reorg)
    elif name == "arrhenius_warshel":
        base_w = weights_arrhenius_warshel(base_barriers, dissipation)
    else:
        base_w = None  # gqr is dynamic

    for k in range(1, EVENTS + 1):
        # shocks
        if k == SHOCK1 or k == SHOCK2:
            disorder = float(np.clip(disorder + SHOCK_DISORDER_JUMP, 0.0, 0.95))

        # pick a pathway
        if name != "gqr":
            idx = rng.choice(N_PATHS, p=base_w)
        else:
            # GQR jurisdiction switching: if disorder high, relax filtering slightly (plasticity)
            # (this prevents overcommitment when coherence is not maintainable)
            if disorder > 0.45:
                filter_setting = 0.65 * GQR_FILTER_BASE
            else:
                filter_setting = GQR_FILTER_BASE

            filter_eff = gqr_effective_filter(filter_setting, disorder, budget)
            w = weights_gqr(base_barriers, filter_eff)
            idx = rng.choice(N_PATHS, p=w)

        # update tallies
        got_product = reward[idx]
        if got_product > 0:
            cum_product += 1.0
        else:
            cum_waste += 1.0

        # dissipation accounting (Warshel slightly reduces dissipation via preorganisation)
        d = dissipation[idx]
        if name == "arrhenius_warshel":
            d = max(0.0, d - WARSHEL_DISSIPATION_REDUCE)
        cum_diss += d

        # budget dynamics (GQR only): pay filter maintenance, earn on efficient product
        if name == "gqr":
            # spend scales with filter_eff (maintenance) + a tiny baseline overhead
            spend = (GQR_FILTER_COST * filter_eff) + 0.0003
            # earn if product formed efficiently (reward - dissipation penalty)
            earn = GQR_EARN_SCALE * (got_product * max(0.0, 1.2 - d))
            budget = float(np.clip(budget + earn - spend, GQR_BUDGET_MIN, GQR_BUDGET_MAX))

        # record series (downsample at PRINT_EVERY cadence, plus final point)
        if (k % PRINT_EVERY) == 0 or k == EVENTS:
            yfrac = cum_product / max(1.0, (cum_product + cum_waste))
            thr = (cum_product + cum_waste) / k  # should be ~1 always; kept for symmetry
            dpp = cum_diss / max(1.0, cum_product)  # dissipation per product made

            t.append(k)
            yield_frac.append(yfrac)
            throughput.append(thr)
            diss_per_prod.append(dpp)
            disorder_series.append(disorder)

            if name == "gqr":
                gqr_budget.append(budget)
                gqr_filter_eff_series.append(filter_eff)
            else:
                gqr_budget.append(np.nan)
                gqr_filter_eff_series.append(np.nan)

            dt = time.time() - t0
            gqr_tag = ""
            if name == "gqr":
                gqr_tag = f" | bud={budget: .2f} filt={filter_eff: .2f} dis={disorder: .2f}"
            print(f"[{name:16s}] event={k:7d}/{EVENTS}  yield={yfrac: .3f}  diss/prod={dpp: .3f}  elapsed={dt: .1f}s{gqr_tag}")

    return {
        "t": np.array(t, dtype=int),
        "yield_frac": np.array(yield_frac, dtype=float),
        "diss_per_prod": np.array(diss_per_prod, dtype=float),
        "disorder": np.array(disorder_series, dtype=float),
        "gqr_budget": np.array(gqr_budget, dtype=float),
        "gqr_filter_eff": np.array(gqr_filter_eff_series, dtype=float),
        "final_product": float(cum_product),
        "final_waste": float(cum_waste),
        "final_diss": float(cum_diss),
    }

# =============================
# Run all regimes + autosave
# =============================
results = {}
print(f"Running enzyme rights-game: N_PATHS={N_PATHS}, EVENTS={EVENTS}, shocks at {SHOCK1} and {SHOCK2}\n")
for i, name in enumerate(REGIMES, 1):
    print(f"\n=== {name} ({i}/{len(REGIMES)}) ===")
    results[name] = run_regime(name)

# autosave to /content
save = {
    "seed": np.array([SEED]),
    "n_paths": np.array([N_PATHS]),
    "events": np.array([EVENTS]),
    "product_idx": np.array([PRODUCT_IDX]),
    "shock1": np.array([SHOCK1]),
    "shock2": np.array([SHOCK2]),
    "shock_disorder_jump": np.array([SHOCK_DISORDER_JUMP]),
    "beta": np.array([BETA]),
    "base_barriers": base_barriers,
    "reorg": reorg,
    "dissipation": dissipation,
    "regimes": np.array(REGIMES),
}
for name in REGIMES:
    for key, arr in results[name].items():
        save[f"{name}_{key}"] = arr

np.savez(OUTFILE, **save)
print(f"\nSaved autosave file to: {OUTFILE}")

# =============================
# Plots
# =============================
def vline_events(ax):
    ax.axvline(SHOCK1, linestyle="--")
    ax.axvline(SHOCK2, linestyle="--")

plt.figure()
for name in REGIMES:
    plt.plot(results[name]["t"], results[name]["yield_frac"], label=name, color=COLORS[name])
vline_events(plt.gca())
plt.xlabel("Catalytic events")
plt.ylabel("Product yield fraction")
plt.title("Yield fraction (1 productive path vs waste paths; shocks marked)")
plt.legend()
plt.show()

plt.figure()
for name in REGIMES:
    plt.plot(results[name]["t"], results[name]["diss_per_prod"], label=name, color=COLORS[name])
vline_events(plt.gca())
plt.xlabel("Catalytic events")
plt.ylabel("Dissipation per product (lower is better)")
plt.title("Thermodynamic efficiency proxy (dissipation per product; shocks marked)")
plt.legend()
plt.show()

plt.figure()
plt.plot(results["gqr"]["t"], results["gqr_budget"], label="gqr budget", color=COLORS["gqr"])
vline_events(plt.gca())
plt.xlabel("Catalytic events")
plt.ylabel("GQR budget (maintenance/debt proxy)")
plt.title("GQR maintenance budget over time (shocks marked)")
plt.legend()
plt.show()

plt.figure()
plt.plot(results["gqr"]["t"], results["gqr_filter_eff"], label="gqr effective filter", color=COLORS["gqr"])
vline_events(plt.gca())
plt.xlabel("Catalytic events")
plt.ylabel("GQR effective filter strength")
plt.title("GQR jurisdiction effectiveness (shocks marked)")
plt.legend()
plt.show()

# =============================
# Final summary
# =============================
print("\nFinal summary:")
for name in REGIMES:
    prod = results[name]["final_product"]
    waste = results[name]["final_waste"]
    y = prod / max(1.0, (prod + waste))
    dpp = results[name]["final_diss"] / max(1.0, prod)
    extra = ""
    if name == "gqr":
        extra = f" | final_budget={results[name]['gqr_budget'][-1]:.2f}"
    print(f"{name:16s} | yield={y:.3f} | diss/prod={dpp:.3f}{extra}")
# Out:
# Running enzyme rights-game: N_PATHS=50, EVENTS=200000, shocks at 50000 and 120000
#
#
# === arrhenius (1/4) ===
# [arrhenius       ] event=  10000/200000  yield= 0.032  diss/prod= 32.551  elapsed= 0.5s
# [arrhenius       ] event=  20000/200000  yield= 0.030  diss/prod= 34.401  elapsed= 0.9s
# [arrhenius       ] event=  30000/200000  yield= 0.031  diss/prod= 33.910  elapsed= 1.4s
# [arrhenius       ] event=  40000/200000  yield= 0.032  diss/prod= 33.133  elapsed= 1.8s
# [arrhenius       ] event=  50000/200000  yield= 0.032  diss/prod= 33.037  elapsed= 2.3s
# [arrhenius       ] event=  60000/200000  yield= 0.031  diss/prod= 33.595  elapsed= 2.6s
# [arrhenius       ] event=  70000/200000  yield= 0.031  diss/prod= 33.890  elapsed= 2.8s
# [arrhenius       ] event=  80000/200000  yield= 0.031  diss/prod= 33.728  elapsed= 3.1s
# [arrhenius       ] event=  90000/200000  yield= 0.031  diss/prod= 33.506  elapsed= 3.3s
# [arrhenius       ] event= 100000/200000  yield= 0.032  diss/prod= 33.255  elapsed= 3.5s
# [arrhenius       ] event= 110000/200000  yield= 0.032  diss/prod= 33.166  elapsed= 3.8s
# [arrhenius       ] event= 120000/200000  yield= 0.032  diss/prod= 32.912  elapsed= 4.0s
# [arrhenius       ] event= 130000/200000  yield= 0.032  diss/prod= 32.831  elapsed= 4.2s
# [arrhenius       ] event= 140000/200000  yield= 0.032  diss/prod= 32.720  elapsed= 4.4s
# [arrhenius       ] event= 150000/200000  yield= 0.032  diss/prod= 32.841  elapsed= 4.6s
# [arrhenius       ] event= 160000/200000  yield= 0.032  diss/prod= 32.927  elapsed= 4.8s
# [arrhenius       ] event= 170000/200000  yield= 0.032  diss/prod= 32.810  elapsed= 5.1s
# [arrhenius       ] event= 180000/200000  yield= 0.032  diss/prod= 32.854  elapsed= 5.3s
# [arrhenius       ] event= 190000/200000  yield= 0.032  diss/prod= 32.802  elapsed= 5.5s
# [arrhenius       ] event= 200000/200000  yield= 0.032  diss/prod= 33.006  elapsed= 5.7s
#
# === arrhenius_marcus (2/4) ===
# [arrhenius_marcus] event=  10000/200000  yield= 0.045  diss/prod= 23.332  elapsed= 0.2s
# [arrhenius_marcus] event=  20000/200000  yield= 0.044  diss/prod= 23.615  elapsed= 0.4s
# [arrhenius_marcus] event=  30000/200000  yield= 0.045  diss/prod= 23.124  elapsed= 0.6s
# [arrhenius_marcus] event=  40000/200000  yield= 0.044  diss/prod= 23.485  elapsed= 0.9s
# [arrhenius_marcus] event=  50000/200000  yield= 0.044  diss/prod= 23.827  elapsed= 1.1s
# [arrhenius_marcus] event=  60000/200000  yield= 0.044  diss/prod= 23.753  elapsed= 1.3s
# [arrhenius_marcus] event=  70000/200000  yield= 0.043  diss/prod= 24.014  elapsed= 1.6s
# [arrhenius_marcus] event=  80000/200000  yield= 0.043  diss/prod= 23.939  elapsed= 1.8s
# [arrhenius_marcus] event=  90000/200000  yield= 0.043  diss/prod= 23.997  elapsed= 2.1s
# [arrhenius_marcus] event= 100000/200000  yield= 0.043  diss/prod= 23.986  elapsed= 2.3s
# [arrhenius_marcus] event= 110000/200000  yield= 0.043  diss/prod= 23.957  elapsed= 2.5s
# [arrhenius_marcus] event= 120000/200000  yield= 0.043  diss/prod= 24.127  elapsed= 2.7s
# [arrhenius_marcus] event= 130000/200000  yield= 0.043  diss/prod= 24.188  elapsed= 3.0s
# [arrhenius_marcus] event= 140000/200000  yield= 0.043  diss/prod= 24.132  elapsed= 3.2s
# [arrhenius_marcus] event= 150000/200000  yield= 0.043  diss/prod= 24.172  elapsed= 3.4s
# [arrhenius_marcus] event= 160000/200000  yield= 0.043  diss/prod= 24.314  elapsed= 3.6s
# [arrhenius_marcus] event= 170000/200000  yield= 0.043  diss/prod= 24.318  elapsed= 3.8s
# [arrhenius_marcus] event= 180000/200000  yield= 0.043  diss/prod= 24.343  elapsed= 4.2s
# [arrhenius_marcus] event= 190000/200000  yield= 0.043  diss/prod= 24.323  elapsed= 4.5s
# [arrhenius_marcus] event= 200000/200000  yield= 0.043  diss/prod= 24.302  elapsed= 4.9s
#
# === arrhenius_warshel (3/4) ===
# [arrhenius_warshel] event=  10000/200000  yield= 0.061  diss/prod= 16.087  elapsed= 0.4s
# [arrhenius_warshel] event=  20000/200000  yield= 0.060  diss/prod= 16.430  elapsed= 0.8s
# [arrhenius_warshel] event=  30000/200000  yield= 0.061  diss/prod= 16.260  elapsed= 1.1s
# [arrhenius_warshel] event=  40000/200000  yield= 0.060  diss/prod= 16.543  elapsed= 1.5s
# [arrhenius_warshel] event=  50000/200000  yield= 0.060  diss/prod= 16.528  elapsed= 1.8s
# [arrhenius_warshel] event=  60000/200000  yield= 0.060  diss/prod= 16.628  elapsed= 2.0s
# [arrhenius_warshel] event=  70000/200000  yield= 0.059  diss/prod= 16.690  elapsed= 2.2s
# [arrhenius_warshel] event=  80000/200000  yield= 0.059  diss/prod= 16.663  elapsed= 2.5s
# [arrhenius_warshel] event=  90000/200000  yield= 0.059  diss/prod= 16.669  elapsed= 2.7s
# [arrhenius_warshel] event= 100000/200000  yield= 0.059  diss/prod= 16.708  elapsed= 2.9s
# [arrhenius_warshel] event= 110000/200000  yield= 0.059  diss/prod= 16.699  elapsed= 3.2s
# [arrhenius_warshel] event= 120000/200000  yield= 0.059  diss/prod= 16.658  elapsed= 3.5s
# [arrhenius_warshel] event= 130000/200000  yield= 0.059  diss/prod= 16.692  elapsed= 3.7s
# [arrhenius_warshel] event= 140000/200000  yield= 0.060  diss/prod= 16.584  elapsed= 3.9s
# [arrhenius_warshel] event= 150000/200000  yield= 0.060  diss/prod= 16.576  elapsed= 4.2s
# [arrhenius_warshel] event= 160000/200000  yield= 0.060  diss/prod= 16.533  elapsed= 4.4s
# [arrhenius_warshel] event= 170000/200000  yield= 0.060  diss/prod= 16.527  elapsed= 4.6s
# [arrhenius_warshel] event= 180000/200000  yield= 0.060  diss/prod= 16.438  elapsed= 4.9s
# [arrhenius_warshel] event= 190000/200000  yield= 0.060  diss/prod= 16.455  elapsed= 5.1s
# [arrhenius_warshel] event= 200000/200000  yield= 0.060  diss/prod= 16.468  elapsed= 5.3s
#
# === gqr (4/4) ===
# [gqr             ] event=  10000/200000  yield= 0.251  diss/prod= 3.912  elapsed= 0.6s | bud= 4.00 filt= 0.90 dis= 0.00
# [gqr             ] event=  20000/200000  yield= 0.252  diss/prod= 3.882  elapsed= 1.2s | bud= 4.00 filt= 0.90 dis= 0.00
# [gqr             ] event=  30000/200000  yield= 0.252  diss/prod= 3.891  elapsed= 1.8s | bud= 4.00 filt= 0.90 dis= 0.00
# [gqr             ] event=  40000/200000  yield= 0.251  diss/prod= 3.896  elapsed= 2.4s | bud= 4.00 filt= 0.90 dis= 0.00
# [gqr             ] event=  50000/200000  yield= 0.251  diss/prod= 3.896  elapsed= 2.9s | bud= 4.00 filt= 0.63 dis= 0.30
# [gqr             ] event=  60000/200000  yield= 0.223  diss/prod= 4.440  elapsed= 3.5s | bud= 4.00 filt= 0.63 dis= 0.30
# [gqr             ] event=  70000/200000  yield= 0.203  diss/prod= 4.898  elapsed= 4.1s | bud= 3.99 filt= 0.63 dis= 0.30
# [gqr             ] event=  80000/200000  yield= 0.188  diss/prod= 5.310  elapsed= 4.7s | bud= 4.00 filt= 0.63 dis= 0.30
# [gqr             ] event=  90000/200000  yield= 0.176  diss/prod= 5.690  elapsed= 5.2s | bud= 3.98 filt= 0.63 dis= 0.30
# [gqr             ] event= 100000/200000  yield= 0.167  diss/prod= 6.018  elapsed= 5.8s | bud= 3.99 filt= 0.63 dis= 0.30
# [gqr             ] event= 110000/200000  yield= 0.160  diss/prod= 6.312  elapsed= 6.5s | bud= 3.99 filt= 0.63 dis= 0.30
# [gqr             ] event= 120000/200000  yield= 0.154  diss/prod= 6.562  elapsed= 7.3s | bud= 4.00 filt= 0.23 dis= 0.60
# [gqr             ] event= 130000/200000  yield= 0.145  diss/prod= 6.967  elapsed= 8.1s | bud= 3.98 filt= 0.23 dis= 0.60
# [gqr             ] event= 140000/200000  yield= 0.138  diss/prod= 7.365  elapsed= 9.0s | bud= 3.97 filt= 0.23 dis= 0.60
# [gqr             ] event= 150000/200000  yield= 0.131  diss/prod= 7.735  elapsed= 9.6s | bud= 3.99 filt= 0.23 dis= 0.60
# [gqr             ] event= 160000/200000  yield= 0.126  diss/prod= 8.087  elapsed= 10.1s | bud= 4.00 filt= 0.23 dis= 0.60
# [gqr             ] event= 170000/200000  yield= 0.121  diss/prod= 8.425  elapsed= 10.7s | bud= 3.98 filt= 0.23 dis= 0.60
# [gqr             ] event= 180000/200000  yield= 0.117  diss/prod= 8.743  elapsed= 11.3s | bud= 3.99 filt= 0.23 dis= 0.60
# [gqr             ] event= 190000/200000  yield= 0.113  diss/prod= 9.060  elapsed= 11.9s | bud= 4.00 filt= 0.23 dis= 0.60
# [gqr             ] event= 200000/200000  yield= 0.109  diss/prod= 9.370  elapsed= 12.5s | bud= 3.94 filt= 0.23 dis= 0.60
#
# Saved autosave file to: /content/enz_rights_game_autosave.npz
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3700865972.py in <cell line: 0>()
#     285
#     286 plt.figure()
# --> 287 plt.plot(results["gqr"]["t"], results["gqr_budget"], label="gqr budget", color=COLORS["gqr"])
#     288 vline_events(plt.gca())
#     289 plt.xlabel("Catalytic events")
#
# KeyError: 'gqr_budget'

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# =============================
# Sweep settings
# =============================
SEED0 = 123
rng_master = np.random.default_rng(SEED0)

N_PATHS = 50
PRODUCT_IDX = 0
EVENTS = 80_000           # keep moderate for sweep speed
PRINT_EVERY = 50          # progress every N runs
OUTFILE = "/content/enz_phase_sweep_results.npz"

# Disorder schedule: single step at 25% events (sweep the step size)
SHOCK_AT = int(0.25 * EVENTS)
BETA = 2.2

# Replication
N_LANDSCAPES = 30         # increase to 100+ for “paper-grade”
N_SEEDS_PER_LAND = 5

# Parameter sweeps (keep small first, then expand)
DISORDER_JUMPS = np.array([0.0, 0.2, 0.4, 0.6])
GQR_FILTER_COSTS = np.array([0.0006, 0.0010, 0.0016, 0.0024])
GQR_EARN_SCALES = np.array([0.010, 0.030, 0.050])

# Fixed Warshel shaping (baseline comparator)
WARSHEL_LOWER_PRODUCT = 0.25
WARSHEL_RAISE_WASTE = 0.05
WARSHEL_DISSIPATION_REDUCE = 0.05

# Fixed GQR filter base + budget dynamics (swept cost/earn)
GQR_FILTER_BASE = 0.90
GQR_BUDGET0 = 2.0
GQR_BUDGET_MIN = -2.0
GQR_BUDGET_MAX = 4.0

def gqr_effective_filter(filter_setting, disorder, budget):
    eff = filter_setting * max(0.0, 1.0 - disorder)
    if budget < 0:
        frac = max(0.0, (budget - GQR_BUDGET_MIN) / (0.0 - GQR_BUDGET_MIN))
        eff *= frac
    return float(np.clip(eff, 0.0, 1.0))

def weights_arrhenius(barriers):
    w = np.exp(-BETA * barriers)
    return w / w.sum()

def weights_arrhenius_marcus(barriers, reorg):
    w = np.exp(-BETA * (barriers + reorg))
    return w / w.sum()

def weights_warshel(barriers):
    b = barriers.copy()
    b[PRODUCT_IDX] = max(0.0, b[PRODUCT_IDX] - WARSHEL_LOWER_PRODUCT)
    b[1:] = b[1:] + WARSHEL_RAISE_WASTE
    w = np.exp(-BETA * b)
    return w / w.sum()

def weights_gqr(barriers, filter_eff):
    w = np.exp(-BETA * barriers)
    w2 = w.copy()
    w2[1:] *= (1.0 - filter_eff)
    s = w2.sum()
    return (w2 / s) if s > 0 else np.ones_like(w2) / len(w2)

def run_once(barriers, reorg, dissipation, disorder_jump, gqr_filter_cost, gqr_earn_scale, seed):
    rng = np.random.default_rng(seed)

    # Precompute static weights
    w_arr = weights_arrhenius(barriers)
    w_mar = weights_arrhenius_marcus(barriers, reorg)
    w_war = weights_warshel(barriers)

    # Tallies: [arr, marcus, warshel, gqr]
    prod = np.zeros(4, dtype=float)
    waste = np.zeros(4, dtype=float)
    diss = np.zeros(4, dtype=float)

    disorder = 0.0
    budget = GQR_BUDGET0

    for k in range(1, EVENTS + 1):
        if k == SHOCK_AT:
            disorder = float(np.clip(disorder + disorder_jump, 0.0, 0.95))

        # Arrhenius
        i = rng.choice(N_PATHS, p=w_arr)
        prod[0] += 1.0 if i == PRODUCT_IDX else 0.0
        waste[0] += 0.0 if i == PRODUCT_IDX else 1.0
        diss[0] += dissipation[i]

        # Marcus
        i = rng.choice(N_PATHS, p=w_mar)
        prod[1] += 1.0 if i == PRODUCT_IDX else 0.0
        waste[1] += 0.0 if i == PRODUCT_IDX else 1.0
        diss[1] += dissipation[i]

        # Warshel
        i = rng.choice(N_PATHS, p=w_war)
        prod[2] += 1.0 if i == PRODUCT_IDX else 0.0
        waste[2] += 0.0 if i == PRODUCT_IDX else 1.0
        diss_w = max(0.0, dissipation[i] - WARSHEL_DISSIPATION_REDUCE)
        diss[2] += diss_w

        # GQR (dynamic)
        filter_eff = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
        w_g = weights_gqr(barriers, filter_eff)
        i = rng.choice(N_PATHS, p=w_g)

        got_prod = 1.0 if i == PRODUCT_IDX else 0.0
        prod[3] += got_prod
        waste[3] += 0.0 if got_prod else 1.0
        d = dissipation[i]
        diss[3] += d

        # budget update
        spend = (gqr_filter_cost * filter_eff) + 0.0003
        earn = gqr_earn_scale * (got_prod * max(0.0, 1.2 - d))
        budget = float(np.clip(budget + earn - spend, GQR_BUDGET_MIN, GQR_BUDGET_MAX))

    yield_frac = prod / np.maximum(1.0, prod + waste)
    dpp = diss / np.maximum(1.0, prod)

    # “collapse” proxy: ended with nonpositive budget AND filter effectively dead under final disorder
    final_filter = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
    gqr_dead = 1 if (final_filter < 0.05) else 0

    return yield_frac, dpp, budget, final_filter, gqr_dead

# =============================
# Main sweep
# =============================
rows = []
run_count = 0
t0 = time.time()

for L in range(N_LANDSCAPES):
    # Landscape draw
    barriers = np.clip(rng_master.normal(1.2, 0.25, size=N_PATHS), 0.3, 2.2)
    barriers[PRODUCT_IDX] = 0.95
    reorg = np.clip(rng_master.normal(0.35, 0.10, size=N_PATHS), 0.05, 0.8)
    reorg[PRODUCT_IDX] = 0.20
    dissipation = np.clip(rng_master.normal(1.0, 0.25, size=N_PATHS), 0.2, 2.0)
    dissipation[PRODUCT_IDX] = 0.75

    for s in range(N_SEEDS_PER_LAND):
        seed = int(rng_master.integers(1, 2**31 - 1))
        for dj in DISORDER_JUMPS:
            for fc in GQR_FILTER_COSTS:
                for es in GQR_EARN_SCALES:
                    y, dpp, bud, filt, dead = run_once(barriers, reorg, dissipation, dj, fc, es, seed)
                    # pack: arr, marc, war, gqr
                    rows.append([L, s, dj, fc, es,
                                 y[0], y[1], y[2], y[3],
                                 dpp[0], dpp[1], dpp[2], dpp[3],
                                 bud, filt, dead])
                    run_count += 1
                    if run_count % PRINT_EVERY == 0:
                        dt = time.time() - t0
                        print(f"runs={run_count:6d} elapsed={dt:6.1f}s")

rows = np.array(rows, dtype=float)

np.savez(
    OUTFILE,
    rows=rows,
    columns=np.array([
        "landscape","seed_idx","disorder_jump","gqr_filter_cost","gqr_earn_scale",
        "y_arr","y_mar","y_war","y_gqr",
        "dpp_arr","dpp_mar","dpp_war","dpp_gqr",
        "gqr_final_budget","gqr_final_filter","gqr_dead"
    ])
)
print(f"\nSaved sweep to: {OUTFILE}")

# =============================
# Quick plots: GQR vs Warshel advantage probability
# =============================
# Advantage definitions
y_gqr = rows[:, 8]
y_war = rows[:, 7]
dpp_gqr = rows[:, 12]
dpp_war = rows[:, 11]
dead = rows[:, 15]

# “GQR wins” if higher yield AND lower diss/prod AND not dead
gqr_wins = (y_gqr > y_war) & (dpp_gqr < dpp_war) & (dead < 0.5)

# Plot win rate vs disorder_jump
plt.figure()
for fc in GQR_FILTER_COSTS:
    mask_fc = np.isclose(rows[:,3], fc)
    win_rates = []
    for dj in DISORDER_JUMPS:
        m = mask_fc & np.isclose(rows[:,2], dj)
        win_rates.append(gqr_wins[m].mean() if m.any() else np.nan)
    plt.plot(DISORDER_JUMPS, win_rates, label=f"cost={fc:g}")
plt.xlabel("Disorder jump at shock")
plt.ylabel("P(GQR beats Warshel)")
plt.title("Phase sweep: probability GQR beats Warshel (yield↑ and diss/prod↓)")
plt.legend()
plt.show()
# Out:
# runs=    50 elapsed= 550.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1376417010.py in <cell line: 0>()
#     153             for fc in GQR_FILTER_COSTS:
#     154                 for es in GQR_EARN_SCALES:
# --> 155                     y, dpp, bud, filt, dead = run_once(barriers, reorg, dissipation, dj, fc, es, seed)
#     156                     # pack: arr, marc, war, gqr
#     157                     rows.append([L, s, dj, fc, es,
#
# /tmp/ipython-input-1376417010.py in run_once(barriers, reorg, dissipation, disorder_jump, gqr_filter_cost, gqr_earn_scale, seed)
#     110         filter_eff = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
#     111         w_g = weights_gqr(barriers, filter_eff)
# --> 112         i = rng.choice(N_PATHS, p=w_g)
#     113
#     114         got_prod = 1.0 if i == PRODUCT_IDX else 0.0
#
# numpy/random/_generator.pyx in numpy.random._generator.Generator.choice()
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/numerictypes.py in issubdtype(arg1, arg2)
#     527     """
#     528     if not issubclass_(arg1, generic):
# --> 529         arg1 = dtype(arg1).type
#     530     if not issubclass_(arg2, generic):
#     531         arg2 = dtype(arg2).type
#
# KeyboardInterrupt:

# %%
import numpy as np
import time

# Assume 'rows' and 'cols' exist from the sweep cell
arr_partial = np.array(rows, dtype=float)

outfile = "/content/enz_phase_sweep_partial.npz"
np.savez(
    outfile,
    rows=arr_partial,
    columns=np.array(cols),
    timestamp=time.time(),
)

print(f"Saved PARTIAL sweep: {outfile}")
print(f"Rows saved: {arr_partial.shape[0]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1004134119.py in <cell line: 0>()
#       9     outfile,
#      10     rows=arr_partial,
# ---> 11     columns=np.array(cols),
#      12     timestamp=time.time(),
#      13 )
#
# NameError: name 'cols' is not defined

# %%
import numpy as np
import time

# Reconstruct column names (must match sweep definition)
cols = [
    "landscape","seed_idx","disorder_jump","gqr_filter_cost","gqr_earn_scale",
    "y_arr","y_mar","y_war","y_gqr",
    "dpp_arr","dpp_mar","dpp_war","dpp_gqr",
    "gqr_final_budget","gqr_final_filter","gqr_dead"
]

# Save whatever rows exist so far
arr_partial = np.array(rows, dtype=float)

outfile = "/content/enz_phase_sweep_partial_autosave.npz"
np.savez(
    outfile,
    rows=arr_partial,
    columns=np.array(cols),
    timestamp=time.time(),
)

print(f"Saved PARTIAL sweep to {outfile}")
print("Rows saved:", arr_partial.shape[0])
# Out:
# Saved PARTIAL sweep to /content/enz_phase_sweep_partial_autosave.npz
# Rows saved: 57

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# =============================
# FAST SWEEP (chunked simulation)
# =============================
SEED0 = 123
rng_master = np.random.default_rng(SEED0)

N_PATHS = 50
PRODUCT_IDX = 0

# Chunked events
EVENTS = 80_000
CHUNK = 1_000
N_CHUNKS = EVENTS // CHUNK

# Shock schedule (step disorder at 25%)
SHOCK_AT_CHUNK = int(0.25 * N_CHUNKS)
BETA = 2.2

# Replication (start smaller; scale later)
N_LANDSCAPES = 20
N_SEEDS_PER_LAND = 4

# Sweeps (small first; expand later)
DISORDER_JUMPS = np.array([0.0, 0.2, 0.4, 0.6])
GQR_FILTER_COSTS = np.array([0.0006, 0.0010, 0.0016, 0.0024])
GQR_EARN_SCALES = np.array([0.010, 0.030, 0.050])

# Warshel shaping
WARSHEL_LOWER_PRODUCT = 0.25
WARSHEL_RAISE_WASTE = 0.05
WARSHEL_DISSIPATION_REDUCE = 0.05

# GQR parameters
GQR_FILTER_BASE = 0.90
GQR_BUDGET0 = 2.0
GQR_BUDGET_MIN = -2.0
GQR_BUDGET_MAX = 4.0

OUTFILE = "/content/enz_phase_sweep_results_fast.npz"

def gqr_effective_filter(filter_setting, disorder, budget):
    eff = filter_setting * max(0.0, 1.0 - disorder)
    if budget < 0:
        frac = max(0.0, (budget - GQR_BUDGET_MIN) / (0.0 - GQR_BUDGET_MIN))
        eff *= frac
    return float(np.clip(eff, 0.0, 1.0))

def softmax_weights(x):
    w = np.exp(x - np.max(x))
    return w / w.sum()

def weights_arrhenius(barriers):
    return softmax_weights(-BETA * barriers)

def weights_marcus(barriers, reorg):
    return softmax_weights(-BETA * (barriers + reorg))

def weights_warshel(barriers):
    b = barriers.copy()
    b[PRODUCT_IDX] = max(0.0, b[PRODUCT_IDX] - WARSHEL_LOWER_PRODUCT)
    b[1:] = b[1:] + WARSHEL_RAISE_WASTE
    return softmax_weights(-BETA * b)

def weights_gqr(barriers, filter_eff):
    w = np.exp(-BETA * barriers)
    w[1:] *= (1.0 - filter_eff)
    s = w.sum()
    return (w / s) if s > 0 else np.ones_like(w) / len(w)

def run_once_chunked(barriers, reorg, dissipation, disorder_jump, gqr_filter_cost, gqr_earn_scale, seed):
    rng = np.random.default_rng(seed)

    w_arr = weights_arrhenius(barriers)
    w_mar = weights_marcus(barriers, reorg)
    w_war = weights_warshel(barriers)

    # Precompute per-path dissipation for Warshel (slightly reduced)
    diss_warshel = dissipation.copy()
    diss_warshel = np.maximum(0.0, diss_warshel - WARSHEL_DISSIPATION_REDUCE)

    prod = np.zeros(4, dtype=float)
    waste = np.zeros(4, dtype=float)
    diss = np.zeros(4, dtype=float)

    disorder = 0.0
    budget = GQR_BUDGET0

    for c in range(N_CHUNKS):
        if c == SHOCK_AT_CHUNK:
            disorder = float(np.clip(disorder + disorder_jump, 0.0, 0.95))

        # --- Arrhenius (multinomial chunk) ---
        counts = rng.multinomial(CHUNK, w_arr)
        prod[0] += counts[PRODUCT_IDX]
        waste[0] += (CHUNK - counts[PRODUCT_IDX])
        diss[0] += float((counts * dissipation).sum())

        # --- Marcus ---
        counts = rng.multinomial(CHUNK, w_mar)
        prod[1] += counts[PRODUCT_IDX]
        waste[1] += (CHUNK - counts[PRODUCT_IDX])
        diss[1] += float((counts * dissipation).sum())

        # --- Warshel ---
        counts = rng.multinomial(CHUNK, w_war)
        prod[2] += counts[PRODUCT_IDX]
        waste[2] += (CHUNK - counts[PRODUCT_IDX])
        diss[2] += float((counts * diss_warshel).sum())

        # --- GQR (dynamic weights each chunk) ---
        filter_eff = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
        w_g = weights_gqr(barriers, filter_eff)
        counts = rng.multinomial(CHUNK, w_g)

        got_prod = float(counts[PRODUCT_IDX])
        prod[3] += got_prod
        waste[3] += (CHUNK - counts[PRODUCT_IDX])
        diss_chunk = float((counts * dissipation).sum())
        diss[3] += diss_chunk

        # Budget update (approx): spend depends on filter_eff per event
        spend = CHUNK * ((gqr_filter_cost * filter_eff) + 0.0003)

        # Earn depends on product count * average (1.2 - diss) for product events
        # Approx product dissipation per event:
        d_prod = dissipation[PRODUCT_IDX]
        earn = gqr_earn_scale * got_prod * max(0.0, 1.2 - d_prod)

        budget = float(np.clip(budget + earn - spend, GQR_BUDGET_MIN, GQR_BUDGET_MAX))

    y = prod / np.maximum(1.0, prod + waste)
    dpp = diss / np.maximum(1.0, prod)
    final_filter = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
    gqr_dead = 1 if final_filter < 0.05 else 0
    return y, dpp, budget, final_filter, gqr_dead

# =============================
# Run sweep with heartbeat + autosave
# =============================
cols = [
    "landscape","seed_idx","disorder_jump","gqr_filter_cost","gqr_earn_scale",
    "y_arr","y_mar","y_war","y_gqr",
    "dpp_arr","dpp_mar","dpp_war","dpp_gqr",
    "gqr_final_budget","gqr_final_filter","gqr_dead"
]

rows = []
run_count = 0
t0 = time.time()
last_beat = time.time()
last_save = time.time()

total_runs = N_LANDSCAPES * N_SEEDS_PER_LAND * len(DISORDER_JUMPS) * len(GQR_FILTER_COSTS) * len(GQR_EARN_SCALES)
print(f"FAST sweep starting: total_runs={total_runs}, EVENTS={EVENTS}, CHUNK={CHUNK}, landscapes={N_LANDSCAPES}, seeds/land={N_SEEDS_PER_LAND}")

for L in range(N_LANDSCAPES):
    # landscape draw
    barriers = np.clip(rng_master.normal(1.2, 0.25, size=N_PATHS), 0.3, 2.2)
    barriers[PRODUCT_IDX] = 0.95
    reorg = np.clip(rng_master.normal(0.35, 0.10, size=N_PATHS), 0.05, 0.8)
    reorg[PRODUCT_IDX] = 0.20
    dissipation = np.clip(rng_master.normal(1.0, 0.25, size=N_PATHS), 0.2, 2.0)
    dissipation[PRODUCT_IDX] = 0.75

    for s in range(N_SEEDS_PER_LAND):
        seed = int(rng_master.integers(1, 2**31 - 1))
        for dj in DISORDER_JUMPS:
            for fc in GQR_FILTER_COSTS:
                for es in GQR_EARN_SCALES:
                    y, dpp, bud, filt, dead = run_once_chunked(barriers, reorg, dissipation, dj, fc, es, seed)
                    rows.append([L, s, dj, fc, es,
                                 y[0], y[1], y[2], y[3],
                                 dpp[0], dpp[1], dpp[2], dpp[3],
                                 bud, filt, dead])
                    run_count += 1

                    now = time.time()
                    if now - last_beat > 10:
                        dt = now - t0
                        print(f"runs={run_count:6d}/{total_runs} ({run_count/total_runs:5.1%}) elapsed={dt:6.1f}s")
                        last_beat = now

                    if now - last_save > 20:
                        arr = np.array(rows, dtype=float)
                        np.savez(OUTFILE, rows=arr, columns=np.array(cols))
                        last_save = now

arr = np.array(rows, dtype=float)
np.savez(OUTFILE, rows=arr, columns=np.array(cols))
print(f"\nSaved sweep to: {OUTFILE}")

# =============================
# Quick plot: P(GQR beats Warshel)
# =============================
y_gqr = arr[:, 8]
y_war = arr[:, 7]
dpp_gqr = arr[:, 12]
dpp_war = arr[:, 11]
dead = arr[:, 15]

gqr_wins = (y_gqr > y_war) & (dpp_gqr < dpp_war) & (dead < 0.5)

plt.figure()
for fc in GQR_FILTER_COSTS:
    mask_fc = np.isclose(arr[:,3], fc)
    win_rates = []
    for dj in DISORDER_JUMPS:
        m = mask_fc & np.isclose(arr[:,2], dj)
        win_rates.append(gqr_wins[m].mean() if m.any() else np.nan)
    plt.plot(DISORDER_JUMPS, win_rates, label=f"cost={fc:g}")
plt.xlabel("Disorder jump at shock")
plt.ylabel("P(GQR beats Warshel)")
plt.title("FAST sweep: P(GQR beats Warshel) vs disorder")
plt.legend()
plt.show()
# Out:
# FAST sweep starting: total_runs=3840, EVENTS=80000, CHUNK=1000, landscapes=20, seeds/land=4
# runs=   989/3840 (25.8%) elapsed=  10.0s
# runs=  2122/3840 (55.3%) elapsed=  20.0s
# runs=  3284/3840 (85.5%) elapsed=  30.0s
#
# Saved sweep to: /content/enz_phase_sweep_results_fast.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# =============================
# FAST chunked sweep: scaling with N_PATHS
# =============================
SEED0 = 123
rng_master = np.random.default_rng(SEED0)

# ---- scaling target (the falsifier) ----
N_PATHS_LIST = [50, 200, 500]      # key falsifier: does GQR win region vanish as decoys explode?

PRODUCT_IDX = 0

# Chunked simulation
EVENTS = 80_000
CHUNK = 1_000
N_CHUNKS = EVENTS // CHUNK

# Shock schedule: single step disorder at 25%
SHOCK_AT_CHUNK = int(0.25 * N_CHUNKS)

# Thermodynamic sensitivity
BETA = 2.2

# Replication (tune up for paper-grade)
N_LANDSCAPES = 60
N_SEEDS_PER_LAND = 3

# Sweep grid (keep moderate; expand later if needed)
DISORDER_JUMPS = np.array([0.0, 0.2, 0.4, 0.6])
GQR_FILTER_COSTS = np.array([0.0006, 0.0010, 0.0016, 0.0024])
GQR_EARN_SCALES = np.array([0.010, 0.030, 0.050])

# Warshel shaping
WARSHEL_LOWER_PRODUCT = 0.25
WARSHEL_RAISE_WASTE = 0.05
WARSHEL_DISSIPATION_REDUCE = 0.05

# GQR parameters
GQR_FILTER_BASE = 0.90
GQR_BUDGET0 = 2.0
GQR_BUDGET_MIN = -2.0
GQR_BUDGET_MAX = 4.0

# Progress + autosave
HEARTBEAT_SECONDS = 10
AUTOSAVE_SECONDS = 25
OUTFILE_PREFIX = "/content/enz_pathsweep"

def gqr_effective_filter(filter_setting, disorder, budget):
    eff = filter_setting * max(0.0, 1.0 - disorder)
    if budget < 0:
        frac = max(0.0, (budget - GQR_BUDGET_MIN) / (0.0 - GQR_BUDGET_MIN))
        eff *= frac
    return float(np.clip(eff, 0.0, 1.0))

def softmax_weights(x):
    w = np.exp(x - np.max(x))
    return w / w.sum()

def weights_arrhenius(barriers):
    return softmax_weights(-BETA * barriers)

def weights_marcus(barriers, reorg):
    return softmax_weights(-BETA * (barriers + reorg))

def weights_warshel(barriers):
    b = barriers.copy()
    b[PRODUCT_IDX] = max(0.0, b[PRODUCT_IDX] - WARSHEL_LOWER_PRODUCT)
    b[1:] = b[1:] + WARSHEL_RAISE_WASTE
    return softmax_weights(-BETA * b)

def weights_gqr(barriers, filter_eff):
    w = np.exp(-BETA * barriers)
    w[1:] *= (1.0 - filter_eff)
    s = w.sum()
    return (w / s) if s > 0 else np.ones_like(w) / len(w)

def run_once_chunked(barriers, reorg, dissipation, disorder_jump, gqr_filter_cost, gqr_earn_scale, seed):
    rng = np.random.default_rng(seed)

    w_arr = weights_arrhenius(barriers)
    w_mar = weights_marcus(barriers, reorg)
    w_war = weights_warshel(barriers)

    diss_warshel = np.maximum(0.0, dissipation - WARSHEL_DISSIPATION_REDUCE)

    prod = np.zeros(4, dtype=float)  # arr, marcus, warshel, gqr
    waste = np.zeros(4, dtype=float)
    diss = np.zeros(4, dtype=float)

    disorder = 0.0
    budget = GQR_BUDGET0

    d_prod = float(dissipation[PRODUCT_IDX])

    for c in range(N_CHUNKS):
        if c == SHOCK_AT_CHUNK:
            disorder = float(np.clip(disorder + disorder_jump, 0.0, 0.95))

        # Arrhenius
        counts = rng.multinomial(CHUNK, w_arr)
        prod[0] += counts[PRODUCT_IDX]
        waste[0] += (CHUNK - counts[PRODUCT_IDX])
        diss[0] += float((counts * dissipation).sum())

        # Marcus
        counts = rng.multinomial(CHUNK, w_mar)
        prod[1] += counts[PRODUCT_IDX]
        waste[1] += (CHUNK - counts[PRODUCT_IDX])
        diss[1] += float((counts * dissipation).sum())

        # Warshel
        counts = rng.multinomial(CHUNK, w_war)
        prod[2] += counts[PRODUCT_IDX]
        waste[2] += (CHUNK - counts[PRODUCT_IDX])
        diss[2] += float((counts * diss_warshel).sum())

        # GQR (dynamic)
        filter_eff = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
        w_g = weights_gqr(barriers, filter_eff)
        counts = rng.multinomial(CHUNK, w_g)

        got_prod = float(counts[PRODUCT_IDX])
        prod[3] += got_prod
        waste[3] += (CHUNK - counts[PRODUCT_IDX])
        diss_chunk = float((counts * dissipation).sum())
        diss[3] += diss_chunk

        spend = CHUNK * ((gqr_filter_cost * filter_eff) + 0.0003)
        earn = gqr_earn_scale * got_prod * max(0.0, 1.2 - d_prod)
        budget = float(np.clip(budget + earn - spend, GQR_BUDGET_MIN, GQR_BUDGET_MAX))

    y = prod / np.maximum(1.0, prod + waste)
    dpp = diss / np.maximum(1.0, prod)
    final_filter = gqr_effective_filter(GQR_FILTER_BASE, disorder, budget)
    gqr_dead = 1 if final_filter < 0.05 else 0
    return y, dpp, budget, final_filter, gqr_dead

COLS = [
    "n_paths","landscape","seed_idx","disorder_jump","gqr_filter_cost","gqr_earn_scale",
    "y_arr","y_mar","y_war","y_gqr",
    "dpp_arr","dpp_mar","dpp_war","dpp_gqr",
    "gqr_final_budget","gqr_final_filter","gqr_dead"
]

def autosave_npz(path, rows):
    arr = np.array(rows, dtype=float)
    np.savez(path, rows=arr, columns=np.array(COLS))

# =============================
# Sweep loop (per N_PATHS)
# =============================
all_rows = []
t0 = time.time()
last_beat = t0
last_save = t0

for N_PATHS in N_PATHS_LIST:
    total_runs = N_LANDSCAPES * N_SEEDS_PER_LAND * len(DISORDER_JUMPS) * len(GQR_FILTER_COSTS) * len(GQR_EARN_SCALES)
    print(f"\n=== N_PATHS={N_PATHS} | total_runs={total_runs} | EVENTS={EVENTS} CHUNK={CHUNK} ===")

    run_count = 0
    rows = []

    for L in range(N_LANDSCAPES):
        # landscape draw
        barriers = np.clip(rng_master.normal(1.2, 0.25, size=N_PATHS), 0.3, 2.2)
        barriers[PRODUCT_IDX] = 0.95
        reorg = np.clip(rng_master.normal(0.35, 0.10, size=N_PATHS), 0.05, 0.8)
        reorg[PRODUCT_IDX] = 0.20
        dissipation = np.clip(rng_master.normal(1.0, 0.25, size=N_PATHS), 0.2, 2.0)
        dissipation[PRODUCT_IDX] = 0.75

        for s in range(N_SEEDS_PER_LAND):
            seed = int(rng_master.integers(1, 2**31 - 1))

            for dj in DISORDER_JUMPS:
                for fc in GQR_FILTER_COSTS:
                    for es in GQR_EARN_SCALES:
                        y, dpp, bud, filt, dead = run_once_chunked(barriers, reorg, dissipation, dj, fc, es, seed)
                        rows.append([
                            N_PATHS, L, s, dj, fc, es,
                            y[0], y[1], y[2], y[3],
                            dpp[0], dpp[1], dpp[2], dpp[3],
                            bud, filt, dead
                        ])
                        run_count += 1

                        now = time.time()
                        if now - last_beat > HEARTBEAT_SECONDS:
                            dt = now - t0
                            print(f"  progress: N_PATHS={N_PATHS} runs={run_count:6d}/{total_runs} ({run_count/total_runs:5.1%}) elapsed={dt:6.1f}s")
                            last_beat = now

                        if now - last_save > AUTOSAVE_SECONDS:
                            autosave_npz(f"{OUTFILE_PREFIX}_partial.npz", all_rows + rows)
                            last_save = now

    # Save per-N_PATHS
    perfile = f"{OUTFILE_PREFIX}_N{N_PATHS}.npz"
    autosave_npz(perfile, rows)
    print(f"Saved: {perfile}  (rows={len(rows)})")

    all_rows += rows

# Save combined
combined = f"{OUTFILE_PREFIX}_ALL.npz"
autosave_npz(combined, all_rows)
print(f"\nSaved combined: {combined} (rows={len(all_rows)})")

# =============================
# Plot: P(GQR beats Warshel) vs disorder, per N_PATHS, grouped by filter cost
# =============================
arr = np.array(all_rows, dtype=float)
ci = {c:i for i,c in enumerate(COLS)}
npaths = arr[:, ci["n_paths"]]
dj = arr[:, ci["disorder_jump"]]
fc = arr[:, ci["gqr_filter_cost"]]

y_war = arr[:, ci["y_war"]]
y_gqr = arr[:, ci["y_gqr"]]
dpp_war = arr[:, ci["dpp_war"]]
dpp_gqr = arr[:, ci["dpp_gqr"]]
dead = arr[:, ci["gqr_dead"]]

gqr_wins = (y_gqr > y_war) & (dpp_gqr < dpp_war) & (dead < 0.5)

for N_PATHS in N_PATHS_LIST:
    plt.figure()
    for cost in GQR_FILTER_COSTS:
        mask = (npaths == N_PATHS) & np.isclose(fc, cost)
        rates = []
        for d in DISORDER_JUMPS:
            m = mask & np.isclose(dj, d)
            rates.append(gqr_wins[m].mean() if m.any() else np.nan)
        plt.plot(DISORDER_JUMPS, rates, label=f"cost={cost:g}")
    plt.xlabel("Disorder jump at shock")
    plt.ylabel("P(GQR beats Warshel)")
    plt.title(f"N_PATHS={N_PATHS}: P(GQR beats Warshel) vs disorder")
    plt.ylim(-0.05, 1.05)
    plt.legend()
    plt.show()
# Out:
# === N_PATHS=50 | total_runs=8640 | EVENTS=80000 CHUNK=1000 ===
#   progress: N_PATHS=50 runs=   925/8640 (10.7%) elapsed=  10.0s
#   progress: N_PATHS=50 runs=  2158/8640 (25.0%) elapsed=  20.0s
#   progress: N_PATHS=50 runs=  3353/8640 (38.8%) elapsed=  30.0s
#   progress: N_PATHS=50 runs=  4494/8640 (52.0%) elapsed=  40.0s
#   progress: N_PATHS=50 runs=  5666/8640 (65.6%) elapsed=  50.0s
#   progress: N_PATHS=50 runs=  6805/8640 (78.8%) elapsed=  60.0s
#   progress: N_PATHS=50 runs=  8053/8640 (93.2%) elapsed=  70.0s
# Saved: /content/enz_pathsweep_N50.npz  (rows=8640)
#
# === N_PATHS=200 | total_runs=8640 | EVENTS=80000 CHUNK=1000 ===
#   progress: N_PATHS=200 runs=   330/8640 ( 3.8%) elapsed=  80.1s
#   progress: N_PATHS=200 runs=  1008/8640 (11.7%) elapsed=  90.1s
#   progress: N_PATHS=200 runs=  1697/8640 (19.6%) elapsed= 100.1s
#   progress: N_PATHS=200 runs=  2367/8640 (27.4%) elapsed= 110.1s
#   progress: N_PATHS=200 runs=  3093/8640 (35.8%) elapsed= 120.1s
#   progress: N_PATHS=200 runs=  3781/8640 (43.8%) elapsed= 130.1s
#   progress: N_PATHS=200 runs=  4477/8640 (51.8%) elapsed= 140.1s
#   progress: N_PATHS=200 runs=  5152/8640 (59.6%) elapsed= 150.1s
#   progress: N_PATHS=200 runs=  5842/8640 (67.6%) elapsed= 160.1s
#   progress: N_PATHS=200 runs=  6555/8640 (75.9%) elapsed= 170.1s
#   progress: N_PATHS=200 runs=  7236/8640 (83.8%) elapsed= 180.1s
#   progress: N_PATHS=200 runs=  7934/8640 (91.8%) elapsed= 190.1s
#   progress: N_PATHS=200 runs=  8622/8640 (99.8%) elapsed= 200.1s
# Saved: /content/enz_pathsweep_N200.npz  (rows=8640)
#
# === N_PATHS=500 | total_runs=8640 | EVENTS=80000 CHUNK=1000 ===
#   progress: N_PATHS=500 runs=   438/8640 ( 5.1%) elapsed= 210.2s
#   progress: N_PATHS=500 runs=   884/8640 (10.2%) elapsed= 220.2s
#   progress: N_PATHS=500 runs=  1316/8640 (15.2%) elapsed= 230.2s
#   progress: N_PATHS=500 runs=  1743/8640 (20.2%) elapsed= 240.2s
#   progress: N_PATHS=500 runs=  2175/8640 (25.2%) elapsed= 250.2s
#   progress: N_PATHS=500 runs=  2626/8640 (30.4%) elapsed= 260.2s
#   progress: N_PATHS=500 runs=  3060/8640 (35.4%) elapsed= 270.2s
#   progress: N_PATHS=500 runs=  3491/8640 (40.4%) elapsed= 280.2s
#   progress: N_PATHS=500 runs=  3921/8640 (45.4%) elapsed= 290.2s
#   progress: N_PATHS=500 runs=  4359/8640 (50.5%) elapsed= 300.2s
#   progress: N_PATHS=500 runs=  4814/8640 (55.7%) elapsed= 310.3s
#   progress: N_PATHS=500 runs=  5243/8640 (60.7%) elapsed= 320.3s
#   progress: N_PATHS=500 runs=  5671/8640 (65.6%) elapsed= 330.3s
#   progress: N_PATHS=500 runs=  6105/8640 (70.7%) elapsed= 340.3s
#   progress: N_PATHS=500 runs=  6550/8640 (75.8%) elapsed= 350.3s
#   progress: N_PATHS=500 runs=  6996/8640 (81.0%) elapsed= 360.3s
#   progress: N_PATHS=500 runs=  7431/8640 (86.0%) elapsed= 370.3s
#   progress: N_PATHS=500 runs=  7861/8640 (91.0%) elapsed= 380.3s
#   progress: N_PATHS=500 runs=  8294/8640 (96.0%) elapsed= 390.4s
# Saved: /content/enz_pathsweep_N500.npz  (rows=8640)
#
# Saved combined: /content/enz_pathsweep_ALL.npz (rows=25920)
