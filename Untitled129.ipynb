# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessutton600613-png/GC/blob/main/Untitled129.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- 1. Environment Class ---
class Environment:
    def __init__(self, total_sim_steps, days_per_cycle=50):
        self.total_sim_steps, self.days_per_cycle, self.time = total_sim_steps, days_per_cycle, 0
        num_years = max(1, total_sim_steps / (365 * days_per_cycle))
        steps_per_year = 365 * days_per_cycle
        daily_uv_cycle = np.sin(np.linspace(0, 2 * np.pi, days_per_cycle)); daily_uv_cycle[daily_uv_cycle < 0] = 0
        full_uv, full_resources = [], []
        for _ in range(int(np.ceil(num_years))):
            uv_severity = np.random.uniform(0.8, 1.25)
            resource_bounty = np.random.uniform(0.8, 1.25)
            seasonal_cycle = np.sin(np.linspace(0, 2 * np.pi, steps_per_year))
            seasonal_amplitude_mod = (0.225 * seasonal_cycle + 0.725) * uv_severity
            seasonal_resource_mod = (-0.20 * seasonal_cycle + 0.80) * resource_bounty
            year_resources = 1200 * seasonal_resource_mod
            year_uv = [daily_uv_cycle[i % days_per_cycle] * seasonal_amplitude_mod[i] for i in range(steps_per_year)]
            full_uv.extend(year_uv); full_resources.extend(year_resources)
        self.uv_intensity = np.array(full_uv)
        self.external_resources = np.array(full_resources)

    def get_current_uv(self):
        return self.uv_intensity[self.time % len(self.uv_intensity)]
    def get_current_resources(self):
        return self.external_resources[self.time % len(self.external_resources)]
    def step(self):
        self.time += 1

# --- 2. Protoribosome Class ---
class Protoribosome:
    def __init__(self, env, strategy, initial_sequence, initial_mass=100.0):
        self.env, self.strategy, self.rna_sequence = env, strategy, list(initial_sequence)
        self.rna_mass = initial_mass
        self.atp_pool, self.mcyw_peptide_pool, self.other_peptide_pool = 500.0, 50.0, 5.0
        self.internal_ntp_stock, self.internal_aa_stock, self.internal_trp_tyr_cys_stock = 200.0, 200.0, 100.0
        self.rna_damage_level = 0.0

        self.location = 'dark_zone'
        self.status = 'ACTIVE'

        self.metabolic_efficiency = 1.0
        self.uv_damage_rate_per_uv = 1.2
        self.repair_rate, self.repair_atp_cost, self.trp_tyr_cys_for_repair_needed = 0.5, 0.0025, 0.0005
        self.uv_protection_factor, self.damage_tolerance_threshold = 0.01, 3.0
        self.atp_generation_rate_per_mcyw_uv, self.baseline_atp_generation_rate = 0.15, 0.5
        self.baseline_atp_chemosynthesis = 1.5
        self.protein_synthesis_rate, self.protein_synthesis_ntp_cost, self.protein_synthesis_aa_cost, self.protein_synthesis_atp_cost = 0.20, 0.1, 0.1, 0.02
        self.replication_rate, self.replication_ntp_cost, self.replication_atp_cost = 0.05, 1.0, 0.2
        self.rna_degradation_rate, self.atp_degradation_rate, self.peptide_degradation_rate = 0.0005, 0.025, 0.0008
        self.diffusion_rate, self.atp_from_ntp_conversion = 0.30, 0.1
        self.mutation_prob = 0.004
        self.failed_synthesis_penalty_atp = 150.0
        self.growth_rate = 0.1
        self.growth_ntp_cost = 1.0
        self.growth_atp_cost = 0.2

    def get_peptide_type(self):
        codons = ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)]
        if any(c in {'UGU', 'UGC', 'UAU', 'UAC', 'UGG'} for c in codons):
            return "MCYW"
        return "XXXX"

    def has_stop_codon(self):
        return any(c in {'UAA', 'UAG', 'UGA'} for c in ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)])

    def _decide_zone_transition(self):
        if self.location == 'dark_zone' and self.atp_pool < 450:
            self.location = 'light_zone'
        elif self.location == 'light_zone' and self.rna_damage_level > self.damage_tolerance_threshold * 0.75:
            self.location = 'dark_zone'

    def _apply_uv_damage(self, current_uv):
        if self.location == 'dark_zone' or current_uv <= 0:
            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate * 0.1)
            return

        protection = self.mcyw_peptide_pool * self.uv_protection_factor
        effective_uv = current_uv * max(0.01, 1 - protection)
        self.rna_damage_level += effective_uv * self.uv_damage_rate_per_uv

        for i in range(len(self.rna_sequence)):
            if random.random() < self.mutation_prob * effective_uv:
                self.rna_sequence[i] = random.choice("AUGC")

    def _manage_state(self, has_stop_codon_cached):
        if self.atp_pool < 0.1 or self.rna_damage_level >= self.damage_tolerance_threshold:
            self.status = 'INACTIVE'
            return

        if self.strategy == 'cautious' and has_stop_codon_cached:
            self.status = 'ARRESTED'
        elif self.status == 'ARRESTED' and not has_stop_codon_cached:
             self.status = 'ACTIVE'

        if self.status == 'ACTIVE':
            self.metabolic_efficiency = 1.25
        else:
            self.metabolic_efficiency = 1.0

    def _synthesize_protein(self, has_stop_codon_cached):
        if self.status != 'ACTIVE': return

        if self.strategy == 'readthrough' and has_stop_codon_cached:
            self.status = 'INACTIVE'
            return

        units = self.protein_synthesis_rate * self.metabolic_efficiency * 10
        required_ntp = units * self.protein_synthesis_ntp_cost
        required_atp = units * self.protein_synthesis_atp_cost
        required_aa_total = units * self.protein_synthesis_aa_cost

        is_mcyw = self.get_peptide_type() == "MCYW"

        if is_mcyw:
            required_special_aa = required_aa_total * 0.5
            required_general_aa = required_aa_total - required_special_aa
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa or
                self.internal_trp_tyr_cys_stock < required_special_aa):
                return
        else:
            required_general_aa = required_aa_total
            required_special_aa = 0
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa):
                return

        self.internal_ntp_stock -= required_ntp
        self.atp_pool -= required_atp
        self.internal_aa_stock -= required_general_aa
        self.internal_trp_tyr_cys_stock -= required_special_aa

        if is_mcyw:
            self.mcyw_peptide_pool += units
        else:
            self.other_peptide_pool += units

    def _replicate_rna(self):
        if self.status != 'ACTIVE' or self.rna_mass < 80: return None

        can_replicate = self.rna_mass * self.replication_rate * self.metabolic_efficiency

        if self.internal_ntp_stock > self.replication_ntp_cost and self.atp_pool > self.replication_atp_cost and can_replicate > 1.0:
            offspring_mass = self.rna_mass * 0.5
            self.rna_mass -= offspring_mass

            self.internal_ntp_stock -= offspring_mass * self.replication_ntp_cost
            self.atp_pool -= offspring_mass * self.replication_atp_cost
            return Protoribosome(self.env, self.strategy, "".join(self.rna_sequence), offspring_mass)
        return None

    def _repair_rna_dna(self, dna_template):
        if self.strategy == 'readthrough': return

        if self.status == 'ACTIVE':
            repair_efficiency = 1.0
        elif self.status == 'ARRESTED':
            repair_efficiency = 0.2
        else:
            return

        if "".join(self.rna_sequence) != dna_template:
            for i in range(len(self.rna_sequence)):
                if self.rna_sequence[i] != dna_template[i]:
                    if random.random() < repair_efficiency:
                        if self.atp_pool >= self.repair_atp_cost and self.internal_trp_tyr_cys_stock >= self.trp_tyr_cys_for_repair_needed:
                            self.atp_pool -= self.repair_atp_cost
                            self.internal_trp_tyr_cys_stock -= self.trp_tyr_cys_for_repair_needed
                            self.rna_sequence[i] = dna_template[i]
                            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate)
                    break

    def _diffuse_resources(self):
        if self.status == 'INACTIVE': return
        available = self.env.get_current_resources()
        if available > 0:
            amount = available * self.diffusion_rate
            self.internal_ntp_stock += amount * 0.50
            self.internal_aa_stock += amount * 0.45
            self.internal_trp_tyr_cys_stock += amount * 0.05

    def _grow_mass(self):
        if self.status != 'ACTIVE': return

        potential_growth = self.rna_mass * self.growth_rate * self.metabolic_efficiency
        ntp_cost = potential_growth * self.growth_ntp_cost
        atp_cost = potential_growth * self.growth_atp_cost

        if self.internal_ntp_stock >= ntp_cost and self.atp_pool >= atp_cost:
            self.internal_ntp_stock -= ntp_cost
            self.atp_pool -= atp_cost
            self.rna_mass += potential_growth

    def step(self, current_uv, dna_template):
        if self.status == 'INACTIVE': return None

        self._decide_zone_transition()
        self._apply_uv_damage(current_uv)
        self._repair_rna_dna(dna_template)

        has_stop = self.has_stop_codon()
        self._manage_state(has_stop)

        if self.status == 'INACTIVE': return None

        self._diffuse_resources()
        self._grow_mass()

        self.atp_pool += self.baseline_atp_chemosynthesis
        self.atp_pool *= (1 - self.atp_degradation_rate)

        if self.location == 'light_zone' and current_uv > 0:
            self.atp_pool += (self.atp_generation_rate_per_mcyw_uv * self.mcyw_peptide_pool * current_uv)

        self._synthesize_protein(has_stop)
        if self.status == 'INACTIVE': return None

        return self._replicate_rna()

# --- 3. Colony Class ---
class Colony:
    def __init__(self, env, dna_template, initial_pop_size, steps_per_day):
        self.env = env
        self.dna_template = dna_template
        self.active_population = [Protoribosome(env, 'cautious' if i%2==0 else 'readthrough', dna_template) for i in range(initial_pop_size)]
        self.inactive_population = []
        self.steps_per_day = steps_per_day
        self.max_population = 10000 # The carrying capacity

    def step(self, current_step):
        newly_replicated = []
        current_uv = self.env.get_current_uv()

        next_active_population = []
        for protoribosome in self.active_population:
            new_offspring = protoribosome.step(current_uv, self.dna_template)

            if protoribosome.status == 'INACTIVE':
                self.inactive_population.append(protoribosome)
            else:
                next_active_population.append(protoribosome)

            if new_offspring:
                newly_replicated.append(new_offspring)

        self.active_population = next_active_population
        self.active_population.extend(newly_replicated)

        # --- FIX: Reinstate the population cap ---
        if len(self.active_population) > self.max_population:
            random.shuffle(self.active_population)
            # Cull the excess active members
            self.active_population = self.active_population[:self.max_population]

        # Apply the tidal flush to the inactive list
        if current_step > 0 and current_step % self.steps_per_day == 0:
            self.inactive_population.clear()

    def get_aggregated_data(self):
        data = { 'cautious': 0, 'readthrough': 0, 'in_light_zone': 0, 'arrested': 0, 'total_damage': 0.0 }

        num_active = len(self.active_population)
        if num_active == 0:
            data['inactive'] = len(self.inactive_population)
            return data

        for p in self.active_population:
            if p.strategy == 'cautious':
                data['cautious'] += 1
                if p.status == 'ARRESTED':
                    data['arrested'] += 1
            else:
                data['readthrough'] += 1

            if p.location == 'light_zone':
                data['in_light_zone'] += 1
            data['total_damage'] += p.rna_damage_level

        data['inactive'] = len(self.inactive_population)
        data['avg_damage'] = data['total_damage'] / num_active if num_active > 0 else 0
        return data

# --- 4. Simulation and Plotting ---
def run_and_plot():
    MAX_STEPS = 365 * 20 * 10
    STEPS_PER_DAY = 10

    IDEAL_DNA_TEMPLATE = "AUGUGUUACUGG"

    env = Environment(MAX_STEPS, STEPS_PER_DAY)
    colony = Colony(env, IDEAL_DNA_TEMPLATE, initial_pop_size=150, steps_per_day=STEPS_PER_DAY)

    data = []
    print_interval = 10

    step_count = 0
    while step_count < MAX_STEPS:
        if step_count % print_interval == 0:
            agg_data = colony.get_aggregated_data()
            cautious_pop = agg_data.get('cautious', 0)
            readthrough_pop = agg_data.get('readthrough', 0)
            inactive_pop = agg_data.get('inactive', 0)

            print(f"Simulating step {step_count}... "
                  f"Cautious: {cautious_pop} | "
                  f"Readthrough: {readthrough_pop} | "
                  f"Inactive: {inactive_pop}", flush=True)

            if step_count > 1000 and (cautious_pop == 0 or readthrough_pop == 0):
                print(f"\n--- KNOCKOUT at step {step_count}! ---")
                if cautious_pop == 0: print("Cautious strategy is extinct. Readthrough wins.")
                else: print("Readthrough strategy is extinct. Cautious wins.")
                break

        colony.step(step_count)

        if step_count % STEPS_PER_DAY == 0:
            agg_data = colony.get_aggregated_data()
            log_entry = {'time': env.time, 'uv': env.get_current_uv()}
            log_entry.update(agg_data)
            data.append(log_entry)

        env.step()
        step_count += 1

    if step_count == MAX_STEPS:
        print(f"\n--- MAX STEPS ({MAX_STEPS}) REACHED --- \nSimulation ended in a stalemate.")


    if not data:
        print("No data was logged. Cannot generate plots.")
        return

    results_df = pd.DataFrame(data)

    fig, axs = plt.subplots(4, 1, figsize=(15, 16), sharex=True)
    fig.suptitle('BREAKTHRU FLUSH KNOCKOUT', fontsize=16)
    colors = {'cautious': 'orange', 'readthrough': 'purple', 'inactive': 'grey'}

    axs[0].plot(results_df['time'], results_df['uv'], color='black', alpha=0.2, label='UV Intensity')
    axs[0].set_title('Environmental Conditions'); axs[0].set_ylabel('UV Intensity'); axs[0].legend()

    axs[1].plot(results_df['time'], results_df['cautious'], label='Cautious', color=colors['cautious'])
    axs[1].plot(results_df['time'], results_df['readthrough'], label='Readthrough', color=colors['readthrough'])
    axs[1].set_title('Active Population by Strategy'); axs[1].set_ylabel('Count'); axs[1].legend()
    axs[1].set_yscale('symlog')

    axs[2].stackplot(results_df['time'],
                     results_df['cautious'],
                     results_df['readthrough'],
                     results_df['inactive'],
                     labels=['Cautious', 'Readthrough', 'Inactive'],
                     colors=[colors['cautious'], colors['readthrough'], colors['inactive']])
    axs[2].set_title('Total Population Composition'); axs[2].set_ylabel('Total Count'); axs[2].legend(loc='upper left')

    ax3_twin = axs[3].twinx()
    axs[3].plot(results_df['time'], results_df['in_light_zone'], label='In Light Zone (Risk)', color='red', alpha=0.6)
    axs[3].plot(results_df['time'], results_df['arrested'], label='Arrested (Response)', color='blue', linestyle='--')
    ax3_twin.plot(results_df['time'], results_df['avg_damage'], label='Avg. RNA Damage', color='brown', alpha=0.7)
    axs[3].set_title('Safety & Risk Analysis'); axs[3].set_ylabel('Population Count'); ax3_twin.set_ylabel('Avg. Damage')
    axs[3].legend(loc='upper left'); ax3_twin.legend(loc='upper right')

    for ax in axs:
        ax.grid(True, linestyle=':', linewidth='0.5', color='gray')
        ax.set_xlim(left=0)

    plt.tight_layout(rect=[0, 0, 1, 0.96]); plt.show()

if __name__ == "__main__":
    run_and_plot()
# Out:
# Simulating step 0... Cautious: 75 | Readthrough: 75 | Inactive: 0
# Simulating step 10... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 20... Cautious: 1200 | Readthrough: 1198 | Inactive: 1
# Simulating step 30... Cautious: 4800 | Readthrough: 4788 | Inactive: 2
# Simulating step 40... Cautious: 4984 | Readthrough: 5016 | Inactive: 11
# Simulating step 50... Cautious: 4955 | Readthrough: 5045 | Inactive: 7
# Simulating step 60... Cautious: 4989 | Readthrough: 5011 | Inactive: 11
# Simulating step 70... Cautious: 4976 | Readthrough: 5024 | Inactive: 16
# Simulating step 80... Cautious: 4996 | Readthrough: 5004 | Inactive: 4
# Simulating step 90... Cautious: 5103 | Readthrough: 4897 | Inactive: 4
# Simulating step 100... Cautious: 5189 | Readthrough: 4811 | Inactive: 9
# Simulating step 110... Cautious: 5164 | Readthrough: 4836 | Inactive: 6
# Simulating step 120... Cautious: 5179 | Readthrough: 4821 | Inactive: 10
# Simulating step 130... Cautious: 5181 | Readthrough: 4819 | Inactive: 11
# Simulating step 140... Cautious: 5171 | Readthrough: 4829 | Inactive: 12
# Simulating step 150... Cautious: 5149 | Readthrough: 4851 | Inactive: 6
# Simulating step 160... Cautious: 5077 | Readthrough: 4923 | Inactive: 5
# Simulating step 170... Cautious: 5076 | Readthrough: 4924 | Inactive: 12
# Simulating step 180... Cautious: 5078 | Readthrough: 4922 | Inactive: 2
# Simulating step 190... Cautious: 5056 | Readthrough: 4944 | Inactive: 7
# Simulating step 200... Cautious: 5080 | Readthrough: 4920 | Inactive: 6
# Simulating step 210... Cautious: 5139 | Readthrough: 4861 | Inactive: 9
# Simulating step 220... Cautious: 5132 | Readthrough: 4868 | Inactive: 4
# Simulating step 230... Cautious: 5087 | Readthrough: 4913 | Inactive: 10
# Simulating step 240... Cautious: 5054 | Readthrough: 4946 | Inactive: 12
# Simulating step 250... Cautious: 5066 | Readthrough: 4934 | Inactive: 9
# Simulating step 260... Cautious: 5202 | Readthrough: 4798 | Inactive: 11
# Simulating step 270... Cautious: 5218 | Readthrough: 4782 | Inactive: 3
# Simulating step 280... Cautious: 5223 | Readthrough: 4777 | Inactive: 5
# Simulating step 290... Cautious: 5194 | Readthrough: 4806 | Inactive: 7
# Simulating step 300... Cautious: 5250 | Readthrough: 4750 | Inactive: 9
# Simulating step 310... Cautious: 5282 | Readthrough: 4718 | Inactive: 7
# Simulating step 320... Cautious: 5352 | Readthrough: 4648 | Inactive: 5
# Simulating step 330... Cautious: 5352 | Readthrough: 4648 | Inactive: 9
# Simulating step 340... Cautious: 5378 | Readthrough: 4622 | Inactive: 7
# Simulating step 350... Cautious: 5367 | Readthrough: 4633 | Inactive: 3
# Simulating step 360... Cautious: 5347 | Readthrough: 4653 | Inactive: 7
# Simulating step 370... Cautious: 5344 | Readthrough: 4656 | Inactive: 14
# Simulating step 380... Cautious: 5424 | Readthrough: 4576 | Inactive: 5
# Simulating step 390... Cautious: 5433 | Readthrough: 4567 | Inactive: 7
# Simulating step 400... Cautious: 5481 | Readthrough: 4519 | Inactive: 9
# Simulating step 410... Cautious: 5505 | Readthrough: 4495 | Inactive: 5
# Simulating step 420... Cautious: 5519 | Readthrough: 4481 | Inactive: 5
# Simulating step 430... Cautious: 5502 | Readthrough: 4498 | Inactive: 12
# Simulating step 440... Cautious: 5482 | Readthrough: 4518 | Inactive: 7
# Simulating step 450... Cautious: 5515 | Readthrough: 4485 | Inactive: 8
# Simulating step 460... Cautious: 5500 | Readthrough: 4500 | Inactive: 6
# Simulating step 470... Cautious: 5450 | Readthrough: 4550 | Inactive: 6
# Simulating step 480... Cautious: 5446 | Readthrough: 4554 | Inactive: 16
# Simulating step 490... Cautious: 5516 | Readthrough: 4484 | Inactive: 8
# Simulating step 500... Cautious: 5445 | Readthrough: 4555 | Inactive: 8
# Simulating step 510... Cautious: 5511 | Readthrough: 4489 | Inactive: 6
# Simulating step 520... Cautious: 5531 | Readthrough: 4469 | Inactive: 11
# Simulating step 530... Cautious: 5541 | Readthrough: 4459 | Inactive: 4
# Simulating step 540... Cautious: 5476 | Readthrough: 4524 | Inactive: 8
# Simulating step 550... Cautious: 5457 | Readthrough: 4543 | Inactive: 5
# Simulating step 560... Cautious: 5442 | Readthrough: 4558 | Inactive: 9
# Simulating step 570... Cautious: 5455 | Readthrough: 4545 | Inactive: 16
# Simulating step 580... Cautious: 5431 | Readthrough: 4569 | Inactive: 3
# Simulating step 590... Cautious: 5468 | Readthrough: 4532 | Inactive: 4
# Simulating step 600... Cautious: 5454 | Readthrough: 4546 | Inactive: 9
# Simulating step 610... Cautious: 5478 | Readthrough: 4522 | Inactive: 3
# Simulating step 620... Cautious: 5463 | Readthrough: 4537 | Inactive: 4
# Simulating step 630... Cautious: 5461 | Readthrough: 4539 | Inactive: 10
# Simulating step 640... Cautious: 5533 | Readthrough: 4467 | Inactive: 14
# Simulating step 650... Cautious: 5541 | Readthrough: 4459 | Inactive: 5
# Simulating step 660... Cautious: 5565 | Readthrough: 4435 | Inactive: 11
# Simulating step 670... Cautious: 5594 | Readthrough: 4406 | Inactive: 10
# Simulating step 680... Cautious: 5600 | Readthrough: 4400 | Inactive: 5
# Simulating step 690... Cautious: 5593 | Readthrough: 4407 | Inactive: 4
# Simulating step 700... Cautious: 5552 | Readthrough: 4448 | Inactive: 10
# Simulating step 710... Cautious: 5525 | Readthrough: 4475 | Inactive: 7
# Simulating step 720... Cautious: 5539 | Readthrough: 4461 | Inactive: 5
# Simulating step 730... Cautious: 5656 | Readthrough: 4344 | Inactive: 4
# Simulating step 740... Cautious: 5625 | Readthrough: 4375 | Inactive: 10
# Simulating step 750... Cautious: 5630 | Readthrough: 4370 | Inactive: 3
# Simulating step 760... Cautious: 5601 | Readthrough: 4399 | Inactive: 14
# Simulating step 770... Cautious: 5562 | Readthrough: 4438 | Inactive: 16
# Simulating step 780... Cautious: 5549 | Readthrough: 4451 | Inactive: 4
# Simulating step 790... Cautious: 5561 | Readthrough: 4439 | Inactive: 9
# Simulating step 800... Cautious: 5520 | Readthrough: 4480 | Inactive: 9
# Simulating step 810... Cautious: 5503 | Readthrough: 4497 | Inactive: 6
# Simulating step 820... Cautious: 5505 | Readthrough: 4495 | Inactive: 2
# Simulating step 830... Cautious: 5493 | Readthrough: 4507 | Inactive: 10
# Simulating step 840... Cautious: 5522 | Readthrough: 4478 | Inactive: 11
# Simulating step 850... Cautious: 5524 | Readthrough: 4476 | Inactive: 9
# Simulating step 860... Cautious: 5564 | Readthrough: 4436 | Inactive: 6
# Simulating step 870... Cautious: 5518 | Readthrough: 4482 | Inactive: 6
# Simulating step 880... Cautious: 5517 | Readthrough: 4483 | Inactive: 7
# Simulating step 890... Cautious: 5550 | Readthrough: 4450 | Inactive: 8
# Simulating step 900... Cautious: 5570 | Readthrough: 4430 | Inactive: 16
# Simulating step 910... Cautious: 5628 | Readthrough: 4372 | Inactive: 7
# Simulating step 920... Cautious: 5711 | Readthrough: 4289 | Inactive: 3
# Simulating step 930... Cautious: 5659 | Readthrough: 4341 | Inactive: 6
# Simulating step 940... Cautious: 5686 | Readthrough: 4314 | Inactive: 7
# Simulating step 950... Cautious: 5703 | Readthrough: 4297 | Inactive: 4
# Simulating step 960... Cautious: 5739 | Readthrough: 4261 | Inactive: 9
# Simulating step 970... Cautious: 5786 | Readthrough: 4214 | Inactive: 7
# Simulating step 980... Cautious: 5662 | Readthrough: 4338 | Inactive: 7
# Simulating step 990... Cautious: 5637 | Readthrough: 4363 | Inactive: 11
# Simulating step 1000... Cautious: 5661 | Readthrough: 4339 | Inactive: 9
# Simulating step 1010... Cautious: 5609 | Readthrough: 4391 | Inactive: 8
# Simulating step 1020... Cautious: 5573 | Readthrough: 4427 | Inactive: 8
# Simulating step 1030... Cautious: 5505 | Readthrough: 4495 | Inactive: 12
# Simulating step 1040... Cautious: 5496 | Readthrough: 4504 | Inactive: 14
# Simulating step 1050... Cautious: 5526 | Readthrough: 4474 | Inactive: 6
# Simulating step 1060... Cautious: 5557 | Readthrough: 4443 | Inactive: 16
# Simulating step 1070... Cautious: 5564 | Readthrough: 4436 | Inactive: 11
# Simulating step 1080... Cautious: 5542 | Readthrough: 4458 | Inactive: 4
# Simulating step 1090... Cautious: 5550 | Readthrough: 4450 | Inactive: 9
# Simulating step 1100... Cautious: 5610 | Readthrough: 4390 | Inactive: 18
# Simulating step 1110... Cautious: 5589 | Readthrough: 4411 | Inactive: 3
# Simulating step 1120... Cautious: 5586 | Readthrough: 4414 | Inactive: 13
# Simulating step 1130... Cautious: 5643 | Readthrough: 4357 | Inactive: 11
# Simulating step 1140... Cautious: 5615 | Readthrough: 4385 | Inactive: 8
# Simulating step 1150... Cautious: 5597 | Readthrough: 4403 | Inactive: 3
# Simulating step 1160... Cautious: 5643 | Readthrough: 4357 | Inactive: 15
# Simulating step 1170... Cautious: 5715 | Readthrough: 4285 | Inactive: 13
# Simulating step 1180... Cautious: 5688 | Readthrough: 4312 | Inactive: 6
# Simulating step 1190... Cautious: 5705 | Readthrough: 4295 | Inactive: 9
# Simulating step 1200... Cautious: 5724 | Readthrough: 4276 | Inactive: 8
# Simulating step 1210... Cautious: 5722 | Readthrough: 4278 | Inactive: 5
# Simulating step 1220... Cautious: 5771 | Readthrough: 4229 | Inactive: 2
# Simulating step 1230... Cautious: 5752 | Readthrough: 4248 | Inactive: 9
# Simulating step 1240... Cautious: 5823 | Readthrough: 4177 | Inactive: 5
# Simulating step 1250... Cautious: 5843 | Readthrough: 4157 | Inactive: 7
# Simulating step 1260... Cautious: 5929 | Readthrough: 4071 | Inactive: 9
# Simulating step 1270... Cautious: 5984 | Readthrough: 4016 | Inactive: 10
# Simulating step 1280... Cautious: 6048 | Readthrough: 3952 | Inactive: 6
# Simulating step 1290... Cautious: 6001 | Readthrough: 3999 | Inactive: 7
# Simulating step 1300... Cautious: 6014 | Readthrough: 3986 | Inactive: 6
# Simulating step 1310... Cautious: 6025 | Readthrough: 3975 | Inactive: 2
# Simulating step 1320... Cautious: 5971 | Readthrough: 4029 | Inactive: 9
# Simulating step 1330... Cautious: 5922 | Readthrough: 4078 | Inactive: 7
# Simulating step 1340... Cautious: 5836 | Readthrough: 4164 | Inactive: 4
# Simulating step 1350... Cautious: 5870 | Readthrough: 4130 | Inactive: 6
# Simulating step 1360... Cautious: 5781 | Readthrough: 4219 | Inactive: 8
# Simulating step 1370... Cautious: 5757 | Readthrough: 4243 | Inactive: 4
# Simulating step 1380... Cautious: 5771 | Readthrough: 4229 | Inactive: 5
# Simulating step 1390... Cautious: 5719 | Readthrough: 4281 | Inactive: 13
# Simulating step 1400... Cautious: 5735 | Readthrough: 4265 | Inactive: 12
# Simulating step 1410... Cautious: 5717 | Readthrough: 4283 | Inactive: 10
# Simulating step 1420... Cautious: 5658 | Readthrough: 4342 | Inactive: 10
# Simulating step 1430... Cautious: 5711 | Readthrough: 4289 | Inactive: 10
# Simulating step 1440... Cautious: 5636 | Readthrough: 4364 | Inactive: 6
# Simulating step 1450... Cautious: 5620 | Readthrough: 4380 | Inactive: 8
# Simulating step 1460... Cautious: 5676 | Readthrough: 4324 | Inactive: 7
# Simulating step 1470... Cautious: 5533 | Readthrough: 4467 | Inactive: 15
# Simulating step 1480... Cautious: 5496 | Readthrough: 4504 | Inactive: 3
# Simulating step 1490... Cautious: 5513 | Readthrough: 4487 | Inactive: 9
# Simulating step 1500... Cautious: 5523 | Readthrough: 4477 | Inactive: 6
# Simulating step 1510... Cautious: 5544 | Readthrough: 4456 | Inactive: 11
# Simulating step 1520... Cautious: 5569 | Readthrough: 4431 | Inactive: 5
# Simulating step 1530... Cautious: 5634 | Readthrough: 4366 | Inactive: 11
# Simulating step 1540... Cautious: 5656 | Readthrough: 4344 | Inactive: 8
# Simulating step 1550... Cautious: 5682 | Readthrough: 4318 | Inactive: 5
# Simulating step 1560... Cautious: 5674 | Readthrough: 4326 | Inactive: 7
# Simulating step 1570... Cautious: 5725 | Readthrough: 4275 | Inactive: 5
# Simulating step 1580... Cautious: 5710 | Readthrough: 4290 | Inactive: 11
# Simulating step 1590... Cautious: 5770 | Readthrough: 4230 | Inactive: 4
# Simulating step 1600... Cautious: 5792 | Readthrough: 4208 | Inactive: 8
# Simulating step 1610... Cautious: 5790 | Readthrough: 4210 | Inactive: 5
# Simulating step 1620... Cautious: 5841 | Readthrough: 4159 | Inactive: 6
# Simulating step 1630... Cautious: 5851 | Readthrough: 4149 | Inactive: 5
# Simulating step 1640... Cautious: 5882 | Readthrough: 4118 | Inactive: 4
# Simulating step 1650... Cautious: 5963 | Readthrough: 4037 | Inactive: 5
# Simulating step 1660... Cautious: 5941 | Readthrough: 4059 | Inactive: 4
# Simulating step 1670... Cautious: 5929 | Readthrough: 4071 | Inactive: 6
# Simulating step 1680... Cautious: 5925 | Readthrough: 4075 | Inactive: 4
# Simulating step 1690... Cautious: 5861 | Readthrough: 4139 | Inactive: 6
# Simulating step 1700... Cautious: 5872 | Readthrough: 4128 | Inactive: 5
# Simulating step 1710... Cautious: 5874 | Readthrough: 4126 | Inactive: 9
# Simulating step 1720... Cautious: 5798 | Readthrough: 4202 | Inactive: 2
# Simulating step 1730... Cautious: 5842 | Readthrough: 4158 | Inactive: 8
# Simulating step 1740... Cautious: 5858 | Readthrough: 4142 | Inactive: 6
# Simulating step 1750... Cautious: 5880 | Readthrough: 4120 | Inactive: 0
# Simulating step 1760... Cautious: 5856 | Readthrough: 4144 | Inactive: 7
# Simulating step 1770... Cautious: 5810 | Readthrough: 4190 | Inactive: 4
# Simulating step 1780... Cautious: 5813 | Readthrough: 4187 | Inactive: 4
# Simulating step 1790... Cautious: 5748 | Readthrough: 4252 | Inactive: 7
# Simulating step 1800... Cautious: 5717 | Readthrough: 4283 | Inactive: 8
# Simulating step 1810... Cautious: 5738 | Readthrough: 4262 | Inactive: 12
# Simulating step 1820... Cautious: 5717 | Readthrough: 4283 | Inactive: 4
# Simulating step 1830... Cautious: 5775 | Readthrough: 4225 | Inactive: 7
# Simulating step 1840... Cautious: 5845 | Readthrough: 4155 | Inactive: 3
# Simulating step 1850... Cautious: 5865 | Readthrough: 4135 | Inactive: 1
# Simulating step 1860... Cautious: 5851 | Readthrough: 4149 | Inactive: 4
# Simulating step 1870... Cautious: 5828 | Readthrough: 4172 | Inactive: 6
# Simulating step 1880... Cautious: 5806 | Readthrough: 4194 | Inactive: 5
# Simulating step 1890... Cautious: 5897 | Readthrough: 4103 | Inactive: 3
# Simulating step 1900... Cautious: 5842 | Readthrough: 4158 | Inactive: 3
# Simulating step 1910... Cautious: 5880 | Readthrough: 4120 | Inactive: 3
# Simulating step 1920... Cautious: 5823 | Readthrough: 4177 | Inactive: 6
# Simulating step 1930... Cautious: 5887 | Readthrough: 4113 | Inactive: 6
# Simulating step 1940... Cautious: 5916 | Readthrough: 4084 | Inactive: 2
# Simulating step 1950... Cautious: 5795 | Readthrough: 4205 | Inactive: 2
# Simulating step 1960... Cautious: 5789 | Readthrough: 4211 | Inactive: 4
# Simulating step 1970... Cautious: 5785 | Readthrough: 4215 | Inactive: 6
# Simulating step 1980... Cautious: 5732 | Readthrough: 4268 | Inactive: 4
# Simulating step 1990... Cautious: 5753 | Readthrough: 4247 | Inactive: 5
# Simulating step 2000... Cautious: 5666 | Readthrough: 4334 | Inactive: 6
# Simulating step 2010... Cautious: 5665 | Readthrough: 4335 | Inactive: 4
# Simulating step 2020... Cautious: 5732 | Readthrough: 4268 | Inactive: 3
# Simulating step 2030... Cautious: 5683 | Readthrough: 4317 | Inactive: 6
# Simulating step 2040... Cautious: 5611 | Readthrough: 4389 | Inactive: 7
# Simulating step 2050... Cautious: 5723 | Readthrough: 4277 | Inactive: 5
# Simulating step 2060... Cautious: 5816 | Readthrough: 4184 | Inactive: 4
# Simulating step 2070... Cautious: 5797 | Readthrough: 4203 | Inactive: 12
# Simulating step 2080... Cautious: 5806 | Readthrough: 4194 | Inactive: 2
# Simulating step 2090... Cautious: 5744 | Readthrough: 4256 | Inactive: 4
# Simulating step 2100... Cautious: 5761 | Readthrough: 4239 | Inactive: 4
# Simulating step 2110... Cautious: 5740 | Readthrough: 4260 | Inactive: 2
# Simulating step 2120... Cautious: 5747 | Readthrough: 4253 | Inactive: 2
# Simulating step 2130... Cautious: 5791 | Readthrough: 4209 | Inactive: 2
# Simulating step 2140... Cautious: 5778 | Readthrough: 4222 | Inactive: 2
# Simulating step 2150... Cautious: 5754 | Readthrough: 4246 | Inactive: 6
# Simulating step 2160... Cautious: 5724 | Readthrough: 4276 | Inactive: 5
# Simulating step 2170... Cautious: 5739 | Readthrough: 4261 | Inactive: 6
# Simulating step 2180... Cautious: 5790 | Readthrough: 4210 | Inactive: 4
# Simulating step 2190... Cautious: 5862 | Readthrough: 4138 | Inactive: 5
# Simulating step 2200... Cautious: 5897 | Readthrough: 4103 | Inactive: 11
# Simulating step 2210... Cautious: 5900 | Readthrough: 4100 | Inactive: 1
# Simulating step 2220... Cautious: 5851 | Readthrough: 4149 | Inactive: 0
# Simulating step 2230... Cautious: 5826 | Readthrough: 4174 | Inactive: 6
# Simulating step 2240... Cautious: 5764 | Readthrough: 4236 | Inactive: 4
# Simulating step 2250... Cautious: 5734 | Readthrough: 4266 | Inactive: 5
# Simulating step 2260... Cautious: 5749 | Readthrough: 4251 | Inactive: 3
# Simulating step 2270... Cautious: 5794 | Readthrough: 4206 | Inactive: 5
# Simulating step 2280... Cautious: 5754 | Readthrough: 4246 | Inactive: 1
# Simulating step 2290... Cautious: 5773 | Readthrough: 4227 | Inactive: 4
# Simulating step 2300... Cautious: 5849 | Readthrough: 4151 | Inactive: 4
# Simulating step 2310... Cautious: 5851 | Readthrough: 4149 | Inactive: 2
# Simulating step 2320... Cautious: 5768 | Readthrough: 4232 | Inactive: 6
# Simulating step 2330... Cautious: 5812 | Readthrough: 4188 | Inactive: 6
# Simulating step 2340... Cautious: 5808 | Readthrough: 4192 | Inactive: 1
# Simulating step 2350... Cautious: 5817 | Readthrough: 4183 | Inactive: 3
# Simulating step 2360... Cautious: 5771 | Readthrough: 4229 | Inactive: 5
# Simulating step 2370... Cautious: 5797 | Readthrough: 4203 | Inactive: 5
# Simulating step 2380... Cautious: 5756 | Readthrough: 4244 | Inactive: 5
# Simulating step 2390... Cautious: 5689 | Readthrough: 4311 | Inactive: 6
# Simulating step 2400... Cautious: 5674 | Readthrough: 4326 | Inactive: 7
# Simulating step 2410... Cautious: 5698 | Readthrough: 4302 | Inactive: 3
# Simulating step 2420... Cautious: 5642 | Readthrough: 4358 | Inactive: 2
# Simulating step 2430... Cautious: 5668 | Readthrough: 4332 | Inactive: 2
# Simulating step 2440... Cautious: 5721 | Readthrough: 4279 | Inactive: 7
# Simulating step 2450... Cautious: 5707 | Readthrough: 4293 | Inactive: 1
# Simulating step 2460... Cautious: 5752 | Readthrough: 4248 | Inactive: 5
# Simulating step 2470... Cautious: 5765 | Readthrough: 4235 | Inactive: 3
# Simulating step 2480... Cautious: 5745 | Readthrough: 4255 | Inactive: 5
# Simulating step 2490... Cautious: 5738 | Readthrough: 4262 | Inactive: 6
# Simulating step 2500... Cautious: 5690 | Readthrough: 4310 | Inactive: 5
# Simulating step 2510... Cautious: 5703 | Readthrough: 4297 | Inactive: 3
# Simulating step 2520... Cautious: 5679 | Readthrough: 4321 | Inactive: 5
# Simulating step 2530... Cautious: 5570 | Readthrough: 4430 | Inactive: 4
# Simulating step 2540... Cautious: 5557 | Readthrough: 4443 | Inactive: 1
# Simulating step 2550... Cautious: 5567 | Readthrough: 4433 | Inactive: 5
# Simulating step 2560... Cautious: 5598 | Readthrough: 4402 | Inactive: 5
# Simulating step 2570... Cautious: 5627 | Readthrough: 4373 | Inactive: 7
# Simulating step 2580... Cautious: 5636 | Readthrough: 4364 | Inactive: 2
# Simulating step 2590... Cautious: 5670 | Readthrough: 4330 | Inactive: 3
# Simulating step 2600... Cautious: 5717 | Readthrough: 4283 | Inactive: 3
# Simulating step 2610... Cautious: 5757 | Readthrough: 4243 | Inactive: 4
# Simulating step 2620... Cautious: 5829 | Readthrough: 4171 | Inactive: 5
# Simulating step 2630... Cautious: 5767 | Readthrough: 4233 | Inactive: 1
# Simulating step 2640... Cautious: 5744 | Readthrough: 4256 | Inactive: 4
# Simulating step 2650... Cautious: 5712 | Readthrough: 4288 | Inactive: 1
# Simulating step 2660... Cautious: 5746 | Readthrough: 4254 | Inactive: 3
# Simulating step 2670... Cautious: 5768 | Readthrough: 4232 | Inactive: 2
# Simulating step 2680... Cautious: 5756 | Readthrough: 4244 | Inactive: 2
# Simulating step 2690... Cautious: 5739 | Readthrough: 4261 | Inactive: 6
# Simulating step 2700... Cautious: 5759 | Readthrough: 4241 | Inactive: 4
# Simulating step 2710... Cautious: 5775 | Readthrough: 4225 | Inactive: 3
# Simulating step 2720... Cautious: 5722 | Readthrough: 4278 | Inactive: 0
# Simulating step 2730... Cautious: 5722 | Readthrough: 4278 | Inactive: 10
# Simulating step 2740... Cautious: 5706 | Readthrough: 4294 | Inactive: 7
# Simulating step 2750... Cautious: 5720 | Readthrough: 4280 | Inactive: 5
# Simulating step 2760... Cautious: 5705 | Readthrough: 4295 | Inactive: 4
# Simulating step 2770... Cautious: 5654 | Readthrough: 4346 | Inactive: 4
# Simulating step 2780... Cautious: 5702 | Readthrough: 4298 | Inactive: 1
# Simulating step 2790... Cautious: 5784 | Readthrough: 4216 | Inactive: 5
# Simulating step 2800... Cautious: 5774 | Readthrough: 4226 | Inactive: 8
# Simulating step 2810... Cautious: 5773 | Readthrough: 4227 | Inactive: 4
# Simulating step 2820... Cautious: 5774 | Readthrough: 4226 | Inactive: 4
# Simulating step 2830... Cautious: 5739 | Readthrough: 4261 | Inactive: 4
# Simulating step 2840... Cautious: 5772 | Readthrough: 4228 | Inactive: 5
# Simulating step 2850... Cautious: 5682 | Readthrough: 4318 | Inactive: 4
# Simulating step 2860... Cautious: 5710 | Readthrough: 4290 | Inactive: 4
# Simulating step 2870... Cautious: 5678 | Readthrough: 4322 | Inactive: 3
# Simulating step 2880... Cautious: 5699 | Readthrough: 4301 | Inactive: 3
# Simulating step 2890... Cautious: 5737 | Readthrough: 4263 | Inactive: 6
# Simulating step 2900... Cautious: 5771 | Readthrough: 4229 | Inactive: 5
# Simulating step 2910... Cautious: 5830 | Readthrough: 4170 | Inactive: 4
# Simulating step 2920... Cautious: 5863 | Readthrough: 4137 | Inactive: 9
# Simulating step 2930... Cautious: 5883 | Readthrough: 4117 | Inactive: 5
# Simulating step 2940... Cautious: 5857 | Readthrough: 4143 | Inactive: 1
# Simulating step 2950... Cautious: 5856 | Readthrough: 4144 | Inactive: 3
# Simulating step 2960... Cautious: 5901 | Readthrough: 4099 | Inactive: 7
# Simulating step 2970... Cautious: 5916 | Readthrough: 4084 | Inactive: 4
# Simulating step 2980... Cautious: 5910 | Readthrough: 4090 | Inactive: 4
# Simulating step 2990... Cautious: 5924 | Readthrough: 4076 | Inactive: 5
# Simulating step 3000... Cautious: 5944 | Readthrough: 4056 | Inactive: 4
# Simulating step 3010... Cautious: 5949 | Readthrough: 4051 | Inactive: 1
# Simulating step 3020... Cautious: 5914 | Readthrough: 4086 | Inactive: 6
# Simulating step 3030... Cautious: 5906 | Readthrough: 4094 | Inactive: 3
# Simulating step 3040... Cautious: 5897 | Readthrough: 4103 | Inactive: 3
# Simulating step 3050... Cautious: 5860 | Readthrough: 4140 | Inactive: 3
# Simulating step 3060... Cautious: 5852 | Readthrough: 4148 | Inactive: 5
# Simulating step 3070... Cautious: 5868 | Readthrough: 4132 | Inactive: 4
# Simulating step 3080... Cautious: 5876 | Readthrough: 4124 | Inactive: 1
# Simulating step 3090... Cautious: 5833 | Readthrough: 4167 | Inactive: 1
# Simulating step 3100... Cautious: 5883 | Readthrough: 4117 | Inactive: 5
# Simulating step 3110... Cautious: 5856 | Readthrough: 4144 | Inactive: 3
# Simulating step 3120... Cautious: 5810 | Readthrough: 4190 | Inactive: 4
# Simulating step 3130... Cautious: 5820 | Readthrough: 4180 | Inactive: 5
# Simulating step 3140... Cautious: 5848 | Readthrough: 4152 | Inactive: 2
# Simulating step 3150... Cautious: 5976 | Readthrough: 4024 | Inactive: 3
# Simulating step 3160... Cautious: 5908 | Readthrough: 4092 | Inactive: 3
# Simulating step 3170... Cautious: 5920 | Readthrough: 4080 | Inactive: 3
# Simulating step 3180... Cautious: 5860 | Readthrough: 4140 | Inactive: 1
# Simulating step 3190... Cautious: 5853 | Readthrough: 4147 | Inactive: 4
# Simulating step 3200... Cautious: 5841 | Readthrough: 4159 | Inactive: 6
# Simulating step 3210... Cautious: 5828 | Readthrough: 4172 | Inactive: 1
# Simulating step 3220... Cautious: 5856 | Readthrough: 4144 | Inactive: 5
# Simulating step 3230... Cautious: 5866 | Readthrough: 4134 | Inactive: 3
# Simulating step 3240... Cautious: 5864 | Readthrough: 4136 | Inactive: 3
# Simulating step 3250... Cautious: 5724 | Readthrough: 4276 | Inactive: 4
# Simulating step 3260... Cautious: 5840 | Readthrough: 4160 | Inactive: 7
# Simulating step 3270... Cautious: 5846 | Readthrough: 4154 | Inactive: 1
# Simulating step 3280... Cautious: 5820 | Readthrough: 4180 | Inactive: 4
# Simulating step 3290... Cautious: 5849 | Readthrough: 4151 | Inactive: 1
# Simulating step 3300... Cautious: 5974 | Readthrough: 4026 | Inactive: 2
# Simulating step 3310... Cautious: 5909 | Readthrough: 4091 | Inactive: 7
# Simulating step 3320... Cautious: 5884 | Readthrough: 4116 | Inactive: 4
# Simulating step 3330... Cautious: 5874 | Readthrough: 4126 | Inactive: 6
# Simulating step 3340... Cautious: 5926 | Readthrough: 4074 | Inactive: 3
# Simulating step 3350... Cautious: 5797 | Readthrough: 4203 | Inactive: 7
# Simulating step 3360... Cautious: 5921 | Readthrough: 4079 | Inactive: 4
# Simulating step 3370... Cautious: 5959 | Readthrough: 4041 | Inactive: 5
# Simulating step 3380... Cautious: 5934 | Readthrough: 4066 | Inactive: 1
# Simulating step 3390... Cautious: 5978 | Readthrough: 4022 | Inactive: 2
# Simulating step 3400... Cautious: 5930 | Readthrough: 4070 | Inactive: 6
# Simulating step 3410... Cautious: 5958 | Readthrough: 4042 | Inactive: 5
# Simulating step 3420... Cautious: 5960 | Readthrough: 4040 | Inactive: 10
# Simulating step 3430... Cautious: 5945 | Readthrough: 4055 | Inactive: 3
# Simulating step 3440... Cautious: 5938 | Readthrough: 4062 | Inactive: 3
# Simulating step 3450... Cautious: 5916 | Readthrough: 4084 | Inactive: 4
# Simulating step 3460... Cautious: 5889 | Readthrough: 4111 | Inactive: 3
# Simulating step 3470... Cautious: 5918 | Readthrough: 4082 | Inactive: 2
# Simulating step 3480... Cautious: 5993 | Readthrough: 4007 | Inactive: 3
# Simulating step 3490... Cautious: 5969 | Readthrough: 4031 | Inactive: 3
# Simulating step 3500... Cautious: 5990 | Readthrough: 4010 | Inactive: 4
# Simulating step 3510... Cautious: 5985 | Readthrough: 4015 | Inactive: 3
# Simulating step 3520... Cautious: 5990 | Readthrough: 4010 | Inactive: 6
# Simulating step 3530... Cautious: 6012 | Readthrough: 3988 | Inactive: 3
# Simulating step 3540... Cautious: 6076 | Readthrough: 3924 | Inactive: 2
# Simulating step 3550... Cautious: 6095 | Readthrough: 3905 | Inactive: 4
# Simulating step 3560... Cautious: 6190 | Readthrough: 3810 | Inactive: 4
# Simulating step 3570... Cautious: 6223 | Readthrough: 3777 | Inactive: 2
# Simulating step 3580... Cautious: 6138 | Readthrough: 3862 | Inactive: 2
# Simulating step 3590... Cautious: 6199 | Readthrough: 3801 | Inactive: 5
# Simulating step 3600... Cautious: 6123 | Readthrough: 3877 | Inactive: 6
# Simulating step 3610... Cautious: 6121 | Readthrough: 3879 | Inactive: 2
# Simulating step 3620... Cautious: 6103 | Readthrough: 3897 | Inactive: 6
# Simulating step 3630... Cautious: 6039 | Readthrough: 3961 | Inactive: 4
# Simulating step 3640... Cautious: 5995 | Readthrough: 4005 | Inactive: 4
# Simulating step 3650... Cautious: 6086 | Readthrough: 3914 | Inactive: 5
# Simulating step 3660... Cautious: 6004 | Readthrough: 3996 | Inactive: 7
# Simulating step 3670... Cautious: 5985 | Readthrough: 4015 | Inactive: 1
# Simulating step 3680... Cautious: 6014 | Readthrough: 3986 | Inactive: 1
# Simulating step 3690... Cautious: 5948 | Readthrough: 4052 | Inactive: 2
# Simulating step 3700... Cautious: 5964 | Readthrough: 4036 | Inactive: 4
# Simulating step 3710... Cautious: 5995 | Readthrough: 4005 | Inactive: 2
# Simulating step 3720... Cautious: 6001 | Readthrough: 3999 | Inactive: 4
# Simulating step 3730... Cautious: 5953 | Readthrough: 4047 | Inactive: 7
# Simulating step 3740... Cautious: 5971 | Readthrough: 4029 | Inactive: 2
# Simulating step 3750... Cautious: 6004 | Readthrough: 3996 | Inactive: 6
# Simulating step 3760... Cautious: 5992 | Readthrough: 4008 | Inactive: 6
# Simulating step 3770... Cautious: 5978 | Readthrough: 4022 | Inactive: 1
# Simulating step 3780... Cautious: 6017 | Readthrough: 3983 | Inactive: 4
# Simulating step 3790... Cautious: 6035 | Readthrough: 3965 | Inactive: 8
# Simulating step 3800... Cautious: 5992 | Readthrough: 4008 | Inactive: 9
# Simulating step 3810... Cautious: 6007 | Readthrough: 3993 | Inactive: 3
# Simulating step 3820... Cautious: 6081 | Readthrough: 3919 | Inactive: 4
# Simulating step 3830... Cautious: 6095 | Readthrough: 3905 | Inactive: 3
# Simulating step 3840... Cautious: 6097 | Readthrough: 3903 | Inactive: 5
# Simulating step 3850... Cautious: 6070 | Readthrough: 3930 | Inactive: 6
# Simulating step 3860... Cautious: 6024 | Readthrough: 3976 | Inactive: 1
# Simulating step 3870... Cautious: 6040 | Readthrough: 3960 | Inactive: 7
# Simulating step 3880... Cautious: 6126 | Readthrough: 3874 | Inactive: 5
# Simulating step 3890... Cautious: 6120 | Readthrough: 3880 | Inactive: 8
# Simulating step 3900... Cautious: 6046 | Readthrough: 3954 | Inactive: 5
# Simulating step 3910... Cautious: 6068 | Readthrough: 3932 | Inactive: 6
# Simulating step 3920... Cautious: 6008 | Readthrough: 3992 | Inactive: 3
# Simulating step 3930... Cautious: 6051 | Readthrough: 3949 | Inactive: 3
# Simulating step 3940... Cautious: 6044 | Readthrough: 3956 | Inactive: 3
# Simulating step 3950... Cautious: 5961 | Readthrough: 4039 | Inactive: 9
# Simulating step 3960... Cautious: 5971 | Readthrough: 4029 | Inactive: 3
# Simulating step 3970... Cautious: 6008 | Readthrough: 3992 | Inactive: 6
# Simulating step 3980... Cautious: 6041 | Readthrough: 3959 | Inactive: 3
# Simulating step 3990... Cautious: 5996 | Readthrough: 4004 | Inactive: 11
# Simulating step 4000... Cautious: 6010 | Readthrough: 3990 | Inactive: 3
# Simulating step 4010... Cautious: 5980 | Readthrough: 4020 | Inactive: 2
# Simulating step 4020... Cautious: 6021 | Readthrough: 3979 | Inactive: 5
# Simulating step 4030... Cautious: 6056 | Readthrough: 3944 | Inactive: 5
# Simulating step 4040... Cautious: 6032 | Readthrough: 3968 | Inactive: 1
# Simulating step 4050... Cautious: 6033 | Readthrough: 3967 | Inactive: 3
# Simulating step 4060... Cautious: 5954 | Readthrough: 4046 | Inactive: 4
# Simulating step 4070... Cautious: 5960 | Readthrough: 4040 | Inactive: 4
# Simulating step 4080... Cautious: 5958 | Readthrough: 4042 | Inactive: 4
# Simulating step 4090... Cautious: 6035 | Readthrough: 3965 | Inactive: 11
# Simulating step 4100... Cautious: 6018 | Readthrough: 3982 | Inactive: 7
# Simulating step 4110... Cautious: 6006 | Readthrough: 3994 | Inactive: 5
# Simulating step 4120... Cautious: 6026 | Readthrough: 3974 | Inactive: 5
# Simulating step 4130... Cautious: 5935 | Readthrough: 4065 | Inactive: 14
# Simulating step 4140... Cautious: 5914 | Readthrough: 4086 | Inactive: 5
# Simulating step 4150... Cautious: 5896 | Readthrough: 4104 | Inactive: 6
# Simulating step 4160... Cautious: 5913 | Readthrough: 4087 | Inactive: 9
# Simulating step 4170... Cautious: 5940 | Readthrough: 4060 | Inactive: 6
# Simulating step 4180... Cautious: 5960 | Readthrough: 4040 | Inactive: 7
# Simulating step 4190... Cautious: 6020 | Readthrough: 3980 | Inactive: 8
# Simulating step 4200... Cautious: 6056 | Readthrough: 3944 | Inactive: 6
# Simulating step 4210... Cautious: 6103 | Readthrough: 3897 | Inactive: 9
# Simulating step 4220... Cautious: 6096 | Readthrough: 3904 | Inactive: 4
# Simulating step 4230... Cautious: 6048 | Readthrough: 3952 | Inactive: 11
# Simulating step 4240... Cautious: 5996 | Readthrough: 4004 | Inactive: 5
# Simulating step 4250... Cautious: 5986 | Readthrough: 4014 | Inactive: 2
# Simulating step 4260... Cautious: 6013 | Readthrough: 3987 | Inactive: 10
# Simulating step 4270... Cautious: 5996 | Readthrough: 4004 | Inactive: 8
# Simulating step 4280... Cautious: 6107 | Readthrough: 3893 | Inactive: 6
# Simulating step 4290... Cautious: 6080 | Readthrough: 3920 | Inactive: 8
# Simulating step 4300... Cautious: 6165 | Readthrough: 3835 | Inactive: 3
# Simulating step 4310... Cautious: 6229 | Readthrough: 3771 | Inactive: 4
# Simulating step 4320... Cautious: 6237 | Readthrough: 3763 | Inactive: 8
# Simulating step 4330... Cautious: 6263 | Readthrough: 3737 | Inactive: 9
# Simulating step 4340... Cautious: 6241 | Readthrough: 3759 | Inactive: 5
# Simulating step 4350... Cautious: 6298 | Readthrough: 3702 | Inactive: 6
# Simulating step 4360... Cautious: 6265 | Readthrough: 3735 | Inactive: 5
# Simulating step 4370... Cautious: 6244 | Readthrough: 3756 | Inactive: 5
# Simulating step 4380... Cautious: 6302 | Readthrough: 3698 | Inactive: 3
# Simulating step 4390... Cautious: 6330 | Readthrough: 3670 | Inactive: 8
# Simulating step 4400... Cautious: 6311 | Readthrough: 3689 | Inactive: 2
# Simulating step 4410... Cautious: 6360 | Readthrough: 3640 | Inactive: 4
# Simulating step 4420... Cautious: 6389 | Readthrough: 3611 | Inactive: 7
# Simulating step 4430... Cautious: 6401 | Readthrough: 3599 | Inactive: 6
# Simulating step 4440... Cautious: 6381 | Readthrough: 3619 | Inactive: 8
# Simulating step 4450... Cautious: 6405 | Readthrough: 3595 | Inactive: 7
# Simulating step 4460... Cautious: 6361 | Readthrough: 3639 | Inactive: 13
# Simulating step 4470... Cautious: 6349 | Readthrough: 3651 | Inactive: 5
# Simulating step 4480... Cautious: 6382 | Readthrough: 3618 | Inactive: 9
# Simulating step 4490... Cautious: 6401 | Readthrough: 3599 | Inactive: 8
# Simulating step 4500... Cautious: 6468 | Readthrough: 3532 | Inactive: 9
# Simulating step 4510... Cautious: 6436 | Readthrough: 3564 | Inactive: 2
# Simulating step 4520... Cautious: 6379 | Readthrough: 3621 | Inactive: 11
# Simulating step 4530... Cautious: 6354 | Readthrough: 3646 | Inactive: 9
# Simulating step 4540... Cautious: 6362 | Readthrough: 3638 | Inactive: 7
# Simulating step 4550... Cautious: 6468 | Readthrough: 3532 | Inactive: 8
# Simulating step 4560... Cautious: 6543 | Readthrough: 3457 | Inactive: 7
# Simulating step 4570... Cautious: 6526 | Readthrough: 3474 | Inactive: 8
# Simulating step 4580... Cautious: 6595 | Readthrough: 3405 | Inactive: 6
# Simulating step 4590... Cautious: 6587 | Readthrough: 3413 | Inactive: 12
# Simulating step 4600... Cautious: 6605 | Readthrough: 3395 | Inactive: 8
# Simulating step 4610... Cautious: 6625 | Readthrough: 3375 | Inactive: 5
# Simulating step 4620... Cautious: 6667 | Readthrough: 3333 | Inactive: 7
# Simulating step 4630... Cautious: 6629 | Readthrough: 3371 | Inactive: 10
# Simulating step 4640... Cautious: 6660 | Readthrough: 3340 | Inactive: 3
# Simulating step 4650... Cautious: 6619 | Readthrough: 3381 | Inactive: 7
# Simulating step 4660... Cautious: 6596 | Readthrough: 3404 | Inactive: 6
# Simulating step 4670... Cautious: 6606 | Readthrough: 3394 | Inactive: 10
# Simulating step 4680... Cautious: 6581 | Readthrough: 3419 | Inactive: 3
# Simulating step 4690... Cautious: 6549 | Readthrough: 3451 | Inactive: 5
# Simulating step 4700... Cautious: 6579 | Readthrough: 3421 | Inactive: 7
# Simulating step 4710... Cautious: 6612 | Readthrough: 3388 | Inactive: 1
# Simulating step 4720... Cautious: 6669 | Readthrough: 3331 | Inactive: 6
# Simulating step 4730... Cautious: 6728 | Readthrough: 3272 | Inactive: 5
# Simulating step 4740... Cautious: 6743 | Readthrough: 3257 | Inactive: 5
# Simulating step 4750... Cautious: 6843 | Readthrough: 3157 | Inactive: 4
# Simulating step 4760... Cautious: 6847 | Readthrough: 3153 | Inactive: 8
# Simulating step 4770... Cautious: 6787 | Readthrough: 3213 | Inactive: 1
# Simulating step 4780... Cautious: 6765 | Readthrough: 3235 | Inactive: 5
# Simulating step 4790... Cautious: 6753 | Readthrough: 3247 | Inactive: 7
# Simulating step 4800... Cautious: 6760 | Readthrough: 3240 | Inactive: 7
# Simulating step 4810... Cautious: 6799 | Readthrough: 3201 | Inactive: 8
# Simulating step 4820... Cautious: 6817 | Readthrough: 3183 | Inactive: 4
# Simulating step 4830... Cautious: 6874 | Readthrough: 3126 | Inactive: 2
# Simulating step 4840... Cautious: 6923 | Readthrough: 3077 | Inactive: 7
# Simulating step 4850... Cautious: 6932 | Readthrough: 3068 | Inactive: 9
# Simulating step 4860... Cautious: 6962 | Readthrough: 3038 | Inactive: 5
# Simulating step 4870... Cautious: 6939 | Readthrough: 3061 | Inactive: 3
# Simulating step 4880... Cautious: 6974 | Readthrough: 3026 | Inactive: 7
# Simulating step 4890... Cautious: 7064 | Readthrough: 2936 | Inactive: 9
# Simulating step 4900... Cautious: 7056 | Readthrough: 2944 | Inactive: 8
# Simulating step 4910... Cautious: 7049 | Readthrough: 2951 | Inactive: 2
# Simulating step 4920... Cautious: 7072 | Readthrough: 2928 | Inactive: 3
# Simulating step 4930... Cautious: 7045 | Readthrough: 2955 | Inactive: 17
# Simulating step 4940... Cautious: 7080 | Readthrough: 2920 | Inactive: 4
# Simulating step 4950... Cautious: 7117 | Readthrough: 2883 | Inactive: 7
# Simulating step 4960... Cautious: 7072 | Readthrough: 2928 | Inactive: 5
# Simulating step 4970... Cautious: 7066 | Readthrough: 2934 | Inactive: 3
# Simulating step 4980... Cautious: 7056 | Readthrough: 2944 | Inactive: 3
# Simulating step 4990... Cautious: 7076 | Readthrough: 2924 | Inactive: 3
# Simulating step 5000... Cautious: 7085 | Readthrough: 2915 | Inactive: 8
# Simulating step 5010... Cautious: 7122 | Readthrough: 2878 | Inactive: 1
# Simulating step 5020... Cautious: 7230 | Readthrough: 2770 | Inactive: 9
# Simulating step 5030... Cautious: 7219 | Readthrough: 2781 | Inactive: 0
# Simulating step 5040... Cautious: 7222 | Readthrough: 2778 | Inactive: 2
# Simulating step 5050... Cautious: 7245 | Readthrough: 2755 | Inactive: 6
# Simulating step 5060... Cautious: 7287 | Readthrough: 2713 | Inactive: 8
# Simulating step 5070... Cautious: 7311 | Readthrough: 2689 | Inactive: 4
# Simulating step 5080... Cautious: 7416 | Readthrough: 2584 | Inactive: 7
# Simulating step 5090... Cautious: 7371 | Readthrough: 2629 | Inactive: 2
# Simulating step 5100... Cautious: 7315 | Readthrough: 2685 | Inactive: 0
# Simulating step 5110... Cautious: 7360 | Readthrough: 2640 | Inactive: 1
# Simulating step 5120... Cautious: 7388 | Readthrough: 2612 | Inactive: 3
# Simulating step 5130... Cautious: 7374 | Readthrough: 2626 | Inactive: 4
# Simulating step 5140... Cautious: 7351 | Readthrough: 2649 | Inactive: 3
# Simulating step 5150... Cautious: 7362 | Readthrough: 2638 | Inactive: 2
# Simulating step 5160... Cautious: 7342 | Readthrough: 2658 | Inactive: 4
# Simulating step 5170... Cautious: 7364 | Readthrough: 2636 | Inactive: 4
# Simulating step 5180... Cautious: 7385 | Readthrough: 2615 | Inactive: 4
# Simulating step 5190... Cautious: 7359 | Readthrough: 2641 | Inactive: 2
# Simulating step 5200... Cautious: 7316 | Readthrough: 2684 | Inactive: 5
# Simulating step 5210... Cautious: 7312 | Readthrough: 2688 | Inactive: 4
# Simulating step 5220... Cautious: 7369 | Readthrough: 2631 | Inactive: 5
# Simulating step 5230... Cautious: 7416 | Readthrough: 2584 | Inactive: 3
# Simulating step 5240... Cautious: 7434 | Readthrough: 2566 | Inactive: 6
# Simulating step 5250... Cautious: 7408 | Readthrough: 2592 | Inactive: 4
# Simulating step 5260... Cautious: 7403 | Readthrough: 2597 | Inactive: 4
# Simulating step 5270... Cautious: 7431 | Readthrough: 2569 | Inactive: 3
# Simulating step 5280... Cautious: 7463 | Readthrough: 2537 | Inactive: 7
# Simulating step 5290... Cautious: 7424 | Readthrough: 2576 | Inactive: 3
# Simulating step 5300... Cautious: 7411 | Readthrough: 2589 | Inactive: 7
# Simulating step 5310... Cautious: 7392 | Readthrough: 2608 | Inactive: 4
# Simulating step 5320... Cautious: 7375 | Readthrough: 2625 | Inactive: 6
# Simulating step 5330... Cautious: 7302 | Readthrough: 2698 | Inactive: 2
# Simulating step 5340... Cautious: 7299 | Readthrough: 2701 | Inactive: 3
# Simulating step 5350... Cautious: 7251 | Readthrough: 2749 | Inactive: 1
# Simulating step 5360... Cautious: 7187 | Readthrough: 2813 | Inactive: 2
# Simulating step 5370... Cautious: 7200 | Readthrough: 2800 | Inactive: 2
# Simulating step 5380... Cautious: 7188 | Readthrough: 2812 | Inactive: 3
# Simulating step 5390... Cautious: 7237 | Readthrough: 2763 | Inactive: 6
# Simulating step 5400... Cautious: 7246 | Readthrough: 2754 | Inactive: 2
# Simulating step 5410... Cautious: 7317 | Readthrough: 2683 | Inactive: 5
# Simulating step 5420... Cautious: 7269 | Readthrough: 2731 | Inactive: 7
# Simulating step 5430... Cautious: 7277 | Readthrough: 2723 | Inactive: 1
# Simulating step 5440... Cautious: 7268 | Readthrough: 2732 | Inactive: 2
# Simulating step 5450... Cautious: 7193 | Readthrough: 2807 | Inactive: 4
# Simulating step 5460... Cautious: 7220 | Readthrough: 2780 | Inactive: 1
# Simulating step 5470... Cautious: 7207 | Readthrough: 2793 | Inactive: 3
# Simulating step 5480... Cautious: 7119 | Readthrough: 2881 | Inactive: 4
# Simulating step 5490... Cautious: 7077 | Readthrough: 2923 | Inactive: 2
# Simulating step 5500... Cautious: 7069 | Readthrough: 2931 | Inactive: 0
# Simulating step 5510... Cautious: 7088 | Readthrough: 2912 | Inactive: 1
# Simulating step 5520... Cautious: 7130 | Readthrough: 2870 | Inactive: 7
# Simulating step 5530... Cautious: 7083 | Readthrough: 2917 | Inactive: 3
# Simulating step 5540... Cautious: 7033 | Readthrough: 2967 | Inactive: 3
# Simulating step 5550... Cautious: 6985 | Readthrough: 3015 | Inactive: 1
# Simulating step 5560... Cautious: 6951 | Readthrough: 3049 | Inactive: 3
# Simulating step 5570... Cautious: 7002 | Readthrough: 2998 | Inactive: 4
# Simulating step 5580... Cautious: 7060 | Readthrough: 2940 | Inactive: 2
# Simulating step 5590... Cautious: 7075 | Readthrough: 2925 | Inactive: 1
# Simulating step 5600... Cautious: 7096 | Readthrough: 2904 | Inactive: 1
# Simulating step 5610... Cautious: 7124 | Readthrough: 2876 | Inactive: 0
# Simulating step 5620... Cautious: 7088 | Readthrough: 2912 | Inactive: 4
# Simulating step 5630... Cautious: 7130 | Readthrough: 2870 | Inactive: 2
# Simulating step 5640... Cautious: 7109 | Readthrough: 2891 | Inactive: 4
# Simulating step 5650... Cautious: 7151 | Readthrough: 2849 | Inactive: 2
# Simulating step 5660... Cautious: 7131 | Readthrough: 2869 | Inactive: 4
# Simulating step 5670... Cautious: 7122 | Readthrough: 2878 | Inactive: 1
# Simulating step 5680... Cautious: 7087 | Readthrough: 2913 | Inactive: 3
# Simulating step 5690... Cautious: 7124 | Readthrough: 2876 | Inactive: 2
# Simulating step 5700... Cautious: 7098 | Readthrough: 2902 | Inactive: 1
# Simulating step 5710... Cautious: 7069 | Readthrough: 2931 | Inactive: 1
# Simulating step 5720... Cautious: 6999 | Readthrough: 3001 | Inactive: 1
# Simulating step 5730... Cautious: 7021 | Readthrough: 2979 | Inactive: 4
# Simulating step 5740... Cautious: 7030 | Readthrough: 2970 | Inactive: 2
# Simulating step 5750... Cautious: 7047 | Readthrough: 2953 | Inactive: 3
# Simulating step 5760... Cautious: 7085 | Readthrough: 2915 | Inactive: 3
# Simulating step 5770... Cautious: 7113 | Readthrough: 2887 | Inactive: 3
# Simulating step 5780... Cautious: 7057 | Readthrough: 2943 | Inactive: 3
# Simulating step 5790... Cautious: 7064 | Readthrough: 2936 | Inactive: 2
# Simulating step 5800... Cautious: 7028 | Readthrough: 2972 | Inactive: 0
# Simulating step 5810... Cautious: 7013 | Readthrough: 2987 | Inactive: 3
# Simulating step 5820... Cautious: 7011 | Readthrough: 2989 | Inactive: 2
# Simulating step 5830... Cautious: 7041 | Readthrough: 2959 | Inactive: 1
# Simulating step 5840... Cautious: 7151 | Readthrough: 2849 | Inactive: 2
# Simulating step 5850... Cautious: 7167 | Readthrough: 2833 | Inactive: 5
# Simulating step 5860... Cautious: 7170 | Readthrough: 2830 | Inactive: 4
# Simulating step 5870... Cautious: 7161 | Readthrough: 2839 | Inactive: 1
# Simulating step 5880... Cautious: 7173 | Readthrough: 2827 | Inactive: 2
# Simulating step 5890... Cautious: 7102 | Readthrough: 2898 | Inactive: 2
# Simulating step 5900... Cautious: 7083 | Readthrough: 2917 | Inactive: 5
# Simulating step 5910... Cautious: 7079 | Readthrough: 2921 | Inactive: 0
# Simulating step 5920... Cautious: 7130 | Readthrough: 2870 | Inactive: 3
# Simulating step 5930... Cautious: 7151 | Readthrough: 2849 | Inactive: 1
# Simulating step 5940... Cautious: 7126 | Readthrough: 2874 | Inactive: 2
# Simulating step 5950... Cautious: 7104 | Readthrough: 2896 | Inactive: 1
# Simulating step 5960... Cautious: 7023 | Readthrough: 2977 | Inactive: 2
# Simulating step 5970... Cautious: 7048 | Readthrough: 2952 | Inactive: 1
# Simulating step 5980... Cautious: 7094 | Readthrough: 2906 | Inactive: 3
# Simulating step 5990... Cautious: 7091 | Readthrough: 2909 | Inactive: 3
# Simulating step 6000... Cautious: 7121 | Readthrough: 2879 | Inactive: 1
# Simulating step 6010... Cautious: 7138 | Readthrough: 2862 | Inactive: 0
# Simulating step 6020... Cautious: 7120 | Readthrough: 2880 | Inactive: 3
# Simulating step 6030... Cautious: 7170 | Readthrough: 2830 | Inactive: 1
# Simulating step 6040... Cautious: 7064 | Readthrough: 2936 | Inactive: 2
# Simulating step 6050... Cautious: 7071 | Readthrough: 2929 | Inactive: 2
# Simulating step 6060... Cautious: 7137 | Readthrough: 2863 | Inactive: 3
# Simulating step 6070... Cautious: 7113 | Readthrough: 2887 | Inactive: 0
# Simulating step 6080... Cautious: 7072 | Readthrough: 2928 | Inactive: 2
# Simulating step 6090... Cautious: 7083 | Readthrough: 2917 | Inactive: 2
# Simulating step 6100... Cautious: 7144 | Readthrough: 2856 | Inactive: 2
# Simulating step 6110... Cautious: 7113 | Readthrough: 2887 | Inactive: 3
# Simulating step 6120... Cautious: 7193 | Readthrough: 2807 | Inactive: 1
# Simulating step 6130... Cautious: 7179 | Readthrough: 2821 | Inactive: 1
# Simulating step 6140... Cautious: 7152 | Readthrough: 2848 | Inactive: 2
# Simulating step 6150... Cautious: 7135 | Readthrough: 2865 | Inactive: 1
# Simulating step 6160... Cautious: 7074 | Readthrough: 2926 | Inactive: 3
# Simulating step 6170... Cautious: 7063 | Readthrough: 2937 | Inactive: 2
# Simulating step 6180... Cautious: 7057 | Readthrough: 2943 | Inactive: 1
# Simulating step 6190... Cautious: 6994 | Readthrough: 3006 | Inactive: 4
# Simulating step 6200... Cautious: 7054 | Readthrough: 2946 | Inactive: 0
# Simulating step 6210... Cautious: 7057 | Readthrough: 2943 | Inactive: 0
# Simulating step 6220... Cautious: 7109 | Readthrough: 2891 | Inactive: 2
# Simulating step 6230... Cautious: 7107 | Readthrough: 2893 | Inactive: 2
# Simulating step 6240... Cautious: 7106 | Readthrough: 2894 | Inactive: 5
# Simulating step 6250... Cautious: 7126 | Readthrough: 2874 | Inactive: 3
# Simulating step 6260... Cautious: 7128 | Readthrough: 2872 | Inactive: 2
# Simulating step 6270... Cautious: 7157 | Readthrough: 2843 | Inactive: 2
# Simulating step 6280... Cautious: 7153 | Readthrough: 2847 | Inactive: 2
# Simulating step 6290... Cautious: 7163 | Readthrough: 2837 | Inactive: 1
# Simulating step 6300... Cautious: 7178 | Readthrough: 2822 | Inactive: 2
# Simulating step 6310... Cautious: 7202 | Readthrough: 2798 | Inactive: 4
# Simulating step 6320... Cautious: 7133 | Readthrough: 2867 | Inactive: 3
# Simulating step 6330... Cautious: 7138 | Readthrough: 2862 | Inactive: 1
# Simulating step 6340... Cautious: 7138 | Readthrough: 2862 | Inactive: 1
# Simulating step 6350... Cautious: 7202 | Readthrough: 2798 | Inactive: 2
# Simulating step 6360... Cautious: 7219 | Readthrough: 2781 | Inactive: 0
# Simulating step 6370... Cautious: 7223 | Readthrough: 2777 | Inactive: 1
# Simulating step 6380... Cautious: 7202 | Readthrough: 2798 | Inactive: 2
# Simulating step 6390... Cautious: 7283 | Readthrough: 2717 | Inactive: 3
# Simulating step 6400... Cautious: 7293 | Readthrough: 2707 | Inactive: 2
# Simulating step 6410... Cautious: 7296 | Readthrough: 2704 | Inactive: 2
# Simulating step 6420... Cautious: 7369 | Readthrough: 2631 | Inactive: 1
# Simulating step 6430... Cautious: 7412 | Readthrough: 2588 | Inactive: 2
# Simulating step 6440... Cautious: 7389 | Readthrough: 2611 | Inactive: 4
# Simulating step 6450... Cautious: 7477 | Readthrough: 2523 | Inactive: 4
# Simulating step 6460... Cautious: 7536 | Readthrough: 2464 | Inactive: 0
# Simulating step 6470... Cautious: 7549 | Readthrough: 2451 | Inactive: 0
# Simulating step 6480... Cautious: 7616 | Readthrough: 2384 | Inactive: 0
# Simulating step 6490... Cautious: 7603 | Readthrough: 2397 | Inactive: 0
# Simulating step 6500... Cautious: 7648 | Readthrough: 2352 | Inactive: 1
# Simulating step 6510... Cautious: 7705 | Readthrough: 2295 | Inactive: 0
# Simulating step 6520... Cautious: 7716 | Readthrough: 2284 | Inactive: 4
# Simulating step 6530... Cautious: 7704 | Readthrough: 2296 | Inactive: 0
# Simulating step 6540... Cautious: 7724 | Readthrough: 2276 | Inactive: 0
# Simulating step 6550... Cautious: 7723 | Readthrough: 2277 | Inactive: 0
# Simulating step 6560... Cautious: 7814 | Readthrough: 2186 | Inactive: 0
# Simulating step 6570... Cautious: 7827 | Readthrough: 2173 | Inactive: 1
# ...
# Simulating step 8720... Cautious: 8358 | Readthrough: 1642 | Inactive: 2
# Simulating step 8730... Cautious: 8398 | Readthrough: 1602 | Inactive: 2
# Simulating step 8740... Cautious: 8444 | Readthrough: 1556 | Inactive: 3
# Simulating step 8750... Cautious: 8393 | Readthrough: 1607 | Inactive: 0
# Simulating step 8760... Cautious: 8387 | Readthrough: 1613 | Inactive: 2
# Simulating step 8770... Cautious: 8420 | Readthrough: 1580 | Inactive: 1
# Simulating step 8780... Cautious: 8388 | Readthrough: 1612 | Inactive: 5
# Simulating step 8790... Cautious: 8397 | Readthrough: 1603 | Inactive: 2
# Simulating step 8800... Cautious: 8392 | Readthrough: 1608 | Inactive: 2
# Simulating step 8810... Cautious: 8331 | Readthrough: 1669 | Inactive: 5
# Simulating step 8820... Cautious: 8393 | Readthrough: 1607 | Inactive: 5
# Simulating step 8830... Cautious: 8400 | Readthrough: 1600 | Inactive: 0
# Simulating step 8840... Cautious: 8420 | Readthrough: 1580 | Inactive: 3
# Simulating step 8850... Cautious: 8370 | Readthrough: 1630 | Inactive: 3
# Simulating step 8860... Cautious: 8348 | Readthrough: 1652 | Inactive: 0
# Simulating step 8870... Cautious: 8438 | Readthrough: 1562 | Inactive: 1
# Simulating step 8880... Cautious: 8389 | Readthrough: 1611 | Inactive: 5
# Simulating step 8890... Cautious: 8400 | Readthrough: 1600 | Inactive: 1
# Simulating step 8900... Cautious: 8423 | Readthrough: 1577 | Inactive: 1
# Simulating step 8910... Cautious: 8436 | Readthrough: 1564 | Inactive: 3
# Simulating step 8920... Cautious: 8421 | Readthrough: 1579 | Inactive: 2
# Simulating step 8930... Cautious: 8477 | Readthrough: 1523 | Inactive: 0
# Simulating step 8940... Cautious: 8469 | Readthrough: 1531 | Inactive: 0
# Simulating step 8950... Cautious: 8473 | Readthrough: 1527 | Inactive: 0
# Simulating step 8960... Cautious: 8463 | Readthrough: 1537 | Inactive: 2
# Simulating step 8970... Cautious: 8458 | Readthrough: 1542 | Inactive: 3
# Simulating step 8980... Cautious: 8482 | Readthrough: 1518 | Inactive: 1
# Simulating step 8990... Cautious: 8493 | Readthrough: 1507 | Inactive: 2
# Simulating step 9000... Cautious: 8525 | Readthrough: 1475 | Inactive: 2
# Simulating step 9010... Cautious: 8592 | Readthrough: 1408 | Inactive: 2
# Simulating step 9020... Cautious: 8588 | Readthrough: 1412 | Inactive: 0
# Simulating step 9030... Cautious: 8578 | Readthrough: 1422 | Inactive: 2
# Simulating step 9040... Cautious: 8577 | Readthrough: 1423 | Inactive: 0
# Simulating step 9050... Cautious: 8587 | Readthrough: 1413 | Inactive: 3
# Simulating step 9060... Cautious: 8577 | Readthrough: 1423 | Inactive: 1
# Simulating step 9070... Cautious: 8543 | Readthrough: 1457 | Inactive: 0
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-2-1057785267.py", line 376, in <cell line: 0>
#     run_and_plot()
#   File "/tmp/ipython-input-2-1057785267.py", line 321, in run_and_plot
#     colony.step(step_count)
#   File "/tmp/ipython-input-2-1057785267.py", line None, in step
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-2-1057785267.py", line 376, in <cell line: 0>
#     run_and_plot()
#   File "/tmp/ipython-input-2-1057785267.py", line 321, in run_and_plot
#     colony.step(step_count)
#   File "/tmp/ipython-input-2-1057785267.py", line None, in step
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipython-input-2-1057785267.py", line 376, in <cell line: 0>
#     run_and_plot()
#   File "/tmp/ipython-input-2-1057785267.py", line 321, in run_and_plot
#     colony.step(step_count)
#   File "/tmp/ipython-input-2-1057785267.py", line None, in step
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3575, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3492, in run_ast_nodes
#     self.showtraceback()
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2101, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#                                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
#            ^^^^^^^^^^^^
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2099, in showtraceback
#     stb = value._render_traceback_()
#           ^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#                                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1739, in getinnerframes
#     traceback_info = getframeinfo(tb, context)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/inspect.py", line 1686, in getframeinfo
#     start = lineno - 1 - context//2
#             ~~~~~~~^~~
# TypeError: unsupported operand type(s) for -: 'NoneType' and 'int'
