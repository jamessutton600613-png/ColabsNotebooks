# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessutton600613-png/GC/blob/main/Untitled114.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- 1. Environment Class ---
class Environment:
    def __init__(self, total_sim_steps, days_per_cycle=50):
        self.total_sim_steps, self.days_per_cycle, self.time = total_sim_steps, days_per_cycle, 0
        num_years = max(1, total_sim_steps / (365 * days_per_cycle))
        steps_per_year = 365 * days_per_cycle
        daily_uv_cycle = np.sin(np.linspace(0, 2 * np.pi, days_per_cycle)); daily_uv_cycle[daily_uv_cycle < 0] = 0
        full_uv, full_resources = [], []
        for _ in range(int(np.ceil(num_years))):
            uv_severity = np.random.uniform(0.8, 1.25)
            resource_bounty = np.random.uniform(0.8, 1.25)
            seasonal_cycle = np.sin(np.linspace(0, 2 * np.pi, steps_per_year))
            seasonal_amplitude_mod = (0.225 * seasonal_cycle + 0.725) * uv_severity
            seasonal_resource_mod = (-0.20 * seasonal_cycle + 0.80) * resource_bounty
            year_resources = 1500 * seasonal_resource_mod
            year_uv = [daily_uv_cycle[i % days_per_cycle] * seasonal_amplitude_mod[i] for i in range(steps_per_year)]
            full_uv.extend(year_uv); full_resources.extend(year_resources)
        self.uv_intensity = np.array(full_uv)[:total_sim_steps]
        self.external_resources = np.array(full_resources)[:total_sim_steps]

    def get_current_uv(self):
        return self.uv_intensity[self.time] if self.time < self.total_sim_steps else 0.0
    def get_current_resources(self):
        return self.external_resources[self.time] if self.time < self.total_sim_steps else 0.0
    def step(self):
        self.time += 1

# --- 2. Protoribosome Class ---
class Protoribosome:
    def __init__(self, env, strategy, initial_sequence, initial_mass=100.0):
        self.env, self.strategy, self.rna_sequence = env, strategy, list(initial_sequence)
        self.rna_mass = initial_mass
        self.atp_pool, self.mcyw_peptide_pool, self.other_peptide_pool = 500.0, 50.0, 5.0
        self.internal_ntp_stock, self.internal_aa_stock, self.internal_trp_tyr_cys_stock = 200.0, 200.0, 100.0
        self.rna_damage_level = 0.0

        self.location = 'dark_zone'
        self.status = 'ACTIVE'

        self.metabolic_efficiency = 1.0
        self.uv_damage_rate_per_uv = 0.5
        self.repair_rate, self.repair_atp_cost, self.trp_tyr_cys_for_repair_needed = 0.5, 0.0025, 0.0005
        self.uv_protection_factor, self.damage_tolerance_threshold = 0.01, 3.0
        self.atp_generation_rate_per_mcyw_uv, self.baseline_atp_generation_rate = 0.15, 0.5
        self.baseline_atp_chemosynthesis = 1.5
        self.protein_synthesis_rate, self.protein_synthesis_ntp_cost, self.protein_synthesis_aa_cost, self.protein_synthesis_atp_cost = 0.20, 0.1, 0.1, 0.02
        self.replication_rate, self.replication_ntp_cost, self.replication_atp_cost = 0.05, 1.0, 0.2
        self.rna_degradation_rate, self.atp_degradation_rate, self.peptide_degradation_rate = 0.0005, 0.025, 0.0008
        self.diffusion_rate, self.atp_from_ntp_conversion = 0.30, 0.1
        self.mutation_prob = 0.004
        self.failed_synthesis_penalty_atp = 50.0
        self.growth_rate = 0.1
        self.growth_ntp_cost = 1.0
        self.growth_atp_cost = 0.2

    def get_peptide_type(self):
        codons = ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)]
        if any(c in {'UGU', 'UGC', 'UAU', 'UAC', 'UGG'} for c in codons):
            return "MCYW"
        return "XXXX"

    def has_stop_codon(self):
        return any(c in {'UAA', 'UAG', 'UGA'} for c in ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)])

    def _decide_zone_transition(self):
        if self.location == 'dark_zone' and self.atp_pool < 450:
            self.location = 'light_zone'
        elif self.location == 'light_zone' and self.rna_damage_level > self.damage_tolerance_threshold * 0.75:
            self.location = 'dark_zone'

    def _apply_uv_damage(self, current_uv):
        if self.location == 'dark_zone' or current_uv <= 0:
            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate * 0.1)
            return

        protection = self.mcyw_peptide_pool * self.uv_protection_factor
        effective_uv = current_uv * max(0.01, 1 - protection)
        self.rna_damage_level += effective_uv * self.uv_damage_rate_per_uv

        for i in range(len(self.rna_sequence)):
            if random.random() < self.mutation_prob * effective_uv:
                self.rna_sequence[i] = random.choice("AUGC")

    def _manage_state(self, has_stop_codon_cached):
        if self.atp_pool < 0.1 or self.rna_damage_level >= self.damage_tolerance_threshold:
            self.status = 'INACTIVE'
            return

        if self.strategy == 'cautious' and has_stop_codon_cached:
            self.status = 'ARRESTED'
            self.metabolic_efficiency = 1.0
        else:
            self.status = 'ACTIVE'
            self.metabolic_efficiency = 1.25

    def _synthesize_protein(self, has_stop_codon_cached):
        if self.status != 'ACTIVE': return
        units = self.protein_synthesis_rate * self.metabolic_efficiency * 10
        required_ntp = units * self.protein_synthesis_ntp_cost
        required_atp = units * self.protein_synthesis_atp_cost
        required_aa_total = units * self.protein_synthesis_aa_cost

        is_mcyw = self.get_peptide_type() == "MCYW" and not (self.strategy == 'readthrough' and has_stop_codon_cached)

        if is_mcyw:
            required_special_aa = required_aa_total * 0.5
            required_general_aa = required_aa_total - required_special_aa
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa or
                self.internal_trp_tyr_cys_stock < required_special_aa):
                return
        else:
            required_general_aa = required_aa_total
            required_special_aa = 0
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa):
                return

        self.internal_ntp_stock -= required_ntp
        self.atp_pool -= required_atp
        self.internal_aa_stock -= required_general_aa
        self.internal_trp_tyr_cys_stock -= required_special_aa

        if is_mcyw:
            self.mcyw_peptide_pool += units
        else:
            self.other_peptide_pool += units
            if self.strategy == 'readthrough' and has_stop_codon_cached:
                self.atp_pool -= self.failed_synthesis_penalty_atp

    def _replicate_rna(self, has_stop_codon_cached, template_health):
        if self.status != 'ACTIVE' or self.rna_mass < 80: return None

        effective_replication_rate = self.replication_rate * template_health
        can_replicate = self.rna_mass * effective_replication_rate * self.metabolic_efficiency

        if self.internal_ntp_stock > self.replication_ntp_cost and self.atp_pool > self.replication_atp_cost and can_replicate > 1.0:
            offspring_mass = self.rna_mass * 0.5
            self.rna_mass -= offspring_mass

            self.internal_ntp_stock -= offspring_mass * self.replication_ntp_cost
            self.atp_pool -= offspring_mass * self.replication_atp_cost
            return Protoribosome(self.env, self.strategy, "".join(self.rna_sequence), offspring_mass)
        return None

    def _repair_rna_dna(self, dna_template, has_stop_codon_cached):
        if self.status != 'ACTIVE' or self.get_peptide_type() != 'MCYW' or has_stop_codon_cached:
            return False

        repaired_a_base = False
        for i in range(len(self.rna_sequence)):
            if self.rna_sequence[i] != dna_template[i]:
                if self.atp_pool >= self.repair_atp_cost and self.internal_trp_tyr_cys_stock >= self.trp_tyr_cys_for_repair_needed:
                    self.atp_pool -= self.repair_atp_cost
                    self.internal_trp_tyr_cys_stock -= self.trp_tyr_cys_for_repair_needed
                    self.rna_sequence[i] = dna_template[i]
                    repaired_a_base = True
                break

        if repaired_a_base:
            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate)
            return True
        return False

    def _diffuse_resources(self):
        available = self.env.get_current_resources()
        if available > 0:
            amount = available * self.diffusion_rate
            self.internal_ntp_stock += amount * 0.50
            self.internal_aa_stock += amount * 0.45
            self.internal_trp_tyr_cys_stock += amount * 0.05

    def _grow_mass(self):
        if self.status != 'ACTIVE': return

        potential_growth = self.rna_mass * self.growth_rate * self.metabolic_efficiency
        ntp_cost = potential_growth * self.growth_ntp_cost
        atp_cost = potential_growth * self.growth_atp_cost

        if self.internal_ntp_stock >= ntp_cost and self.atp_pool >= atp_cost:
            self.internal_ntp_stock -= ntp_cost
            self.atp_pool -= atp_cost
            self.rna_mass += potential_growth

    def step(self, current_uv, dna_template, template_health):
        if self.status == 'INACTIVE': return False, None

        # --- Optimization: Calculate this once ---
        has_stop = self.has_stop_codon()

        self._decide_zone_transition()
        self._apply_uv_damage(current_uv)
        self._manage_state(has_stop)
        if self.status == 'INACTIVE': return False, None

        self._diffuse_resources()
        self._grow_mass()

        self.atp_pool += self.baseline_atp_chemosynthesis
        self.atp_pool *= (1 - self.atp_degradation_rate)

        if self.location == 'light_zone' and current_uv > 0:
            self.atp_pool += (self.atp_generation_rate_per_mcyw_uv * self.mcyw_peptide_pool * current_uv)

        was_repaired = self._repair_rna_dna(dna_template, has_stop)
        self._synthesize_protein(has_stop)
        new_offspring = self._replicate_rna(has_stop, template_health)

        return was_repaired, new_offspring

# --- 3. Colony Class ---
class Colony:
    def __init__(self, env, dna_template, initial_pop_size=50):
        self.env = env
        self.dna_template = dna_template
        self.population = []
        for i in range(initial_pop_size):
            strategy = 'cautious' if i % 2 == 0 else 'readthrough'
            self.population.append(Protoribosome(env, strategy, dna_template))

        self.template_health = 1.0
        self.template_repair_rate = 0.05
        self.template_decay_rate = 0.001
        self.max_population = 10000

    def step(self):
        newly_replicated = []
        successful_repairs = 0
        current_uv = self.env.get_current_uv()

        # --- Optimization: Iterate directly over the list, no copy needed ---
        for protoribosome in self.population:
            was_repaired, new_offspring = protoribosome.step(current_uv, self.dna_template, self.template_health)

            if was_repaired:
                successful_repairs += 1
            if new_offspring:
                newly_replicated.append(new_offspring)

        self.template_health += successful_repairs * self.template_repair_rate
        self.template_health *= (1 - self.template_decay_rate)
        self.template_health = min(1.0, self.template_health)

        self.population.extend(newly_replicated)

        if len(self.population) > self.max_population:
            random.shuffle(self.population)
            self.population = self.population[:self.max_population]

    def get_aggregated_data(self):
        data = { 'cautious': 0, 'readthrough': 0, 'inactive': 0, 'in_light_zone': 0 }
        if not self.population: return data
        for p in self.population:
            if p.status == 'INACTIVE':
                data['inactive'] += 1
            elif p.strategy == 'cautious':
                data['cautious'] += 1
            elif p.strategy == 'readthrough':
                data['readthrough'] += 1
            if p.location == 'light_zone':
                data['in_light_zone'] += 1
        return data

# --- 4. Simulation and Plotting ---
def run_and_plot():
    # --- MODIFICATION: 1-year simulation with fewer steps per day ---
    SIMULATION_DAYS = 365
    STEPS_PER_DAY = 10
    TOTAL_STEPS = SIMULATION_DAYS * STEPS_PER_DAY

    IDEAL_DNA_TEMPLATE = "AUGUGUUACUGG"

    env = Environment(TOTAL_STEPS, STEPS_PER_DAY)
    colony = Colony(env, IDEAL_DNA_TEMPLATE, initial_pop_size=150)

    data = []
    print_interval = max(1, TOTAL_STEPS / 1000)

    for i in range(TOTAL_STEPS):
        if i % int(print_interval) == 0:
            agg_data = colony.get_aggregated_data()
            cautious_pop = agg_data.get('cautious', 0)
            readthrough_pop = agg_data.get('readthrough', 0)
            inactive_pop = agg_data.get('inactive', 0)

            print(f"Simulating step {i}/{TOTAL_STEPS} ({(i/TOTAL_STEPS)*100:.1f}%)... "
                  f"Cautious: {cautious_pop} | "
                  f"Readthrough: {readthrough_pop} | "
                  f"Inactive: {inactive_pop}")

            if i > 200 and (cautious_pop + readthrough_pop == 0):
                print("Active population extinct. Ending simulation early.")
                break

        colony.step()

        log_interval = 1 if TOTAL_STEPS <= 4000 else STEPS_PER_DAY
        if i % log_interval == 0:
            agg_data = colony.get_aggregated_data()
            log_entry = {
                'time': env.time,
                'uv': env.get_current_uv(),
                'template_health': colony.template_health
            }
            log_entry.update(agg_data)

        env.step()

    if not data:
        print("No data was logged. Cannot generate plots.")
        return

    results_df = pd.DataFrame(data)

    fig, axs = plt.subplots(3, 1, figsize=(15, 12), sharex=True)
    fig.suptitle('Protoribosome Colony Simulation (1 Year)', fontsize=16)
    colors = {'cautious': 'orange', 'readthrough': 'purple', 'inactive': 'grey'}

    ax0_twin = axs[0].twinx()
    axs[0].plot(results_df['time'], results_df['uv'], color='black', alpha=0.2, label='UV Intensity')
    ax0_twin.plot(results_df['time'], results_df['template_health'], color='cyan', label='Template Health')
    axs[0].set_title('Environmental Conditions & DNA Health'); axs[0].set_ylabel('UV'); ax0_twin.set_ylabel('Health')
    axs[0].legend(loc='upper left'); ax0_twin.legend(loc='upper right')

    axs[1].plot(results_df['time'], results_df['cautious'], label='Cautious', color=colors['cautious'])
    axs[1].plot(results_df['time'], results_df['readthrough'], label='Readthrough', color=colors['readthrough'])
    axs[1].set_title('Active Population by Strategy'); axs[1].set_ylabel('Count'); axs[1].legend()
    axs[1].set_yscale('symlog')

    axs[2].stackplot(results_df['time'],
                     results_df['cautious'] + results_df['readthrough'],
                     results_df['inactive'],
                     labels=['Active', 'Inactive'],
                     colors=[colors['cautious'], colors['inactive']])
    axs[2].set_title('Total Population State (Active vs. Inactive)'); axs[2].set_ylabel('Total Count'); axs[2].legend(loc='upper left')

    for ax in axs:
        ax.grid(True, linestyle=':', linewidth='0.5', color='gray')
        ax.set_xlim(0, TOTAL_STEPS)

    plt.tight_layout(rect=[0, 0, 1, 0.96]); plt.show()

if __name__ == "__main__":
    run_and_plot()
# Out:
# Simulating step 0/3650 (0.0%)... Cautious: 75 | Readthrough: 75 | Inactive: 0
# Simulating step 3/3650 (0.1%)... Cautious: 150 | Readthrough: 150 | Inactive: 0
# Simulating step 6/3650 (0.2%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 9/3650 (0.2%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 12/3650 (0.3%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 15/3650 (0.4%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 18/3650 (0.5%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 21/3650 (0.6%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 24/3650 (0.7%)... Cautious: 2400 | Readthrough: 2400 | Inactive: 0
# Simulating step 27/3650 (0.7%)... Cautious: 2400 | Readthrough: 2400 | Inactive: 0
# Simulating step 30/3650 (0.8%)... Cautious: 4800 | Readthrough: 4800 | Inactive: 0
# Simulating step 33/3650 (0.9%)... Cautious: 4800 | Readthrough: 4800 | Inactive: 0
# Simulating step 36/3650 (1.0%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 0
# Simulating step 39/3650 (1.1%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 0
# Simulating step 42/3650 (1.2%)... Cautious: 5025 | Readthrough: 4975 | Inactive: 0
# Simulating step 45/3650 (1.2%)... Cautious: 5025 | Readthrough: 4975 | Inactive: 0
# Simulating step 48/3650 (1.3%)... Cautious: 5026 | Readthrough: 4974 | Inactive: 0
# Simulating step 51/3650 (1.4%)... Cautious: 5026 | Readthrough: 4974 | Inactive: 0
# Simulating step 54/3650 (1.5%)... Cautious: 5030 | Readthrough: 4970 | Inactive: 0
# Simulating step 57/3650 (1.6%)... Cautious: 5088 | Readthrough: 4912 | Inactive: 0
# Simulating step 60/3650 (1.6%)... Cautious: 5088 | Readthrough: 4912 | Inactive: 0
# Simulating step 63/3650 (1.7%)... Cautious: 5085 | Readthrough: 4915 | Inactive: 0
# Simulating step 66/3650 (1.8%)... Cautious: 5085 | Readthrough: 4915 | Inactive: 0
# Simulating step 69/3650 (1.9%)... Cautious: 5078 | Readthrough: 4922 | Inactive: 0
# Simulating step 72/3650 (2.0%)... Cautious: 5078 | Readthrough: 4922 | Inactive: 0
# Simulating step 75/3650 (2.1%)... Cautious: 5078 | Readthrough: 4922 | Inactive: 0
# Simulating step 78/3650 (2.1%)... Cautious: 5078 | Readthrough: 4922 | Inactive: 0
# Simulating step 81/3650 (2.2%)... Cautious: 5071 | Readthrough: 4929 | Inactive: 0
# Simulating step 84/3650 (2.3%)... Cautious: 5071 | Readthrough: 4929 | Inactive: 0
# Simulating step 87/3650 (2.4%)... Cautious: 5089 | Readthrough: 4911 | Inactive: 0
# Simulating step 90/3650 (2.5%)... Cautious: 5089 | Readthrough: 4911 | Inactive: 0
# Simulating step 93/3650 (2.5%)... Cautious: 5011 | Readthrough: 4988 | Inactive: 1
# Simulating step 96/3650 (2.6%)... Cautious: 5011 | Readthrough: 4988 | Inactive: 1
# Simulating step 99/3650 (2.7%)... Cautious: 5021 | Readthrough: 4979 | Inactive: 0
# Simulating step 102/3650 (2.8%)... Cautious: 5021 | Readthrough: 4979 | Inactive: 0
# Simulating step 105/3650 (2.9%)... Cautious: 4948 | Readthrough: 5052 | Inactive: 0
# Simulating step 108/3650 (3.0%)... Cautious: 4948 | Readthrough: 5052 | Inactive: 0
# Simulating step 111/3650 (3.0%)... Cautious: 4973 | Readthrough: 5027 | Inactive: 0
# Simulating step 114/3650 (3.1%)... Cautious: 4973 | Readthrough: 5027 | Inactive: 0
# Simulating step 117/3650 (3.2%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 0
# Simulating step 120/3650 (3.3%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 0
# Simulating step 123/3650 (3.4%)... Cautious: 4942 | Readthrough: 5058 | Inactive: 0
# Simulating step 126/3650 (3.5%)... Cautious: 4942 | Readthrough: 5058 | Inactive: 0
# Simulating step 129/3650 (3.5%)... Cautious: 4970 | Readthrough: 5030 | Inactive: 0
# Simulating step 132/3650 (3.6%)... Cautious: 4970 | Readthrough: 5030 | Inactive: 0
# Simulating step 135/3650 (3.7%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 0
# Simulating step 138/3650 (3.8%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 0
# Simulating step 141/3650 (3.9%)... Cautious: 4939 | Readthrough: 5061 | Inactive: 0
# Simulating step 144/3650 (3.9%)... Cautious: 4939 | Readthrough: 5061 | Inactive: 0
# Simulating step 147/3650 (4.0%)... Cautious: 4888 | Readthrough: 5112 | Inactive: 0
# Simulating step 150/3650 (4.1%)... Cautious: 4888 | Readthrough: 5112 | Inactive: 0
# Simulating step 153/3650 (4.2%)... Cautious: 4860 | Readthrough: 5140 | Inactive: 0
# Simulating step 156/3650 (4.3%)... Cautious: 4860 | Readthrough: 5140 | Inactive: 0
# Simulating step 159/3650 (4.4%)... Cautious: 4943 | Readthrough: 5057 | Inactive: 0
# Simulating step 162/3650 (4.4%)... Cautious: 4943 | Readthrough: 5057 | Inactive: 0
# Simulating step 165/3650 (4.5%)... Cautious: 4977 | Readthrough: 5023 | Inactive: 0
# Simulating step 168/3650 (4.6%)... Cautious: 4977 | Readthrough: 5023 | Inactive: 0
# Simulating step 171/3650 (4.7%)... Cautious: 4982 | Readthrough: 5018 | Inactive: 0
# Simulating step 174/3650 (4.8%)... Cautious: 4982 | Readthrough: 5018 | Inactive: 0
# Simulating step 177/3650 (4.8%)... Cautious: 4981 | Readthrough: 5019 | Inactive: 0
# Simulating step 180/3650 (4.9%)... Cautious: 4981 | Readthrough: 5019 | Inactive: 0
# Simulating step 183/3650 (5.0%)... Cautious: 4962 | Readthrough: 5038 | Inactive: 0
# Simulating step 186/3650 (5.1%)... Cautious: 4962 | Readthrough: 5038 | Inactive: 0
# Simulating step 189/3650 (5.2%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 0
# Simulating step 192/3650 (5.3%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 0
# Simulating step 195/3650 (5.3%)... Cautious: 5050 | Readthrough: 4950 | Inactive: 0
# Simulating step 198/3650 (5.4%)... Cautious: 5050 | Readthrough: 4950 | Inactive: 0
# Simulating step 201/3650 (5.5%)... Cautious: 5033 | Readthrough: 4967 | Inactive: 0
# Simulating step 204/3650 (5.6%)... Cautious: 5033 | Readthrough: 4967 | Inactive: 0
# Simulating step 207/3650 (5.7%)... Cautious: 5085 | Readthrough: 4915 | Inactive: 0
# Simulating step 210/3650 (5.8%)... Cautious: 5029 | Readthrough: 4971 | Inactive: 0
# Simulating step 213/3650 (5.8%)... Cautious: 5029 | Readthrough: 4971 | Inactive: 0
# Simulating step 216/3650 (5.9%)... Cautious: 5032 | Readthrough: 4968 | Inactive: 0
# Simulating step 219/3650 (6.0%)... Cautious: 5032 | Readthrough: 4968 | Inactive: 0
# Simulating step 222/3650 (6.1%)... Cautious: 5064 | Readthrough: 4936 | Inactive: 0
# Simulating step 225/3650 (6.2%)... Cautious: 5064 | Readthrough: 4936 | Inactive: 0
# Simulating step 228/3650 (6.2%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 0
# Simulating step 231/3650 (6.3%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 0
# Simulating step 234/3650 (6.4%)... Cautious: 5069 | Readthrough: 4931 | Inactive: 0
# Simulating step 237/3650 (6.5%)... Cautious: 5069 | Readthrough: 4931 | Inactive: 0
# Simulating step 240/3650 (6.6%)... Cautious: 5067 | Readthrough: 4933 | Inactive: 0
# Simulating step 243/3650 (6.7%)... Cautious: 5067 | Readthrough: 4933 | Inactive: 0
# Simulating step 246/3650 (6.7%)... Cautious: 5076 | Readthrough: 4924 | Inactive: 0
# Simulating step 249/3650 (6.8%)... Cautious: 5076 | Readthrough: 4924 | Inactive: 0
# Simulating step 252/3650 (6.9%)... Cautious: 5047 | Readthrough: 4953 | Inactive: 0
# Simulating step 255/3650 (7.0%)... Cautious: 5047 | Readthrough: 4953 | Inactive: 0
# Simulating step 258/3650 (7.1%)... Cautious: 5018 | Readthrough: 4982 | Inactive: 0
# Simulating step 261/3650 (7.2%)... Cautious: 5018 | Readthrough: 4982 | Inactive: 0
# Simulating step 264/3650 (7.2%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 267/3650 (7.3%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 270/3650 (7.4%)... Cautious: 5026 | Readthrough: 4974 | Inactive: 0
# Simulating step 273/3650 (7.5%)... Cautious: 5026 | Readthrough: 4974 | Inactive: 0
# Simulating step 276/3650 (7.6%)... Cautious: 5130 | Readthrough: 4870 | Inactive: 0
# Simulating step 279/3650 (7.6%)... Cautious: 5130 | Readthrough: 4870 | Inactive: 0
# Simulating step 282/3650 (7.7%)... Cautious: 5139 | Readthrough: 4861 | Inactive: 0
# Simulating step 285/3650 (7.8%)... Cautious: 5139 | Readthrough: 4861 | Inactive: 0
# Simulating step 288/3650 (7.9%)... Cautious: 5066 | Readthrough: 4934 | Inactive: 0
# Simulating step 291/3650 (8.0%)... Cautious: 5066 | Readthrough: 4934 | Inactive: 0
# Simulating step 294/3650 (8.1%)... Cautious: 5063 | Readthrough: 4937 | Inactive: 0
# Simulating step 297/3650 (8.1%)... Cautious: 5063 | Readthrough: 4937 | Inactive: 0
# Simulating step 300/3650 (8.2%)... Cautious: 5079 | Readthrough: 4921 | Inactive: 0
# Simulating step 303/3650 (8.3%)... Cautious: 5079 | Readthrough: 4921 | Inactive: 0
# Simulating step 306/3650 (8.4%)... Cautious: 5087 | Readthrough: 4913 | Inactive: 0
# Simulating step 309/3650 (8.5%)... Cautious: 5087 | Readthrough: 4913 | Inactive: 0
# Simulating step 312/3650 (8.5%)... Cautious: 5093 | Readthrough: 4907 | Inactive: 0
# Simulating step 315/3650 (8.6%)... Cautious: 5093 | Readthrough: 4907 | Inactive: 0
# Simulating step 318/3650 (8.7%)... Cautious: 5086 | Readthrough: 4914 | Inactive: 0
# Simulating step 321/3650 (8.8%)... Cautious: 5086 | Readthrough: 4914 | Inactive: 0
# Simulating step 324/3650 (8.9%)... Cautious: 5074 | Readthrough: 4926 | Inactive: 0
# Simulating step 327/3650 (9.0%)... Cautious: 5074 | Readthrough: 4926 | Inactive: 0
# Simulating step 330/3650 (9.0%)... Cautious: 5093 | Readthrough: 4907 | Inactive: 0
# Simulating step 333/3650 (9.1%)... Cautious: 5093 | Readthrough: 4907 | Inactive: 0
# Simulating step 336/3650 (9.2%)... Cautious: 5111 | Readthrough: 4889 | Inactive: 0
# Simulating step 339/3650 (9.3%)... Cautious: 5111 | Readthrough: 4889 | Inactive: 0
# Simulating step 342/3650 (9.4%)... Cautious: 5151 | Readthrough: 4849 | Inactive: 0
# Simulating step 345/3650 (9.5%)... Cautious: 5151 | Readthrough: 4849 | Inactive: 0
# Simulating step 348/3650 (9.5%)... Cautious: 5187 | Readthrough: 4813 | Inactive: 0
# Simulating step 351/3650 (9.6%)... Cautious: 5187 | Readthrough: 4813 | Inactive: 0
# Simulating step 354/3650 (9.7%)... Cautious: 5152 | Readthrough: 4848 | Inactive: 0
# Simulating step 357/3650 (9.8%)... Cautious: 5152 | Readthrough: 4848 | Inactive: 0
# Simulating step 360/3650 (9.9%)... Cautious: 5179 | Readthrough: 4821 | Inactive: 0
# Simulating step 363/3650 (9.9%)... Cautious: 5132 | Readthrough: 4868 | Inactive: 0
# Simulating step 366/3650 (10.0%)... Cautious: 5132 | Readthrough: 4868 | Inactive: 0
# Simulating step 369/3650 (10.1%)... Cautious: 5170 | Readthrough: 4830 | Inactive: 0
# Simulating step 372/3650 (10.2%)... Cautious: 5170 | Readthrough: 4830 | Inactive: 0
# Simulating step 375/3650 (10.3%)... Cautious: 5139 | Readthrough: 4861 | Inactive: 0
# Simulating step 378/3650 (10.4%)... Cautious: 5139 | Readthrough: 4861 | Inactive: 0
# Simulating step 381/3650 (10.4%)... Cautious: 5124 | Readthrough: 4876 | Inactive: 0
# Simulating step 384/3650 (10.5%)... Cautious: 5124 | Readthrough: 4876 | Inactive: 0
# Simulating step 387/3650 (10.6%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 0
# Simulating step 390/3650 (10.7%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 0
# Simulating step 393/3650 (10.8%)... Cautious: 5187 | Readthrough: 4813 | Inactive: 0
# Simulating step 396/3650 (10.8%)... Cautious: 5187 | Readthrough: 4813 | Inactive: 0
# Simulating step 399/3650 (10.9%)... Cautious: 5155 | Readthrough: 4845 | Inactive: 0
# Simulating step 402/3650 (11.0%)... Cautious: 5155 | Readthrough: 4845 | Inactive: 0
# Simulating step 405/3650 (11.1%)... Cautious: 5201 | Readthrough: 4799 | Inactive: 0
# Simulating step 408/3650 (11.2%)... Cautious: 5201 | Readthrough: 4799 | Inactive: 0
# Simulating step 411/3650 (11.3%)... Cautious: 5166 | Readthrough: 4834 | Inactive: 0
# Simulating step 414/3650 (11.3%)... Cautious: 5166 | Readthrough: 4834 | Inactive: 0
# Simulating step 417/3650 (11.4%)... Cautious: 5223 | Readthrough: 4777 | Inactive: 0
# Simulating step 420/3650 (11.5%)... Cautious: 5223 | Readthrough: 4777 | Inactive: 0
# Simulating step 423/3650 (11.6%)... Cautious: 5165 | Readthrough: 4835 | Inactive: 0
# Simulating step 426/3650 (11.7%)... Cautious: 5165 | Readthrough: 4835 | Inactive: 0
# Simulating step 429/3650 (11.8%)... Cautious: 5190 | Readthrough: 4810 | Inactive: 0
# Simulating step 432/3650 (11.8%)... Cautious: 5190 | Readthrough: 4810 | Inactive: 0
# Simulating step 435/3650 (11.9%)... Cautious: 5196 | Readthrough: 4804 | Inactive: 0
# Simulating step 438/3650 (12.0%)... Cautious: 5196 | Readthrough: 4804 | Inactive: 0
# Simulating step 441/3650 (12.1%)... Cautious: 5244 | Readthrough: 4756 | Inactive: 0
# Simulating step 444/3650 (12.2%)... Cautious: 5244 | Readthrough: 4756 | Inactive: 0
# Simulating step 447/3650 (12.2%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 0
# Simulating step 450/3650 (12.3%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 0
# Simulating step 453/3650 (12.4%)... Cautious: 5193 | Readthrough: 4807 | Inactive: 0
# Simulating step 456/3650 (12.5%)... Cautious: 5193 | Readthrough: 4807 | Inactive: 0
# Simulating step 459/3650 (12.6%)... Cautious: 5199 | Readthrough: 4801 | Inactive: 0
# Simulating step 462/3650 (12.7%)... Cautious: 5199 | Readthrough: 4801 | Inactive: 0
# Simulating step 465/3650 (12.7%)... Cautious: 5235 | Readthrough: 4765 | Inactive: 0
# Simulating step 468/3650 (12.8%)... Cautious: 5235 | Readthrough: 4765 | Inactive: 0
# Simulating step 471/3650 (12.9%)... Cautious: 5291 | Readthrough: 4709 | Inactive: 0
# Simulating step 474/3650 (13.0%)... Cautious: 5291 | Readthrough: 4709 | Inactive: 0
# Simulating step 477/3650 (13.1%)... Cautious: 5241 | Readthrough: 4759 | Inactive: 0
# Simulating step 480/3650 (13.2%)... Cautious: 5241 | Readthrough: 4759 | Inactive: 0
# Simulating step 483/3650 (13.2%)... Cautious: 5306 | Readthrough: 4694 | Inactive: 0
# Simulating step 486/3650 (13.3%)... Cautious: 5306 | Readthrough: 4694 | Inactive: 0
# Simulating step 489/3650 (13.4%)... Cautious: 5378 | Readthrough: 4622 | Inactive: 0
# Simulating step 492/3650 (13.5%)... Cautious: 5378 | Readthrough: 4622 | Inactive: 0
# Simulating step 495/3650 (13.6%)... Cautious: 5344 | Readthrough: 4656 | Inactive: 0
# Simulating step 498/3650 (13.6%)... Cautious: 5344 | Readthrough: 4656 | Inactive: 0
# Simulating step 501/3650 (13.7%)... Cautious: 5338 | Readthrough: 4662 | Inactive: 0
# Simulating step 504/3650 (13.8%)... Cautious: 5338 | Readthrough: 4662 | Inactive: 0
# Simulating step 507/3650 (13.9%)... Cautious: 5290 | Readthrough: 4710 | Inactive: 0
# Simulating step 510/3650 (14.0%)... Cautious: 5290 | Readthrough: 4710 | Inactive: 0
# Simulating step 513/3650 (14.1%)... Cautious: 5322 | Readthrough: 4678 | Inactive: 0
# Simulating step 516/3650 (14.1%)... Cautious: 5375 | Readthrough: 4625 | Inactive: 0
# Simulating step 519/3650 (14.2%)... Cautious: 5375 | Readthrough: 4625 | Inactive: 0
# Simulating step 522/3650 (14.3%)... Cautious: 5416 | Readthrough: 4584 | Inactive: 0
# Simulating step 525/3650 (14.4%)... Cautious: 5416 | Readthrough: 4584 | Inactive: 0
# Simulating step 528/3650 (14.5%)... Cautious: 5431 | Readthrough: 4569 | Inactive: 0
# Simulating step 531/3650 (14.5%)... Cautious: 5431 | Readthrough: 4569 | Inactive: 0
# Simulating step 534/3650 (14.6%)... Cautious: 5433 | Readthrough: 4567 | Inactive: 0
# Simulating step 537/3650 (14.7%)... Cautious: 5433 | Readthrough: 4567 | Inactive: 0
# Simulating step 540/3650 (14.8%)... Cautious: 5445 | Readthrough: 4555 | Inactive: 0
# Simulating step 543/3650 (14.9%)... Cautious: 5445 | Readthrough: 4555 | Inactive: 0
# Simulating step 546/3650 (15.0%)... Cautious: 5498 | Readthrough: 4502 | Inactive: 0
# Simulating step 549/3650 (15.0%)... Cautious: 5498 | Readthrough: 4502 | Inactive: 0
# Simulating step 552/3650 (15.1%)... Cautious: 5516 | Readthrough: 4484 | Inactive: 0
# Simulating step 555/3650 (15.2%)... Cautious: 5516 | Readthrough: 4484 | Inactive: 0
# Simulating step 558/3650 (15.3%)... Cautious: 5524 | Readthrough: 4476 | Inactive: 0
# Simulating step 561/3650 (15.4%)... Cautious: 5524 | Readthrough: 4476 | Inactive: 0
# Simulating step 564/3650 (15.5%)... Cautious: 5548 | Readthrough: 4452 | Inactive: 0
# Simulating step 567/3650 (15.5%)... Cautious: 5548 | Readthrough: 4452 | Inactive: 0
# Simulating step 570/3650 (15.6%)... Cautious: 5548 | Readthrough: 4452 | Inactive: 0
# Simulating step 573/3650 (15.7%)... Cautious: 5548 | Readthrough: 4452 | Inactive: 0
# Simulating step 576/3650 (15.8%)... Cautious: 5576 | Readthrough: 4424 | Inactive: 0
# Simulating step 579/3650 (15.9%)... Cautious: 5576 | Readthrough: 4424 | Inactive: 0
# Simulating step 582/3650 (15.9%)... Cautious: 5566 | Readthrough: 4434 | Inactive: 0
# Simulating step 585/3650 (16.0%)... Cautious: 5566 | Readthrough: 4434 | Inactive: 0
# Simulating step 588/3650 (16.1%)... Cautious: 5510 | Readthrough: 4490 | Inactive: 0
# Simulating step 591/3650 (16.2%)... Cautious: 5510 | Readthrough: 4490 | Inactive: 0
# Simulating step 594/3650 (16.3%)... Cautious: 5554 | Readthrough: 4446 | Inactive: 0
# Simulating step 597/3650 (16.4%)... Cautious: 5554 | Readthrough: 4446 | Inactive: 0
# Simulating step 600/3650 (16.4%)... Cautious: 5505 | Readthrough: 4495 | Inactive: 0
# Simulating step 603/3650 (16.5%)... Cautious: 5505 | Readthrough: 4495 | Inactive: 0
# Simulating step 606/3650 (16.6%)... Cautious: 5448 | Readthrough: 4552 | Inactive: 0
# Simulating step 609/3650 (16.7%)... Cautious: 5448 | Readthrough: 4552 | Inactive: 0
# Simulating step 612/3650 (16.8%)... Cautious: 5398 | Readthrough: 4602 | Inactive: 0
# Simulating step 615/3650 (16.8%)... Cautious: 5398 | Readthrough: 4602 | Inactive: 0
# Simulating step 618/3650 (16.9%)... Cautious: 5408 | Readthrough: 4592 | Inactive: 0
# Simulating step 621/3650 (17.0%)... Cautious: 5408 | Readthrough: 4592 | Inactive: 0
# Simulating step 624/3650 (17.1%)... Cautious: 5473 | Readthrough: 4527 | Inactive: 0
# Simulating step 627/3650 (17.2%)... Cautious: 5473 | Readthrough: 4527 | Inactive: 0
# Simulating step 630/3650 (17.3%)... Cautious: 5476 | Readthrough: 4524 | Inactive: 0
# Simulating step 633/3650 (17.3%)... Cautious: 5476 | Readthrough: 4524 | Inactive: 0
# Simulating step 636/3650 (17.4%)... Cautious: 5471 | Readthrough: 4529 | Inactive: 0
# Simulating step 639/3650 (17.5%)... Cautious: 5471 | Readthrough: 4529 | Inactive: 0
# Simulating step 642/3650 (17.6%)... Cautious: 5463 | Readthrough: 4537 | Inactive: 0
# Simulating step 645/3650 (17.7%)... Cautious: 5463 | Readthrough: 4537 | Inactive: 0
# Simulating step 648/3650 (17.8%)... Cautious: 5498 | Readthrough: 4502 | Inactive: 0
# Simulating step 651/3650 (17.8%)... Cautious: 5498 | Readthrough: 4502 | Inactive: 0
# Simulating step 654/3650 (17.9%)... Cautious: 5493 | Readthrough: 4507 | Inactive: 0
# Simulating step 657/3650 (18.0%)... Cautious: 5493 | Readthrough: 4507 | Inactive: 0
# Simulating step 660/3650 (18.1%)... Cautious: 5436 | Readthrough: 4564 | Inactive: 0
# Simulating step 663/3650 (18.2%)... Cautious: 5436 | Readthrough: 4564 | Inactive: 0
# Simulating step 666/3650 (18.2%)... Cautious: 5440 | Readthrough: 4560 | Inactive: 0
# Simulating step 669/3650 (18.3%)... Cautious: 5519 | Readthrough: 4481 | Inactive: 0
# Simulating step 672/3650 (18.4%)... Cautious: 5519 | Readthrough: 4481 | Inactive: 0
# Simulating step 675/3650 (18.5%)... Cautious: 5545 | Readthrough: 4455 | Inactive: 0
# Simulating step 678/3650 (18.6%)... Cautious: 5545 | Readthrough: 4455 | Inactive: 0
# Simulating step 681/3650 (18.7%)... Cautious: 5524 | Readthrough: 4476 | Inactive: 0
# Simulating step 684/3650 (18.7%)... Cautious: 5524 | Readthrough: 4476 | Inactive: 0
# Simulating step 687/3650 (18.8%)... Cautious: 5508 | Readthrough: 4492 | Inactive: 0
# Simulating step 690/3650 (18.9%)... Cautious: 5508 | Readthrough: 4492 | Inactive: 0
# Simulating step 693/3650 (19.0%)... Cautious: 5531 | Readthrough: 4469 | Inactive: 0
# Simulating step 696/3650 (19.1%)... Cautious: 5531 | Readthrough: 4469 | Inactive: 0
# Simulating step 699/3650 (19.2%)... Cautious: 5518 | Readthrough: 4482 | Inactive: 0
# Simulating step 702/3650 (19.2%)... Cautious: 5518 | Readthrough: 4482 | Inactive: 0
# Simulating step 705/3650 (19.3%)... Cautious: 5532 | Readthrough: 4468 | Inactive: 0
# Simulating step 708/3650 (19.4%)... Cautious: 5532 | Readthrough: 4468 | Inactive: 0
# Simulating step 711/3650 (19.5%)... Cautious: 5552 | Readthrough: 4448 | Inactive: 0
# Simulating step 714/3650 (19.6%)... Cautious: 5552 | Readthrough: 4448 | Inactive: 0
# Simulating step 717/3650 (19.6%)... Cautious: 5517 | Readthrough: 4483 | Inactive: 0
# Simulating step 720/3650 (19.7%)... Cautious: 5517 | Readthrough: 4483 | Inactive: 0
# Simulating step 723/3650 (19.8%)... Cautious: 5542 | Readthrough: 4458 | Inactive: 0
# Simulating step 726/3650 (19.9%)... Cautious: 5542 | Readthrough: 4458 | Inactive: 0
# Simulating step 729/3650 (20.0%)... Cautious: 5517 | Readthrough: 4483 | Inactive: 0
# Simulating step 732/3650 (20.1%)... Cautious: 5517 | Readthrough: 4483 | Inactive: 0
# Simulating step 735/3650 (20.1%)... Cautious: 5491 | Readthrough: 4509 | Inactive: 0
# Simulating step 738/3650 (20.2%)... Cautious: 5491 | Readthrough: 4509 | Inactive: 0
# Simulating step 741/3650 (20.3%)... Cautious: 5496 | Readthrough: 4504 | Inactive: 0
# Simulating step 744/3650 (20.4%)... Cautious: 5496 | Readthrough: 4504 | Inactive: 0
# Simulating step 747/3650 (20.5%)... Cautious: 5469 | Readthrough: 4531 | Inactive: 0
# Simulating step 750/3650 (20.5%)... Cautious: 5469 | Readthrough: 4531 | Inactive: 0
# Simulating step 753/3650 (20.6%)... Cautious: 5454 | Readthrough: 4546 | Inactive: 0
# Simulating step 756/3650 (20.7%)... Cautious: 5454 | Readthrough: 4546 | Inactive: 0
# Simulating step 759/3650 (20.8%)... Cautious: 5415 | Readthrough: 4585 | Inactive: 0
# Simulating step 762/3650 (20.9%)... Cautious: 5415 | Readthrough: 4585 | Inactive: 0
# Simulating step 765/3650 (21.0%)... Cautious: 5472 | Readthrough: 4528 | Inactive: 0
# Simulating step 768/3650 (21.0%)... Cautious: 5472 | Readthrough: 4528 | Inactive: 0
# Simulating step 771/3650 (21.1%)... Cautious: 5464 | Readthrough: 4536 | Inactive: 0
# Simulating step 774/3650 (21.2%)... Cautious: 5464 | Readthrough: 4536 | Inactive: 0
# Simulating step 777/3650 (21.3%)... Cautious: 5424 | Readthrough: 4576 | Inactive: 0
# Simulating step 780/3650 (21.4%)... Cautious: 5424 | Readthrough: 4576 | Inactive: 0
# Simulating step 783/3650 (21.5%)... Cautious: 5447 | Readthrough: 4553 | Inactive: 0
# Simulating step 786/3650 (21.5%)... Cautious: 5447 | Readthrough: 4553 | Inactive: 0
# Simulating step 789/3650 (21.6%)... Cautious: 5482 | Readthrough: 4518 | Inactive: 0
# Simulating step 792/3650 (21.7%)... Cautious: 5482 | Readthrough: 4518 | Inactive: 0
# Simulating step 795/3650 (21.8%)... Cautious: 5351 | Readthrough: 4649 | Inactive: 0
# Simulating step 798/3650 (21.9%)... Cautious: 5351 | Readthrough: 4649 | Inactive: 0
# Simulating step 801/3650 (21.9%)... Cautious: 5415 | Readthrough: 4585 | Inactive: 0
# Simulating step 804/3650 (22.0%)... Cautious: 5415 | Readthrough: 4584 | Inactive: 1
# Simulating step 807/3650 (22.1%)... Cautious: 5402 | Readthrough: 4598 | Inactive: 0
# Simulating step 810/3650 (22.2%)... Cautious: 5402 | Readthrough: 4598 | Inactive: 0
# Simulating step 813/3650 (22.3%)... Cautious: 5406 | Readthrough: 4594 | Inactive: 0
# Simulating step 816/3650 (22.4%)... Cautious: 5406 | Readthrough: 4594 | Inactive: 0
# Simulating step 819/3650 (22.4%)... Cautious: 5473 | Readthrough: 4527 | Inactive: 0
# Simulating step 822/3650 (22.5%)... Cautious: 5365 | Readthrough: 4635 | Inactive: 0
# Simulating step 825/3650 (22.6%)... Cautious: 5365 | Readthrough: 4635 | Inactive: 0
# Simulating step 828/3650 (22.7%)... Cautious: 5302 | Readthrough: 4698 | Inactive: 0
# Simulating step 831/3650 (22.8%)... Cautious: 5302 | Readthrough: 4698 | Inactive: 0
# Simulating step 834/3650 (22.8%)... Cautious: 5306 | Readthrough: 4694 | Inactive: 0
# Simulating step 837/3650 (22.9%)... Cautious: 5306 | Readthrough: 4694 | Inactive: 0
# Simulating step 840/3650 (23.0%)... Cautious: 5310 | Readthrough: 4690 | Inactive: 0
# Simulating step 843/3650 (23.1%)... Cautious: 5310 | Readthrough: 4690 | Inactive: 0
# Simulating step 846/3650 (23.2%)... Cautious: 5292 | Readthrough: 4708 | Inactive: 0
# Simulating step 849/3650 (23.3%)... Cautious: 5292 | Readthrough: 4708 | Inactive: 0
# Simulating step 852/3650 (23.3%)... Cautious: 5288 | Readthrough: 4712 | Inactive: 0
# Simulating step 855/3650 (23.4%)... Cautious: 5288 | Readthrough: 4712 | Inactive: 0
# Simulating step 858/3650 (23.5%)... Cautious: 5308 | Readthrough: 4692 | Inactive: 0
# Simulating step 861/3650 (23.6%)... Cautious: 5308 | Readthrough: 4692 | Inactive: 0
# Simulating step 864/3650 (23.7%)... Cautious: 5365 | Readthrough: 4635 | Inactive: 0
# Simulating step 867/3650 (23.8%)... Cautious: 5365 | Readthrough: 4635 | Inactive: 0
# Simulating step 870/3650 (23.8%)... Cautious: 5384 | Readthrough: 4616 | Inactive: 0
# Simulating step 873/3650 (23.9%)... Cautious: 5384 | Readthrough: 4616 | Inactive: 0
# Simulating step 876/3650 (24.0%)... Cautious: 5296 | Readthrough: 4704 | Inactive: 0
# Simulating step 879/3650 (24.1%)... Cautious: 5296 | Readthrough: 4704 | Inactive: 0
# Simulating step 882/3650 (24.2%)... Cautious: 5251 | Readthrough: 4749 | Inactive: 0
# Simulating step 885/3650 (24.2%)... Cautious: 5251 | Readthrough: 4749 | Inactive: 0
# Simulating step 888/3650 (24.3%)... Cautious: 5239 | Readthrough: 4761 | Inactive: 0
# Simulating step 891/3650 (24.4%)... Cautious: 5239 | Readthrough: 4761 | Inactive: 0
# Simulating step 894/3650 (24.5%)... Cautious: 5244 | Readthrough: 4756 | Inactive: 0
# Simulating step 897/3650 (24.6%)... Cautious: 5244 | Readthrough: 4756 | Inactive: 0
# Simulating step 900/3650 (24.7%)... Cautious: 5239 | Readthrough: 4761 | Inactive: 0
# Simulating step 903/3650 (24.7%)... Cautious: 5239 | Readthrough: 4761 | Inactive: 0
# Simulating step 906/3650 (24.8%)... Cautious: 5228 | Readthrough: 4772 | Inactive: 0
# Simulating step 909/3650 (24.9%)... Cautious: 5228 | Readthrough: 4772 | Inactive: 0
# Simulating step 912/3650 (25.0%)... Cautious: 5212 | Readthrough: 4788 | Inactive: 0
# Simulating step 915/3650 (25.1%)... Cautious: 5212 | Readthrough: 4788 | Inactive: 0
# Simulating step 918/3650 (25.2%)... Cautious: 5154 | Readthrough: 4846 | Inactive: 0
# Simulating step 921/3650 (25.2%)... Cautious: 5154 | Readthrough: 4846 | Inactive: 0
# Simulating step 924/3650 (25.3%)... Cautious: 5155 | Readthrough: 4845 | Inactive: 0
# Simulating step 927/3650 (25.4%)... Cautious: 5155 | Readthrough: 4845 | Inactive: 0
# Simulating step 930/3650 (25.5%)... Cautious: 5157 | Readthrough: 4843 | Inactive: 0
# Simulating step 933/3650 (25.6%)... Cautious: 5157 | Readthrough: 4843 | Inactive: 0
# Simulating step 936/3650 (25.6%)... Cautious: 5250 | Readthrough: 4750 | Inactive: 0
# Simulating step 939/3650 (25.7%)... Cautious: 5250 | Readthrough: 4750 | Inactive: 0
# Simulating step 942/3650 (25.8%)... Cautious: 5283 | Readthrough: 4717 | Inactive: 0
# Simulating step 945/3650 (25.9%)... Cautious: 5283 | Readthrough: 4717 | Inactive: 0
# Simulating step 948/3650 (26.0%)... Cautious: 5235 | Readthrough: 4765 | Inactive: 0
# Simulating step 951/3650 (26.1%)... Cautious: 5235 | Readthrough: 4765 | Inactive: 0
# Simulating step 954/3650 (26.1%)... Cautious: 5319 | Readthrough: 4681 | Inactive: 0
# Simulating step 957/3650 (26.2%)... Cautious: 5319 | Readthrough: 4681 | Inactive: 0
# Simulating step 960/3650 (26.3%)... Cautious: 5359 | Readthrough: 4641 | Inactive: 0
# Simulating step 963/3650 (26.4%)... Cautious: 5359 | Readthrough: 4641 | Inactive: 0
# Simulating step 966/3650 (26.5%)... Cautious: 5370 | Readthrough: 4630 | Inactive: 0
# Simulating step 969/3650 (26.5%)... Cautious: 5370 | Readthrough: 4630 | Inactive: 0
# Simulating step 972/3650 (26.6%)... Cautious: 5376 | Readthrough: 4624 | Inactive: 0
# Simulating step 975/3650 (26.7%)... Cautious: 5376 | Readthrough: 4624 | Inactive: 0
# Simulating step 978/3650 (26.8%)... Cautious: 5411 | Readthrough: 4589 | Inactive: 0
# Simulating step 981/3650 (26.9%)... Cautious: 5349 | Readthrough: 4651 | Inactive: 0
# Simulating step 984/3650 (27.0%)... Cautious: 5349 | Readthrough: 4651 | Inactive: 0
# Simulating step 987/3650 (27.0%)... Cautious: 5309 | Readthrough: 4691 | Inactive: 0
# Simulating step 990/3650 (27.1%)... Cautious: 5309 | Readthrough: 4691 | Inactive: 0
# Simulating step 993/3650 (27.2%)... Cautious: 5303 | Readthrough: 4697 | Inactive: 0
# Simulating step 996/3650 (27.3%)... Cautious: 5303 | Readthrough: 4697 | Inactive: 0
# Simulating step 999/3650 (27.4%)... Cautious: 5311 | Readthrough: 4689 | Inactive: 0
# Simulating step 1002/3650 (27.5%)... Cautious: 5311 | Readthrough: 4689 | Inactive: 0
# Simulating step 1005/3650 (27.5%)... Cautious: 5283 | Readthrough: 4717 | Inactive: 0
# Simulating step 1008/3650 (27.6%)... Cautious: 5283 | Readthrough: 4717 | Inactive: 0
# Simulating step 1011/3650 (27.7%)... Cautious: 5286 | Readthrough: 4714 | Inactive: 0
# Simulating step 1014/3650 (27.8%)... Cautious: 5286 | Readthrough: 4714 | Inactive: 0
# Simulating step 1017/3650 (27.9%)... Cautious: 5306 | Readthrough: 4694 | Inactive: 0
# Simulating step 1020/3650 (27.9%)... Cautious: 5306 | Readthrough: 4694 | Inactive: 0
# Simulating step 1023/3650 (28.0%)... Cautious: 5318 | Readthrough: 4682 | Inactive: 0
# Simulating step 1026/3650 (28.1%)... Cautious: 5318 | Readthrough: 4682 | Inactive: 0
# Simulating step 1029/3650 (28.2%)... Cautious: 5323 | Readthrough: 4677 | Inactive: 0
# Simulating step 1032/3650 (28.3%)... Cautious: 5323 | Readthrough: 4677 | Inactive: 0
# Simulating step 1035/3650 (28.4%)... Cautious: 5290 | Readthrough: 4710 | Inactive: 0
# Simulating step 1038/3650 (28.4%)... Cautious: 5290 | Readthrough: 4710 | Inactive: 0
# Simulating step 1041/3650 (28.5%)... Cautious: 5276 | Readthrough: 4724 | Inactive: 0
# Simulating step 1044/3650 (28.6%)... Cautious: 5276 | Readthrough: 4724 | Inactive: 0
# Simulating step 1047/3650 (28.7%)... Cautious: 5260 | Readthrough: 4740 | Inactive: 0
# Simulating step 1050/3650 (28.8%)... Cautious: 5260 | Readthrough: 4740 | Inactive: 0
# Simulating step 1053/3650 (28.8%)... Cautious: 5250 | Readthrough: 4750 | Inactive: 0
# Simulating step 1056/3650 (28.9%)... Cautious: 5250 | Readthrough: 4750 | Inactive: 0
# Simulating step 1059/3650 (29.0%)... Cautious: 5254 | Readthrough: 4746 | Inactive: 0
# Simulating step 1062/3650 (29.1%)... Cautious: 5254 | Readthrough: 4746 | Inactive: 0
# Simulating step 1065/3650 (29.2%)... Cautious: 5286 | Readthrough: 4714 | Inactive: 0
# Simulating step 1068/3650 (29.3%)... Cautious: 5286 | Readthrough: 4714 | Inactive: 0
# Simulating step 1071/3650 (29.3%)... Cautious: 5261 | Readthrough: 4739 | Inactive: 0
# Simulating step 1074/3650 (29.4%)... Cautious: 5261 | Readthrough: 4739 | Inactive: 0
# Simulating step 1077/3650 (29.5%)... Cautious: 5244 | Readthrough: 4756 | Inactive: 0
# Simulating step 1080/3650 (29.6%)... Cautious: 5244 | Readthrough: 4756 | Inactive: 0
# Simulating step 1083/3650 (29.7%)... Cautious: 5251 | Readthrough: 4749 | Inactive: 0
# Simulating step 1086/3650 (29.8%)... Cautious: 5251 | Readthrough: 4749 | Inactive: 0
# Simulating step 1089/3650 (29.8%)... Cautious: 5208 | Readthrough: 4792 | Inactive: 0
# Simulating step 1092/3650 (29.9%)... Cautious: 5208 | Readthrough: 4792 | Inactive: 0
# Simulating step 1095/3650 (30.0%)... Cautious: 5298 | Readthrough: 4702 | Inactive: 0
# Simulating step 1098/3650 (30.1%)... Cautious: 5298 | Readthrough: 4702 | Inactive: 0
# Simulating step 1101/3650 (30.2%)... Cautious: 5273 | Readthrough: 4727 | Inactive: 0
# Simulating step 1104/3650 (30.2%)... Cautious: 5273 | Readthrough: 4727 | Inactive: 0
# Simulating step 1107/3650 (30.3%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 0
# Simulating step 1110/3650 (30.4%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 0
# Simulating step 1113/3650 (30.5%)... Cautious: 5260 | Readthrough: 4740 | Inactive: 0
# Simulating step 1116/3650 (30.6%)... Cautious: 5260 | Readthrough: 4740 | Inactive: 0
# Simulating step 1119/3650 (30.7%)... Cautious: 5256 | Readthrough: 4744 | Inactive: 0
# Simulating step 1122/3650 (30.7%)... Cautious: 5256 | Readthrough: 4744 | Inactive: 0
# Simulating step 1125/3650 (30.8%)... Cautious: 5270 | Readthrough: 4730 | Inactive: 0
# Simulating step 1128/3650 (30.9%)... Cautious: 5270 | Readthrough: 4730 | Inactive: 0
# Simulating step 1131/3650 (31.0%)... Cautious: 5289 | Readthrough: 4711 | Inactive: 0
# Simulating step 1134/3650 (31.1%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 0
# Simulating step 1137/3650 (31.2%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 0
# Simulating step 1140/3650 (31.2%)... Cautious: 5366 | Readthrough: 4634 | Inactive: 0
# Simulating step 1143/3650 (31.3%)... Cautious: 5366 | Readthrough: 4634 | Inactive: 0
# Simulating step 1146/3650 (31.4%)... Cautious: 5372 | Readthrough: 4628 | Inactive: 0
# Simulating step 1149/3650 (31.5%)... Cautious: 5372 | Readthrough: 4628 | Inactive: 0
# Simulating step 1152/3650 (31.6%)... Cautious: 5386 | Readthrough: 4614 | Inactive: 0
# Simulating step 1155/3650 (31.6%)... Cautious: 5386 | Readthrough: 4614 | Inactive: 0
# Simulating step 1158/3650 (31.7%)... Cautious: 5264 | Readthrough: 4736 | Inactive: 0
# Simulating step 1161/3650 (31.8%)... Cautious: 5264 | Readthrough: 4736 | Inactive: 0
# Simulating step 1164/3650 (31.9%)... Cautious: 5278 | Readthrough: 4722 | Inactive: 0
# Simulating step 1167/3650 (32.0%)... Cautious: 5278 | Readthrough: 4722 | Inactive: 0
# Simulating step 1170/3650 (32.1%)... Cautious: 5303 | Readthrough: 4697 | Inactive: 0
# Simulating step 1173/3650 (32.1%)... Cautious: 5303 | Readthrough: 4697 | Inactive: 0
# Simulating step 1176/3650 (32.2%)... Cautious: 5285 | Readthrough: 4715 | Inactive: 0
# Simulating step 1179/3650 (32.3%)... Cautious: 5285 | Readthrough: 4715 | Inactive: 0
# Simulating step 1182/3650 (32.4%)... Cautious: 5299 | Readthrough: 4701 | Inactive: 0
# Simulating step 1185/3650 (32.5%)... Cautious: 5299 | Readthrough: 4701 | Inactive: 0
# Simulating step 1188/3650 (32.5%)... Cautious: 5308 | Readthrough: 4692 | Inactive: 0
# Simulating step 1191/3650 (32.6%)... Cautious: 5308 | Readthrough: 4692 | Inactive: 0
# Simulating step 1194/3650 (32.7%)... Cautious: 5293 | Readthrough: 4707 | Inactive: 0
# Simulating step 1197/3650 (32.8%)... Cautious: 5293 | Readthrough: 4707 | Inactive: 0
# Simulating step 1200/3650 (32.9%)... Cautious: 5236 | Readthrough: 4764 | Inactive: 0
# Simulating step 1203/3650 (33.0%)... Cautious: 5236 | Readthrough: 4764 | Inactive: 0
# Simulating step 1206/3650 (33.0%)... Cautious: 5258 | Readthrough: 4742 | Inactive: 0
# Simulating step 1209/3650 (33.1%)... Cautious: 5258 | Readthrough: 4742 | Inactive: 0
# Simulating step 1212/3650 (33.2%)... Cautious: 5331 | Readthrough: 4669 | Inactive: 0
# Simulating step 1215/3650 (33.3%)... Cautious: 5331 | Readthrough: 4669 | Inactive: 0
# Simulating step 1218/3650 (33.4%)... Cautious: 5339 | Readthrough: 4661 | Inactive: 0
# Simulating step 1221/3650 (33.5%)... Cautious: 5339 | Readthrough: 4661 | Inactive: 0
# Simulating step 1224/3650 (33.5%)... Cautious: 5308 | Readthrough: 4692 | Inactive: 0
# Simulating step 1227/3650 (33.6%)... Cautious: 5308 | Readthrough: 4692 | Inactive: 0
# Simulating step 1230/3650 (33.7%)... Cautious: 5238 | Readthrough: 4762 | Inactive: 0
# Simulating step 1233/3650 (33.8%)... Cautious: 5238 | Readthrough: 4762 | Inactive: 0
# Simulating step 1236/3650 (33.9%)... Cautious: 5221 | Readthrough: 4779 | Inactive: 0
# Simulating step 1239/3650 (33.9%)... Cautious: 5221 | Readthrough: 4779 | Inactive: 0
# Simulating step 1242/3650 (34.0%)... Cautious: 5204 | Readthrough: 4796 | Inactive: 0
# Simulating step 1245/3650 (34.1%)... Cautious: 5204 | Readthrough: 4796 | Inactive: 0
# Simulating step 1248/3650 (34.2%)... Cautious: 5176 | Readthrough: 4824 | Inactive: 0
# Simulating step 1251/3650 (34.3%)... Cautious: 5176 | Readthrough: 4824 | Inactive: 0
# Simulating step 1254/3650 (34.4%)... Cautious: 5183 | Readthrough: 4817 | Inactive: 0
# Simulating step 1257/3650 (34.4%)... Cautious: 5183 | Readthrough: 4817 | Inactive: 0
# Simulating step 1260/3650 (34.5%)... Cautious: 5228 | Readthrough: 4772 | Inactive: 0
# Simulating step 1263/3650 (34.6%)... Cautious: 5228 | Readthrough: 4772 | Inactive: 0
# Simulating step 1266/3650 (34.7%)... Cautious: 5180 | Readthrough: 4820 | Inactive: 0
# Simulating step 1269/3650 (34.8%)... Cautious: 5180 | Readthrough: 4820 | Inactive: 0
# Simulating step 1272/3650 (34.8%)... Cautious: 5156 | Readthrough: 4844 | Inactive: 0
# Simulating step 1275/3650 (34.9%)... Cautious: 5156 | Readthrough: 4844 | Inactive: 0
# Simulating step 1278/3650 (35.0%)... Cautious: 5141 | Readthrough: 4859 | Inactive: 0
# Simulating step 1281/3650 (35.1%)... Cautious: 5141 | Readthrough: 4859 | Inactive: 0
# Simulating step 1284/3650 (35.2%)... Cautious: 5153 | Readthrough: 4847 | Inactive: 0
# Simulating step 1287/3650 (35.3%)... Cautious: 5072 | Readthrough: 4928 | Inactive: 0
# Simulating step 1290/3650 (35.3%)... Cautious: 5072 | Readthrough: 4928 | Inactive: 0
# Simulating step 1293/3650 (35.4%)... Cautious: 5056 | Readthrough: 4944 | Inactive: 0
# Simulating step 1296/3650 (35.5%)... Cautious: 5056 | Readthrough: 4944 | Inactive: 0
# Simulating step 1299/3650 (35.6%)... Cautious: 4955 | Readthrough: 5045 | Inactive: 0
# Simulating step 1302/3650 (35.7%)... Cautious: 4955 | Readthrough: 5045 | Inactive: 0
# Simulating step 1305/3650 (35.8%)... Cautious: 5003 | Readthrough: 4997 | Inactive: 0
# Simulating step 1308/3650 (35.8%)... Cautious: 5003 | Readthrough: 4997 | Inactive: 0
# Simulating step 1311/3650 (35.9%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 1314/3650 (36.0%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 1317/3650 (36.1%)... Cautious: 4997 | Readthrough: 5003 | Inactive: 0
# Simulating step 1320/3650 (36.2%)... Cautious: 4997 | Readthrough: 5003 | Inactive: 0
# Simulating step 1323/3650 (36.2%)... Cautious: 4961 | Readthrough: 5039 | Inactive: 0
# Simulating step 1326/3650 (36.3%)... Cautious: 4961 | Readthrough: 5039 | Inactive: 0
# Simulating step 1329/3650 (36.4%)... Cautious: 4917 | Readthrough: 5083 | Inactive: 0
# Simulating step 1332/3650 (36.5%)... Cautious: 4917 | Readthrough: 5083 | Inactive: 0
# Simulating step 1335/3650 (36.6%)... Cautious: 4871 | Readthrough: 5129 | Inactive: 0
# Simulating step 1338/3650 (36.7%)... Cautious: 4871 | Readthrough: 5129 | Inactive: 0
# Simulating step 1341/3650 (36.7%)... Cautious: 4876 | Readthrough: 5124 | Inactive: 0
# Simulating step 1344/3650 (36.8%)... Cautious: 4876 | Readthrough: 5124 | Inactive: 0
# Simulating step 1347/3650 (36.9%)... Cautious: 4889 | Readthrough: 5111 | Inactive: 0
# Simulating step 1350/3650 (37.0%)... Cautious: 4889 | Readthrough: 5111 | Inactive: 0
# Simulating step 1353/3650 (37.1%)... Cautious: 4875 | Readthrough: 5125 | Inactive: 0
# Simulating step 1356/3650 (37.2%)... Cautious: 4875 | Readthrough: 5125 | Inactive: 0
# Simulating step 1359/3650 (37.2%)... Cautious: 4854 | Readthrough: 5146 | Inactive: 0
# Simulating step 1362/3650 (37.3%)... Cautious: 4854 | Readthrough: 5146 | Inactive: 0
# Simulating step 1365/3650 (37.4%)... Cautious: 4840 | Readthrough: 5160 | Inactive: 0
# Simulating step 1368/3650 (37.5%)... Cautious: 4840 | Readthrough: 5160 | Inactive: 0
# Simulating step 1371/3650 (37.6%)... Cautious: 4828 | Readthrough: 5172 | Inactive: 0
# Simulating step 1374/3650 (37.6%)... Cautious: 4828 | Readthrough: 5172 | Inactive: 0
# Simulating step 1377/3650 (37.7%)... Cautious: 4887 | Readthrough: 5113 | Inactive: 0
# Simulating step 1380/3650 (37.8%)... Cautious: 4887 | Readthrough: 5113 | Inactive: 0
# Simulating step 1383/3650 (37.9%)... Cautious: 4894 | Readthrough: 5106 | Inactive: 0
# Simulating step 1386/3650 (38.0%)... Cautious: 4894 | Readthrough: 5106 | Inactive: 0
# Simulating step 1389/3650 (38.1%)... Cautious: 4925 | Readthrough: 5075 | Inactive: 0
# Simulating step 1392/3650 (38.1%)... Cautious: 4925 | Readthrough: 5075 | Inactive: 0
# Simulating step 1395/3650 (38.2%)... Cautious: 4856 | Readthrough: 5144 | Inactive: 0
# Simulating step 1398/3650 (38.3%)... Cautious: 4856 | Readthrough: 5144 | Inactive: 0
# Simulating step 1401/3650 (38.4%)... Cautious: 4841 | Readthrough: 5159 | Inactive: 0
# Simulating step 1404/3650 (38.5%)... Cautious: 4841 | Readthrough: 5159 | Inactive: 0
# Simulating step 1407/3650 (38.5%)... Cautious: 4791 | Readthrough: 5209 | Inactive: 0
# Simulating step 1410/3650 (38.6%)... Cautious: 4791 | Readthrough: 5209 | Inactive: 0
# Simulating step 1413/3650 (38.7%)... Cautious: 4795 | Readthrough: 5205 | Inactive: 0
# Simulating step 1416/3650 (38.8%)... Cautious: 4795 | Readthrough: 5205 | Inactive: 0
# Simulating step 1419/3650 (38.9%)... Cautious: 4749 | Readthrough: 5251 | Inactive: 0
# Simulating step 1422/3650 (39.0%)... Cautious: 4749 | Readthrough: 5251 | Inactive: 0
# Simulating step 1425/3650 (39.0%)... Cautious: 4800 | Readthrough: 5200 | Inactive: 0
# Simulating step 1428/3650 (39.1%)... Cautious: 4800 | Readthrough: 5200 | Inactive: 0
# Simulating step 1431/3650 (39.2%)... Cautious: 4739 | Readthrough: 5261 | Inactive: 0
# Simulating step 1434/3650 (39.3%)... Cautious: 4739 | Readthrough: 5261 | Inactive: 0
# Simulating step 1437/3650 (39.4%)... Cautious: 4728 | Readthrough: 5272 | Inactive: 0
# Simulating step 1440/3650 (39.5%)... Cautious: 4754 | Readthrough: 5246 | Inactive: 0
# Simulating step 1443/3650 (39.5%)... Cautious: 4754 | Readthrough: 5246 | Inactive: 0
# Simulating step 1446/3650 (39.6%)... Cautious: 4740 | Readthrough: 5260 | Inactive: 0
# Simulating step 1449/3650 (39.7%)... Cautious: 4740 | Readthrough: 5260 | Inactive: 0
# Simulating step 1452/3650 (39.8%)... Cautious: 4744 | Readthrough: 5256 | Inactive: 0
# Simulating step 1455/3650 (39.9%)... Cautious: 4744 | Readthrough: 5256 | Inactive: 0
# Simulating step 1458/3650 (39.9%)... Cautious: 4765 | Readthrough: 5235 | Inactive: 0
# Simulating step 1461/3650 (40.0%)... Cautious: 4765 | Readthrough: 5235 | Inactive: 0
# Simulating step 1464/3650 (40.1%)... Cautious: 4753 | Readthrough: 5247 | Inactive: 0
# Simulating step 1467/3650 (40.2%)... Cautious: 4753 | Readthrough: 5247 | Inactive: 0
# Simulating step 1470/3650 (40.3%)... Cautious: 4767 | Readthrough: 5233 | Inactive: 0
# Simulating step 1473/3650 (40.4%)... Cautious: 4767 | Readthrough: 5233 | Inactive: 0
# Simulating step 1476/3650 (40.4%)... Cautious: 4698 | Readthrough: 5302 | Inactive: 0
# Simulating step 1479/3650 (40.5%)... Cautious: 4698 | Readthrough: 5302 | Inactive: 0
# Simulating step 1482/3650 (40.6%)... Cautious: 4715 | Readthrough: 5285 | Inactive: 0
# Simulating step 1485/3650 (40.7%)... Cautious: 4715 | Readthrough: 5285 | Inactive: 0
# Simulating step 1488/3650 (40.8%)... Cautious: 4709 | Readthrough: 5291 | Inactive: 0
# Simulating step 1491/3650 (40.8%)... Cautious: 4709 | Readthrough: 5291 | Inactive: 0
# Simulating step 1494/3650 (40.9%)... Cautious: 4708 | Readthrough: 5292 | Inactive: 0
# Simulating step 1497/3650 (41.0%)... Cautious: 4708 | Readthrough: 5292 | Inactive: 0
# Simulating step 1500/3650 (41.1%)... Cautious: 4771 | Readthrough: 5229 | Inactive: 0
# Simulating step 1503/3650 (41.2%)... Cautious: 4771 | Readthrough: 5228 | Inactive: 1
# Simulating step 1506/3650 (41.3%)... Cautious: 4771 | Readthrough: 5229 | Inactive: 0
# Simulating step 1509/3650 (41.3%)... Cautious: 4771 | Readthrough: 5229 | Inactive: 0
# Simulating step 1512/3650 (41.4%)... Cautious: 4795 | Readthrough: 5205 | Inactive: 0
# Simulating step 1515/3650 (41.5%)... Cautious: 4795 | Readthrough: 5205 | Inactive: 0
# Simulating step 1518/3650 (41.6%)... Cautious: 4814 | Readthrough: 5185 | Inactive: 1
# Simulating step 1521/3650 (41.7%)... Cautious: 4814 | Readthrough: 5185 | Inactive: 1
# Simulating step 1524/3650 (41.8%)... Cautious: 4840 | Readthrough: 5159 | Inactive: 1
# Simulating step 1527/3650 (41.8%)... Cautious: 4840 | Readthrough: 5159 | Inactive: 1
# Simulating step 1530/3650 (41.9%)... Cautious: 4846 | Readthrough: 5153 | Inactive: 1
# Simulating step 1533/3650 (42.0%)... Cautious: 4846 | Readthrough: 5153 | Inactive: 1
# Simulating step 1536/3650 (42.1%)... Cautious: 4807 | Readthrough: 5192 | Inactive: 1
# Simulating step 1539/3650 (42.2%)... Cautious: 4807 | Readthrough: 5192 | Inactive: 1
# Simulating step 1542/3650 (42.2%)... Cautious: 4759 | Readthrough: 5240 | Inactive: 1
# Simulating step 1545/3650 (42.3%)... Cautious: 4759 | Readthrough: 5240 | Inactive: 1
# Simulating step 1548/3650 (42.4%)... Cautious: 4738 | Readthrough: 5262 | Inactive: 0
# Simulating step 1551/3650 (42.5%)... Cautious: 4738 | Readthrough: 5262 | Inactive: 0
# Simulating step 1554/3650 (42.6%)... Cautious: 4747 | Readthrough: 5253 | Inactive: 0
# Simulating step 1557/3650 (42.7%)... Cautious: 4747 | Readthrough: 5253 | Inactive: 0
# Simulating step 1560/3650 (42.7%)... Cautious: 4748 | Readthrough: 5252 | Inactive: 0
# Simulating step 1563/3650 (42.8%)... Cautious: 4748 | Readthrough: 5252 | Inactive: 0
# Simulating step 1566/3650 (42.9%)... Cautious: 4700 | Readthrough: 5300 | Inactive: 0
# Simulating step 1569/3650 (43.0%)... Cautious: 4700 | Readthrough: 5300 | Inactive: 0
# Simulating step 1572/3650 (43.1%)... Cautious: 4756 | Readthrough: 5244 | Inactive: 0
# Simulating step 1575/3650 (43.2%)... Cautious: 4756 | Readthrough: 5244 | Inactive: 0
# Simulating step 1578/3650 (43.2%)... Cautious: 4769 | Readthrough: 5231 | Inactive: 0
# Simulating step 1581/3650 (43.3%)... Cautious: 4769 | Readthrough: 5231 | Inactive: 0
# Simulating step 1584/3650 (43.4%)... Cautious: 4796 | Readthrough: 5204 | Inactive: 0
# Simulating step 1587/3650 (43.5%)... Cautious: 4796 | Readthrough: 5204 | Inactive: 0
# Simulating step 1590/3650 (43.6%)... Cautious: 4885 | Readthrough: 5115 | Inactive: 0
# Simulating step 1593/3650 (43.6%)... Cautious: 4867 | Readthrough: 5133 | Inactive: 0
# Simulating step 1596/3650 (43.7%)... Cautious: 4867 | Readthrough: 5133 | Inactive: 0
# Simulating step 1599/3650 (43.8%)... Cautious: 4924 | Readthrough: 5076 | Inactive: 0
# Simulating step 1602/3650 (43.9%)... Cautious: 4924 | Readthrough: 5076 | Inactive: 0
# Simulating step 1605/3650 (44.0%)... Cautious: 4945 | Readthrough: 5055 | Inactive: 0
# Simulating step 1608/3650 (44.1%)... Cautious: 4945 | Readthrough: 5055 | Inactive: 0
# Simulating step 1611/3650 (44.1%)... Cautious: 4903 | Readthrough: 5097 | Inactive: 0
# Simulating step 1614/3650 (44.2%)... Cautious: 4903 | Readthrough: 5097 | Inactive: 0
# Simulating step 1617/3650 (44.3%)... Cautious: 4902 | Readthrough: 5098 | Inactive: 0
# Simulating step 1620/3650 (44.4%)... Cautious: 4902 | Readthrough: 5098 | Inactive: 0
# Simulating step 1623/3650 (44.5%)... Cautious: 4919 | Readthrough: 5081 | Inactive: 0
# Simulating step 1626/3650 (44.5%)... Cautious: 4919 | Readthrough: 5081 | Inactive: 0
# Simulating step 1629/3650 (44.6%)... Cautious: 4910 | Readthrough: 5090 | Inactive: 0
# Simulating step 1632/3650 (44.7%)... Cautious: 4910 | Readthrough: 5090 | Inactive: 0
# Simulating step 1635/3650 (44.8%)... Cautious: 4934 | Readthrough: 5066 | Inactive: 0
# Simulating step 1638/3650 (44.9%)... Cautious: 4934 | Readthrough: 5066 | Inactive: 0
# Simulating step 1641/3650 (45.0%)... Cautious: 4930 | Readthrough: 5070 | Inactive: 0
# Simulating step 1644/3650 (45.0%)... Cautious: 4930 | Readthrough: 5069 | Inactive: 1
# Simulating step 1647/3650 (45.1%)... Cautious: 4941 | Readthrough: 5059 | Inactive: 0
# Simulating step 1650/3650 (45.2%)... Cautious: 4941 | Readthrough: 5059 | Inactive: 0
# Simulating step 1653/3650 (45.3%)... Cautious: 4937 | Readthrough: 5063 | Inactive: 0
# Simulating step 1656/3650 (45.4%)... Cautious: 4937 | Readthrough: 5063 | Inactive: 0
# Simulating step 1659/3650 (45.5%)... Cautious: 4929 | Readthrough: 5071 | Inactive: 0
# Simulating step 1662/3650 (45.5%)... Cautious: 4929 | Readthrough: 5071 | Inactive: 0
# Simulating step 1665/3650 (45.6%)... Cautious: 4960 | Readthrough: 5040 | Inactive: 0
# Simulating step 1668/3650 (45.7%)... Cautious: 4960 | Readthrough: 5040 | Inactive: 0
# Simulating step 1671/3650 (45.8%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 0
# Simulating step 1674/3650 (45.9%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 0
# Simulating step 1677/3650 (45.9%)... Cautious: 4956 | Readthrough: 5044 | Inactive: 0
# Simulating step 1680/3650 (46.0%)... Cautious: 4956 | Readthrough: 5044 | Inactive: 0
# Simulating step 1683/3650 (46.1%)... Cautious: 4912 | Readthrough: 5088 | Inactive: 0
# Simulating step 1686/3650 (46.2%)... Cautious: 4912 | Readthrough: 5088 | Inactive: 0
# Simulating step 1689/3650 (46.3%)... Cautious: 4883 | Readthrough: 5117 | Inactive: 0
# ...
# Simulating step 3096/3650 (84.8%)... Cautious: 4259 | Readthrough: 5741 | Inactive: 0
# Simulating step 3099/3650 (84.9%)... Cautious: 4259 | Readthrough: 5741 | Inactive: 0
# Simulating step 3102/3650 (85.0%)... Cautious: 4193 | Readthrough: 5807 | Inactive: 0
# Simulating step 3105/3650 (85.1%)... Cautious: 4193 | Readthrough: 5807 | Inactive: 0
# Simulating step 3108/3650 (85.2%)... Cautious: 4177 | Readthrough: 5823 | Inactive: 0
# Simulating step 3111/3650 (85.2%)... Cautious: 4177 | Readthrough: 5823 | Inactive: 0
# Simulating step 3114/3650 (85.3%)... Cautious: 4150 | Readthrough: 5850 | Inactive: 0
# Simulating step 3117/3650 (85.4%)... Cautious: 4150 | Readthrough: 5850 | Inactive: 0
# Simulating step 3120/3650 (85.5%)... Cautious: 4202 | Readthrough: 5798 | Inactive: 0
# Simulating step 3123/3650 (85.6%)... Cautious: 4202 | Readthrough: 5798 | Inactive: 0
# Simulating step 3126/3650 (85.6%)... Cautious: 4210 | Readthrough: 5790 | Inactive: 0
# Simulating step 3129/3650 (85.7%)... Cautious: 4197 | Readthrough: 5803 | Inactive: 0
# Simulating step 3132/3650 (85.8%)... Cautious: 4197 | Readthrough: 5803 | Inactive: 0
# Simulating step 3135/3650 (85.9%)... Cautious: 4191 | Readthrough: 5809 | Inactive: 0
# Simulating step 3138/3650 (86.0%)... Cautious: 4191 | Readthrough: 5809 | Inactive: 0
# Simulating step 3141/3650 (86.1%)... Cautious: 4188 | Readthrough: 5812 | Inactive: 0
# Simulating step 3144/3650 (86.1%)... Cautious: 4188 | Readthrough: 5812 | Inactive: 0
# Simulating step 3147/3650 (86.2%)... Cautious: 4192 | Readthrough: 5808 | Inactive: 0
# Simulating step 3150/3650 (86.3%)... Cautious: 4192 | Readthrough: 5808 | Inactive: 0
# Simulating step 3153/3650 (86.4%)... Cautious: 4225 | Readthrough: 5775 | Inactive: 0
# Simulating step 3156/3650 (86.5%)... Cautious: 4225 | Readthrough: 5775 | Inactive: 0
# Simulating step 3159/3650 (86.5%)... Cautious: 4281 | Readthrough: 5719 | Inactive: 0
# Simulating step 3162/3650 (86.6%)... Cautious: 4281 | Readthrough: 5719 | Inactive: 0
# Simulating step 3165/3650 (86.7%)... Cautious: 4262 | Readthrough: 5738 | Inactive: 0
# Simulating step 3168/3650 (86.8%)... Cautious: 4262 | Readthrough: 5738 | Inactive: 0
# Simulating step 3171/3650 (86.9%)... Cautious: 4325 | Readthrough: 5675 | Inactive: 0
# Simulating step 3174/3650 (87.0%)... Cautious: 4325 | Readthrough: 5675 | Inactive: 0
# Simulating step 3177/3650 (87.0%)... Cautious: 4303 | Readthrough: 5697 | Inactive: 0
# Simulating step 3180/3650 (87.1%)... Cautious: 4303 | Readthrough: 5697 | Inactive: 0
# Simulating step 3183/3650 (87.2%)... Cautious: 4382 | Readthrough: 5618 | Inactive: 0
# Simulating step 3186/3650 (87.3%)... Cautious: 4382 | Readthrough: 5618 | Inactive: 0
# Simulating step 3189/3650 (87.4%)... Cautious: 4383 | Readthrough: 5617 | Inactive: 0
# Simulating step 3192/3650 (87.5%)... Cautious: 4383 | Readthrough: 5617 | Inactive: 0
# Simulating step 3195/3650 (87.5%)... Cautious: 4405 | Readthrough: 5595 | Inactive: 0
# Simulating step 3198/3650 (87.6%)... Cautious: 4405 | Readthrough: 5595 | Inactive: 0
# Simulating step 3201/3650 (87.7%)... Cautious: 4424 | Readthrough: 5576 | Inactive: 0
# Simulating step 3204/3650 (87.8%)... Cautious: 4424 | Readthrough: 5576 | Inactive: 0
# Simulating step 3207/3650 (87.9%)... Cautious: 4446 | Readthrough: 5554 | Inactive: 0
# Simulating step 3210/3650 (87.9%)... Cautious: 4446 | Readthrough: 5554 | Inactive: 0
# Simulating step 3213/3650 (88.0%)... Cautious: 4405 | Readthrough: 5595 | Inactive: 0
# Simulating step 3216/3650 (88.1%)... Cautious: 4405 | Readthrough: 5595 | Inactive: 0
# Simulating step 3219/3650 (88.2%)... Cautious: 4372 | Readthrough: 5628 | Inactive: 0
# Simulating step 3222/3650 (88.3%)... Cautious: 4372 | Readthrough: 5628 | Inactive: 0
# Simulating step 3225/3650 (88.4%)... Cautious: 4382 | Readthrough: 5618 | Inactive: 0
# Simulating step 3228/3650 (88.4%)... Cautious: 4382 | Readthrough: 5618 | Inactive: 0
# Simulating step 3231/3650 (88.5%)... Cautious: 4415 | Readthrough: 5585 | Inactive: 0
# Simulating step 3234/3650 (88.6%)... Cautious: 4415 | Readthrough: 5585 | Inactive: 0
# Simulating step 3237/3650 (88.7%)... Cautious: 4439 | Readthrough: 5561 | Inactive: 0
# Simulating step 3240/3650 (88.8%)... Cautious: 4439 | Readthrough: 5561 | Inactive: 0
# Simulating step 3243/3650 (88.8%)... Cautious: 4421 | Readthrough: 5579 | Inactive: 0
# Simulating step 3246/3650 (88.9%)... Cautious: 4421 | Readthrough: 5579 | Inactive: 0
# Simulating step 3249/3650 (89.0%)... Cautious: 4432 | Readthrough: 5568 | Inactive: 0
# Simulating step 3252/3650 (89.1%)... Cautious: 4432 | Readthrough: 5568 | Inactive: 0
# Simulating step 3255/3650 (89.2%)... Cautious: 4448 | Readthrough: 5552 | Inactive: 0
# Simulating step 3258/3650 (89.3%)... Cautious: 4448 | Readthrough: 5552 | Inactive: 0
# Simulating step 3261/3650 (89.3%)... Cautious: 4492 | Readthrough: 5508 | Inactive: 0
# Simulating step 3264/3650 (89.4%)... Cautious: 4492 | Readthrough: 5508 | Inactive: 0
# Simulating step 3267/3650 (89.5%)... Cautious: 4524 | Readthrough: 5476 | Inactive: 0
# Simulating step 3270/3650 (89.6%)... Cautious: 4524 | Readthrough: 5476 | Inactive: 0
# Simulating step 3273/3650 (89.7%)... Cautious: 4490 | Readthrough: 5510 | Inactive: 0
# Simulating step 3276/3650 (89.8%)... Cautious: 4490 | Readthrough: 5510 | Inactive: 0
# Simulating step 3279/3650 (89.8%)... Cautious: 4466 | Readthrough: 5534 | Inactive: 0
# Simulating step 3282/3650 (89.9%)... Cautious: 4476 | Readthrough: 5524 | Inactive: 0
# Simulating step 3285/3650 (90.0%)... Cautious: 4476 | Readthrough: 5524 | Inactive: 0
# Simulating step 3288/3650 (90.1%)... Cautious: 4423 | Readthrough: 5577 | Inactive: 0
# Simulating step 3291/3650 (90.2%)... Cautious: 4423 | Readthrough: 5577 | Inactive: 0
# Simulating step 3294/3650 (90.2%)... Cautious: 4391 | Readthrough: 5609 | Inactive: 0
# Simulating step 3297/3650 (90.3%)... Cautious: 4391 | Readthrough: 5609 | Inactive: 0
# Simulating step 3300/3650 (90.4%)... Cautious: 4382 | Readthrough: 5618 | Inactive: 0
# Simulating step 3303/3650 (90.5%)... Cautious: 4382 | Readthrough: 5618 | Inactive: 0
# Simulating step 3306/3650 (90.6%)... Cautious: 4389 | Readthrough: 5611 | Inactive: 0
# Simulating step 3309/3650 (90.7%)... Cautious: 4389 | Readthrough: 5611 | Inactive: 0
# Simulating step 3312/3650 (90.7%)... Cautious: 4379 | Readthrough: 5621 | Inactive: 0
# Simulating step 3315/3650 (90.8%)... Cautious: 4379 | Readthrough: 5621 | Inactive: 0
# Simulating step 3318/3650 (90.9%)... Cautious: 4360 | Readthrough: 5640 | Inactive: 0
# Simulating step 3321/3650 (91.0%)... Cautious: 4360 | Readthrough: 5640 | Inactive: 0
# Simulating step 3324/3650 (91.1%)... Cautious: 4360 | Readthrough: 5640 | Inactive: 0
# Simulating step 3327/3650 (91.2%)... Cautious: 4360 | Readthrough: 5640 | Inactive: 0
# Simulating step 3330/3650 (91.2%)... Cautious: 4303 | Readthrough: 5697 | Inactive: 0
# Simulating step 3333/3650 (91.3%)... Cautious: 4303 | Readthrough: 5697 | Inactive: 0
# Simulating step 3336/3650 (91.4%)... Cautious: 4304 | Readthrough: 5696 | Inactive: 0
# Simulating step 3339/3650 (91.5%)... Cautious: 4304 | Readthrough: 5696 | Inactive: 0
# Simulating step 3342/3650 (91.6%)... Cautious: 4287 | Readthrough: 5713 | Inactive: 0
# Simulating step 3345/3650 (91.6%)... Cautious: 4287 | Readthrough: 5713 | Inactive: 0
# Simulating step 3348/3650 (91.7%)... Cautious: 4306 | Readthrough: 5694 | Inactive: 0
# Simulating step 3351/3650 (91.8%)... Cautious: 4306 | Readthrough: 5694 | Inactive: 0
# Simulating step 3354/3650 (91.9%)... Cautious: 4318 | Readthrough: 5682 | Inactive: 0
# Simulating step 3357/3650 (92.0%)... Cautious: 4318 | Readthrough: 5682 | Inactive: 0
# Simulating step 3360/3650 (92.1%)... Cautious: 4322 | Readthrough: 5678 | Inactive: 0
# Simulating step 3363/3650 (92.1%)... Cautious: 4322 | Readthrough: 5678 | Inactive: 0
# Simulating step 3366/3650 (92.2%)... Cautious: 4311 | Readthrough: 5689 | Inactive: 0
# Simulating step 3369/3650 (92.3%)... Cautious: 4311 | Readthrough: 5689 | Inactive: 0
# Simulating step 3372/3650 (92.4%)... Cautious: 4293 | Readthrough: 5707 | Inactive: 0
# Simulating step 3375/3650 (92.5%)... Cautious: 4293 | Readthrough: 5707 | Inactive: 0
# Simulating step 3378/3650 (92.5%)... Cautious: 4281 | Readthrough: 5719 | Inactive: 0
# Simulating step 3381/3650 (92.6%)... Cautious: 4281 | Readthrough: 5719 | Inactive: 0
# Simulating step 3384/3650 (92.7%)... Cautious: 4317 | Readthrough: 5683 | Inactive: 0
# Simulating step 3387/3650 (92.8%)... Cautious: 4317 | Readthrough: 5683 | Inactive: 0
# Simulating step 3390/3650 (92.9%)... Cautious: 4362 | Readthrough: 5638 | Inactive: 0
# Simulating step 3393/3650 (93.0%)... Cautious: 4362 | Readthrough: 5638 | Inactive: 0
# Simulating step 3396/3650 (93.0%)... Cautious: 4333 | Readthrough: 5667 | Inactive: 0
# Simulating step 3399/3650 (93.1%)... Cautious: 4333 | Readthrough: 5667 | Inactive: 0
# Simulating step 3402/3650 (93.2%)... Cautious: 4294 | Readthrough: 5706 | Inactive: 0
# Simulating step 3405/3650 (93.3%)... Cautious: 4294 | Readthrough: 5706 | Inactive: 0
# Simulating step 3408/3650 (93.4%)... Cautious: 4310 | Readthrough: 5690 | Inactive: 0
# Simulating step 3411/3650 (93.5%)... Cautious: 4310 | Readthrough: 5690 | Inactive: 0
# Simulating step 3414/3650 (93.5%)... Cautious: 4294 | Readthrough: 5706 | Inactive: 0
# Simulating step 3417/3650 (93.6%)... Cautious: 4294 | Readthrough: 5706 | Inactive: 0
# Simulating step 3420/3650 (93.7%)... Cautious: 4266 | Readthrough: 5734 | Inactive: 0
# Simulating step 3423/3650 (93.8%)... Cautious: 4266 | Readthrough: 5734 | Inactive: 0
# Simulating step 3426/3650 (93.9%)... Cautious: 4315 | Readthrough: 5685 | Inactive: 0
# Simulating step 3429/3650 (93.9%)... Cautious: 4315 | Readthrough: 5685 | Inactive: 0
# Simulating step 3432/3650 (94.0%)... Cautious: 4351 | Readthrough: 5649 | Inactive: 0
# Simulating step 3435/3650 (94.1%)... Cautious: 4289 | Readthrough: 5711 | Inactive: 0
# Simulating step 3438/3650 (94.2%)... Cautious: 4289 | Readthrough: 5711 | Inactive: 0
# Simulating step 3441/3650 (94.3%)... Cautious: 4192 | Readthrough: 5808 | Inactive: 0
# Simulating step 3444/3650 (94.4%)... Cautious: 4192 | Readthrough: 5808 | Inactive: 0
# Simulating step 3447/3650 (94.4%)... Cautious: 4109 | Readthrough: 5891 | Inactive: 0
# Simulating step 3450/3650 (94.5%)... Cautious: 4109 | Readthrough: 5891 | Inactive: 0
# Simulating step 3453/3650 (94.6%)... Cautious: 4127 | Readthrough: 5873 | Inactive: 0
# Simulating step 3456/3650 (94.7%)... Cautious: 4127 | Readthrough: 5873 | Inactive: 0
# Simulating step 3459/3650 (94.8%)... Cautious: 4124 | Readthrough: 5876 | Inactive: 0
# Simulating step 3462/3650 (94.8%)... Cautious: 4124 | Readthrough: 5876 | Inactive: 0
# Simulating step 3465/3650 (94.9%)... Cautious: 4149 | Readthrough: 5851 | Inactive: 0
# Simulating step 3468/3650 (95.0%)... Cautious: 4149 | Readthrough: 5851 | Inactive: 0
# Simulating step 3471/3650 (95.1%)... Cautious: 4123 | Readthrough: 5877 | Inactive: 0
# Simulating step 3474/3650 (95.2%)... Cautious: 4123 | Readthrough: 5877 | Inactive: 0
# Simulating step 3477/3650 (95.3%)... Cautious: 4091 | Readthrough: 5909 | Inactive: 0
# Simulating step 3480/3650 (95.3%)... Cautious: 4091 | Readthrough: 5909 | Inactive: 0
# Simulating step 3483/3650 (95.4%)... Cautious: 4054 | Readthrough: 5946 | Inactive: 0
# Simulating step 3486/3650 (95.5%)... Cautious: 4054 | Readthrough: 5946 | Inactive: 0
# Simulating step 3489/3650 (95.6%)... Cautious: 4014 | Readthrough: 5986 | Inactive: 0
# Simulating step 3492/3650 (95.7%)... Cautious: 4014 | Readthrough: 5986 | Inactive: 0
# Simulating step 3495/3650 (95.8%)... Cautious: 3987 | Readthrough: 6013 | Inactive: 0
# Simulating step 3498/3650 (95.8%)... Cautious: 3987 | Readthrough: 6013 | Inactive: 0
# Simulating step 3501/3650 (95.9%)... Cautious: 3968 | Readthrough: 6032 | Inactive: 0
# Simulating step 3504/3650 (96.0%)... Cautious: 3968 | Readthrough: 6032 | Inactive: 0
# Simulating step 3507/3650 (96.1%)... Cautious: 3974 | Readthrough: 6026 | Inactive: 0
# Simulating step 3510/3650 (96.2%)... Cautious: 3974 | Readthrough: 6026 | Inactive: 0
# Simulating step 3513/3650 (96.2%)... Cautious: 4000 | Readthrough: 6000 | Inactive: 0
# Simulating step 3516/3650 (96.3%)... Cautious: 4000 | Readthrough: 6000 | Inactive: 0
# Simulating step 3519/3650 (96.4%)... Cautious: 4017 | Readthrough: 5983 | Inactive: 0
# Simulating step 3522/3650 (96.5%)... Cautious: 4017 | Readthrough: 5983 | Inactive: 0
# Simulating step 3525/3650 (96.6%)... Cautious: 4036 | Readthrough: 5964 | Inactive: 0
# Simulating step 3528/3650 (96.7%)... Cautious: 4036 | Readthrough: 5964 | Inactive: 0
# Simulating step 3531/3650 (96.7%)... Cautious: 4023 | Readthrough: 5977 | Inactive: 0
# Simulating step 3534/3650 (96.8%)... Cautious: 4023 | Readthrough: 5977 | Inactive: 0
# Simulating step 3537/3650 (96.9%)... Cautious: 4023 | Readthrough: 5977 | Inactive: 0
# Simulating step 3540/3650 (97.0%)... Cautious: 4023 | Readthrough: 5977 | Inactive: 0
# Simulating step 3543/3650 (97.1%)... Cautious: 4028 | Readthrough: 5972 | Inactive: 0
# Simulating step 3546/3650 (97.2%)... Cautious: 4028 | Readthrough: 5972 | Inactive: 0
# Simulating step 3549/3650 (97.2%)... Cautious: 4062 | Readthrough: 5938 | Inactive: 0
# Simulating step 3552/3650 (97.3%)... Cautious: 4062 | Readthrough: 5938 | Inactive: 0
# Simulating step 3555/3650 (97.4%)... Cautious: 4070 | Readthrough: 5930 | Inactive: 0
# Simulating step 3558/3650 (97.5%)... Cautious: 4070 | Readthrough: 5930 | Inactive: 0
# Simulating step 3561/3650 (97.6%)... Cautious: 4109 | Readthrough: 5891 | Inactive: 0
# Simulating step 3564/3650 (97.6%)... Cautious: 4109 | Readthrough: 5891 | Inactive: 0
# Simulating step 3567/3650 (97.7%)... Cautious: 4120 | Readthrough: 5880 | Inactive: 0
# Simulating step 3570/3650 (97.8%)... Cautious: 4120 | Readthrough: 5880 | Inactive: 0
# Simulating step 3573/3650 (97.9%)... Cautious: 4119 | Readthrough: 5881 | Inactive: 0
# Simulating step 3576/3650 (98.0%)... Cautious: 4119 | Readthrough: 5881 | Inactive: 0
# Simulating step 3579/3650 (98.1%)... Cautious: 4134 | Readthrough: 5866 | Inactive: 0
# Simulating step 3582/3650 (98.1%)... Cautious: 4134 | Readthrough: 5866 | Inactive: 0
# Simulating step 3585/3650 (98.2%)... Cautious: 4084 | Readthrough: 5916 | Inactive: 0
# Simulating step 3588/3650 (98.3%)... Cautious: 4110 | Readthrough: 5890 | Inactive: 0
# Simulating step 3591/3650 (98.4%)... Cautious: 4110 | Readthrough: 5890 | Inactive: 0
# Simulating step 3594/3650 (98.5%)... Cautious: 4143 | Readthrough: 5857 | Inactive: 0
# Simulating step 3597/3650 (98.5%)... Cautious: 4143 | Readthrough: 5857 | Inactive: 0
# Simulating step 3600/3650 (98.6%)... Cautious: 4163 | Readthrough: 5837 | Inactive: 0
# Simulating step 3603/3650 (98.7%)... Cautious: 4163 | Readthrough: 5837 | Inactive: 0
# Simulating step 3606/3650 (98.8%)... Cautious: 4134 | Readthrough: 5866 | Inactive: 0
# Simulating step 3609/3650 (98.9%)... Cautious: 4134 | Readthrough: 5866 | Inactive: 0
# Simulating step 3612/3650 (99.0%)... Cautious: 4119 | Readthrough: 5881 | Inactive: 0
# Simulating step 3615/3650 (99.0%)... Cautious: 4119 | Readthrough: 5881 | Inactive: 0
# Simulating step 3618/3650 (99.1%)... Cautious: 4132 | Readthrough: 5868 | Inactive: 0
# Simulating step 3621/3650 (99.2%)... Cautious: 4132 | Readthrough: 5868 | Inactive: 0
# Simulating step 3624/3650 (99.3%)... Cautious: 4191 | Readthrough: 5809 | Inactive: 0
# Simulating step 3627/3650 (99.4%)... Cautious: 4191 | Readthrough: 5809 | Inactive: 0
# Simulating step 3630/3650 (99.5%)... Cautious: 4217 | Readthrough: 5783 | Inactive: 0
# Simulating step 3633/3650 (99.5%)... Cautious: 4217 | Readthrough: 5783 | Inactive: 0
# Simulating step 3636/3650 (99.6%)... Cautious: 4229 | Readthrough: 5771 | Inactive: 0
# Simulating step 3639/3650 (99.7%)... Cautious: 4229 | Readthrough: 5771 | Inactive: 0
# Simulating step 3642/3650 (99.8%)... Cautious: 4237 | Readthrough: 5763 | Inactive: 0
# Simulating step 3645/3650 (99.9%)... Cautious: 4237 | Readthrough: 5763 | Inactive: 0
# Simulating step 3648/3650 (99.9%)... Cautious: 4230 | Readthrough: 5770 | Inactive: 0
# No data was logged. Cannot generate plots.
