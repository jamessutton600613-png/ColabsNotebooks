# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessutton600613-png/GC/blob/main/Untitled131.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# --- 1. Environment Class ---
class Environment:
    def __init__(self, total_sim_steps, days_per_cycle=50):
        self.total_sim_steps, self.days_per_cycle, self.time = total_sim_steps, days_per_cycle, 0
        num_years = max(1, total_sim_steps / (365 * days_per_cycle))
        steps_per_year = 365 * days_per_cycle
        daily_uv_cycle = np.sin(np.linspace(0, 2 * np.pi, days_per_cycle)); daily_uv_cycle[daily_uv_cycle < 0] = 0
        full_uv, full_resources = [], []
        for _ in range(int(np.ceil(num_years))):
            uv_severity = np.random.uniform(0.8, 1.25)
            resource_bounty = np.random.uniform(0.8, 1.25)
            seasonal_cycle = np.sin(np.linspace(0, 2 * np.pi, steps_per_year))
            seasonal_amplitude_mod = (0.225 * seasonal_cycle + 0.725) * uv_severity
            seasonal_resource_mod = (-0.20 * seasonal_cycle + 0.80) * resource_bounty
            year_resources = 1200 * seasonal_resource_mod
            year_uv = [daily_uv_cycle[i % days_per_cycle] * seasonal_amplitude_mod[i] for i in range(steps_per_year)]
            full_uv.extend(year_uv); full_resources.extend(year_resources)
        self.uv_intensity = np.array(full_uv)
        self.external_resources = np.array(full_resources)

    def get_current_uv(self):
        return self.uv_intensity[self.time % len(self.uv_intensity)]
    def get_current_resources(self):
        return self.external_resources[self.time % len(self.external_resources)]
    def step(self):
        self.time += 1

# --- 2. Protoribosome Class ---
class Protoribosome:
    def __init__(self, env, strategy, initial_sequence, initial_mass=100.0):
        self.env, self.strategy, self.rna_sequence = env, strategy, list(initial_sequence)
        self.rna_mass = initial_mass
        self.atp_pool, self.mcyw_peptide_pool, self.other_peptide_pool = 500.0, 50.0, 5.0
        self.internal_ntp_stock, self.internal_aa_stock, self.internal_trp_tyr_cys_stock = 200.0, 200.0, 100.0
        self.rna_damage_level = 0.0

        self.location = 'dark_zone'
        self.status = 'ACTIVE'

        self.metabolic_efficiency = 1.0
        self.uv_damage_rate_per_uv = 1.2
        self.repair_rate, self.repair_atp_cost, self.trp_tyr_cys_for_repair_needed = 0.5, 0.0025, 0.0005
        self.uv_protection_factor, self.damage_tolerance_threshold = 0.01, 3.0
        self.atp_generation_rate_per_mcyw_uv, self.baseline_atp_generation_rate = 0.15, 0.5
        self.baseline_atp_chemosynthesis = 1.5
        self.protein_synthesis_rate, self.protein_synthesis_ntp_cost, self.protein_synthesis_aa_cost, self.protein_synthesis_atp_cost = 0.20, 0.1, 0.1, 0.02
        self.replication_rate, self.replication_ntp_cost, self.replication_atp_cost = 0.05, 1.0, 0.2
        self.rna_degradation_rate, self.atp_degradation_rate, self.peptide_degradation_rate = 0.0005, 0.025, 0.0008
        self.diffusion_rate, self.atp_from_ntp_conversion = 0.30, 0.1
        self.mutation_prob = 0.004
        self.failed_synthesis_penalty_atp = 150.0
        self.growth_rate = 0.1
        self.growth_ntp_cost = 1.0
        self.growth_atp_cost = 0.2

    def get_peptide_type(self):
        codons = ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)]
        if any(c in {'UGU', 'UGC', 'UAU', 'UAC', 'UGG'} for c in codons):
            return "MCYW"
        return "XXXX"

    def has_stop_codon(self):
        return any(c in {'UAA', 'UAG', 'UGA'} for c in ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)])

    def _decide_zone_transition(self):
        if self.location == 'dark_zone' and self.atp_pool < 450:
            self.location = 'light_zone'
        elif self.location == 'light_zone' and self.rna_damage_level > self.damage_tolerance_threshold * 0.75:
            self.location = 'dark_zone'

    def _apply_uv_damage(self, current_uv):
        if self.location == 'dark_zone' or current_uv <= 0:
            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate * 0.1)
            return

        protection = self.mcyw_peptide_pool * self.uv_protection_factor
        effective_uv = current_uv * max(0.01, 1 - protection)
        self.rna_damage_level += effective_uv * self.uv_damage_rate_per_uv

        for i in range(len(self.rna_sequence)):
            if random.random() < self.mutation_prob * effective_uv:
                self.rna_sequence[i] = random.choice("AUGC")

    def _manage_state(self, has_stop_codon_cached):
        if self.atp_pool < 0.1 or self.rna_damage_level >= self.damage_tolerance_threshold:
            self.status = 'INACTIVE'
            return

        if self.strategy == 'cautious' and has_stop_codon_cached:
            self.status = 'ARRESTED'
        elif self.status == 'ARRESTED' and not has_stop_codon_cached:
             self.status = 'ACTIVE'

        if self.status == 'ACTIVE':
            self.metabolic_efficiency = 1.25
        else:
            self.metabolic_efficiency = 1.0

    def _synthesize_protein(self, has_stop_codon_cached):
        if self.status != 'ACTIVE': return

        if self.strategy == 'readthrough' and has_stop_codon_cached:
            self.status = 'INACTIVE'
            return

        units = self.protein_synthesis_rate * self.metabolic_efficiency * 10
        required_ntp = units * self.protein_synthesis_ntp_cost
        required_atp = units * self.protein_synthesis_atp_cost
        required_aa_total = units * self.protein_synthesis_aa_cost

        is_mcyw = self.get_peptide_type() == "MCYW"

        if is_mcyw:
            required_special_aa = required_aa_total * 0.5
            required_general_aa = required_aa_total - required_special_aa
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa or
                self.internal_trp_tyr_cys_stock < required_special_aa):
                return
        else:
            required_general_aa = required_aa_total
            required_special_aa = 0
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa):
                return

        self.internal_ntp_stock -= required_ntp
        self.atp_pool -= required_atp
        self.internal_aa_stock -= required_general_aa
        self.internal_trp_tyr_cys_stock -= required_special_aa

        if is_mcyw:
            self.mcyw_peptide_pool += units
        else:
            self.other_peptide_pool += units

    def _replicate_rna(self):
        if self.status != 'ACTIVE' or self.rna_mass < 80: return None

        can_replicate = self.rna_mass * self.replication_rate * self.metabolic_efficiency

        if self.internal_ntp_stock > self.replication_ntp_cost and self.atp_pool > self.replication_atp_cost and can_replicate > 1.0:
            offspring_mass = self.rna_mass * 0.5
            self.rna_mass -= offspring_mass

            self.internal_ntp_stock -= offspring_mass * self.replication_ntp_cost
            self.atp_pool -= offspring_mass * self.replication_atp_cost
            return Protoribosome(self.env, self.strategy, "".join(self.rna_sequence), offspring_mass)
        return None

    def _repair_rna_dna(self, dna_template):
        if self.strategy == 'readthrough': return

        if self.status == 'ACTIVE':
            repair_efficiency = 1.0
        elif self.status == 'ARRESTED':
            repair_efficiency = 0.2
        else:
            return

        if "".join(self.rna_sequence) != dna_template:
            for i in range(len(self.rna_sequence)):
                if self.rna_sequence[i] != dna_template[i]:
                    if random.random() < repair_efficiency:
                        if self.atp_pool >= self.repair_atp_cost and self.internal_trp_tyr_cys_stock >= self.trp_tyr_cys_for_repair_needed:
                            self.atp_pool -= self.repair_atp_cost
                            self.internal_trp_tyr_cys_stock -= self.trp_tyr_cys_for_repair_needed
                            self.rna_sequence[i] = dna_template[i]
                            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate)
                    break

    def _diffuse_resources(self):
        if self.status == 'INACTIVE': return
        available = self.env.get_current_resources()
        if available > 0:
            amount = available * self.diffusion_rate
            self.internal_ntp_stock += amount * 0.50
            self.internal_aa_stock += amount * 0.45
            self.internal_trp_tyr_cys_stock += amount * 0.05

    def _grow_mass(self):
        if self.status != 'ACTIVE': return

        potential_growth = self.rna_mass * self.growth_rate * self.metabolic_efficiency
        ntp_cost = potential_growth * self.growth_ntp_cost
        atp_cost = potential_growth * self.growth_atp_cost

        if self.internal_ntp_stock >= ntp_cost and self.atp_pool >= atp_cost:
            self.internal_ntp_stock -= ntp_cost
            self.atp_pool -= atp_cost
            self.rna_mass += potential_growth

    def step(self, current_uv, dna_template):
        if self.status == 'INACTIVE': return None

        self._decide_zone_transition()
        self._apply_uv_damage(current_uv)
        self._repair_rna_dna(dna_template)

        has_stop = self.has_stop_codon()
        self._manage_state(has_stop)

        if self.status == 'INACTIVE': return None

        self._diffuse_resources()
        self._grow_mass()

        self.atp_pool += self.baseline_atp_chemosynthesis
        self.atp_pool *= (1 - self.atp_degradation_rate)

        if self.location == 'light_zone' and current_uv > 0:
            self.atp_pool += (self.atp_generation_rate_per_mcyw_uv * self.mcyw_peptide_pool * current_uv)

        self._synthesize_protein(has_stop)
        if self.status == 'INACTIVE': return None

        return self._replicate_rna()

# --- 3. Colony Class ---
class Colony:
    def __init__(self, env, dna_template, initial_pop_size, steps_per_day):
        self.env = env
        self.dna_template = dna_template
        self.active_population = [Protoribosome(env, 'cautious' if i%2==0 else 'readthrough', dna_template) for i in range(initial_pop_size)]
        self.inactive_population = []
        self.steps_per_day = steps_per_day
        self.max_population = 10000

    def step(self, current_step):
        newly_replicated = []
        current_uv = self.env.get_current_uv()

        next_active_population = []
        for protoribosome in self.active_population:
            new_offspring = protoribosome.step(current_uv, self.dna_template)

            if protoribosome.status == 'INACTIVE':
                self.inactive_population.append(protoribosome)
            else:
                next_active_population.append(protoribosome)

            if new_offspring:
                newly_replicated.append(new_offspring)

        self.active_population = next_active_population
        self.active_population.extend(newly_replicated)

        if len(self.active_population) > self.max_population:
            random.shuffle(self.active_population)
            self.active_population = self.active_population[:self.max_population]

        if current_step > 0 and current_step % self.steps_per_day == 0:
            self.inactive_population.clear()

    def get_aggregated_data(self):
        data = { 'cautious': 0, 'readthrough': 0, 'in_light_zone': 0, 'arrested': 0, 'total_damage': 0.0 }

        num_active = len(self.active_population)
        if num_active == 0:
            data['inactive'] = len(self.inactive_population)
            return data

        for p in self.active_population:
            if p.strategy == 'cautious':
                data['cautious'] += 1
                if p.status == 'ARRESTED':
                    data['arrested'] += 1
            else:
                data['readthrough'] += 1

            if p.location == 'light_zone':
                data['in_light_zone'] += 1
            data['total_damage'] += p.rna_damage_level

        data['inactive'] = len(self.inactive_population)
        data['avg_damage'] = data['total_damage'] / num_active if num_active > 0 else 0
        return data

# --- 4. Simulation and Plotting ---
def run_and_plot():
    # --- MODIFICATION: Duration set to 6 months (182 days) ---
    SIMULATION_DAYS = 182
    STEPS_PER_DAY = 10
    TOTAL_STEPS = SIMULATION_DAYS * STEPS_PER_DAY

    IDEAL_DNA_TEMPLATE = "AUGUGUUACUGG"

    env = Environment(TOTAL_STEPS, STEPS_PER_DAY)
    colony = Colony(env, IDEAL_DNA_TEMPLATE, initial_pop_size=150, steps_per_day=STEPS_PER_DAY)

    data = []
    print_interval = max(1, TOTAL_STEPS / 1000)

    for i in range(TOTAL_STEPS):
        if i % int(print_interval) == 0:
            agg_data = colony.get_aggregated_data()
            cautious_pop = agg_data.get('cautious', 0)
            readthrough_pop = agg_data.get('readthrough', 0)
            inactive_pop = agg_data.get('inactive', 0)

            print(f"Simulating step {i}/{TOTAL_STEPS} ({(i/TOTAL_STEPS)*100:.1f}%)... "
                  f"Cautious: {cautious_pop} | "
                  f"Readthrough: {readthrough_pop} | "
                  f"Inactive: {inactive_pop}", flush=True)

            if i > 200 and (cautious_pop + readthrough_pop == 0):
                print("Active population extinct. Ending simulation early.")
                break

        colony.step(i)

        if i % STEPS_PER_DAY == 0:
            agg_data = colony.get_aggregated_data()
            log_entry = {'time': env.time, 'uv': env.get_current_uv()}
            log_entry.update(agg_data)
            data.append(log_entry)

        env.step()

    if not data:
        print("No data was logged. Cannot generate plots.")
        return

    results_df = pd.DataFrame(data)

    fig, axs = plt.subplots(4, 1, figsize=(15, 16), sharex=True)
    fig.suptitle('BREAKTHRU PLUS SAFE (6 Month Simulation)', fontsize=16)
    colors = {'cautious': 'orange', 'readthrough': 'purple', 'inactive': 'grey'}

    axs[0].plot(results_df['time'], results_df['uv'], color='black', alpha=0.2, label='UV Intensity')
    axs[0].set_title('Environmental Conditions'); axs[0].set_ylabel('UV Intensity'); axs[0].legend()

    axs[1].plot(results_df['time'], results_df['cautious'], label='Cautious', color=colors['cautious'])
    axs[1].plot(results_df['time'], results_df['readthrough'], label='Readthrough', color=colors['readthrough'])
    axs[1].set_title('Active Population by Strategy'); axs[1].set_ylabel('Count'); axs[1].legend()
    axs[1].set_yscale('symlog')

    axs[2].stackplot(results_df['time'],
                     results_df['cautious'],
                     results_df['readthrough'],
                     results_df['inactive'],
                     labels=['Cautious', 'Readthrough', 'Inactive'],
                     colors=[colors['cautious'], colors['readthrough'], colors['inactive']])
    axs[2].set_title('Total Population Composition'); axs[2].set_ylabel('Total Count'); axs[2].legend(loc='upper left')

    ax3_twin = axs[3].twinx()
    axs[3].plot(results_df['time'], results_df['in_light_zone'], label='In Light Zone (Risk)', color='red', alpha=0.6)
    axs[3].plot(results_df['time'], results_df['arrested'], label='Arrested (Response)', color='blue', linestyle='--')
    ax3_twin.plot(results_df['time'], results_df['avg_damage'], label='Avg. RNA Damage', color='brown', alpha=0.7)
    axs[3].set_title('Safety & Risk Analysis'); axs[3].set_ylabel('Population Count'); ax3_twin.set_ylabel('Avg. Damage')
    axs[3].legend(loc='upper left'); ax3_twin.legend(loc='upper right')


    for ax in axs:
        ax.grid(True, linestyle=':', linewidth='0.5', color='gray')
        ax.set_xlim(0, TOTAL_STEPS)

    plt.tight_layout(rect=[0, 0, 1, 0.96]); plt.show()

if __name__ == "__main__":
    run_and_plot()
# Out:
# Simulating step 0/1820 (0.0%)... Cautious: 75 | Readthrough: 75 | Inactive: 0
# Simulating step 1/1820 (0.1%)... Cautious: 150 | Readthrough: 150 | Inactive: 0
# Simulating step 2/1820 (0.1%)... Cautious: 150 | Readthrough: 150 | Inactive: 0
# Simulating step 3/1820 (0.2%)... Cautious: 150 | Readthrough: 150 | Inactive: 0
# Simulating step 4/1820 (0.2%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 5/1820 (0.3%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 6/1820 (0.3%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 7/1820 (0.4%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 8/1820 (0.4%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 9/1820 (0.5%)... Cautious: 300 | Readthrough: 300 | Inactive: 0
# Simulating step 10/1820 (0.5%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 11/1820 (0.6%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 12/1820 (0.7%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 13/1820 (0.7%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 14/1820 (0.8%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 15/1820 (0.8%)... Cautious: 600 | Readthrough: 600 | Inactive: 0
# Simulating step 16/1820 (0.9%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 17/1820 (0.9%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 18/1820 (1.0%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 19/1820 (1.0%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 20/1820 (1.1%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 21/1820 (1.2%)... Cautious: 1200 | Readthrough: 1200 | Inactive: 0
# Simulating step 22/1820 (1.2%)... Cautious: 2400 | Readthrough: 2400 | Inactive: 0
# Simulating step 23/1820 (1.3%)... Cautious: 2400 | Readthrough: 2400 | Inactive: 0
# Simulating step 24/1820 (1.3%)... Cautious: 2400 | Readthrough: 2398 | Inactive: 2
# Simulating step 25/1820 (1.4%)... Cautious: 2400 | Readthrough: 2398 | Inactive: 2
# Simulating step 26/1820 (1.4%)... Cautious: 2400 | Readthrough: 2398 | Inactive: 2
# Simulating step 27/1820 (1.5%)... Cautious: 2400 | Readthrough: 2398 | Inactive: 2
# Simulating step 28/1820 (1.5%)... Cautious: 4800 | Readthrough: 4796 | Inactive: 2
# Simulating step 29/1820 (1.6%)... Cautious: 4800 | Readthrough: 4796 | Inactive: 2
# Simulating step 30/1820 (1.6%)... Cautious: 4800 | Readthrough: 4796 | Inactive: 2
# Simulating step 31/1820 (1.7%)... Cautious: 4800 | Readthrough: 4796 | Inactive: 0
# Simulating step 32/1820 (1.8%)... Cautious: 4800 | Readthrough: 4795 | Inactive: 1
# Simulating step 33/1820 (1.8%)... Cautious: 4800 | Readthrough: 4793 | Inactive: 3
# Simulating step 34/1820 (1.9%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 6
# Simulating step 35/1820 (1.9%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 6
# Simulating step 36/1820 (2.0%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 6
# Simulating step 37/1820 (2.0%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 6
# Simulating step 38/1820 (2.1%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 6
# Simulating step 39/1820 (2.1%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 6
# Simulating step 40/1820 (2.2%)... Cautious: 5002 | Readthrough: 4998 | Inactive: 6
# Simulating step 41/1820 (2.3%)... Cautious: 5002 | Readthrough: 4998 | Inactive: 0
# Simulating step 42/1820 (2.3%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 43/1820 (2.4%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 44/1820 (2.4%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 45/1820 (2.5%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 46/1820 (2.5%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 1
# Simulating step 47/1820 (2.6%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 1
# Simulating step 48/1820 (2.6%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 1
# Simulating step 49/1820 (2.7%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 1
# Simulating step 50/1820 (2.7%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 1
# Simulating step 51/1820 (2.8%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 0
# Simulating step 52/1820 (2.9%)... Cautious: 5018 | Readthrough: 4982 | Inactive: 1
# Simulating step 53/1820 (2.9%)... Cautious: 5018 | Readthrough: 4981 | Inactive: 2
# Simulating step 54/1820 (3.0%)... Cautious: 5018 | Readthrough: 4981 | Inactive: 2
# Simulating step 55/1820 (3.0%)... Cautious: 5018 | Readthrough: 4981 | Inactive: 2
# Simulating step 56/1820 (3.1%)... Cautious: 5018 | Readthrough: 4981 | Inactive: 2
# Simulating step 57/1820 (3.1%)... Cautious: 5015 | Readthrough: 4985 | Inactive: 2
# Simulating step 58/1820 (3.2%)... Cautious: 5015 | Readthrough: 4985 | Inactive: 2
# Simulating step 59/1820 (3.2%)... Cautious: 5015 | Readthrough: 4985 | Inactive: 2
# Simulating step 60/1820 (3.3%)... Cautious: 5015 | Readthrough: 4985 | Inactive: 2
# Simulating step 61/1820 (3.4%)... Cautious: 5015 | Readthrough: 4985 | Inactive: 0
# Simulating step 62/1820 (3.4%)... Cautious: 5015 | Readthrough: 4984 | Inactive: 1
# Simulating step 63/1820 (3.5%)... Cautious: 4986 | Readthrough: 5014 | Inactive: 6
# Simulating step 64/1820 (3.5%)... Cautious: 4986 | Readthrough: 5012 | Inactive: 8
# Simulating step 65/1820 (3.6%)... Cautious: 4986 | Readthrough: 5012 | Inactive: 8
# Simulating step 66/1820 (3.6%)... Cautious: 4986 | Readthrough: 5012 | Inactive: 8
# Simulating step 67/1820 (3.7%)... Cautious: 4986 | Readthrough: 5012 | Inactive: 8
# Simulating step 68/1820 (3.7%)... Cautious: 4986 | Readthrough: 5012 | Inactive: 8
# Simulating step 69/1820 (3.8%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 8
# Simulating step 70/1820 (3.8%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 8
# Simulating step 71/1820 (3.9%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 0
# Simulating step 72/1820 (4.0%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 0
# Simulating step 73/1820 (4.0%)... Cautious: 5012 | Readthrough: 4986 | Inactive: 2
# Simulating step 74/1820 (4.1%)... Cautious: 5012 | Readthrough: 4985 | Inactive: 3
# Simulating step 75/1820 (4.1%)... Cautious: 5000 | Readthrough: 5000 | Inactive: 3
# Simulating step 76/1820 (4.2%)... Cautious: 5000 | Readthrough: 5000 | Inactive: 3
# Simulating step 77/1820 (4.2%)... Cautious: 5000 | Readthrough: 5000 | Inactive: 3
# Simulating step 78/1820 (4.3%)... Cautious: 5000 | Readthrough: 5000 | Inactive: 3
# Simulating step 79/1820 (4.3%)... Cautious: 5000 | Readthrough: 5000 | Inactive: 3
# Simulating step 80/1820 (4.4%)... Cautious: 5000 | Readthrough: 5000 | Inactive: 3
# Simulating step 81/1820 (4.5%)... Cautious: 5015 | Readthrough: 4985 | Inactive: 0
# Simulating step 82/1820 (4.5%)... Cautious: 5015 | Readthrough: 4982 | Inactive: 3
# Simulating step 83/1820 (4.6%)... Cautious: 5015 | Readthrough: 4980 | Inactive: 5
# Simulating step 84/1820 (4.6%)... Cautious: 5015 | Readthrough: 4978 | Inactive: 7
# Simulating step 85/1820 (4.7%)... Cautious: 5015 | Readthrough: 4977 | Inactive: 8
# Simulating step 86/1820 (4.7%)... Cautious: 5015 | Readthrough: 4977 | Inactive: 8
# Simulating step 87/1820 (4.8%)... Cautious: 5120 | Readthrough: 4880 | Inactive: 8
# Simulating step 88/1820 (4.8%)... Cautious: 5120 | Readthrough: 4880 | Inactive: 8
# Simulating step 89/1820 (4.9%)... Cautious: 5120 | Readthrough: 4880 | Inactive: 8
# Simulating step 90/1820 (4.9%)... Cautious: 5120 | Readthrough: 4880 | Inactive: 8
# Simulating step 91/1820 (5.0%)... Cautious: 5120 | Readthrough: 4880 | Inactive: 0
# Simulating step 92/1820 (5.1%)... Cautious: 5120 | Readthrough: 4880 | Inactive: 0
# Simulating step 93/1820 (5.1%)... Cautious: 5093 | Readthrough: 4907 | Inactive: 7
# Simulating step 94/1820 (5.2%)... Cautious: 5093 | Readthrough: 4906 | Inactive: 8
# Simulating step 95/1820 (5.2%)... Cautious: 5093 | Readthrough: 4906 | Inactive: 8
# Simulating step 96/1820 (5.3%)... Cautious: 5093 | Readthrough: 4906 | Inactive: 8
# Simulating step 97/1820 (5.3%)... Cautious: 5093 | Readthrough: 4906 | Inactive: 8
# Simulating step 98/1820 (5.4%)... Cautious: 5093 | Readthrough: 4906 | Inactive: 8
# Simulating step 99/1820 (5.4%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 8
# Simulating step 100/1820 (5.5%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 8
# Simulating step 101/1820 (5.5%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 0
# Simulating step 102/1820 (5.6%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 0
# Simulating step 103/1820 (5.7%)... Cautious: 5103 | Readthrough: 4895 | Inactive: 2
# Simulating step 104/1820 (5.7%)... Cautious: 5103 | Readthrough: 4895 | Inactive: 2
# Simulating step 105/1820 (5.8%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 4
# Simulating step 106/1820 (5.8%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 4
# Simulating step 107/1820 (5.9%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 4
# Simulating step 108/1820 (5.9%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 4
# Simulating step 109/1820 (6.0%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 4
# Simulating step 110/1820 (6.0%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 4
# Simulating step 111/1820 (6.1%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 0
# Simulating step 112/1820 (6.2%)... Cautious: 5105 | Readthrough: 4894 | Inactive: 1
# Simulating step 113/1820 (6.2%)... Cautious: 5105 | Readthrough: 4894 | Inactive: 1
# Simulating step 114/1820 (6.3%)... Cautious: 5105 | Readthrough: 4891 | Inactive: 4
# Simulating step 115/1820 (6.3%)... Cautious: 5105 | Readthrough: 4891 | Inactive: 4
# Simulating step 116/1820 (6.4%)... Cautious: 5091 | Readthrough: 4909 | Inactive: 4
# Simulating step 117/1820 (6.4%)... Cautious: 5091 | Readthrough: 4909 | Inactive: 4
# Simulating step 118/1820 (6.5%)... Cautious: 5091 | Readthrough: 4909 | Inactive: 4
# Simulating step 119/1820 (6.5%)... Cautious: 5091 | Readthrough: 4909 | Inactive: 4
# Simulating step 120/1820 (6.6%)... Cautious: 5091 | Readthrough: 4909 | Inactive: 4
# Simulating step 121/1820 (6.6%)... Cautious: 5091 | Readthrough: 4909 | Inactive: 0
# Simulating step 122/1820 (6.7%)... Cautious: 5062 | Readthrough: 4938 | Inactive: 6
# Simulating step 123/1820 (6.8%)... Cautious: 5062 | Readthrough: 4934 | Inactive: 10
# Simulating step 124/1820 (6.8%)... Cautious: 5062 | Readthrough: 4931 | Inactive: 13
# Simulating step 125/1820 (6.9%)... Cautious: 5062 | Readthrough: 4931 | Inactive: 13
# Simulating step 126/1820 (6.9%)... Cautious: 5062 | Readthrough: 4931 | Inactive: 13
# Simulating step 127/1820 (7.0%)... Cautious: 5062 | Readthrough: 4931 | Inactive: 13
# Simulating step 128/1820 (7.0%)... Cautious: 5062 | Readthrough: 4938 | Inactive: 13
# Simulating step 129/1820 (7.1%)... Cautious: 5062 | Readthrough: 4938 | Inactive: 13
# Simulating step 130/1820 (7.1%)... Cautious: 5062 | Readthrough: 4938 | Inactive: 13
# Simulating step 131/1820 (7.2%)... Cautious: 5062 | Readthrough: 4938 | Inactive: 0
# Simulating step 132/1820 (7.3%)... Cautious: 5062 | Readthrough: 4936 | Inactive: 2
# Simulating step 133/1820 (7.3%)... Cautious: 5062 | Readthrough: 4936 | Inactive: 2
# Simulating step 134/1820 (7.4%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 8
# Simulating step 135/1820 (7.4%)... Cautious: 5009 | Readthrough: 4989 | Inactive: 10
# Simulating step 136/1820 (7.5%)... Cautious: 5009 | Readthrough: 4989 | Inactive: 10
# Simulating step 137/1820 (7.5%)... Cautious: 5009 | Readthrough: 4989 | Inactive: 10
# Simulating step 138/1820 (7.6%)... Cautious: 5009 | Readthrough: 4989 | Inactive: 10
# Simulating step 139/1820 (7.6%)... Cautious: 5009 | Readthrough: 4989 | Inactive: 10
# Simulating step 140/1820 (7.7%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 10
# Simulating step 141/1820 (7.7%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 142/1820 (7.8%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 143/1820 (7.9%)... Cautious: 5009 | Readthrough: 4990 | Inactive: 1
# Simulating step 144/1820 (7.9%)... Cautious: 5009 | Readthrough: 4987 | Inactive: 4
# Simulating step 145/1820 (8.0%)... Cautious: 5009 | Readthrough: 4987 | Inactive: 4
# Simulating step 146/1820 (8.0%)... Cautious: 5046 | Readthrough: 4954 | Inactive: 4
# Simulating step 147/1820 (8.1%)... Cautious: 5046 | Readthrough: 4954 | Inactive: 4
# Simulating step 148/1820 (8.1%)... Cautious: 5046 | Readthrough: 4954 | Inactive: 4
# Simulating step 149/1820 (8.2%)... Cautious: 5046 | Readthrough: 4954 | Inactive: 4
# Simulating step 150/1820 (8.2%)... Cautious: 5046 | Readthrough: 4954 | Inactive: 4
# Simulating step 151/1820 (8.3%)... Cautious: 5046 | Readthrough: 4954 | Inactive: 0
# Simulating step 152/1820 (8.4%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 5
# Simulating step 153/1820 (8.4%)... Cautious: 5105 | Readthrough: 4893 | Inactive: 7
# Simulating step 154/1820 (8.5%)... Cautious: 5105 | Readthrough: 4891 | Inactive: 9
# Simulating step 155/1820 (8.5%)... Cautious: 5105 | Readthrough: 4890 | Inactive: 10
# Simulating step 156/1820 (8.6%)... Cautious: 5105 | Readthrough: 4890 | Inactive: 10
# Simulating step 157/1820 (8.6%)... Cautious: 5082 | Readthrough: 4918 | Inactive: 10
# Simulating step 158/1820 (8.7%)... Cautious: 5082 | Readthrough: 4918 | Inactive: 10
# Simulating step 159/1820 (8.7%)... Cautious: 5082 | Readthrough: 4918 | Inactive: 10
# Simulating step 160/1820 (8.8%)... Cautious: 5082 | Readthrough: 4918 | Inactive: 10
# Simulating step 161/1820 (8.8%)... Cautious: 5082 | Readthrough: 4918 | Inactive: 0
# Simulating step 162/1820 (8.9%)... Cautious: 5082 | Readthrough: 4916 | Inactive: 2
# Simulating step 163/1820 (9.0%)... Cautious: 5058 | Readthrough: 4942 | Inactive: 8
# Simulating step 164/1820 (9.0%)... Cautious: 5058 | Readthrough: 4938 | Inactive: 12
# Simulating step 165/1820 (9.1%)... Cautious: 5058 | Readthrough: 4938 | Inactive: 12
# Simulating step 166/1820 (9.1%)... Cautious: 5058 | Readthrough: 4938 | Inactive: 12
# Simulating step 167/1820 (9.2%)... Cautious: 5058 | Readthrough: 4938 | Inactive: 12
# Simulating step 168/1820 (9.2%)... Cautious: 5058 | Readthrough: 4938 | Inactive: 12
# Simulating step 169/1820 (9.3%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 12
# Simulating step 170/1820 (9.3%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 12
# Simulating step 171/1820 (9.4%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 0
# Simulating step 172/1820 (9.5%)... Cautious: 5027 | Readthrough: 4970 | Inactive: 3
# Simulating step 173/1820 (9.5%)... Cautious: 5027 | Readthrough: 4970 | Inactive: 3
# Simulating step 174/1820 (9.6%)... Cautious: 5027 | Readthrough: 4967 | Inactive: 6
# Simulating step 175/1820 (9.6%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 11
# Simulating step 176/1820 (9.7%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 11
# Simulating step 177/1820 (9.7%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 11
# Simulating step 178/1820 (9.8%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 11
# Simulating step 179/1820 (9.8%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 11
# Simulating step 180/1820 (9.9%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 11
# Simulating step 181/1820 (9.9%)... Cautious: 5030 | Readthrough: 4970 | Inactive: 0
# Simulating step 182/1820 (10.0%)... Cautious: 5030 | Readthrough: 4969 | Inactive: 1
# Simulating step 183/1820 (10.1%)... Cautious: 5030 | Readthrough: 4966 | Inactive: 4
# Simulating step 184/1820 (10.1%)... Cautious: 5030 | Readthrough: 4963 | Inactive: 7
# Simulating step 185/1820 (10.2%)... Cautious: 5030 | Readthrough: 4962 | Inactive: 8
# Simulating step 186/1820 (10.2%)... Cautious: 5030 | Readthrough: 4962 | Inactive: 8
# Simulating step 187/1820 (10.3%)... Cautious: 5040 | Readthrough: 4960 | Inactive: 8
# Simulating step 188/1820 (10.3%)... Cautious: 5040 | Readthrough: 4960 | Inactive: 8
# Simulating step 189/1820 (10.4%)... Cautious: 5040 | Readthrough: 4960 | Inactive: 8
# Simulating step 190/1820 (10.4%)... Cautious: 5040 | Readthrough: 4960 | Inactive: 8
# Simulating step 191/1820 (10.5%)... Cautious: 5040 | Readthrough: 4960 | Inactive: 0
# Simulating step 192/1820 (10.5%)... Cautious: 5040 | Readthrough: 4958 | Inactive: 2
# Simulating step 193/1820 (10.6%)... Cautious: 5012 | Readthrough: 4988 | Inactive: 5
# Simulating step 194/1820 (10.7%)... Cautious: 5012 | Readthrough: 4987 | Inactive: 6
# Simulating step 195/1820 (10.7%)... Cautious: 5012 | Readthrough: 4986 | Inactive: 7
# Simulating step 196/1820 (10.8%)... Cautious: 5012 | Readthrough: 4986 | Inactive: 7
# Simulating step 197/1820 (10.8%)... Cautious: 5012 | Readthrough: 4986 | Inactive: 7
# Simulating step 198/1820 (10.9%)... Cautious: 5012 | Readthrough: 4986 | Inactive: 7
# Simulating step 199/1820 (10.9%)... Cautious: 5020 | Readthrough: 4980 | Inactive: 7
# Simulating step 200/1820 (11.0%)... Cautious: 5020 | Readthrough: 4980 | Inactive: 7
# Simulating step 201/1820 (11.0%)... Cautious: 5020 | Readthrough: 4980 | Inactive: 0
# Simulating step 202/1820 (11.1%)... Cautious: 5020 | Readthrough: 4978 | Inactive: 2
# Simulating step 203/1820 (11.2%)... Cautious: 5020 | Readthrough: 4977 | Inactive: 3
# Simulating step 204/1820 (11.2%)... Cautious: 5020 | Readthrough: 4976 | Inactive: 4
# Simulating step 205/1820 (11.3%)... Cautious: 5052 | Readthrough: 4948 | Inactive: 6
# Simulating step 206/1820 (11.3%)... Cautious: 5052 | Readthrough: 4948 | Inactive: 6
# Simulating step 207/1820 (11.4%)... Cautious: 5052 | Readthrough: 4948 | Inactive: 6
# Simulating step 208/1820 (11.4%)... Cautious: 5052 | Readthrough: 4948 | Inactive: 6
# Simulating step 209/1820 (11.5%)... Cautious: 5052 | Readthrough: 4948 | Inactive: 6
# Simulating step 210/1820 (11.5%)... Cautious: 5064 | Readthrough: 4936 | Inactive: 6
# Simulating step 211/1820 (11.6%)... Cautious: 5064 | Readthrough: 4936 | Inactive: 0
# Simulating step 212/1820 (11.6%)... Cautious: 5064 | Readthrough: 4935 | Inactive: 1
# Simulating step 213/1820 (11.7%)... Cautious: 5064 | Readthrough: 4930 | Inactive: 6
# Simulating step 214/1820 (11.8%)... Cautious: 5064 | Readthrough: 4928 | Inactive: 8
# Simulating step 215/1820 (11.8%)... Cautious: 5064 | Readthrough: 4927 | Inactive: 9
# Simulating step 216/1820 (11.9%)... Cautious: 5037 | Readthrough: 4963 | Inactive: 9
# Simulating step 217/1820 (11.9%)... Cautious: 5037 | Readthrough: 4963 | Inactive: 9
# Simulating step 218/1820 (12.0%)... Cautious: 5037 | Readthrough: 4963 | Inactive: 9
# Simulating step 219/1820 (12.0%)... Cautious: 5037 | Readthrough: 4963 | Inactive: 9
# Simulating step 220/1820 (12.1%)... Cautious: 5037 | Readthrough: 4963 | Inactive: 9
# Simulating step 221/1820 (12.1%)... Cautious: 5037 | Readthrough: 4963 | Inactive: 0
# Simulating step 222/1820 (12.2%)... Cautious: 4986 | Readthrough: 5014 | Inactive: 3
# Simulating step 223/1820 (12.3%)... Cautious: 4986 | Readthrough: 5014 | Inactive: 3
# Simulating step 224/1820 (12.3%)... Cautious: 4986 | Readthrough: 5013 | Inactive: 4
# Simulating step 225/1820 (12.4%)... Cautious: 4986 | Readthrough: 5013 | Inactive: 4
# Simulating step 226/1820 (12.4%)... Cautious: 4986 | Readthrough: 5013 | Inactive: 4
# Simulating step 227/1820 (12.5%)... Cautious: 4986 | Readthrough: 5013 | Inactive: 4
# Simulating step 228/1820 (12.5%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 4
# Simulating step 229/1820 (12.6%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 4
# Simulating step 230/1820 (12.6%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 4
# Simulating step 231/1820 (12.7%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 0
# Simulating step 232/1820 (12.7%)... Cautious: 5045 | Readthrough: 4954 | Inactive: 1
# Simulating step 233/1820 (12.8%)... Cautious: 5045 | Readthrough: 4954 | Inactive: 1
# Simulating step 234/1820 (12.9%)... Cautious: 4996 | Readthrough: 5004 | Inactive: 7
# Simulating step 235/1820 (12.9%)... Cautious: 4996 | Readthrough: 5004 | Inactive: 7
# Simulating step 236/1820 (13.0%)... Cautious: 4996 | Readthrough: 5004 | Inactive: 7
# Simulating step 237/1820 (13.0%)... Cautious: 4996 | Readthrough: 5004 | Inactive: 7
# Simulating step 238/1820 (13.1%)... Cautious: 4996 | Readthrough: 5004 | Inactive: 7
# Simulating step 239/1820 (13.1%)... Cautious: 4996 | Readthrough: 5004 | Inactive: 7
# Simulating step 240/1820 (13.2%)... Cautious: 4934 | Readthrough: 5066 | Inactive: 7
# Simulating step 241/1820 (13.2%)... Cautious: 4934 | Readthrough: 5066 | Inactive: 0
# Simulating step 242/1820 (13.3%)... Cautious: 4934 | Readthrough: 5065 | Inactive: 1
# Simulating step 243/1820 (13.4%)... Cautious: 4934 | Readthrough: 5065 | Inactive: 1
# Simulating step 244/1820 (13.4%)... Cautious: 4934 | Readthrough: 5063 | Inactive: 3
# Simulating step 245/1820 (13.5%)... Cautious: 4934 | Readthrough: 5061 | Inactive: 5
# Simulating step 246/1820 (13.5%)... Cautious: 4905 | Readthrough: 5095 | Inactive: 5
# Simulating step 247/1820 (13.6%)... Cautious: 4905 | Readthrough: 5095 | Inactive: 5
# Simulating step 248/1820 (13.6%)... Cautious: 4905 | Readthrough: 5095 | Inactive: 5
# Simulating step 249/1820 (13.7%)... Cautious: 4905 | Readthrough: 5095 | Inactive: 5
# Simulating step 250/1820 (13.7%)... Cautious: 4905 | Readthrough: 5095 | Inactive: 5
# Simulating step 251/1820 (13.8%)... Cautious: 4905 | Readthrough: 5095 | Inactive: 0
# Simulating step 252/1820 (13.8%)... Cautious: 4910 | Readthrough: 5090 | Inactive: 4
# Simulating step 253/1820 (13.9%)... Cautious: 4910 | Readthrough: 5089 | Inactive: 5
# Simulating step 254/1820 (14.0%)... Cautious: 4910 | Readthrough: 5088 | Inactive: 6
# Simulating step 255/1820 (14.0%)... Cautious: 4910 | Readthrough: 5088 | Inactive: 6
# Simulating step 256/1820 (14.1%)... Cautious: 4910 | Readthrough: 5088 | Inactive: 6
# Simulating step 257/1820 (14.1%)... Cautious: 4910 | Readthrough: 5088 | Inactive: 6
# Simulating step 258/1820 (14.2%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 6
# Simulating step 259/1820 (14.2%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 6
# Simulating step 260/1820 (14.3%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 6
# Simulating step 261/1820 (14.3%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 0
# Simulating step 262/1820 (14.4%)... Cautious: 5024 | Readthrough: 4975 | Inactive: 1
# Simulating step 263/1820 (14.5%)... Cautious: 5082 | Readthrough: 4918 | Inactive: 1
# Simulating step 264/1820 (14.5%)... Cautious: 5084 | Readthrough: 4916 | Inactive: 3
# Simulating step 265/1820 (14.6%)... Cautious: 5084 | Readthrough: 4916 | Inactive: 3
# Simulating step 266/1820 (14.6%)... Cautious: 5084 | Readthrough: 4916 | Inactive: 3
# Simulating step 267/1820 (14.7%)... Cautious: 5084 | Readthrough: 4916 | Inactive: 3
# Simulating step 268/1820 (14.7%)... Cautious: 5084 | Readthrough: 4916 | Inactive: 3
# Simulating step 269/1820 (14.8%)... Cautious: 5057 | Readthrough: 4943 | Inactive: 3
# Simulating step 270/1820 (14.8%)... Cautious: 5057 | Readthrough: 4943 | Inactive: 3
# Simulating step 271/1820 (14.9%)... Cautious: 5057 | Readthrough: 4943 | Inactive: 0
# Simulating step 272/1820 (14.9%)... Cautious: 5057 | Readthrough: 4943 | Inactive: 0
# Simulating step 273/1820 (15.0%)... Cautious: 5057 | Readthrough: 4942 | Inactive: 1
# Simulating step 274/1820 (15.1%)... Cautious: 5057 | Readthrough: 4941 | Inactive: 2
# Simulating step 275/1820 (15.1%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 2
# Simulating step 276/1820 (15.2%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 2
# Simulating step 277/1820 (15.2%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 2
# Simulating step 278/1820 (15.3%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 2
# Simulating step 279/1820 (15.3%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 2
# Simulating step 280/1820 (15.4%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 2
# Simulating step 281/1820 (15.4%)... Cautious: 5104 | Readthrough: 4896 | Inactive: 0
# Simulating step 282/1820 (15.5%)... Cautious: 5104 | Readthrough: 4895 | Inactive: 1
# Simulating step 283/1820 (15.5%)... Cautious: 5104 | Readthrough: 4895 | Inactive: 1
# Simulating step 284/1820 (15.6%)... Cautious: 5104 | Readthrough: 4893 | Inactive: 3
# Simulating step 285/1820 (15.7%)... Cautious: 5104 | Readthrough: 4892 | Inactive: 4
# Simulating step 286/1820 (15.7%)... Cautious: 5104 | Readthrough: 4892 | Inactive: 4
# Simulating step 287/1820 (15.8%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 4
# Simulating step 288/1820 (15.8%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 4
# Simulating step 289/1820 (15.9%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 4
# Simulating step 290/1820 (15.9%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 4
# Simulating step 291/1820 (16.0%)... Cautious: 5105 | Readthrough: 4895 | Inactive: 0
# Simulating step 292/1820 (16.0%)... Cautious: 5105 | Readthrough: 4894 | Inactive: 1
# Simulating step 293/1820 (16.1%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 7
# Simulating step 294/1820 (16.2%)... Cautious: 5108 | Readthrough: 4890 | Inactive: 9
# Simulating step 295/1820 (16.2%)... Cautious: 5108 | Readthrough: 4890 | Inactive: 9
# Simulating step 296/1820 (16.3%)... Cautious: 5108 | Readthrough: 4890 | Inactive: 9
# Simulating step 297/1820 (16.3%)... Cautious: 5108 | Readthrough: 4890 | Inactive: 9
# Simulating step 298/1820 (16.4%)... Cautious: 5108 | Readthrough: 4890 | Inactive: 9
# Simulating step 299/1820 (16.4%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 9
# Simulating step 300/1820 (16.5%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 9
# Simulating step 301/1820 (16.5%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 0
# Simulating step 302/1820 (16.6%)... Cautious: 5108 | Readthrough: 4890 | Inactive: 2
# Simulating step 303/1820 (16.6%)... Cautious: 5108 | Readthrough: 4888 | Inactive: 4
# Simulating step 304/1820 (16.7%)... Cautious: 5108 | Readthrough: 4888 | Inactive: 4
# Simulating step 305/1820 (16.8%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 4
# Simulating step 306/1820 (16.8%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 4
# Simulating step 307/1820 (16.9%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 4
# Simulating step 308/1820 (16.9%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 4
# Simulating step 309/1820 (17.0%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 4
# Simulating step 310/1820 (17.0%)... Cautious: 5115 | Readthrough: 4885 | Inactive: 4
# Simulating step 311/1820 (17.1%)... Cautious: 5062 | Readthrough: 4938 | Inactive: 0
# Simulating step 312/1820 (17.1%)... Cautious: 5062 | Readthrough: 4937 | Inactive: 1
# Simulating step 313/1820 (17.2%)... Cautious: 5062 | Readthrough: 4930 | Inactive: 8
# Simulating step 314/1820 (17.3%)... Cautious: 5062 | Readthrough: 4929 | Inactive: 9
# Simulating step 315/1820 (17.3%)... Cautious: 5062 | Readthrough: 4927 | Inactive: 11
# Simulating step 316/1820 (17.4%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 11
# Simulating step 317/1820 (17.4%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 11
# Simulating step 318/1820 (17.5%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 11
# Simulating step 319/1820 (17.5%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 11
# Simulating step 320/1820 (17.6%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 11
# Simulating step 321/1820 (17.6%)... Cautious: 5103 | Readthrough: 4897 | Inactive: 0
# Simulating step 322/1820 (17.7%)... Cautious: 5057 | Readthrough: 4943 | Inactive: 2
# Simulating step 323/1820 (17.7%)... Cautious: 5057 | Readthrough: 4941 | Inactive: 4
# Simulating step 324/1820 (17.8%)... Cautious: 5057 | Readthrough: 4936 | Inactive: 9
# Simulating step 325/1820 (17.9%)... Cautious: 5057 | Readthrough: 4933 | Inactive: 12
# Simulating step 326/1820 (17.9%)... Cautious: 5057 | Readthrough: 4933 | Inactive: 12
# Simulating step 327/1820 (18.0%)... Cautious: 5057 | Readthrough: 4933 | Inactive: 12
# Simulating step 328/1820 (18.0%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 12
# Simulating step 329/1820 (18.1%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 12
# Simulating step 330/1820 (18.1%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 12
# Simulating step 331/1820 (18.2%)... Cautious: 5060 | Readthrough: 4940 | Inactive: 0
# Simulating step 332/1820 (18.2%)... Cautious: 5060 | Readthrough: 4938 | Inactive: 2
# Simulating step 333/1820 (18.3%)... Cautious: 5060 | Readthrough: 4937 | Inactive: 3
# Simulating step 334/1820 (18.4%)... Cautious: 5075 | Readthrough: 4925 | Inactive: 8
# Simulating step 335/1820 (18.4%)... Cautious: 5075 | Readthrough: 4925 | Inactive: 8
# Simulating step 336/1820 (18.5%)... Cautious: 5075 | Readthrough: 4925 | Inactive: 8
# Simulating step 337/1820 (18.5%)... Cautious: 5075 | Readthrough: 4925 | Inactive: 8
# Simulating step 338/1820 (18.6%)... Cautious: 5075 | Readthrough: 4925 | Inactive: 8
# Simulating step 339/1820 (18.6%)... Cautious: 5075 | Readthrough: 4925 | Inactive: 8
# Simulating step 340/1820 (18.7%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 8
# Simulating step 341/1820 (18.7%)... Cautious: 4998 | Readthrough: 5002 | Inactive: 0
# Simulating step 342/1820 (18.8%)... Cautious: 4998 | Readthrough: 5001 | Inactive: 1
# Simulating step 343/1820 (18.8%)... Cautious: 4998 | Readthrough: 4998 | Inactive: 4
# Simulating step 344/1820 (18.9%)... Cautious: 4998 | Readthrough: 4996 | Inactive: 6
# Simulating step 345/1820 (19.0%)... Cautious: 4998 | Readthrough: 4996 | Inactive: 6
# Simulating step 346/1820 (19.0%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 6
# Simulating step 347/1820 (19.1%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 6
# Simulating step 348/1820 (19.1%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 6
# Simulating step 349/1820 (19.2%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 6
# Simulating step 350/1820 (19.2%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 6
# Simulating step 351/1820 (19.3%)... Cautious: 5007 | Readthrough: 4993 | Inactive: 0
# Simulating step 352/1820 (19.3%)... Cautious: 5036 | Readthrough: 4964 | Inactive: 1
# Simulating step 353/1820 (19.4%)... Cautious: 5036 | Readthrough: 4961 | Inactive: 4
# Simulating step 354/1820 (19.5%)... Cautious: 5036 | Readthrough: 4960 | Inactive: 5
# Simulating step 355/1820 (19.5%)... Cautious: 5036 | Readthrough: 4960 | Inactive: 5
# Simulating step 356/1820 (19.6%)... Cautious: 5036 | Readthrough: 4960 | Inactive: 5
# Simulating step 357/1820 (19.6%)... Cautious: 5036 | Readthrough: 4960 | Inactive: 5
# Simulating step 358/1820 (19.7%)... Cautious: 5049 | Readthrough: 4951 | Inactive: 5
# Simulating step 359/1820 (19.7%)... Cautious: 5049 | Readthrough: 4951 | Inactive: 5
# Simulating step 360/1820 (19.8%)... Cautious: 5049 | Readthrough: 4951 | Inactive: 5
# Simulating step 361/1820 (19.8%)... Cautious: 5049 | Readthrough: 4951 | Inactive: 0
# Simulating step 362/1820 (19.9%)... Cautious: 5049 | Readthrough: 4951 | Inactive: 0
# Simulating step 363/1820 (19.9%)... Cautious: 4982 | Readthrough: 5018 | Inactive: 0
# Simulating step 364/1820 (20.0%)... Cautious: 4982 | Readthrough: 5016 | Inactive: 2
# Simulating step 365/1820 (20.1%)... Cautious: 4982 | Readthrough: 5015 | Inactive: 3
# Simulating step 366/1820 (20.1%)... Cautious: 4982 | Readthrough: 5015 | Inactive: 3
# Simulating step 367/1820 (20.2%)... Cautious: 4982 | Readthrough: 5015 | Inactive: 3
# Simulating step 368/1820 (20.2%)... Cautious: 4982 | Readthrough: 5015 | Inactive: 3
# Simulating step 369/1820 (20.3%)... Cautious: 4936 | Readthrough: 5064 | Inactive: 3
# Simulating step 370/1820 (20.3%)... Cautious: 4936 | Readthrough: 5064 | Inactive: 3
# Simulating step 371/1820 (20.4%)... Cautious: 4936 | Readthrough: 5064 | Inactive: 0
# Simulating step 372/1820 (20.4%)... Cautious: 4936 | Readthrough: 5061 | Inactive: 3
# Simulating step 373/1820 (20.5%)... Cautious: 4936 | Readthrough: 5059 | Inactive: 5
# Simulating step 374/1820 (20.5%)... Cautious: 4936 | Readthrough: 5058 | Inactive: 6
# Simulating step 375/1820 (20.6%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 8
# Simulating step 376/1820 (20.7%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 8
# Simulating step 377/1820 (20.7%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 8
# Simulating step 378/1820 (20.8%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 8
# Simulating step 379/1820 (20.8%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 8
# Simulating step 380/1820 (20.9%)... Cautious: 4914 | Readthrough: 5086 | Inactive: 8
# Simulating step 381/1820 (20.9%)... Cautious: 4959 | Readthrough: 5041 | Inactive: 0
# Simulating step 382/1820 (21.0%)... Cautious: 4959 | Readthrough: 5039 | Inactive: 2
# Simulating step 383/1820 (21.0%)... Cautious: 4959 | Readthrough: 5037 | Inactive: 4
# Simulating step 384/1820 (21.1%)... Cautious: 4959 | Readthrough: 5037 | Inactive: 4
# Simulating step 385/1820 (21.2%)... Cautious: 4959 | Readthrough: 5037 | Inactive: 4
# Simulating step 386/1820 (21.2%)... Cautious: 4959 | Readthrough: 5037 | Inactive: 4
# Simulating step 387/1820 (21.3%)... Cautious: 4995 | Readthrough: 5005 | Inactive: 4
# Simulating step 388/1820 (21.3%)... Cautious: 4995 | Readthrough: 5005 | Inactive: 4
# Simulating step 389/1820 (21.4%)... Cautious: 4995 | Readthrough: 5005 | Inactive: 4
# Simulating step 390/1820 (21.4%)... Cautious: 4995 | Readthrough: 5005 | Inactive: 4
# Simulating step 391/1820 (21.5%)... Cautious: 4995 | Readthrough: 5005 | Inactive: 0
# Simulating step 392/1820 (21.5%)... Cautious: 4995 | Readthrough: 5004 | Inactive: 1
# Simulating step 393/1820 (21.6%)... Cautious: 5064 | Readthrough: 4936 | Inactive: 3
# Simulating step 394/1820 (21.6%)... Cautious: 5064 | Readthrough: 4934 | Inactive: 5
# Simulating step 395/1820 (21.7%)... Cautious: 5064 | Readthrough: 4932 | Inactive: 7
# Simulating step 396/1820 (21.8%)... Cautious: 5064 | Readthrough: 4932 | Inactive: 7
# Simulating step 397/1820 (21.8%)... Cautious: 5064 | Readthrough: 4932 | Inactive: 7
# Simulating step 398/1820 (21.9%)... Cautious: 5064 | Readthrough: 4932 | Inactive: 7
# Simulating step 399/1820 (21.9%)... Cautious: 5080 | Readthrough: 4920 | Inactive: 7
# Simulating step 400/1820 (22.0%)... Cautious: 5080 | Readthrough: 4920 | Inactive: 7
# Simulating step 401/1820 (22.0%)... Cautious: 5080 | Readthrough: 4920 | Inactive: 0
# Simulating step 402/1820 (22.1%)... Cautious: 5080 | Readthrough: 4919 | Inactive: 1
# Simulating step 403/1820 (22.1%)... Cautious: 5080 | Readthrough: 4918 | Inactive: 2
# Simulating step 404/1820 (22.2%)... Cautious: 5080 | Readthrough: 4916 | Inactive: 4
# Simulating step 405/1820 (22.3%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 7
# Simulating step 406/1820 (22.3%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 7
# Simulating step 407/1820 (22.4%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 7
# Simulating step 408/1820 (22.4%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 7
# Simulating step 409/1820 (22.5%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 7
# Simulating step 410/1820 (22.5%)... Cautious: 5083 | Readthrough: 4917 | Inactive: 7
# Simulating step 411/1820 (22.6%)... Cautious: 5047 | Readthrough: 4953 | Inactive: 0
# Simulating step 412/1820 (22.6%)... Cautious: 5047 | Readthrough: 4953 | Inactive: 0
# Simulating step 413/1820 (22.7%)... Cautious: 5047 | Readthrough: 4949 | Inactive: 4
# Simulating step 414/1820 (22.7%)... Cautious: 5047 | Readthrough: 4947 | Inactive: 6
# Simulating step 415/1820 (22.8%)... Cautious: 5047 | Readthrough: 4946 | Inactive: 7
# Simulating step 416/1820 (22.9%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 7
# Simulating step 417/1820 (22.9%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 7
# Simulating step 418/1820 (23.0%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 7
# Simulating step 419/1820 (23.0%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 7
# Simulating step 420/1820 (23.1%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 7
# Simulating step 421/1820 (23.1%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 0
# Simulating step 422/1820 (23.2%)... Cautious: 5017 | Readthrough: 4983 | Inactive: 6
# Simulating step 423/1820 (23.2%)... Cautious: 5017 | Readthrough: 4980 | Inactive: 9
# Simulating step 424/1820 (23.3%)... Cautious: 5017 | Readthrough: 4980 | Inactive: 9
# Simulating step 425/1820 (23.4%)... Cautious: 5017 | Readthrough: 4977 | Inactive: 12
# Simulating step 426/1820 (23.4%)... Cautious: 5017 | Readthrough: 4977 | Inactive: 12
# Simulating step 427/1820 (23.5%)... Cautious: 5017 | Readthrough: 4977 | Inactive: 12
# Simulating step 428/1820 (23.5%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 12
# Simulating step 429/1820 (23.6%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 12
# Simulating step 430/1820 (23.6%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 12
# Simulating step 431/1820 (23.7%)... Cautious: 5024 | Readthrough: 4976 | Inactive: 0
# Simulating step 432/1820 (23.7%)... Cautious: 5024 | Readthrough: 4972 | Inactive: 4
# Simulating step 433/1820 (23.8%)... Cautious: 5024 | Readthrough: 4969 | Inactive: 7
# Simulating step 434/1820 (23.8%)... Cautious: 5008 | Readthrough: 4992 | Inactive: 11
# Simulating step 435/1820 (23.9%)... Cautious: 5008 | Readthrough: 4991 | Inactive: 12
# Simulating step 436/1820 (24.0%)... Cautious: 5008 | Readthrough: 4991 | Inactive: 12
# Simulating step 437/1820 (24.0%)... Cautious: 5008 | Readthrough: 4991 | Inactive: 12
# Simulating step 438/1820 (24.1%)... Cautious: 5008 | Readthrough: 4991 | Inactive: 12
# Simulating step 439/1820 (24.1%)... Cautious: 5008 | Readthrough: 4991 | Inactive: 12
# Simulating step 440/1820 (24.2%)... Cautious: 5002 | Readthrough: 4998 | Inactive: 12
# Simulating step 441/1820 (24.2%)... Cautious: 5002 | Readthrough: 4998 | Inactive: 0
# Simulating step 442/1820 (24.3%)... Cautious: 5002 | Readthrough: 4998 | Inactive: 0
# Simulating step 443/1820 (24.3%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 444/1820 (24.4%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 445/1820 (24.5%)... Cautious: 5002 | Readthrough: 4997 | Inactive: 1
# Simulating step 446/1820 (24.5%)... Cautious: 4979 | Readthrough: 5021 | Inactive: 1
# Simulating step 447/1820 (24.6%)... Cautious: 4979 | Readthrough: 5021 | Inactive: 1
# Simulating step 448/1820 (24.6%)... Cautious: 4979 | Readthrough: 5021 | Inactive: 1
# Simulating step 449/1820 (24.7%)... Cautious: 4979 | Readthrough: 5021 | Inactive: 1
# Simulating step 450/1820 (24.7%)... Cautious: 4979 | Readthrough: 5021 | Inactive: 1
# Simulating step 451/1820 (24.8%)... Cautious: 4979 | Readthrough: 5021 | Inactive: 0
# Simulating step 452/1820 (24.8%)... Cautious: 4962 | Readthrough: 5038 | Inactive: 1
# Simulating step 453/1820 (24.9%)... Cautious: 4962 | Readthrough: 5035 | Inactive: 4
# Simulating step 454/1820 (24.9%)... Cautious: 4962 | Readthrough: 5035 | Inactive: 4
# Simulating step 455/1820 (25.0%)... Cautious: 4962 | Readthrough: 5034 | Inactive: 5
# Simulating step 456/1820 (25.1%)... Cautious: 4962 | Readthrough: 5034 | Inactive: 5
# Simulating step 457/1820 (25.1%)... Cautious: 4962 | Readthrough: 5034 | Inactive: 5
# Simulating step 458/1820 (25.2%)... Cautious: 4983 | Readthrough: 5017 | Inactive: 5
# Simulating step 459/1820 (25.2%)... Cautious: 4983 | Readthrough: 5017 | Inactive: 5
# Simulating step 460/1820 (25.3%)... Cautious: 4983 | Readthrough: 5017 | Inactive: 5
# Simulating step 461/1820 (25.3%)... Cautious: 4983 | Readthrough: 5017 | Inactive: 0
# Simulating step 462/1820 (25.4%)... Cautious: 4983 | Readthrough: 5015 | Inactive: 2
# Simulating step 463/1820 (25.4%)... Cautious: 4983 | Readthrough: 5013 | Inactive: 4
# Simulating step 464/1820 (25.5%)... Cautious: 5021 | Readthrough: 4979 | Inactive: 8
# Simulating step 465/1820 (25.5%)... Cautious: 5021 | Readthrough: 4978 | Inactive: 9
# Simulating step 466/1820 (25.6%)... Cautious: 5021 | Readthrough: 4978 | Inactive: 9
# Simulating step 467/1820 (25.7%)... Cautious: 5021 | Readthrough: 4978 | Inactive: 9
# Simulating step 468/1820 (25.7%)... Cautious: 5021 | Readthrough: 4978 | Inactive: 9
# Simulating step 469/1820 (25.8%)... Cautious: 4994 | Readthrough: 5006 | Inactive: 9
# Simulating step 470/1820 (25.8%)... Cautious: 4994 | Readthrough: 5006 | Inactive: 9
# Simulating step 471/1820 (25.9%)... Cautious: 4994 | Readthrough: 5006 | Inactive: 0
# Simulating step 472/1820 (25.9%)... Cautious: 4994 | Readthrough: 5005 | Inactive: 1
# Simulating step 473/1820 (26.0%)... Cautious: 4994 | Readthrough: 5005 | Inactive: 1
# Simulating step 474/1820 (26.0%)... Cautious: 4994 | Readthrough: 5005 | Inactive: 1
# Simulating step 475/1820 (26.1%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 2
# Simulating step 476/1820 (26.2%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 2
# Simulating step 477/1820 (26.2%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 2
# Simulating step 478/1820 (26.3%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 2
# Simulating step 479/1820 (26.3%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 2
# Simulating step 480/1820 (26.4%)... Cautious: 5027 | Readthrough: 4973 | Inactive: 2
# Simulating step 481/1820 (26.4%)... Cautious: 5023 | Readthrough: 4977 | Inactive: 0
# Simulating step 482/1820 (26.5%)... Cautious: 5023 | Readthrough: 4976 | Inactive: 1
# Simulating step 483/1820 (26.5%)... Cautious: 5023 | Readthrough: 4971 | Inactive: 6
# Simulating step 484/1820 (26.6%)... Cautious: 5023 | Readthrough: 4971 | Inactive: 6
# Simulating step 485/1820 (26.6%)... Cautious: 5023 | Readthrough: 4971 | Inactive: 6
# Simulating step 486/1820 (26.7%)... Cautious: 5023 | Readthrough: 4971 | Inactive: 6
# Simulating step 487/1820 (26.8%)... Cautious: 5004 | Readthrough: 4996 | Inactive: 6
# Simulating step 488/1820 (26.8%)... Cautious: 5004 | Readthrough: 4996 | Inactive: 6
# Simulating step 489/1820 (26.9%)... Cautious: 5004 | Readthrough: 4996 | Inactive: 6
# Simulating step 490/1820 (26.9%)... Cautious: 5004 | Readthrough: 4996 | Inactive: 6
# Simulating step 491/1820 (27.0%)... Cautious: 5004 | Readthrough: 4996 | Inactive: 0
# Simulating step 492/1820 (27.0%)... Cautious: 5004 | Readthrough: 4995 | Inactive: 1
# Simulating step 493/1820 (27.1%)... Cautious: 5011 | Readthrough: 4989 | Inactive: 9
# Simulating step 494/1820 (27.1%)... Cautious: 5011 | Readthrough: 4987 | Inactive: 11
# Simulating step 495/1820 (27.2%)... Cautious: 5011 | Readthrough: 4986 | Inactive: 12
# Simulating step 496/1820 (27.3%)... Cautious: 5011 | Readthrough: 4986 | Inactive: 12
# Simulating step 497/1820 (27.3%)... Cautious: 5011 | Readthrough: 4986 | Inactive: 12
# Simulating step 498/1820 (27.4%)... Cautious: 5011 | Readthrough: 4986 | Inactive: 12
# Simulating step 499/1820 (27.4%)... Cautious: 5029 | Readthrough: 4971 | Inactive: 12
# Simulating step 500/1820 (27.5%)... Cautious: 5029 | Readthrough: 4971 | Inactive: 12
# Simulating step 501/1820 (27.5%)... Cautious: 5029 | Readthrough: 4971 | Inactive: 0
# Simulating step 502/1820 (27.6%)... Cautious: 5029 | Readthrough: 4969 | Inactive: 2
# Simulating step 503/1820 (27.6%)... Cautious: 5029 | Readthrough: 4969 | Inactive: 2
# Simulating step 504/1820 (27.7%)... Cautious: 5029 | Readthrough: 4967 | Inactive: 4
# Simulating step 505/1820 (27.7%)... Cautious: 4987 | Readthrough: 5013 | Inactive: 6
# Simulating step 506/1820 (27.8%)... Cautious: 4987 | Readthrough: 5013 | Inactive: 6
# Simulating step 507/1820 (27.9%)... Cautious: 4987 | Readthrough: 5013 | Inactive: 6
# Simulating step 508/1820 (27.9%)... Cautious: 4987 | Readthrough: 5013 | Inactive: 6
# Simulating step 509/1820 (28.0%)... Cautious: 4987 | Readthrough: 5013 | Inactive: 6
# Simulating step 510/1820 (28.0%)... Cautious: 4987 | Readthrough: 5013 | Inactive: 6
# Simulating step 511/1820 (28.1%)... Cautious: 4941 | Readthrough: 5059 | Inactive: 0
# Simulating step 512/1820 (28.1%)... Cautious: 4941 | Readthrough: 5057 | Inactive: 2
# Simulating step 513/1820 (28.2%)... Cautious: 4941 | Readthrough: 5056 | Inactive: 3
# Simulating step 514/1820 (28.2%)... Cautious: 4941 | Readthrough: 5055 | Inactive: 4
# Simulating step 515/1820 (28.3%)... Cautious: 4941 | Readthrough: 5054 | Inactive: 5
# Simulating step 516/1820 (28.4%)... Cautious: 4922 | Readthrough: 5078 | Inactive: 5
# Simulating step 517/1820 (28.4%)... Cautious: 4922 | Readthrough: 5078 | Inactive: 5
# Simulating step 518/1820 (28.5%)... Cautious: 4922 | Readthrough: 5078 | Inactive: 5
# Simulating step 519/1820 (28.5%)... Cautious: 4922 | Readthrough: 5078 | Inactive: 5
# Simulating step 520/1820 (28.6%)... Cautious: 4922 | Readthrough: 5078 | Inactive: 5
# Simulating step 521/1820 (28.6%)... Cautious: 4922 | Readthrough: 5078 | Inactive: 0
# Simulating step 522/1820 (28.7%)... Cautious: 4931 | Readthrough: 5069 | Inactive: 4
# Simulating step 523/1820 (28.7%)... Cautious: 4931 | Readthrough: 5069 | Inactive: 4
# Simulating step 524/1820 (28.8%)... Cautious: 4931 | Readthrough: 5069 | Inactive: 4
# Simulating step 525/1820 (28.8%)... Cautious: 4931 | Readthrough: 5067 | Inactive: 6
# Simulating step 526/1820 (28.9%)... Cautious: 4931 | Readthrough: 5067 | Inactive: 6
# Simulating step 527/1820 (29.0%)... Cautious: 4931 | Readthrough: 5067 | Inactive: 6
# Simulating step 528/1820 (29.0%)... Cautious: 4981 | Readthrough: 5019 | Inactive: 6
# Simulating step 529/1820 (29.1%)... Cautious: 4981 | Readthrough: 5019 | Inactive: 6
# Simulating step 530/1820 (29.1%)... Cautious: 4981 | Readthrough: 5019 | Inactive: 6
# Simulating step 531/1820 (29.2%)... Cautious: 4981 | Readthrough: 5019 | Inactive: 0
# Simulating step 532/1820 (29.2%)... Cautious: 4981 | Readthrough: 5018 | Inactive: 1
# Simulating step 533/1820 (29.3%)... Cautious: 4981 | Readthrough: 5016 | Inactive: 3
# Simulating step 534/1820 (29.3%)... Cautious: 4973 | Readthrough: 5027 | Inactive: 10
# Simulating step 535/1820 (29.4%)... Cautious: 4973 | Readthrough: 5025 | Inactive: 12
# Simulating step 536/1820 (29.5%)... Cautious: 4973 | Readthrough: 5025 | Inactive: 12
# Simulating step 537/1820 (29.5%)... Cautious: 4973 | Readthrough: 5025 | Inactive: 12
# Simulating step 538/1820 (29.6%)... Cautious: 4973 | Readthrough: 5025 | Inactive: 12
# Simulating step 539/1820 (29.6%)... Cautious: 4973 | Readthrough: 5025 | Inactive: 12
# Simulating step 540/1820 (29.7%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 12
# Simulating step 541/1820 (29.7%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 0
# Simulating step 542/1820 (29.8%)... Cautious: 5009 | Readthrough: 4990 | Inactive: 1
# Simulating step 543/1820 (29.8%)... Cautious: 5009 | Readthrough: 4986 | Inactive: 5
# Simulating step 544/1820 (29.9%)... Cautious: 5009 | Readthrough: 4985 | Inactive: 6
# Simulating step 545/1820 (29.9%)... Cautious: 5009 | Readthrough: 4985 | Inactive: 6
# Simulating step 546/1820 (30.0%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 6
# Simulating step 547/1820 (30.1%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 6
# Simulating step 548/1820 (30.1%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 6
# Simulating step 549/1820 (30.2%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 6
# Simulating step 550/1820 (30.2%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 6
# Simulating step 551/1820 (30.3%)... Cautious: 5045 | Readthrough: 4955 | Inactive: 0
# Simulating step 552/1820 (30.3%)... Cautious: 4959 | Readthrough: 5041 | Inactive: 4
# Simulating step 553/1820 (30.4%)... Cautious: 4959 | Readthrough: 5038 | Inactive: 7
# Simulating step 554/1820 (30.4%)... Cautious: 4959 | Readthrough: 5036 | Inactive: 9
# Simulating step 555/1820 (30.5%)... Cautious: 4959 | Readthrough: 5036 | Inactive: 9
# Simulating step 556/1820 (30.5%)... Cautious: 4959 | Readthrough: 5036 | Inactive: 9
# Simulating step 557/1820 (30.6%)... Cautious: 4959 | Readthrough: 5036 | Inactive: 9
# Simulating step 558/1820 (30.7%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 9
# Simulating step 559/1820 (30.7%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 9
# Simulating step 560/1820 (30.8%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 9
# Simulating step 561/1820 (30.8%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 0
# Simulating step 562/1820 (30.9%)... Cautious: 4953 | Readthrough: 5047 | Inactive: 0
# Simulating step 563/1820 (30.9%)... Cautious: 4953 | Readthrough: 5046 | Inactive: 1
# Simulating step 564/1820 (31.0%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 3
# Simulating step 565/1820 (31.0%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 3
# Simulating step 566/1820 (31.1%)... Cautious: 5009 | Readthrough: 4991 | Inactive: 3
# ...
# Simulating step 1634/1820 (89.8%)... Cautious: 5272 | Readthrough: 4724 | Inactive: 4
# Simulating step 1635/1820 (89.8%)... Cautious: 5341 | Readthrough: 4659 | Inactive: 7
# Simulating step 1636/1820 (89.9%)... Cautious: 5341 | Readthrough: 4659 | Inactive: 7
# Simulating step 1637/1820 (89.9%)... Cautious: 5342 | Readthrough: 4658 | Inactive: 7
# Simulating step 1638/1820 (90.0%)... Cautious: 5342 | Readthrough: 4658 | Inactive: 7
# Simulating step 1639/1820 (90.1%)... Cautious: 5342 | Readthrough: 4658 | Inactive: 7
# Simulating step 1640/1820 (90.1%)... Cautious: 5342 | Readthrough: 4658 | Inactive: 7
# Simulating step 1641/1820 (90.2%)... Cautious: 5321 | Readthrough: 4679 | Inactive: 0
# Simulating step 1642/1820 (90.2%)... Cautious: 5321 | Readthrough: 4679 | Inactive: 0
# Simulating step 1643/1820 (90.3%)... Cautious: 5323 | Readthrough: 4675 | Inactive: 4
# Simulating step 1644/1820 (90.3%)... Cautious: 5323 | Readthrough: 4670 | Inactive: 9
# Simulating step 1645/1820 (90.4%)... Cautious: 5323 | Readthrough: 4670 | Inactive: 9
# Simulating step 1646/1820 (90.4%)... Cautious: 5341 | Readthrough: 4659 | Inactive: 9
# Simulating step 1647/1820 (90.5%)... Cautious: 5341 | Readthrough: 4659 | Inactive: 9
# Simulating step 1648/1820 (90.5%)... Cautious: 5343 | Readthrough: 4657 | Inactive: 9
# Simulating step 1649/1820 (90.6%)... Cautious: 5343 | Readthrough: 4657 | Inactive: 9
# Simulating step 1650/1820 (90.7%)... Cautious: 5343 | Readthrough: 4657 | Inactive: 9
# Simulating step 1651/1820 (90.7%)... Cautious: 5343 | Readthrough: 4657 | Inactive: 0
# Simulating step 1652/1820 (90.8%)... Cautious: 5373 | Readthrough: 4627 | Inactive: 3
# Simulating step 1653/1820 (90.8%)... Cautious: 5373 | Readthrough: 4626 | Inactive: 4
# Simulating step 1654/1820 (90.9%)... Cautious: 5377 | Readthrough: 4623 | Inactive: 6
# Simulating step 1655/1820 (90.9%)... Cautious: 5377 | Readthrough: 4623 | Inactive: 6
# Simulating step 1656/1820 (91.0%)... Cautious: 5377 | Readthrough: 4623 | Inactive: 6
# Simulating step 1657/1820 (91.0%)... Cautious: 5377 | Readthrough: 4623 | Inactive: 6
# Simulating step 1658/1820 (91.1%)... Cautious: 5365 | Readthrough: 4635 | Inactive: 6
# Simulating step 1659/1820 (91.2%)... Cautious: 5365 | Readthrough: 4635 | Inactive: 6
# Simulating step 1660/1820 (91.2%)... Cautious: 5370 | Readthrough: 4630 | Inactive: 6
# Simulating step 1661/1820 (91.3%)... Cautious: 5370 | Readthrough: 4630 | Inactive: 0
# Simulating step 1662/1820 (91.3%)... Cautious: 5370 | Readthrough: 4629 | Inactive: 1
# Simulating step 1663/1820 (91.4%)... Cautious: 5370 | Readthrough: 4628 | Inactive: 2
# Simulating step 1664/1820 (91.4%)... Cautious: 5346 | Readthrough: 4654 | Inactive: 4
# Simulating step 1665/1820 (91.5%)... Cautious: 5346 | Readthrough: 4654 | Inactive: 4
# Simulating step 1666/1820 (91.5%)... Cautious: 5350 | Readthrough: 4650 | Inactive: 4
# Simulating step 1667/1820 (91.6%)... Cautious: 5350 | Readthrough: 4650 | Inactive: 4
# Simulating step 1668/1820 (91.6%)... Cautious: 5350 | Readthrough: 4650 | Inactive: 4
# Simulating step 1669/1820 (91.7%)... Cautious: 5350 | Readthrough: 4650 | Inactive: 4
# Simulating step 1670/1820 (91.8%)... Cautious: 5330 | Readthrough: 4670 | Inactive: 4
# Simulating step 1671/1820 (91.8%)... Cautious: 5330 | Readthrough: 4670 | Inactive: 0
# Simulating step 1672/1820 (91.9%)... Cautious: 5333 | Readthrough: 4667 | Inactive: 1
# Simulating step 1673/1820 (91.9%)... Cautious: 5333 | Readthrough: 4666 | Inactive: 2
# Simulating step 1674/1820 (92.0%)... Cautious: 5333 | Readthrough: 4666 | Inactive: 2
# Simulating step 1675/1820 (92.0%)... Cautious: 5333 | Readthrough: 4665 | Inactive: 3
# Simulating step 1676/1820 (92.1%)... Cautious: 5278 | Readthrough: 4722 | Inactive: 3
# Simulating step 1677/1820 (92.1%)... Cautious: 5278 | Readthrough: 4722 | Inactive: 3
# Simulating step 1678/1820 (92.2%)... Cautious: 5280 | Readthrough: 4720 | Inactive: 3
# Simulating step 1679/1820 (92.3%)... Cautious: 5280 | Readthrough: 4720 | Inactive: 3
# Simulating step 1680/1820 (92.3%)... Cautious: 5280 | Readthrough: 4720 | Inactive: 3
# Simulating step 1681/1820 (92.4%)... Cautious: 5280 | Readthrough: 4720 | Inactive: 0
# Simulating step 1682/1820 (92.4%)... Cautious: 5304 | Readthrough: 4696 | Inactive: 2
# Simulating step 1683/1820 (92.5%)... Cautious: 5304 | Readthrough: 4695 | Inactive: 3
# Simulating step 1684/1820 (92.5%)... Cautious: 5310 | Readthrough: 4690 | Inactive: 4
# Simulating step 1685/1820 (92.6%)... Cautious: 5310 | Readthrough: 4690 | Inactive: 4
# Simulating step 1686/1820 (92.6%)... Cautious: 5310 | Readthrough: 4690 | Inactive: 4
# Simulating step 1687/1820 (92.7%)... Cautious: 5310 | Readthrough: 4690 | Inactive: 4
# Simulating step 1688/1820 (92.7%)... Cautious: 5282 | Readthrough: 4718 | Inactive: 4
# Simulating step 1689/1820 (92.8%)... Cautious: 5282 | Readthrough: 4718 | Inactive: 4
# Simulating step 1690/1820 (92.9%)... Cautious: 5286 | Readthrough: 4714 | Inactive: 4
# Simulating step 1691/1820 (92.9%)... Cautious: 5286 | Readthrough: 4714 | Inactive: 0
# Simulating step 1692/1820 (93.0%)... Cautious: 5286 | Readthrough: 4713 | Inactive: 1
# Simulating step 1693/1820 (93.0%)... Cautious: 5283 | Readthrough: 4717 | Inactive: 5
# Simulating step 1694/1820 (93.1%)... Cautious: 5283 | Readthrough: 4714 | Inactive: 8
# Simulating step 1695/1820 (93.1%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 9
# Simulating step 1696/1820 (93.2%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 9
# Simulating step 1697/1820 (93.2%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 9
# Simulating step 1698/1820 (93.3%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 9
# Simulating step 1699/1820 (93.4%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 9
# Simulating step 1700/1820 (93.4%)... Cautious: 5287 | Readthrough: 4713 | Inactive: 9
# Simulating step 1701/1820 (93.5%)... Cautious: 5290 | Readthrough: 4710 | Inactive: 0
# Simulating step 1702/1820 (93.5%)... Cautious: 5290 | Readthrough: 4707 | Inactive: 3
# Simulating step 1703/1820 (93.6%)... Cautious: 5290 | Readthrough: 4706 | Inactive: 4
# Simulating step 1704/1820 (93.6%)... Cautious: 5290 | Readthrough: 4705 | Inactive: 5
# Simulating step 1705/1820 (93.7%)... Cautious: 5239 | Readthrough: 4761 | Inactive: 6
# Simulating step 1706/1820 (93.7%)... Cautious: 5239 | Readthrough: 4761 | Inactive: 6
# Simulating step 1707/1820 (93.8%)... Cautious: 5241 | Readthrough: 4759 | Inactive: 6
# Simulating step 1708/1820 (93.8%)... Cautious: 5241 | Readthrough: 4759 | Inactive: 6
# Simulating step 1709/1820 (93.9%)... Cautious: 5241 | Readthrough: 4759 | Inactive: 6
# Simulating step 1710/1820 (94.0%)... Cautious: 5241 | Readthrough: 4759 | Inactive: 6
# Simulating step 1711/1820 (94.0%)... Cautious: 5256 | Readthrough: 4744 | Inactive: 0
# Simulating step 1712/1820 (94.1%)... Cautious: 5256 | Readthrough: 4744 | Inactive: 0
# Simulating step 1713/1820 (94.1%)... Cautious: 5259 | Readthrough: 4741 | Inactive: 3
# Simulating step 1714/1820 (94.2%)... Cautious: 5259 | Readthrough: 4740 | Inactive: 4
# Simulating step 1715/1820 (94.2%)... Cautious: 5259 | Readthrough: 4740 | Inactive: 4
# Simulating step 1716/1820 (94.3%)... Cautious: 5259 | Readthrough: 4740 | Inactive: 4
# Simulating step 1717/1820 (94.3%)... Cautious: 5350 | Readthrough: 4650 | Inactive: 4
# Simulating step 1718/1820 (94.4%)... Cautious: 5350 | Readthrough: 4650 | Inactive: 4
# Simulating step 1719/1820 (94.5%)... Cautious: 5352 | Readthrough: 4648 | Inactive: 4
# Simulating step 1720/1820 (94.5%)... Cautious: 5352 | Readthrough: 4648 | Inactive: 4
# Simulating step 1721/1820 (94.6%)... Cautious: 5352 | Readthrough: 4648 | Inactive: 0
# Simulating step 1722/1820 (94.6%)... Cautious: 5352 | Readthrough: 4648 | Inactive: 0
# Simulating step 1723/1820 (94.7%)... Cautious: 5288 | Readthrough: 4712 | Inactive: 2
# Simulating step 1724/1820 (94.7%)... Cautious: 5288 | Readthrough: 4709 | Inactive: 5
# Simulating step 1725/1820 (94.8%)... Cautious: 5290 | Readthrough: 4709 | Inactive: 5
# Simulating step 1726/1820 (94.8%)... Cautious: 5290 | Readthrough: 4709 | Inactive: 5
# Simulating step 1727/1820 (94.9%)... Cautious: 5290 | Readthrough: 4709 | Inactive: 5
# Simulating step 1728/1820 (94.9%)... Cautious: 5290 | Readthrough: 4709 | Inactive: 5
# Simulating step 1729/1820 (95.0%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 5
# Simulating step 1730/1820 (95.1%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 5
# Simulating step 1731/1820 (95.1%)... Cautious: 5265 | Readthrough: 4735 | Inactive: 0
# Simulating step 1732/1820 (95.2%)... Cautious: 5265 | Readthrough: 4734 | Inactive: 1
# Simulating step 1733/1820 (95.2%)... Cautious: 5265 | Readthrough: 4733 | Inactive: 2
# Simulating step 1734/1820 (95.3%)... Cautious: 5265 | Readthrough: 4733 | Inactive: 2
# Simulating step 1735/1820 (95.3%)... Cautious: 5292 | Readthrough: 4708 | Inactive: 2
# Simulating step 1736/1820 (95.4%)... Cautious: 5292 | Readthrough: 4708 | Inactive: 2
# Simulating step 1737/1820 (95.4%)... Cautious: 5294 | Readthrough: 4706 | Inactive: 2
# Simulating step 1738/1820 (95.5%)... Cautious: 5294 | Readthrough: 4706 | Inactive: 2
# Simulating step 1739/1820 (95.5%)... Cautious: 5294 | Readthrough: 4706 | Inactive: 2
# Simulating step 1740/1820 (95.6%)... Cautious: 5294 | Readthrough: 4706 | Inactive: 2
# Simulating step 1741/1820 (95.7%)... Cautious: 5278 | Readthrough: 4722 | Inactive: 0
# Simulating step 1742/1820 (95.7%)... Cautious: 5278 | Readthrough: 4720 | Inactive: 2
# Simulating step 1743/1820 (95.8%)... Cautious: 5281 | Readthrough: 4719 | Inactive: 2
# Simulating step 1744/1820 (95.8%)... Cautious: 5281 | Readthrough: 4718 | Inactive: 3
# Simulating step 1745/1820 (95.9%)... Cautious: 5281 | Readthrough: 4716 | Inactive: 5
# Simulating step 1746/1820 (95.9%)... Cautious: 5304 | Readthrough: 4696 | Inactive: 5
# Simulating step 1747/1820 (96.0%)... Cautious: 5304 | Readthrough: 4696 | Inactive: 5
# Simulating step 1748/1820 (96.0%)... Cautious: 5305 | Readthrough: 4695 | Inactive: 5
# Simulating step 1749/1820 (96.1%)... Cautious: 5305 | Readthrough: 4695 | Inactive: 5
# Simulating step 1750/1820 (96.2%)... Cautious: 5305 | Readthrough: 4695 | Inactive: 5
# Simulating step 1751/1820 (96.2%)... Cautious: 5305 | Readthrough: 4695 | Inactive: 0
# Simulating step 1752/1820 (96.3%)... Cautious: 5276 | Readthrough: 4724 | Inactive: 1
# Simulating step 1753/1820 (96.3%)... Cautious: 5276 | Readthrough: 4722 | Inactive: 3
# Simulating step 1754/1820 (96.4%)... Cautious: 5280 | Readthrough: 4720 | Inactive: 5
# Simulating step 1755/1820 (96.4%)... Cautious: 5280 | Readthrough: 4719 | Inactive: 6
# Simulating step 1756/1820 (96.5%)... Cautious: 5280 | Readthrough: 4719 | Inactive: 6
# Simulating step 1757/1820 (96.5%)... Cautious: 5280 | Readthrough: 4719 | Inactive: 6
# Simulating step 1758/1820 (96.6%)... Cautious: 5230 | Readthrough: 4770 | Inactive: 6
# Simulating step 1759/1820 (96.6%)... Cautious: 5230 | Readthrough: 4770 | Inactive: 6
# Simulating step 1760/1820 (96.7%)... Cautious: 5234 | Readthrough: 4766 | Inactive: 6
# Simulating step 1761/1820 (96.8%)... Cautious: 5234 | Readthrough: 4766 | Inactive: 0
# Simulating step 1762/1820 (96.8%)... Cautious: 5234 | Readthrough: 4765 | Inactive: 1
# Simulating step 1763/1820 (96.9%)... Cautious: 5234 | Readthrough: 4765 | Inactive: 1
# Simulating step 1764/1820 (96.9%)... Cautious: 5224 | Readthrough: 4776 | Inactive: 3
# Simulating step 1765/1820 (97.0%)... Cautious: 5224 | Readthrough: 4775 | Inactive: 4
# Simulating step 1766/1820 (97.0%)... Cautious: 5229 | Readthrough: 4771 | Inactive: 4
# Simulating step 1767/1820 (97.1%)... Cautious: 5229 | Readthrough: 4771 | Inactive: 4
# Simulating step 1768/1820 (97.1%)... Cautious: 5229 | Readthrough: 4771 | Inactive: 4
# Simulating step 1769/1820 (97.2%)... Cautious: 5229 | Readthrough: 4771 | Inactive: 4
# Simulating step 1770/1820 (97.3%)... Cautious: 5219 | Readthrough: 4781 | Inactive: 4
# Simulating step 1771/1820 (97.3%)... Cautious: 5219 | Readthrough: 4781 | Inactive: 0
# Simulating step 1772/1820 (97.4%)... Cautious: 5223 | Readthrough: 4777 | Inactive: 0
# Simulating step 1773/1820 (97.4%)... Cautious: 5223 | Readthrough: 4777 | Inactive: 0
# Simulating step 1774/1820 (97.5%)... Cautious: 5223 | Readthrough: 4776 | Inactive: 1
# Simulating step 1775/1820 (97.5%)... Cautious: 5223 | Readthrough: 4776 | Inactive: 1
# Simulating step 1776/1820 (97.6%)... Cautious: 5237 | Readthrough: 4763 | Inactive: 1
# Simulating step 1777/1820 (97.6%)... Cautious: 5237 | Readthrough: 4763 | Inactive: 1
# Simulating step 1778/1820 (97.7%)... Cautious: 5240 | Readthrough: 4760 | Inactive: 1
# Simulating step 1779/1820 (97.7%)... Cautious: 5240 | Readthrough: 4760 | Inactive: 1
# Simulating step 1780/1820 (97.8%)... Cautious: 5240 | Readthrough: 4760 | Inactive: 1
# Simulating step 1781/1820 (97.9%)... Cautious: 5240 | Readthrough: 4760 | Inactive: 0
# Simulating step 1782/1820 (97.9%)... Cautious: 5164 | Readthrough: 4836 | Inactive: 0
# Simulating step 1783/1820 (98.0%)... Cautious: 5164 | Readthrough: 4836 | Inactive: 0
# Simulating step 1784/1820 (98.0%)... Cautious: 5168 | Readthrough: 4832 | Inactive: 0
# Simulating step 1785/1820 (98.1%)... Cautious: 5168 | Readthrough: 4832 | Inactive: 0
# Simulating step 1786/1820 (98.1%)... Cautious: 5168 | Readthrough: 4832 | Inactive: 0
# Simulating step 1787/1820 (98.2%)... Cautious: 5168 | Readthrough: 4832 | Inactive: 0
# Simulating step 1788/1820 (98.2%)... Cautious: 5188 | Readthrough: 4812 | Inactive: 0
# Simulating step 1789/1820 (98.3%)... Cautious: 5188 | Readthrough: 4812 | Inactive: 0
# Simulating step 1790/1820 (98.4%)... Cautious: 5193 | Readthrough: 4807 | Inactive: 0
# Simulating step 1791/1820 (98.4%)... Cautious: 5193 | Readthrough: 4807 | Inactive: 0
# Simulating step 1792/1820 (98.5%)... Cautious: 5193 | Readthrough: 4807 | Inactive: 0
# Simulating step 1793/1820 (98.5%)... Cautious: 5193 | Readthrough: 4806 | Inactive: 1
# Simulating step 1794/1820 (98.6%)... Cautious: 5181 | Readthrough: 4819 | Inactive: 1
# Simulating step 1795/1820 (98.6%)... Cautious: 5181 | Readthrough: 4818 | Inactive: 2
# Simulating step 1796/1820 (98.7%)... Cautious: 5186 | Readthrough: 4814 | Inactive: 2
# Simulating step 1797/1820 (98.7%)... Cautious: 5186 | Readthrough: 4814 | Inactive: 2
# Simulating step 1798/1820 (98.8%)... Cautious: 5186 | Readthrough: 4814 | Inactive: 2
# Simulating step 1799/1820 (98.8%)... Cautious: 5190 | Readthrough: 4810 | Inactive: 2
# Simulating step 1800/1820 (98.9%)... Cautious: 5190 | Readthrough: 4810 | Inactive: 2
# Simulating step 1801/1820 (99.0%)... Cautious: 5194 | Readthrough: 4806 | Inactive: 0
# Simulating step 1802/1820 (99.0%)... Cautious: 5194 | Readthrough: 4803 | Inactive: 3
# Simulating step 1803/1820 (99.1%)... Cautious: 5194 | Readthrough: 4802 | Inactive: 4
# Simulating step 1804/1820 (99.1%)... Cautious: 5194 | Readthrough: 4802 | Inactive: 4
# Simulating step 1805/1820 (99.2%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 8
# Simulating step 1806/1820 (99.2%)... Cautious: 5108 | Readthrough: 4892 | Inactive: 8
# Simulating step 1807/1820 (99.3%)... Cautious: 5112 | Readthrough: 4888 | Inactive: 8
# Simulating step 1808/1820 (99.3%)... Cautious: 5112 | Readthrough: 4888 | Inactive: 8
# Simulating step 1809/1820 (99.4%)... Cautious: 5112 | Readthrough: 4888 | Inactive: 8
# Simulating step 1810/1820 (99.5%)... Cautious: 5112 | Readthrough: 4888 | Inactive: 8
# Simulating step 1811/1820 (99.5%)... Cautious: 5102 | Readthrough: 4898 | Inactive: 0
# Simulating step 1812/1820 (99.6%)... Cautious: 5102 | Readthrough: 4896 | Inactive: 2
# Simulating step 1813/1820 (99.6%)... Cautious: 5109 | Readthrough: 4891 | Inactive: 2
# Simulating step 1814/1820 (99.7%)... Cautious: 5109 | Readthrough: 4889 | Inactive: 4
# Simulating step 1815/1820 (99.7%)... Cautious: 5109 | Readthrough: 4889 | Inactive: 4
# Simulating step 1816/1820 (99.8%)... Cautious: 5109 | Readthrough: 4889 | Inactive: 4
# Simulating step 1817/1820 (99.8%)... Cautious: 5110 | Readthrough: 4890 | Inactive: 4
# Simulating step 1818/1820 (99.9%)... Cautious: 5110 | Readthrough: 4890 | Inactive: 4
# Simulating step 1819/1820 (99.9%)... Cautious: 5116 | Readthrough: 4884 | Inactive: 4
