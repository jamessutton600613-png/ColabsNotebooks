# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessutton600613-png/GC/blob/main/Untitled145.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import os

# --- 1. Environment Class (No changes) ---
class Environment:
    def __init__(self, total_sim_steps, days_per_cycle=50):
        self.total_sim_steps, self.days_per_cycle, self.time = total_sim_steps, days_per_cycle, 0
        num_years = max(1, total_sim_steps / (365 * days_per_cycle))
        steps_per_year = 365 * days_per_cycle

        daily_uv_cycle = np.sin(np.linspace(0, 2 * np.pi, days_per_cycle)); daily_uv_cycle[daily_uv_cycle < 0] = 0
        daily_temp_swing = -4 * np.cos(np.linspace(0, 2 * np.pi, days_per_cycle))

        full_uv, full_resources, full_temp = [], [], []
        for _ in range(int(np.ceil(num_years))):
            uv_severity = np.random.uniform(0.8, 1.25)
            resource_bounty = np.random.uniform(0.8, 1.25)

            seasonal_cycle = np.sin(np.linspace(0, 2 * np.pi, steps_per_year))
            seasonal_temp_base = 15 - 10 * np.cos(np.linspace(0, 2 * np.pi, steps_per_year))

            seasonal_amplitude_mod = (0.225 * seasonal_cycle + 0.725) * uv_severity

            GEOTHERMAL_BASE_TEMP = 4.0
            year_temp = []
            for i in range(steps_per_year):
                solar_temp = seasonal_temp_base[i] + daily_temp_swing[i % days_per_cycle]
                year_temp.append(max(GEOTHERMAL_BASE_TEMP, solar_temp))

            full_uv.extend([daily_uv_cycle[i % days_per_cycle] * seasonal_amplitude_mod[i] for i in range(steps_per_year)])
            full_temp.extend(year_temp)

        self.uv_intensity = np.array(full_uv)
        self.temperature = np.array(full_temp)

    def get_current_uv(self):
        return self.uv_intensity[self.time % len(self.uv_intensity)]
    def get_current_temperature(self):
        return self.temperature[self.time % len(self.temperature)]
    def step(self):
        self.time += 1

# --- 2. Protoribosome Class (No changes) ---
class Protoribosome:
    def __init__(self, env, strategy, initial_sequence, initial_mass=100.0):
        self.env, self.strategy, self.rna_sequence = env, strategy, list(initial_sequence)
        self.rna_mass = initial_mass
        self.atp_pool, self.mcyw_peptide_pool, self.other_peptide_pool = 500.0, 50.0, 5.0
        self.rna_damage_level = 0.0
        self.location = 'dark_zone'
        self.status = 'ACTIVE'
        self.metabolic_efficiency = 1.0

        self.uv_damage_rate_per_uv = 1.2
        self.repair_rate = 0.5
        self.uv_protection_factor, self.damage_tolerance_threshold = 0.01, 3.0
        self.atp_generation_rate_per_mcyw_uv = 0.15
        self.baseline_atp_chemosynthesis = 1.5
        self.protein_synthesis_rate = 0.20
        self.replication_rate = 0.05
        self.atp_degradation_rate = 0.025
        self.mutation_prob = 0.004
        self.growth_rate = 0.1
        self.optimal_temp = 25.0
        self.temp_tolerance = 15.0

    def get_peptide_type(self):
        codons = ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)]
        if any(c in {'UGU', 'UGC', 'UAU', 'UAC', 'UGG'} for c in codons):
            return "MCYW"
        return "XXXX"

    def has_stop_codon(self):
        return any(c in {'UAA', 'UAG', 'UGA'} for c in ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)])

    def _decide_zone_transition(self):
        if self.location == 'dark_zone' and self.atp_pool < 450:
            self.location = 'light_zone'
        elif self.location == 'light_zone' and self.rna_damage_level > self.damage_tolerance_threshold * 0.75:
            self.location = 'dark_zone'

    def _apply_uv_damage(self, current_uv):
        if self.location == 'dark_zone' or current_uv <= 0:
            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate * 0.1)
            return

        protection = self.mcyw_peptide_pool * self.uv_protection_factor
        effective_uv = current_uv * max(0.01, 1 - protection)
        self.rna_damage_level += effective_uv * self.uv_damage_rate_per_uv

        for i in range(len(self.rna_sequence)):
            if random.random() < self.mutation_prob * effective_uv:
                self.rna_sequence[i] = random.choice("AUGC")

    def _manage_state(self, has_stop_codon_cached):
        if self.atp_pool < 0.1 or self.rna_damage_level >= self.damage_tolerance_threshold:
            self.status = 'INACTIVE'
            return

        if self.strategy == 'cautious' and has_stop_codon_cached:
            self.status = 'ARRESTED'
        elif self.status == 'ARRESTED' and not has_stop_codon_cached:
             self.status = 'ACTIVE'

        if self.status == 'ACTIVE': self.metabolic_efficiency = 1.25
        else: self.metabolic_efficiency = 1.0

    def _synthesize_protein(self, has_stop_codon_cached, temp_factor):
        if self.status != 'ACTIVE': return

        if self.strategy == 'readthrough' and has_stop_codon_cached:
            self.status = 'INACTIVE'
            return

        units = self.protein_synthesis_rate * self.metabolic_efficiency * temp_factor * 10
        if self.get_peptide_type() == "MCYW":
            self.mcyw_peptide_pool += units
        else:
            self.other_peptide_pool += units
        self.atp_pool -= units * 0.02

    def _replicate_rna(self, temp_factor):
        if self.status != 'ACTIVE' or self.rna_mass < 80: return None

        can_replicate = self.rna_mass * self.replication_rate * self.metabolic_efficiency * temp_factor
        if self.atp_pool > can_replicate * 0.2:
            offspring_mass = self.rna_mass * 0.5
            self.rna_mass -= offspring_mass
            self.atp_pool -= can_replicate * 0.2
            return Protoribosome(self.env, self.strategy, "".join(self.rna_sequence), offspring_mass)
        return None

    def _repair_rna_dna(self, dna_template, temp_factor):
        if self.strategy == 'readthrough': return
        repair_efficiency = temp_factor
        if self.status == 'ARRESTED': repair_efficiency *= 0.2
        elif self.status != 'ACTIVE': return
        if "".join(self.rna_sequence) != dna_template:
            for i in range(len(self.rna_sequence)):
                if self.rna_sequence[i] != dna_template[i]:
                    if random.random() < repair_efficiency:
                        if self.atp_pool > 0.0025:
                            self.atp_pool -= 0.0025
                            self.rna_sequence[i] = dna_template[i]
                            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate)
                    break

    def _grow_mass(self, temp_factor):
        if self.status != 'ACTIVE': return
        potential_growth = self.rna_mass * self.growth_rate * self.metabolic_efficiency * temp_factor
        self.rna_mass += potential_growth
        self.atp_pool -= potential_growth * 0.1

    def step(self, current_uv, current_temp, dna_template):
        if self.status == 'INACTIVE': return None

        if current_temp < 10:
            temp_factor = 0.2 + ((current_temp - 5) / 5.0) * 0.8; temp_factor = max(0.2, temp_factor)
        elif current_temp > 22:
            heat_penalty = (current_temp - 22) / 6.0; temp_factor = max(0.1, 1.0 - heat_penalty)
        else:
            temp_factor = 1.0

        self._decide_zone_transition()
        self._apply_uv_damage(current_uv)
        self._repair_rna_dna(dna_template, temp_factor)
        has_stop = self.has_stop_codon()
        self._manage_state(has_stop)
        if self.status == 'INACTIVE': return None

        self.atp_pool += self.baseline_atp_chemosynthesis
        self.atp_pool *= (1 - self.atp_degradation_rate)
        if self.location == 'light_zone' and current_uv > 0:
            photosynthesis_gain = self.atp_generation_rate_per_mcyw_uv * self.mcyw_peptide_pool * current_uv
            if current_temp > 18: photosynthesis_gain *= 1.5
            self.atp_pool += photosynthesis_gain

        self._grow_mass(temp_factor)
        self. _synthesize_protein(has_stop, temp_factor)
        if self.status == 'INACTIVE': return None
        return self._replicate_rna(temp_factor)

# --- 3. Colony Class (No changes) ---
class Colony:
    def __init__(self, env, dna_template, initial_pop_size, steps_per_day):
        self.env = env
        self.dna_template = dna_template
        self.active_population = [Protoribosome(env, 'cautious' if i%2==0 else 'readthrough', dna_template) for i in range(initial_pop_size)]
        self.inactive_population = []
        self.steps_per_day = steps_per_day
        self.max_population = 10000

    def step(self, current_step):
        current_uv = self.env.get_current_uv()
        current_temp = self.env.get_current_temperature()

        if current_step > 0 and current_step % self.steps_per_day == 0:
            self.inactive_population.clear()

        next_generation = []
        for protoribosome in self.active_population:
            new_offspring = protoribosome.step(current_uv, current_temp, self.dna_template)
            if protoribosome.status != 'INACTIVE':
                next_generation.append(protoribosome)
            else:
                self.inactive_population.append(protoribosome)
            if new_offspring:
                next_generation.append(new_offspring)

        self.active_population = next_generation

        if len(self.active_population) > self.max_population:
            random.shuffle(self.active_population)
            self.active_population = self.active_population[:self.max_population]

    def get_aggregated_data(self):
        data = { 'cautious': 0, 'readthrough': 0, 'arrested': 0, 'inactive': 0, 'in_light_zone': 0, 'avg_damage': 0.0 }
        total_damage = 0

        if not self.active_population:
            data['inactive'] = len(self.inactive_population)
            return data

        for p in self.active_population:
            if p.strategy == 'cautious':
                data['cautious'] += 1
                if p.status == 'ARRESTED': data['arrested'] += 1
            else: data['readthrough'] += 1
            if p.location == 'light_zone': data['in_light_zone'] += 1
            total_damage += p.rna_damage_level

        data['inactive'] = len(self.inactive_population)
        data['avg_damage'] = total_damage / len(self.active_population)
        return data

# --- 4. Simulation Runner (MODIFIED) ---
def run_single_simulation(sim_id, total_steps, steps_per_day):
    """
    Runs one complete simulation and returns the results.
    """
    print(f"\n--- Starting Competition #{sim_id} ---")
    IDEAL_DNA_TEMPLATE = "AUGUGUUACUGG"
    env = Environment(total_steps, steps_per_day)
    colony = Colony(env, IDEAL_DNA_TEMPLATE, initial_pop_size=5000, steps_per_day=steps_per_day)
    data_log = []

    step_count = 0
    winner = "Stalemate"

    while step_count < total_steps:
        # ===== UPDATE: Report status every 20 steps =====
        if step_count % 20 == 0:
            agg_data = colony.get_aggregated_data()
            cautious_pop = agg_data.get('cautious', 0)
            readthrough_pop = agg_data.get('readthrough', 0)
            print(f"  [Sim #{sim_id} | Day {step_count // steps_per_day}] Cautious: {cautious_pop:<5} | Reckless: {readthrough_pop:<5}", flush=True)
        # ===============================================

        # Check for a winner (knockout)
        if step_count > 1000:
            agg_data = colony.get_aggregated_data()
            cautious_pop = agg_data.get('cautious', 0)
            readthrough_pop = agg_data.get('readthrough', 0)

            if cautious_pop == 0 and readthrough_pop > 0:
                winner = "Reckless (Readthrough)"
                print(f"KNOCKOUT on day {step_count // steps_per_day}: {winner} wins.")
                break
            if readthrough_pop == 0 and cautious_pop > 0:
                winner = "Cautious"
                print(f"KNOCKOUT on day {step_count // steps_per_day}: {winner} wins.")
                break
            if readthrough_pop == 0 and cautious_pop == 0:
                winner = "Mutual Extinction"
                break


        colony.step(step_count)

        # Log data once per simulated day
        if step_count % steps_per_day == 0:
            agg_data = colony.get_aggregated_data()
            log_entry = {'time': env.time, 'uv': env.get_current_uv(), 'temp': env.get_current_temperature()}
            log_entry.update(agg_data)
            data_log.append(log_entry)

        env.step()
        step_count += 1

    if step_count >= total_steps:
        print(f"MAX STEPS REACHED: Simulation ended in a {winner}.")

    duration_days = step_count // steps_per_day
    results_df = pd.DataFrame(data_log)

    summary = {
        'Competition ID': sim_id,
        'Winner': winner,
        'Duration (Days)': duration_days
    }
    return summary, results_df

# --- 5. Plotting Function (No changes) ---
def plot_all_populations(list_of_dfs):
    """
    Plots the total population from a list of simulation DataFrames on a single graph.
    """
    fig, ax = plt.subplots(figsize=(16, 9))

    # Use a colormap to get 10 distinct colors
    colors = plt.cm.get_cmap('tab10', 10)

    for i, df in enumerate(list_of_dfs):
        if not df.empty:
            # Calculate total active population for the plot
            total_pop = df['cautious'] + df['readthrough']
            ax.plot(df['time'], total_pop, label=f'Sim #{i+1}', color=colors(i), linewidth=1.5)

    ax.set_title('Total Active Population for 10 Parallel Simulations', fontsize=16)
    ax.set_xlabel('Time (Simulation Steps)', fontsize=12)
    ax.set_ylabel('Total Active Population', fontsize=12)
    ax.set_yscale('symlog') # Use symlog to handle zero values and large ranges
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
    ax.legend(title='Simulation ID', bbox_to_anchor=(1.01, 1), loc='upper left')
    ax.set_xlim(left=0)

    plt.tight_layout(rect=[0, 0, 0.9, 1]) # Adjust layout to make space for legend
    plt.show()

# --- 6. Main Orchestrator (No changes) ---
def main():
    """
    Main function to run all simulations and report results.
    """
    NUM_SIMULATIONS = 10
    MAX_STEPS = 365 * 20 * 10
    STEPS_PER_DAY = 10

    all_summaries = []
    all_details_dfs = []

    for i in range(1, NUM_SIMULATIONS + 1):
        summary, details_df = run_single_simulation(
            sim_id=i,
            total_steps=MAX_STEPS,
            steps_per_day=STEPS_PER_DAY
        )
        all_summaries.append(summary)
        all_details_dfs.append(details_df)

    # --- Display Final Tabled Report ---
    print("\n\n" + "="*50)
    print(" " * 10 + "FINAL SIMULATION RESULTS")
    print("="*50)

    summary_df = pd.DataFrame(all_summaries)
    print(summary_df.to_string(index=False))

    print("\n" + "-"*50)
    print(" " * 15 + "OVERALL STATISTICS")
    print("-"*50)

    win_counts = summary_df['Winner'].value_counts()
    print(win_counts)

    decisive_matches = summary_df[summary_df['Winner'] != 'Stalemate']
    avg_duration = decisive_matches['Duration (Days)'].mean()
    if pd.notna(avg_duration):
        print(f"\nAverage competition duration: {avg_duration:.2f} days")
    print("="*50)

    # --- Plot all simulations on one graph ---
    plot_all_populations(all_details_dfs)

if __name__ == "__main__":
    main()
# Out:
# --- Starting Competition #1 ---
#   [Sim #1 | Day 0] Cautious: 2500  | Reckless: 2500
#   [Sim #1 | Day 2] Cautious: 4971  | Reckless: 5014
#   [Sim #1 | Day 4] Cautious: 4976  | Reckless: 5024
#   [Sim #1 | Day 6] Cautious: 4908  | Reckless: 5092
#   [Sim #1 | Day 8] Cautious: 4905  | Reckless: 5090
#   [Sim #1 | Day 10] Cautious: 4927  | Reckless: 5073
#   [Sim #1 | Day 12] Cautious: 4971  | Reckless: 5029
#   [Sim #1 | Day 14] Cautious: 4985  | Reckless: 5009
#   [Sim #1 | Day 16] Cautious: 5016  | Reckless: 4984
#   [Sim #1 | Day 18] Cautious: 4989  | Reckless: 5011
#   [Sim #1 | Day 20] Cautious: 4946  | Reckless: 5054
#   [Sim #1 | Day 22] Cautious: 4964  | Reckless: 5036
#   [Sim #1 | Day 24] Cautious: 4859  | Reckless: 5141
#   [Sim #1 | Day 26] Cautious: 4941  | Reckless: 5059
#   [Sim #1 | Day 28] Cautious: 4953  | Reckless: 5047
#   [Sim #1 | Day 30] Cautious: 4914  | Reckless: 5086
#   [Sim #1 | Day 32] Cautious: 4977  | Reckless: 5023
#   [Sim #1 | Day 34] Cautious: 4961  | Reckless: 5039
#   [Sim #1 | Day 36] Cautious: 4961  | Reckless: 5039
#   [Sim #1 | Day 38] Cautious: 5015  | Reckless: 4985
#   [Sim #1 | Day 40] Cautious: 5100  | Reckless: 4900
#   [Sim #1 | Day 42] Cautious: 5080  | Reckless: 4920
#   [Sim #1 | Day 44] Cautious: 5063  | Reckless: 4937
#   [Sim #1 | Day 46] Cautious: 5126  | Reckless: 4874
#   [Sim #1 | Day 48] Cautious: 5116  | Reckless: 4884
#   [Sim #1 | Day 50] Cautious: 5124  | Reckless: 4876
#   [Sim #1 | Day 52] Cautious: 5179  | Reckless: 4821
#   [Sim #1 | Day 54] Cautious: 5147  | Reckless: 4853
#   [Sim #1 | Day 56] Cautious: 5172  | Reckless: 4828
#   [Sim #1 | Day 58] Cautious: 5126  | Reckless: 4874
#   [Sim #1 | Day 60] Cautious: 5025  | Reckless: 4975
#   [Sim #1 | Day 62] Cautious: 5034  | Reckless: 4966
#   [Sim #1 | Day 64] Cautious: 5051  | Reckless: 4949
#   [Sim #1 | Day 66] Cautious: 5105  | Reckless: 4895
#   [Sim #1 | Day 68] Cautious: 5051  | Reckless: 4949
#   [Sim #1 | Day 70] Cautious: 4987  | Reckless: 5013
#   [Sim #1 | Day 72] Cautious: 5086  | Reckless: 4914
#   [Sim #1 | Day 74] Cautious: 5024  | Reckless: 4976
#   [Sim #1 | Day 76] Cautious: 5149  | Reckless: 4851
#   [Sim #1 | Day 78] Cautious: 5195  | Reckless: 4805
#   [Sim #1 | Day 80] Cautious: 5267  | Reckless: 4733
#   [Sim #1 | Day 82] Cautious: 5267  | Reckless: 4733
#   [Sim #1 | Day 84] Cautious: 5276  | Reckless: 4724
#   [Sim #1 | Day 86] Cautious: 5323  | Reckless: 4677
#   [Sim #1 | Day 88] Cautious: 5398  | Reckless: 4602
#   [Sim #1 | Day 90] Cautious: 5437  | Reckless: 4563
#   [Sim #1 | Day 92] Cautious: 5372  | Reckless: 4628
#   [Sim #1 | Day 94] Cautious: 5383  | Reckless: 4617
#   [Sim #1 | Day 96] Cautious: 5320  | Reckless: 4680
#   [Sim #1 | Day 98] Cautious: 5375  | Reckless: 4625
#   [Sim #1 | Day 100] Cautious: 5369  | Reckless: 4631
#   [Sim #1 | Day 102] Cautious: 5369  | Reckless: 4631
#   [Sim #1 | Day 104] Cautious: 5317  | Reckless: 4683
#   [Sim #1 | Day 106] Cautious: 5365  | Reckless: 4635
#   [Sim #1 | Day 108] Cautious: 5349  | Reckless: 4651
#   [Sim #1 | Day 110] Cautious: 5299  | Reckless: 4701
#   [Sim #1 | Day 112] Cautious: 5260  | Reckless: 4740
#   [Sim #1 | Day 114] Cautious: 5301  | Reckless: 4699
#   [Sim #1 | Day 116] Cautious: 5240  | Reckless: 4760
#   [Sim #1 | Day 118] Cautious: 5231  | Reckless: 4769
#   [Sim #1 | Day 120] Cautious: 5258  | Reckless: 4742
#   [Sim #1 | Day 122] Cautious: 5275  | Reckless: 4725
#   [Sim #1 | Day 124] Cautious: 5275  | Reckless: 4725
#   [Sim #1 | Day 126] Cautious: 5201  | Reckless: 4799
#   [Sim #1 | Day 128] Cautious: 5285  | Reckless: 4715
#   [Sim #1 | Day 130] Cautious: 5266  | Reckless: 4734
#   [Sim #1 | Day 132] Cautious: 5339  | Reckless: 4661
#   [Sim #1 | Day 134] Cautious: 5243  | Reckless: 4757
#   [Sim #1 | Day 136] Cautious: 5318  | Reckless: 4682
#   [Sim #1 | Day 138] Cautious: 5342  | Reckless: 4658
#   [Sim #1 | Day 140] Cautious: 5438  | Reckless: 4562
#   [Sim #1 | Day 142] Cautious: 5397  | Reckless: 4603
#   [Sim #1 | Day 144] Cautious: 5402  | Reckless: 4598
#   [Sim #1 | Day 146] Cautious: 5427  | Reckless: 4573
#   [Sim #1 | Day 148] Cautious: 5412  | Reckless: 4588
#   [Sim #1 | Day 150] Cautious: 5505  | Reckless: 4495
#   [Sim #1 | Day 152] Cautious: 5523  | Reckless: 4477
#   [Sim #1 | Day 154] Cautious: 5517  | Reckless: 4483
#   [Sim #1 | Day 156] Cautious: 5520  | Reckless: 4480
#   [Sim #1 | Day 158] Cautious: 5483  | Reckless: 4517
#   [Sim #1 | Day 160] Cautious: 5523  | Reckless: 4477
#   [Sim #1 | Day 162] Cautious: 5507  | Reckless: 4493
#   [Sim #1 | Day 164] Cautious: 5586  | Reckless: 4414
#   [Sim #1 | Day 166] Cautious: 5509  | Reckless: 4491
#   [Sim #1 | Day 168] Cautious: 5506  | Reckless: 4494
#   [Sim #1 | Day 170] Cautious: 5473  | Reckless: 4527
#   [Sim #1 | Day 172] Cautious: 5520  | Reckless: 4480
#   [Sim #1 | Day 174] Cautious: 5518  | Reckless: 4482
#   [Sim #1 | Day 176] Cautious: 5591  | Reckless: 4409
#   [Sim #1 | Day 178] Cautious: 5635  | Reckless: 4365
#   [Sim #1 | Day 180] Cautious: 5586  | Reckless: 4414
#   [Sim #1 | Day 182] Cautious: 5627  | Reckless: 4373
#   [Sim #1 | Day 184] Cautious: 5652  | Reckless: 4348
#   [Sim #1 | Day 186] Cautious: 5646  | Reckless: 4354
#   [Sim #1 | Day 188] Cautious: 5667  | Reckless: 4333
#   [Sim #1 | Day 190] Cautious: 5700  | Reckless: 4300
#   [Sim #1 | Day 192] Cautious: 5756  | Reckless: 4244
#   [Sim #1 | Day 194] Cautious: 5813  | Reckless: 4187
#   [Sim #1 | Day 196] Cautious: 5823  | Reckless: 4177
#   [Sim #1 | Day 198] Cautious: 5613  | Reckless: 4387
#   [Sim #1 | Day 200] Cautious: 5605  | Reckless: 4395
#   [Sim #1 | Day 202] Cautious: 5623  | Reckless: 4377
#   [Sim #1 | Day 204] Cautious: 5523  | Reckless: 4477
#   [Sim #1 | Day 206] Cautious: 5545  | Reckless: 4455
#   [Sim #1 | Day 208] Cautious: 5558  | Reckless: 4442
#   [Sim #1 | Day 210] Cautious: 5609  | Reckless: 4391
#   [Sim #1 | Day 212] Cautious: 5554  | Reckless: 4446
#   [Sim #1 | Day 214] Cautious: 5568  | Reckless: 4432
#   [Sim #1 | Day 216] Cautious: 5622  | Reckless: 4378
#   [Sim #1 | Day 218] Cautious: 5597  | Reckless: 4403
#   [Sim #1 | Day 220] Cautious: 5687  | Reckless: 4313
#   [Sim #1 | Day 222] Cautious: 5529  | Reckless: 4471
#   [Sim #1 | Day 224] Cautious: 5634  | Reckless: 4366
#   [Sim #1 | Day 226] Cautious: 5602  | Reckless: 4398
#   [Sim #1 | Day 228] Cautious: 5548  | Reckless: 4452
#   [Sim #1 | Day 230] Cautious: 5596  | Reckless: 4404
#   [Sim #1 | Day 232] Cautious: 5450  | Reckless: 4550
#   [Sim #1 | Day 234] Cautious: 5334  | Reckless: 4666
#   [Sim #1 | Day 236] Cautious: 5376  | Reckless: 4624
#   [Sim #1 | Day 238] Cautious: 5291  | Reckless: 4709
#   [Sim #1 | Day 240] Cautious: 5316  | Reckless: 4684
#   [Sim #1 | Day 242] Cautious: 5221  | Reckless: 4779
#   [Sim #1 | Day 244] Cautious: 5174  | Reckless: 4826
#   [Sim #1 | Day 246] Cautious: 5187  | Reckless: 4813
#   [Sim #1 | Day 248] Cautious: 5185  | Reckless: 4815
#   [Sim #1 | Day 250] Cautious: 5175  | Reckless: 4825
#   [Sim #1 | Day 252] Cautious: 5039  | Reckless: 4961
#   [Sim #1 | Day 254] Cautious: 5069  | Reckless: 4931
#   [Sim #1 | Day 256] Cautious: 5060  | Reckless: 4940
#   [Sim #1 | Day 258] Cautious: 5159  | Reckless: 4841
#   [Sim #1 | Day 260] Cautious: 5165  | Reckless: 4835
#   [Sim #1 | Day 262] Cautious: 5097  | Reckless: 4903
#   [Sim #1 | Day 264] Cautious: 5155  | Reckless: 4845
#   [Sim #1 | Day 266] Cautious: 5184  | Reckless: 4816
#   [Sim #1 | Day 268] Cautious: 5261  | Reckless: 4739
#   [Sim #1 | Day 270] Cautious: 5329  | Reckless: 4671
#   [Sim #1 | Day 272] Cautious: 5206  | Reckless: 4794
#   [Sim #1 | Day 274] Cautious: 5177  | Reckless: 4823
#   [Sim #1 | Day 276] Cautious: 5123  | Reckless: 4877
#   [Sim #1 | Day 278] Cautious: 5023  | Reckless: 4977
#   [Sim #1 | Day 280] Cautious: 5062  | Reckless: 4938
#   [Sim #1 | Day 282] Cautious: 4893  | Reckless: 5107
#   [Sim #1 | Day 284] Cautious: 4905  | Reckless: 5095
#   [Sim #1 | Day 286] Cautious: 4816  | Reckless: 5184
#   [Sim #1 | Day 288] Cautious: 4775  | Reckless: 5225
#   [Sim #1 | Day 290] Cautious: 4648  | Reckless: 5352
#   [Sim #1 | Day 292] Cautious: 4645  | Reckless: 5355
#   [Sim #1 | Day 294] Cautious: 4586  | Reckless: 5414
#   [Sim #1 | Day 296] Cautious: 4548  | Reckless: 5452
#   [Sim #1 | Day 298] Cautious: 4610  | Reckless: 5390
#   [Sim #1 | Day 300] Cautious: 4693  | Reckless: 5307
#   [Sim #1 | Day 302] Cautious: 4636  | Reckless: 5364
#   [Sim #1 | Day 304] Cautious: 4616  | Reckless: 5384
#   [Sim #1 | Day 306] Cautious: 4686  | Reckless: 5314
#   [Sim #1 | Day 308] Cautious: 4756  | Reckless: 5244
#   [Sim #1 | Day 310] Cautious: 4852  | Reckless: 5148
#   [Sim #1 | Day 312] Cautious: 4860  | Reckless: 5140
#   [Sim #1 | Day 314] Cautious: 4847  | Reckless: 5153
#   [Sim #1 | Day 316] Cautious: 4806  | Reckless: 5194
#   [Sim #1 | Day 318] Cautious: 4819  | Reckless: 5181
#   [Sim #1 | Day 320] Cautious: 4863  | Reckless: 5137
#   [Sim #1 | Day 322] Cautious: 4826  | Reckless: 5174
#   [Sim #1 | Day 324] Cautious: 4769  | Reckless: 5231
#   [Sim #1 | Day 326] Cautious: 4785  | Reckless: 5215
#   [Sim #1 | Day 328] Cautious: 4824  | Reckless: 5176
#   [Sim #1 | Day 330] Cautious: 4885  | Reckless: 5115
#   [Sim #1 | Day 332] Cautious: 4859  | Reckless: 5141
#   [Sim #1 | Day 334] Cautious: 4834  | Reckless: 5166
#   [Sim #1 | Day 336] Cautious: 4868  | Reckless: 5132
#   [Sim #1 | Day 338] Cautious: 4937  | Reckless: 5063
#   [Sim #1 | Day 340] Cautious: 4823  | Reckless: 5177
#   [Sim #1 | Day 342] Cautious: 4969  | Reckless: 5031
#   [Sim #1 | Day 344] Cautious: 4951  | Reckless: 5049
#   [Sim #1 | Day 346] Cautious: 5091  | Reckless: 4909
#   [Sim #1 | Day 348] Cautious: 4982  | Reckless: 5018
#   [Sim #1 | Day 350] Cautious: 5118  | Reckless: 4882
#   [Sim #1 | Day 352] Cautious: 5186  | Reckless: 4814
#   [Sim #1 | Day 354] Cautious: 5081  | Reckless: 4919
#   [Sim #1 | Day 356] Cautious: 5290  | Reckless: 4710
#   [Sim #1 | Day 358] Cautious: 5276  | Reckless: 4724
#   [Sim #1 | Day 360] Cautious: 5140  | Reckless: 4860
#   [Sim #1 | Day 362] Cautious: 5224  | Reckless: 4776
#   [Sim #1 | Day 364] Cautious: 5284  | Reckless: 4716
#   [Sim #1 | Day 366] Cautious: 5137  | Reckless: 4863
#   [Sim #1 | Day 368] Cautious: 5225  | Reckless: 4775
#   [Sim #1 | Day 370] Cautious: 5005  | Reckless: 4995
#   [Sim #1 | Day 372] Cautious: 5110  | Reckless: 4890
#   [Sim #1 | Day 374] Cautious: 5191  | Reckless: 4809
#   [Sim #1 | Day 376] Cautious: 5110  | Reckless: 4890
#   [Sim #1 | Day 378] Cautious: 5162  | Reckless: 4838
#   [Sim #1 | Day 380] Cautious: 5164  | Reckless: 4836
#   [Sim #1 | Day 382] Cautious: 5020  | Reckless: 4980
#   [Sim #1 | Day 384] Cautious: 5121  | Reckless: 4879
#   [Sim #1 | Day 386] Cautious: 5090  | Reckless: 4910
#   [Sim #1 | Day 388] Cautious: 5228  | Reckless: 4772
#   [Sim #1 | Day 390] Cautious: 5071  | Reckless: 4929
#   [Sim #1 | Day 392] Cautious: 5216  | Reckless: 4784
#   [Sim #1 | Day 394] Cautious: 5277  | Reckless: 4723
#   [Sim #1 | Day 396] Cautious: 5188  | Reckless: 4812
#   [Sim #1 | Day 398] Cautious: 5339  | Reckless: 4661
#   [Sim #1 | Day 400] Cautious: 5355  | Reckless: 4645
#   [Sim #1 | Day 402] Cautious: 5368  | Reckless: 4632
#   [Sim #1 | Day 404] Cautious: 5278  | Reckless: 4722
#   [Sim #1 | Day 406] Cautious: 5280  | Reckless: 4720
#   [Sim #1 | Day 408] Cautious: 5230  | Reckless: 4770
#   [Sim #1 | Day 410] Cautious: 5250  | Reckless: 4750
#   [Sim #1 | Day 412] Cautious: 5248  | Reckless: 4752
#   [Sim #1 | Day 414] Cautious: 5341  | Reckless: 4659
#   [Sim #1 | Day 416] Cautious: 5362  | Reckless: 4638
#   [Sim #1 | Day 418] Cautious: 5470  | Reckless: 4530
#   [Sim #1 | Day 420] Cautious: 5422  | Reckless: 4578
#   [Sim #1 | Day 422] Cautious: 5301  | Reckless: 4699
#   [Sim #1 | Day 424] Cautious: 5452  | Reckless: 4548
#   [Sim #1 | Day 426] Cautious: 5428  | Reckless: 4572
#   [Sim #1 | Day 428] Cautious: 5541  | Reckless: 4459
#   [Sim #1 | Day 430] Cautious: 5406  | Reckless: 4594
#   [Sim #1 | Day 432] Cautious: 5290  | Reckless: 4710
#   [Sim #1 | Day 434] Cautious: 5117  | Reckless: 4883
#   [Sim #1 | Day 436] Cautious: 5111  | Reckless: 4889
#   [Sim #1 | Day 438] Cautious: 5091  | Reckless: 4909
#   [Sim #1 | Day 440] Cautious: 5068  | Reckless: 4932
#   [Sim #1 | Day 442] Cautious: 5108  | Reckless: 4892
#   [Sim #1 | Day 444] Cautious: 5165  | Reckless: 4835
#   [Sim #1 | Day 446] Cautious: 5153  | Reckless: 4847
#   [Sim #1 | Day 448] Cautious: 5112  | Reckless: 4888
#   [Sim #1 | Day 450] Cautious: 5227  | Reckless: 4773
#   [Sim #1 | Day 452] Cautious: 5094  | Reckless: 4906
#   [Sim #1 | Day 454] Cautious: 5207  | Reckless: 4793
#   [Sim #1 | Day 456] Cautious: 5199  | Reckless: 4801
#   [Sim #1 | Day 458] Cautious: 4999  | Reckless: 5001
#   [Sim #1 | Day 460] Cautious: 5209  | Reckless: 4791
#   [Sim #1 | Day 462] Cautious: 5273  | Reckless: 4727
#   [Sim #1 | Day 464] Cautious: 5383  | Reckless: 4617
#   [Sim #1 | Day 466] Cautious: 5467  | Reckless: 4533
#   [Sim #1 | Day 468] Cautious: 5292  | Reckless: 4708
#   [Sim #1 | Day 470] Cautious: 5424  | Reckless: 4576
#   [Sim #1 | Day 472] Cautious: 5226  | Reckless: 4774
#   [Sim #1 | Day 474] Cautious: 5273  | Reckless: 4727
#   [Sim #1 | Day 476] Cautious: 5330  | Reckless: 4670
#   [Sim #1 | Day 478] Cautious: 5170  | Reckless: 4830
#   [Sim #1 | Day 480] Cautious: 5371  | Reckless: 4629
#   [Sim #1 | Day 482] Cautious: 5381  | Reckless: 4619
#   [Sim #1 | Day 484] Cautious: 5237  | Reckless: 4763
#   [Sim #1 | Day 486] Cautious: 5253  | Reckless: 4747
#   [Sim #1 | Day 488] Cautious: 5346  | Reckless: 4654
#   [Sim #1 | Day 490] Cautious: 5378  | Reckless: 4622
#   [Sim #1 | Day 492] Cautious: 5431  | Reckless: 4569
#   [Sim #1 | Day 494] Cautious: 5409  | Reckless: 4591
#   [Sim #1 | Day 496] Cautious: 5455  | Reckless: 4545
#   [Sim #1 | Day 498] Cautious: 5562  | Reckless: 4438
#   [Sim #1 | Day 500] Cautious: 5602  | Reckless: 4398
#   [Sim #1 | Day 502] Cautious: 5551  | Reckless: 4449
#   [Sim #1 | Day 504] Cautious: 5774  | Reckless: 4226
#   [Sim #1 | Day 506] Cautious: 5723  | Reckless: 4277
#   [Sim #1 | Day 508] Cautious: 5445  | Reckless: 4555
#   [Sim #1 | Day 510] Cautious: 5651  | Reckless: 4349
#   [Sim #1 | Day 512] Cautious: 5507  | Reckless: 4493
#   [Sim #1 | Day 514] Cautious: 5668  | Reckless: 4332
#   [Sim #1 | Day 516] Cautious: 5682  | Reckless: 4318
#   [Sim #1 | Day 518] Cautious: 5566  | Reckless: 4434
#   [Sim #1 | Day 520] Cautious: 5809  | Reckless: 4191
#   [Sim #1 | Day 522] Cautious: 5859  | Reckless: 4141
#   [Sim #1 | Day 524] Cautious: 5858  | Reckless: 4142
#   [Sim #1 | Day 526] Cautious: 5465  | Reckless: 4535
#   [Sim #1 | Day 528] Cautious: 5385  | Reckless: 4615
#   [Sim #1 | Day 530] Cautious: 5451  | Reckless: 4549
#   [Sim #1 | Day 532] Cautious: 5545  | Reckless: 4455
#   [Sim #1 | Day 534] Cautious: 5536  | Reckless: 4464
#   [Sim #1 | Day 536] Cautious: 5517  | Reckless: 4483
#   [Sim #1 | Day 538] Cautious: 5433  | Reckless: 4567
#   [Sim #1 | Day 540] Cautious: 5445  | Reckless: 4555
#   [Sim #1 | Day 542] Cautious: 5390  | Reckless: 4610
#   [Sim #1 | Day 544] Cautious: 5339  | Reckless: 4661
#   [Sim #1 | Day 546] Cautious: 5358  | Reckless: 4642
#   [Sim #1 | Day 548] Cautious: 5364  | Reckless: 4636
#   [Sim #1 | Day 550] Cautious: 5375  | Reckless: 4625
#   [Sim #1 | Day 552] Cautious: 5352  | Reckless: 4648
#   [Sim #1 | Day 554] Cautious: 5354  | Reckless: 4646
#   [Sim #1 | Day 556] Cautious: 5413  | Reckless: 4587
#   [Sim #1 | Day 558] Cautious: 5533  | Reckless: 4467
#   [Sim #1 | Day 560] Cautious: 5663  | Reckless: 4337
#   [Sim #1 | Day 562] Cautious: 5611  | Reckless: 4389
#   [Sim #1 | Day 564] Cautious: 5702  | Reckless: 4298
#   [Sim #1 | Day 566] Cautious: 5653  | Reckless: 4347
#   [Sim #1 | Day 568] Cautious: 5664  | Reckless: 4336
#   [Sim #1 | Day 570] Cautious: 5613  | Reckless: 4387
#   [Sim #1 | Day 572] Cautious: 5609  | Reckless: 4391
#   [Sim #1 | Day 574] Cautious: 5307  | Reckless: 4693
#   [Sim #1 | Day 576] Cautious: 5518  | Reckless: 4482
#   [Sim #1 | Day 578] Cautious: 5565  | Reckless: 4435
#   [Sim #1 | Day 580] Cautious: 5623  | Reckless: 4377
#   [Sim #1 | Day 582] Cautious: 5519  | Reckless: 4481
#   [Sim #1 | Day 584] Cautious: 5547  | Reckless: 4453
#   [Sim #1 | Day 586] Cautious: 5492  | Reckless: 4508
#   [Sim #1 | Day 588] Cautious: 5601  | Reckless: 4399
#   [Sim #1 | Day 590] Cautious: 5519  | Reckless: 4481
#   [Sim #1 | Day 592] Cautious: 5285  | Reckless: 4715
#   [Sim #1 | Day 594] Cautious: 5523  | Reckless: 4477
#   [Sim #1 | Day 596] Cautious: 5564  | Reckless: 4436
#   [Sim #1 | Day 598] Cautious: 5416  | Reckless: 4584
#   [Sim #1 | Day 600] Cautious: 5291  | Reckless: 4709
#   [Sim #1 | Day 602] Cautious: 5278  | Reckless: 4722
#   [Sim #1 | Day 604] Cautious: 5340  | Reckless: 4660
#   [Sim #1 | Day 606] Cautious: 5308  | Reckless: 4692
#   [Sim #1 | Day 608] Cautious: 5361  | Reckless: 4639
#   [Sim #1 | Day 610] Cautious: 5311  | Reckless: 4689
#   [Sim #1 | Day 612] Cautious: 5163  | Reckless: 4837
#   [Sim #1 | Day 614] Cautious: 5160  | Reckless: 4840
#   [Sim #1 | Day 616] Cautious: 5103  | Reckless: 4897
#   [Sim #1 | Day 618] Cautious: 4913  | Reckless: 5087
#   [Sim #1 | Day 620] Cautious: 5147  | Reckless: 4853
#   [Sim #1 | Day 622] Cautious: 5221  | Reckless: 4779
#   [Sim #1 | Day 624] Cautious: 5114  | Reckless: 4886
#   [Sim #1 | Day 626] Cautious: 5222  | Reckless: 4778
#   [Sim #1 | Day 628] Cautious: 5070  | Reckless: 4930
#   [Sim #1 | Day 630] Cautious: 5185  | Reckless: 4815
#   [Sim #1 | Day 632] Cautious: 5120  | Reckless: 4880
#   [Sim #1 | Day 634] Cautious: 4980  | Reckless: 5020
#   [Sim #1 | Day 636] Cautious: 5065  | Reckless: 4935
#   [Sim #1 | Day 638] Cautious: 4940  | Reckless: 5060
#   [Sim #1 | Day 640] Cautious: 5133  | Reckless: 4867
#   [Sim #1 | Day 642] Cautious: 5269  | Reckless: 4731
#   [Sim #1 | Day 644] Cautious: 5091  | Reckless: 4909
#   [Sim #1 | Day 646] Cautious: 5201  | Reckless: 4799
#   [Sim #1 | Day 648] Cautious: 5180  | Reckless: 4820
#   [Sim #1 | Day 650] Cautious: 5198  | Reckless: 4802
#   [Sim #1 | Day 652] Cautious: 5181  | Reckless: 4819
#   [Sim #1 | Day 654] Cautious: 5290  | Reckless: 4710
#   [Sim #1 | Day 656] Cautious: 5380  | Reckless: 4620
#   [Sim #1 | Day 658] Cautious: 5263  | Reckless: 4737
#   [Sim #1 | Day 660] Cautious: 5348  | Reckless: 4652
#   [Sim #1 | Day 662] Cautious: 5462  | Reckless: 4538
#   [Sim #1 | Day 664] Cautious: 5529  | Reckless: 4471
#   [Sim #1 | Day 666] Cautious: 5513  | Reckless: 4487
#   [Sim #1 | Day 668] Cautious: 5397  | Reckless: 4603
#   [Sim #1 | Day 670] Cautious: 5617  | Reckless: 4383
#   [Sim #1 | Day 672] Cautious: 5440  | Reckless: 4560
#   [Sim #1 | Day 674] Cautious: 5488  | Reckless: 4512
#   [Sim #1 | Day 676] Cautious: 5470  | Reckless: 4530
#   [Sim #1 | Day 678] Cautious: 5570  | Reckless: 4430
#   [Sim #1 | Day 680] Cautious: 5644  | Reckless: 4356
#   [Sim #1 | Day 682] Cautious: 5747  | Reckless: 4253
#   [Sim #1 | Day 684] Cautious: 5816  | Reckless: 4184
#   [Sim #1 | Day 686] Cautious: 5828  | Reckless: 4172
#   [Sim #1 | Day 688] Cautious: 5843  | Reckless: 4157
#   [Sim #1 | Day 690] Cautious: 5782  | Reckless: 4218
#   [Sim #1 | Day 692] Cautious: 5758  | Reckless: 4242
#   [Sim #1 | Day 694] Cautious: 5680  | Reckless: 4320
#   [Sim #1 | Day 696] Cautious: 5840  | Reckless: 4160
#   [Sim #1 | Day 698] Cautious: 5833  | Reckless: 4167
#   [Sim #1 | Day 700] Cautious: 5741  | Reckless: 4259
#   [Sim #1 | Day 702] Cautious: 5679  | Reckless: 4321
#   [Sim #1 | Day 704] Cautious: 5822  | Reckless: 4178
#   [Sim #1 | Day 706] Cautious: 5782  | Reckless: 4218
#   [Sim #1 | Day 708] Cautious: 5957  | Reckless: 4043
#   [Sim #1 | Day 710] Cautious: 5784  | Reckless: 4216
#   [Sim #1 | Day 712] Cautious: 5921  | Reckless: 4079
#   [Sim #1 | Day 714] Cautious: 5840  | Reckless: 4160
#   [Sim #1 | Day 716] Cautious: 6019  | Reckless: 3981
#   [Sim #1 | Day 718] Cautious: 6083  | Reckless: 3917
#   [Sim #1 | Day 720] Cautious: 5968  | Reckless: 4032
#   [Sim #1 | Day 722] Cautious: 6055  | Reckless: 3945
#   [Sim #1 | Day 724] Cautious: 6133  | Reckless: 3867
#   [Sim #1 | Day 726] Cautious: 6102  | Reckless: 3898
#   [Sim #1 | Day 728] Cautious: 6107  | Reckless: 3893
#   [Sim #1 | Day 730] Cautious: 5901  | Reckless: 4099
#   [Sim #1 | Day 732] Cautious: 6018  | Reckless: 3982
#   [Sim #1 | Day 734] Cautious: 6074  | Reckless: 3926
#   [Sim #1 | Day 736] Cautious: 5973  | Reckless: 4027
#   [Sim #1 | Day 738] Cautious: 6075  | Reckless: 3925
#   [Sim #1 | Day 740] Cautious: 6123  | Reckless: 3877
#   [Sim #1 | Day 742] Cautious: 6002  | Reckless: 3998
#   [Sim #1 | Day 744] Cautious: 6108  | Reckless: 3892
#   [Sim #1 | Day 746] Cautious: 6146  | Reckless: 3854
#   [Sim #1 | Day 748] Cautious: 6105  | Reckless: 3895
#   [Sim #1 | Day 750] Cautious: 6228  | Reckless: 3772
#   [Sim #1 | Day 752] Cautious: 6125  | Reckless: 3875
#   [Sim #1 | Day 754] Cautious: 6290  | Reckless: 3710
#   [Sim #1 | Day 756] Cautious: 6127  | Reckless: 3873
#   [Sim #1 | Day 758] Cautious: 5933  | Reckless: 4067
#   [Sim #1 | Day 760] Cautious: 6129  | Reckless: 3871
#   [Sim #1 | Day 762] Cautious: 6081  | Reckless: 3919
#   [Sim #1 | Day 764] Cautious: 5926  | Reckless: 4074
#   [Sim #1 | Day 766] Cautious: 6228  | Reckless: 3772
#   [Sim #1 | Day 768] Cautious: 6247  | Reckless: 3753
#   [Sim #1 | Day 770] Cautious: 6125  | Reckless: 3875
#   [Sim #1 | Day 772] Cautious: 6040  | Reckless: 3960
#   [Sim #1 | Day 774] Cautious: 5965  | Reckless: 4035
#   [Sim #1 | Day 776] Cautious: 6074  | Reckless: 3926
#   [Sim #1 | Day 778] Cautious: 6032  | Reckless: 3968
#   [Sim #1 | Day 780] Cautious: 6049  | Reckless: 3951
#   [Sim #1 | Day 782] Cautious: 6074  | Reckless: 3926
#   [Sim #1 | Day 784] Cautious: 6118  | Reckless: 3882
#   [Sim #1 | Day 786] Cautious: 5961  | Reckless: 4039
#   [Sim #1 | Day 788] Cautious: 6096  | Reckless: 3904
#   [Sim #1 | Day 790] Cautious: 5901  | Reckless: 4099
#   [Sim #1 | Day 792] Cautious: 5986  | Reckless: 4014
#   [Sim #1 | Day 794] Cautious: 5943  | Reckless: 4057
#   [Sim #1 | Day 796] Cautious: 5941  | Reckless: 4059
#   [Sim #1 | Day 798] Cautious: 5855  | Reckless: 4145
#   [Sim #1 | Day 800] Cautious: 6114  | Reckless: 3886
#   [Sim #1 | Day 802] Cautious: 6140  | Reckless: 3860
#   [Sim #1 | Day 804] Cautious: 5786  | Reckless: 4214
#   [Sim #1 | Day 806] Cautious: 5849  | Reckless: 4151
#   [Sim #1 | Day 808] Cautious: 5972  | Reckless: 4028
#   [Sim #1 | Day 810] Cautious: 6113  | Reckless: 3887
#   [Sim #1 | Day 812] Cautious: 6244  | Reckless: 3756
#   [Sim #1 | Day 814] Cautious: 6137  | Reckless: 3863
#   [Sim #1 | Day 816] Cautious: 6196  | Reckless: 3804
#   [Sim #1 | Day 818] Cautious: 6148  | Reckless: 3852
#   [Sim #1 | Day 820] Cautious: 6320  | Reckless: 3680
#   [Sim #1 | Day 822] Cautious: 6392  | Reckless: 3608
#   [Sim #1 | Day 824] Cautious: 6254  | Reckless: 3746
#   [Sim #1 | Day 826] Cautious: 6362  | Reckless: 3638
#   [Sim #1 | Day 828] Cautious: 6095  | Reckless: 3905
#   [Sim #1 | Day 830] Cautious: 6233  | Reckless: 3767
#   [Sim #1 | Day 832] Cautious: 6315  | Reckless: 3685
#   [Sim #1 | Day 834] Cautious: 6073  | Reckless: 3927
#   [Sim #1 | Day 836] Cautious: 6089  | Reckless: 3911
#   [Sim #1 | Day 838] Cautious: 5930  | Reckless: 4070
#   [Sim #1 | Day 840] Cautious: 6204  | Reckless: 3796
#   [Sim #1 | Day 842] Cautious: 6254  | Reckless: 3746
#   [Sim #1 | Day 844] Cautious: 6250  | Reckless: 3750
#   [Sim #1 | Day 846] Cautious: 6236  | Reckless: 3764
#   [Sim #1 | Day 848] Cautious: 6230  | Reckless: 3770
#   [Sim #1 | Day 850] Cautious: 5996  | Reckless: 4004
#   [Sim #1 | Day 852] Cautious: 6182  | Reckless: 3818
#   [Sim #1 | Day 854] Cautious: 6146  | Reckless: 3854
#   [Sim #1 | Day 856] Cautious: 6222  | Reckless: 3778
#   [Sim #1 | Day 858] Cautious: 6301  | Reckless: 3699
#   [Sim #1 | Day 860] Cautious: 6287  | Reckless: 3713
#   [Sim #1 | Day 862] Cautious: 6336  | Reckless: 3664
#   [Sim #1 | Day 864] Cautious: 6345  | Reckless: 3655
#   [Sim #1 | Day 866] Cautious: 6172  | Reckless: 3828
#   [Sim #1 | Day 868] Cautious: 6421  | Reckless: 3579
#   [Sim #1 | Day 870] Cautious: 6347  | Reckless: 3653
#   [Sim #1 | Day 872] Cautious: 6286  | Reckless: 3714
#   [Sim #1 | Day 874] Cautious: 6283  | Reckless: 3717
#   [Sim #1 | Day 876] Cautious: 6313  | Reckless: 3687
#   [Sim #1 | Day 878] Cautious: 6321  | Reckless: 3679
#   [Sim #1 | Day 880] Cautious: 6168  | Reckless: 3832
#   [Sim #1 | Day 882] Cautious: 6305  | Reckless: 3695
#   [Sim #1 | Day 884] Cautious: 6322  | Reckless: 3678
#   [Sim #1 | Day 886] Cautious: 6303  | Reckless: 3697
#   [Sim #1 | Day 888] Cautious: 5985  | Reckless: 4015
#   [Sim #1 | Day 890] Cautious: 6285  | Reckless: 3715
#   [Sim #1 | Day 892] Cautious: 6299  | Reckless: 3701
#   [Sim #1 | Day 894] Cautious: 6352  | Reckless: 3648
#   [Sim #1 | Day 896] Cautious: 6260  | Reckless: 3740
#   [Sim #1 | Day 898] Cautious: 6284  | Reckless: 3716
#   [Sim #1 | Day 900] Cautious: 6297  | Reckless: 3703
#   [Sim #1 | Day 902] Cautious: 6266  | Reckless: 3734
#   [Sim #1 | Day 904] Cautious: 6362  | Reckless: 3638
#   [Sim #1 | Day 906] Cautious: 6408  | Reckless: 3592
#   [Sim #1 | Day 908] Cautious: 6428  | Reckless: 3572
#   [Sim #1 | Day 910] Cautious: 6447  | Reckless: 3553
#   [Sim #1 | Day 912] Cautious: 6512  | Reckless: 3488
#   [Sim #1 | Day 914] Cautious: 6508  | Reckless: 3492
#   [Sim #1 | Day 916] Cautious: 6494  | Reckless: 3506
#   [Sim #1 | Day 918] Cautious: 6451  | Reckless: 3549
#   [Sim #1 | Day 920] Cautious: 6474  | Reckless: 3526
#   [Sim #1 | Day 922] Cautious: 6427  | Reckless: 3573
#   [Sim #1 | Day 924] Cautious: 6365  | Reckless: 3635
#   [Sim #1 | Day 926] Cautious: 6372  | Reckless: 3628
#   [Sim #1 | Day 928] Cautious: 6322  | Reckless: 3678
#   [Sim #1 | Day 930] Cautious: 6329  | Reckless: 3671
#   [Sim #1 | Day 932] Cautious: 6373  | Reckless: 3627
#   [Sim #1 | Day 934] Cautious: 6208  | Reckless: 3792
#   [Sim #1 | Day 936] Cautious: 6235  | Reckless: 3765
#   [Sim #1 | Day 938] Cautious: 6317  | Reckless: 3683
#   [Sim #1 | Day 940] Cautious: 6359  | Reckless: 3641
#   [Sim #1 | Day 942] Cautious: 6434  | Reckless: 3566
#   [Sim #1 | Day 944] Cautious: 6265  | Reckless: 3735
#   [Sim #1 | Day 946] Cautious: 6394  | Reckless: 3606
#   [Sim #1 | Day 948] Cautious: 6502  | Reckless: 3498
#   [Sim #1 | Day 950] Cautious: 6358  | Reckless: 3642
#   [Sim #1 | Day 952] Cautious: 6471  | Reckless: 3529
#   [Sim #1 | Day 954] Cautious: 6485  | Reckless: 3515
#   [Sim #1 | Day 956] Cautious: 6299  | Reckless: 3701
#   [Sim #1 | Day 958] Cautious: 6485  | Reckless: 3515
#   [Sim #1 | Day 960] Cautious: 6438  | Reckless: 3562
#   [Sim #1 | Day 962] Cautious: 6369  | Reckless: 3631
#   [Sim #1 | Day 964] Cautious: 6364  | Reckless: 3636
#   [Sim #1 | Day 966] Cautious: 6402  | Reckless: 3598
#   [Sim #1 | Day 968] Cautious: 6338  | Reckless: 3662
#   [Sim #1 | Day 970] Cautious: 6365  | Reckless: 3635
#   [Sim #1 | Day 972] Cautious: 6592  | Reckless: 3408
#   [Sim #1 | Day 974] Cautious: 6661  | Reckless: 3339
#   [Sim #1 | Day 976] Cautious: 6726  | Reckless: 3274
#   [Sim #1 | Day 978] Cautious: 6523  | Reckless: 3477
#   [Sim #1 | Day 980] Cautious: 6720  | Reckless: 3280
#   [Sim #1 | Day 982] Cautious: 6686  | Reckless: 3314
#   [Sim #1 | Day 984] Cautious: 6652  | Reckless: 3348
#   [Sim #1 | Day 986] Cautious: 6722  | Reckless: 3278
#   [Sim #1 | Day 988] Cautious: 6696  | Reckless: 3304
#   [Sim #1 | Day 990] Cautious: 6586  | Reckless: 3414
#   [Sim #1 | Day 992] Cautious: 6710  | Reckless: 3290
#   [Sim #1 | Day 994] Cautious: 6519  | Reckless: 3481
#   [Sim #1 | Day 996] Cautious: 6715  | Reckless: 3285
#   [Sim #1 | Day 998] Cautious: 6732  | Reckless: 3268
#   [Sim #1 | Day 1000] Cautious: 6675  | Reckless: 3325
#   [Sim #1 | Day 1002] Cautious: 6700  | Reckless: 3300
#   [Sim #1 | Day 1004] Cautious: 6358  | Reckless: 3642
#   [Sim #1 | Day 1006] Cautious: 6536  | Reckless: 3464
#   [Sim #1 | Day 1008] Cautious: 6626  | Reckless: 3374
#   [Sim #1 | Day 1010] Cautious: 6471  | Reckless: 3529
#   [Sim #1 | Day 1012] Cautious: 6437  | Reckless: 3563
#   [Sim #1 | Day 1014] Cautious: 5981  | Reckless: 4019
#   [Sim #1 | Day 1016] Cautious: 6308  | Reckless: 3692
#   [Sim #1 | Day 1018] Cautious: 6301  | Reckless: 3699
#   [Sim #1 | Day 1020] Cautious: 6293  | Reckless: 3707
#   [Sim #1 | Day 1022] Cautious: 6406  | Reckless: 3594
#   [Sim #1 | Day 1024] Cautious: 6389  | Reckless: 3611
#   [Sim #1 | Day 1026] Cautious: 6321  | Reckless: 3679
#   [Sim #1 | Day 1028] Cautious: 6194  | Reckless: 3806
#   [Sim #1 | Day 1030] Cautious: 6176  | Reckless: 3824
#   [Sim #1 | Day 1032] Cautious: 6200  | Reckless: 3800
#   [Sim #1 | Day 1034] Cautious: 6345  | Reckless: 3655
#   [Sim #1 | Day 1036] Cautious: 6244  | Reckless: 3756
#   [Sim #1 | Day 1038] Cautious: 6381  | Reckless: 3619
#   [Sim #1 | Day 1040] Cautious: 6230  | Reckless: 3770
#   [Sim #1 | Day 1042] Cautious: 6269  | Reckless: 3731
#   [Sim #1 | Day 1044] Cautious: 6365  | Reckless: 3635
#   [Sim #1 | Day 1046] Cautious: 6311  | Reckless: 3689
#   [Sim #1 | Day 1048] Cautious: 6359  | Reckless: 3641
#   [Sim #1 | Day 1050] Cautious: 6413  | Reckless: 3587
#   [Sim #1 | Day 1052] Cautious: 6360  | Reckless: 3640
#   [Sim #1 | Day 1054] Cautious: 6400  | Reckless: 3600
#   [Sim #1 | Day 1056] Cautious: 6401  | Reckless: 3599
#   [Sim #1 | Day 1058] Cautious: 6339  | Reckless: 3661
#   [Sim #1 | Day 1060] Cautious: 6397  | Reckless: 3603
#   [Sim #1 | Day 1062] Cautious: 6152  | Reckless: 3848
#   [Sim #1 | Day 1064] Cautious: 6451  | Reckless: 3549
#   [Sim #1 | Day 1066] Cautious: 6315  | Reckless: 3685
#   [Sim #1 | Day 1068] Cautious: 6146  | Reckless: 3854
#   [Sim #1 | Day 1070] Cautious: 6298  | Reckless: 3702
#   [Sim #1 | Day 1072] Cautious: 6202  | Reckless: 3798
#   [Sim #1 | Day 1074] Cautious: 6204  | Reckless: 3796
#   [Sim #1 | Day 1076] Cautious: 6131  | Reckless: 3869
#   [Sim #1 | Day 1078] Cautious: 6217  | Reckless: 3783
#   [Sim #1 | Day 1080] Cautious: 6018  | Reckless: 3982
#   [Sim #1 | Day 1082] Cautious: 6203  | Reckless: 3797
#   [Sim #1 | Day 1084] Cautious: 6285  | Reckless: 3715
#   [Sim #1 | Day 1086] Cautious: 6163  | Reckless: 3837
#   [Sim #1 | Day 1088] Cautious: 6238  | Reckless: 3762
#   [Sim #1 | Day 1090] Cautious: 5987  | Reckless: 4013
#   [Sim #1 | Day 1092] Cautious: 6152  | Reckless: 3848
#   [Sim #1 | Day 1094] Cautious: 6242  | Reckless: 3758
#   [Sim #1 | Day 1096] Cautious: 6067  | Reckless: 3933
#   [Sim #1 | Day 1098] Cautious: 6247  | Reckless: 3753
#   [Sim #1 | Day 1100] Cautious: 6259  | Reckless: 3741
#   [Sim #1 | Day 1102] Cautious: 6032  | Reckless: 3968
#   [Sim #1 | Day 1104] Cautious: 6235  | Reckless: 3765
#   [Sim #1 | Day 1106] Cautious: 6289  | Reckless: 3711
#   [Sim #1 | Day 1108] Cautious: 6210  | Reckless: 3790
#   [Sim #1 | Day 1110] Cautious: 6216  | Reckless: 3784
#   [Sim #1 | Day 1112] Cautious: 6031  | Reckless: 3969
#   [Sim #1 | Day 1114] Cautious: 6310  | Reckless: 3690
#   [Sim #1 | Day 1116] Cautious: 6399  | Reckless: 3601
#   [Sim #1 | Day 1118] Cautious: 6361  | Reckless: 3639
#   [Sim #1 | Day 1120] Cautious: 6456  | Reckless: 3544
#   [Sim #1 | Day 1122] Cautious: 6360  | Reckless: 3640
#   [Sim #1 | Day 1124] Cautious: 6142  | Reckless: 3858
#   [Sim #1 | Day 1126] Cautious: 6387  | Reckless: 3613
#   [Sim #1 | Day 1128] Cautious: 6370  | Reckless: 3630
#   [Sim #1 | Day 1130] Cautious: 6362  | Reckless: 3638
#   [Sim #1 | Day 1132] Cautious: 6260  | Reckless: 3740
#   [Sim #1 | Day 1134] Cautious: 6484  | Reckless: 3516
#   [Sim #1 | Day 1136] Cautious: 6555  | Reckless: 3445
#   [Sim #1 | Day 1138] Cautious: 6525  | Reckless: 3475
#   [Sim #1 | Day 1140] Cautious: 6559  | Reckless: 3441
#   [Sim #1 | Day 1142] Cautious: 6498  | Reckless: 3502
#   [Sim #1 | Day 1144] Cautious: 6539  | Reckless: 3461
#   [Sim #1 | Day 1146] Cautious: 6198  | Reckless: 3802
#   [Sim #1 | Day 1148] Cautious: 6259  | Reckless: 3741
#   [Sim #1 | Day 1150] Cautious: 6339  | Reckless: 3661
#   [Sim #1 | Day 1152] Cautious: 6382  | Reckless: 3618
#   [Sim #1 | Day 1154] Cautious: 6162  | Reckless: 3838
#   [Sim #1 | Day 1156] Cautious: 6190  | Reckless: 3810
#   [Sim #1 | Day 1158] Cautious: 6108  | Reckless: 3892
#   [Sim #1 | Day 1160] Cautious: 5982  | Reckless: 4018
#   [Sim #1 | Day 1162] Cautious: 6309  | Reckless: 3691
#   [Sim #1 | Day 1164] Cautious: 6341  | Reckless: 3659
#   [Sim #1 | Day 1166] Cautious: 6376  | Reckless: 3624
#   [Sim #1 | Day 1168] Cautious: 6544  | Reckless: 3456
#   [Sim #1 | Day 1170] Cautious: 6548  | Reckless: 3452
#   [Sim #1 | Day 1172] Cautious: 6170  | Reckless: 3830
#   [Sim #1 | Day 1174] Cautious: 6448  | Reckless: 3552
#   [Sim #1 | Day 1176] Cautious: 6441  | Reckless: 3559
#   [Sim #1 | Day 1178] Cautious: 6412  | Reckless: 3588
#   [Sim #1 | Day 1180] Cautious: 6269  | Reckless: 3731
#   [Sim #1 | Day 1182] Cautious: 6422  | Reckless: 3578
#   [Sim #1 | Day 1184] Cautious: 6119  | Reckless: 3881
#   [Sim #1 | Day 1186] Cautious: 6312  | Reckless: 3688
#   [Sim #1 | Day 1188] Cautious: 6377  | Reckless: 3623
#   [Sim #1 | Day 1190] Cautious: 6340  | Reckless: 3660
#   [Sim #1 | Day 1192] Cautious: 6490  | Reckless: 3510
#   [Sim #1 | Day 1194] Cautious: 6151  | Reckless: 3849
#   [Sim #1 | Day 1196] Cautious: 6471  | Reckless: 3529
#   [Sim #1 | Day 1198] Cautious: 6543  | Reckless: 3457
#   [Sim #1 | Day 1200] Cautious: 6396  | Reckless: 3604
#   [Sim #1 | Day 1202] Cautious: 6525  | Reckless: 3475
#   [Sim #1 | Day 1204] Cautious: 6335  | Reckless: 3665
#   [Sim #1 | Day 1206] Cautious: 6672  | Reckless: 3328
#   [Sim #1 | Day 1208] Cautious: 6792  | Reckless: 3208
#   [Sim #1 | Day 1210] Cautious: 6672  | Reckless: 3328
#   [Sim #1 | Day 1212] Cautious: 6734  | Reckless: 3266
#   [Sim #1 | Day 1214] Cautious: 6784  | Reckless: 3216
#   [Sim #1 | Day 1216] Cautious: 6426  | Reckless: 3574
#   [Sim #1 | Day 1218] Cautious: 6676  | Reckless: 3324
#   [Sim #1 | Day 1220] Cautious: 6737  | Reckless: 3263
#   [Sim #1 | Day 1222] Cautious: 6804  | Reckless: 3196
#   [Sim #1 | Day 1224] Cautious: 6720  | Reckless: 3280
#   [Sim #1 | Day 1226] Cautious: 6764  | Reckless: 3236
#   [Sim #1 | Day 1228] Cautious: 6736  | Reckless: 3264
#   [Sim #1 | Day 1230] Cautious: 6467  | Reckless: 3533
#   [Sim #1 | Day 1232] Cautious: 6733  | Reckless: 3267
#   [Sim #1 | Day 1234] Cautious: 6624  | Reckless: 3376
#   [Sim #1 | Day 1236] Cautious: 6632  | Reckless: 3368
#   [Sim #1 | Day 1238] Cautious: 6725  | Reckless: 3275
#   [Sim #1 | Day 1240] Cautious: 6691  | Reckless: 3309
#   [Sim #1 | Day 1242] Cautious: 6764  | Reckless: 3236
#   [Sim #1 | Day 1244] Cautious: 6665  | Reckless: 3335
#   [Sim #1 | Day 1246] Cautious: 6820  | Reckless: 3180
#   [Sim #1 | Day 1248] Cautious: 6889  | Reckless: 3111
#   [Sim #1 | Day 1250] Cautious: 6586  | Reckless: 3414
#   [Sim #1 | Day 1252] Cautious: 6771  | Reckless: 3229
#   [Sim #1 | Day 1254] Cautious: 6852  | Reckless: 3148
#   [Sim #1 | Day 1256] Cautious: 6816  | Reckless: 3184
#   [Sim #1 | Day 1258] Cautious: 6858  | Reckless: 3142
#   [Sim #1 | Day 1260] Cautious: 6917  | Reckless: 3083
#   [Sim #1 | Day 1262] Cautious: 6876  | Reckless: 3124
#   [Sim #1 | Day 1264] Cautious: 6595  | Reckless: 3405
#   [Sim #1 | Day 1266] Cautious: 6583  | Reckless: 3417
#   [Sim #1 | Day 1268] Cautious: 6595  | Reckless: 3405
#   [Sim #1 | Day 1270] Cautious: 6605  | Reckless: 3395
#   [Sim #1 | Day 1272] Cautious: 6678  | Reckless: 3322
#   [Sim #1 | Day 1274] Cautious: 6718  | Reckless: 3282
#   [Sim #1 | Day 1276] Cautious: 6773  | Reckless: 3227
#   [Sim #1 | Day 1278] Cautious: 6753  | Reckless: 3247
#   [Sim #1 | Day 1280] Cautious: 6684  | Reckless: 3316
#   [Sim #1 | Day 1282] Cautious: 7023  | Reckless: 2977
#   [Sim #1 | Day 1284] Cautious: 7023  | Reckless: 2977
#   [Sim #1 | Day 1286] Cautious: 7108  | Reckless: 2892
#   [Sim #1 | Day 1288] Cautious: 7083  | Reckless: 2917
#   [Sim #1 | Day 1290] Cautious: 6645  | Reckless: 3355
#   [Sim #1 | Day 1292] Cautious: 6659  | Reckless: 3341
#   [Sim #1 | Day 1294] Cautious: 6585  | Reckless: 3415
#   [Sim #1 | Day 1296] Cautious: 6611  | Reckless: 3389
#   [Sim #1 | Day 1298] Cautious: 6765  | Reckless: 3235
#   [Sim #1 | Day 1300] Cautious: 6813  | Reckless: 3187
#   [Sim #1 | Day 1302] Cautious: 6781  | Reckless: 3219
#   [Sim #1 | Day 1304] Cautious: 6822  | Reckless: 3178
#   [Sim #1 | Day 1306] Cautious: 6356  | Reckless: 3644
#   [Sim #1 | Day 1308] Cautious: 6539  | Reckless: 3461
#   [Sim #1 | Day 1310] Cautious: 6724  | Reckless: 3276
#   [Sim #1 | Day 1312] Cautious: 6732  | Reckless: 3268
#   [Sim #1 | Day 1314] Cautious: 6579  | Reckless: 3421
#   [Sim #1 | Day 1316] Cautious: 6807  | Reckless: 3193
#   [Sim #1 | Day 1318] Cautious: 6662  | Reckless: 3338
#   [Sim #1 | Day 1320] Cautious: 6192  | Reckless: 3808
#   [Sim #1 | Day 1322] Cautious: 6541  | Reckless: 3459
#   [Sim #1 | Day 1324] Cautious: 6580  | Reckless: 3420
#   [Sim #1 | Day 1326] Cautious: 6479  | Reckless: 3521
#   [Sim #1 | Day 1328] Cautious: 6495  | Reckless: 3505
#   [Sim #1 | Day 1330] Cautious: 6261  | Reckless: 3739
#   [Sim #1 | Day 1332] Cautious: 6377  | Reckless: 3623
#   [Sim #1 | Day 1334] Cautious: 6237  | Reckless: 3763
#   [Sim #1 | Day 1336] Cautious: 6497  | Reckless: 3503
#   [Sim #1 | Day 1338] Cautious: 6495  | Reckless: 3505
#   [Sim #1 | Day 1340] Cautious: 6573  | Reckless: 3427
#   [Sim #1 | Day 1342] Cautious: 6647  | Reckless: 3353
#   [Sim #1 | Day 1344] Cautious: 6195  | Reckless: 3805
#   [Sim #1 | Day 1346] Cautious: 6525  | Reckless: 3475
#   [Sim #1 | Day 1348] Cautious: 6643  | Reckless: 3357
#   [Sim #1 | Day 1350] Cautious: 6519  | Reckless: 3481
#   [Sim #1 | Day 1352] Cautious: 6508  | Reckless: 3492
#   [Sim #1 | Day 1354] Cautious: 5926  | Reckless: 4074
#   [Sim #1 | Day 1356] Cautious: 6240  | Reckless: 3760
#   [Sim #1 | Day 1358] Cautious: 6239  | Reckless: 3761
#   [Sim #1 | Day 1360] Cautious: 6030  | Reckless: 3970
#   [Sim #1 | Day 1362] Cautious: 6157  | Reckless: 3843
#   [Sim #1 | Day 1364] Cautious: 5863  | Reckless: 4137
#   [Sim #1 | Day 1366] Cautious: 6339  | Reckless: 3661
#   [Sim #1 | Day 1368] Cautious: 6386  | Reckless: 3614
#   [Sim #1 | Day 1370] Cautious: 6322  | Reckless: 3678
#   [Sim #1 | Day 1372] Cautious: 6375  | Reckless: 3625
#   [Sim #1 | Day 1374] Cautious: 6020  | Reckless: 3980
#   [Sim #1 | Day 1376] Cautious: 6339  | Reckless: 3661
#   [Sim #1 | Day 1378] Cautious: 6348  | Reckless: 3652
#   [Sim #1 | Day 1380] Cautious: 5952  | Reckless: 4048
#   [Sim #1 | Day 1382] Cautious: 6249  | Reckless: 3751
#   [Sim #1 | Day 1384] Cautious: 6263  | Reckless: 3737
#   [Sim #1 | Day 1386] Cautious: 6314  | Reckless: 3686
#   [Sim #1 | Day 1388] Cautious: 6263  | Reckless: 3737
#   [Sim #1 | Day 1390] Cautious: 6310  | Reckless: 3690
#   [Sim #1 | Day 1392] Cautious: 6214  | Reckless: 3786
#   [Sim #1 | Day 1394] Cautious: 6006  | Reckless: 3994
#   [Sim #1 | Day 1396] Cautious: 5956  | Reckless: 4044
#   [Sim #1 | Day 1398] Cautious: 5938  | Reckless: 4062
#   [Sim #1 | Day 1400] Cautious: 5790  | Reckless: 4210
#   [Sim #1 | Day 1402] Cautious: 5660  | Reckless: 4340
#   [Sim #1 | Day 1404] Cautious: 5825  | Reckless: 4175
#   [Sim #1 | Day 1406] Cautious: 5855  | Reckless: 4145
#   [Sim #1 | Day 1408] Cautious: 5864  | Reckless: 4136
#   [Sim #1 | Day 1410] Cautious: 5497  | Reckless: 4503
#   [Sim #1 | Day 1412] Cautious: 5760  | Reckless: 4240
#   [Sim #1 | Day 1414] Cautious: 5776  | Reckless: 4224
#   [Sim #1 | Day 1416] Cautious: 5751  | Reckless: 4249
#   [Sim #1 | Day 1418] Cautious: 5733  | Reckless: 4267
#   [Sim #1 | Day 1420] Cautious: 5475  | Reckless: 4525
#   [Sim #1 | Day 1422] Cautious: 5448  | Reckless: 4552
#   [Sim #1 | Day 1424] Cautious: 5843  | Reckless: 4157
#   [Sim #1 | Day 1426] Cautious: 5798  | Reckless: 4202
#   [Sim #1 | Day 1428] Cautious: 5738  | Reckless: 4262
#   [Sim #1 | Day 1430] Cautious: 5537  | Reckless: 4463
#   [Sim #1 | Day 1432] Cautious: 5917  | Reckless: 4083
#   [Sim #1 | Day 1434] Cautious: 5898  | Reckless: 4102
#   [Sim #1 | Day 1436] Cautious: 6024  | Reckless: 3976
#   [Sim #1 | Day 1438] Cautious: 6007  | Reckless: 3993
#   [Sim #1 | Day 1440] Cautious: 6119  | Reckless: 3881
#   [Sim #1 | Day 1442] Cautious: 6115  | Reckless: 3885
#   [Sim #1 | Day 1444] Cautious: 6151  | Reckless: 3849
#   [Sim #1 | Day 1446] Cautious: 5786  | Reckless: 4214
#   [Sim #1 | Day 1448] Cautious: 6072  | Reckless: 3928
#   [Sim #1 | Day 1450] Cautious: 6102  | Reckless: 3898
#   [Sim #1 | Day 1452] Cautious: 6007  | Reckless: 3993
#   [Sim #1 | Day 1454] Cautious: 6096  | Reckless: 3904
#   [Sim #1 | Day 1456] Cautious: 5708  | Reckless: 4292
#   [Sim #1 | Day 1458] Cautious: 6053  | Reckless: 3947
#   [Sim #1 | Day 1460] Cautious: 6111  | Reckless: 3889
#   [Sim #1 | Day 1462] Cautious: 5921  | Reckless: 4079
#   [Sim #1 | Day 1464] Cautious: 6165  | Reckless: 3835
#   [Sim #1 | Day 1466] Cautious: 6231  | Reckless: 3769
#   [Sim #1 | Day 1468] Cautious: 5936  | Reckless: 4064
#   [Sim #1 | Day 1470] Cautious: 6208  | Reckless: 3792
#   [Sim #1 | Day 1472] Cautious: 6294  | Reckless: 3706
#   [Sim #1 | Day 1474] Cautious: 6243  | Reckless: 3757
#   [Sim #1 | Day 1476] Cautious: 6380  | Reckless: 3620
#   [Sim #1 | Day 1478] Cautious: 6109  | Reckless: 3891
#   [Sim #1 | Day 1480] Cautious: 6406  | Reckless: 3594
#   [Sim #1 | Day 1482] Cautious: 6028  | Reckless: 3972
#   [Sim #1 | Day 1484] Cautious: 6472  | Reckless: 3528
#   [Sim #1 | Day 1486] Cautious: 6254  | Reckless: 3746
#   [Sim #1 | Day 1488] Cautious: 6670  | Reckless: 3330
#   [Sim #1 | Day 1490] Cautious: 6655  | Reckless: 3345
#   [Sim #1 | Day 1492] Cautious: 6288  | Reckless: 3712
#   [Sim #1 | Day 1494] Cautious: 6735  | Reckless: 3265
#   [Sim #1 | Day 1496] Cautious: 6719  | Reckless: 3281
#   [Sim #1 | Day 1498] Cautious: 6634  | Reckless: 3366
#   [Sim #1 | Day 1500] Cautious: 6636  | Reckless: 3364
#   [Sim #1 | Day 1502] Cautious: 6372  | Reckless: 3628
#   [Sim #1 | Day 1504] Cautious: 6326  | Reckless: 3674
#   [Sim #1 | Day 1506] Cautious: 6348  | Reckless: 3652
#   [Sim #1 | Day 1508] Cautious: 6415  | Reckless: 3585
#   [Sim #1 | Day 1510] Cautious: 6718  | Reckless: 3282
#   [Sim #1 | Day 1512] Cautious: 6801  | Reckless: 3199
#   [Sim #1 | Day 1514] Cautious: 6924  | Reckless: 3076
#   [Sim #1 | Day 1516] Cautious: 7024  | Reckless: 2976
#   [Sim #1 | Day 1518] Cautious: 6953  | Reckless: 3047
#   [Sim #1 | Day 1520] Cautious: 7039  | Reckless: 2961
#   [Sim #1 | Day 1522] Cautious: 7041  | Reckless: 2959
#   [Sim #1 | Day 1524] Cautious: 6715  | Reckless: 3285
#   [Sim #1 | Day 1526] Cautious: 7045  | Reckless: 2955
#   [Sim #1 | Day 1528] Cautious: 7085  | Reckless: 2915
#   [Sim #1 | Day 1530] Cautious: 7094  | Reckless: 2906
#   [Sim #1 | Day 1532] Cautious: 7073  | Reckless: 2927
#   [Sim #1 | Day 1534] Cautious: 7069  | Reckless: 2931
#   [Sim #1 | Day 1536] Cautious: 7077  | Reckless: 2923
#   [Sim #1 | Day 1538] Cautious: 6775  | Reckless: 3225
#   [Sim #1 | Day 1540] Cautious: 7059  | Reckless: 2941
#   [Sim #1 | Day 1542] Cautious: 7101  | Reckless: 2899
#   [Sim #1 | Day 1544] Cautious: 6719  | Reckless: 3281
#   [Sim #1 | Day 1546] Cautious: 7027  | Reckless: 2973
#   [Sim #1 | Day 1548] Cautious: 7152  | Reckless: 2848
#   [Sim #1 | Day 1550] Cautious: 7091  | Reckless: 2909
#   [Sim #1 | Day 1552] Cautious: 7160  | Reckless: 2840
#   [Sim #1 | Day 1554] Cautious: 7184  | Reckless: 2816
#   [Sim #1 | Day 1556] Cautious: 6977  | Reckless: 3023
#   [Sim #1 | Day 1558] Cautious: 7066  | Reckless: 2934
#   [Sim #1 | Day 1560] Cautious: 6764  | Reckless: 3236
#   [Sim #1 | Day 1562] Cautious: 7084  | Reckless: 2916
#   [Sim #1 | Day 1564] Cautious: 7152  | Reckless: 2848
#   [Sim #1 | Day 1566] Cautious: 7171  | Reckless: 2829
#   [Sim #1 | Day 1568] Cautious: 7304  | Reckless: 2696
#   [Sim #1 | Day 1570] Cautious: 6917  | Reckless: 3083
#   [Sim #1 | Day 1572] Cautious: 7126  | Reckless: 2874
#   [Sim #1 | Day 1574] Cautious: 7226  | Reckless: 2774
#   [Sim #1 | Day 1576] Cautious: 7145  | Reckless: 2855
#   [Sim #1 | Day 1578] Cautious: 7174  | Reckless: 2826
#   [Sim #1 | Day 1580] Cautious: 7144  | Reckless: 2856
#   [Sim #1 | Day 1582] Cautious: 7187  | Reckless: 2813
#   [Sim #1 | Day 1584] Cautious: 6872  | Reckless: 3128
#   [Sim #1 | Day 1586] Cautious: 7180  | Reckless: 2820
#   [Sim #1 | Day 1588] Cautious: 7201  | Reckless: 2799
#   [Sim #1 | Day 1590] Cautious: 7102  | Reckless: 2898
#   [Sim #1 | Day 1592] Cautious: 7098  | Reckless: 2902
#   [Sim #1 | Day 1594] Cautious: 6849  | Reckless: 3151
#   [Sim #1 | Day 1596] Cautious: 7246  | Reckless: 2754
#   [Sim #1 | Day 1598] Cautious: 7178  | Reckless: 2822
#   [Sim #1 | Day 1600] Cautious: 7077  | Reckless: 2923
#   [Sim #1 | Day 1602] Cautious: 7174  | Reckless: 2826
#   [Sim #1 | Day 1604] Cautious: 7101  | Reckless: 2899
#   [Sim #1 | Day 1606] Cautious: 6825  | Reckless: 3175
#   [Sim #1 | Day 1608] Cautious: 7191  | Reckless: 2809
#   [Sim #1 | Day 1610] Cautious: 7208  | Reckless: 2792
#   [Sim #1 | Day 1612] Cautious: 6849  | Reckless: 3151
#   [Sim #1 | Day 1614] Cautious: 7113  | Reckless: 2887
#   [Sim #1 | Day 1616] Cautious: 7066  | Reckless: 2934
#   [Sim #1 | Day 1618] Cautious: 7147  | Reckless: 2853
#   [Sim #1 | Day 1620] Cautious: 7193  | Reckless: 2807
#   [Sim #1 | Day 1622] Cautious: 6817  | Reckless: 3183
#   [Sim #1 | Day 1624] Cautious: 7135  | Reckless: 2865
#   [Sim #1 | Day 1626] Cautious: 7203  | Reckless: 2797
#   [Sim #1 | Day 1628] Cautious: 7159  | Reckless: 2841
#   [Sim #1 | Day 1630] Cautious: 7202  | Reckless: 2798
#   [Sim #1 | Day 1632] Cautious: 7292  | Reckless: 2708
#   [Sim #1 | Day 1634] Cautious: 7279  | Reckless: 2721
#   [Sim #1 | Day 1636] Cautious: 7268  | Reckless: 2732
#   [Sim #1 | Day 1638] Cautious: 7202  | Reckless: 2798
#   [Sim #1 | Day 1640] Cautious: 7198  | Reckless: 2802
#   [Sim #1 | Day 1642] Cautious: 7262  | Reckless: 2738
#   [Sim #1 | Day 1644] Cautious: 7279  | Reckless: 2721
#   [Sim #1 | Day 1646] Cautious: 7259  | Reckless: 2741
#   [Sim #1 | Day 1648] Cautious: 7288  | Reckless: 2712
#   [Sim #1 | Day 1650] Cautious: 7271  | Reckless: 2729
#   [Sim #1 | Day 1652] Cautious: 7268  | Reckless: 2732
#   [Sim #1 | Day 1654] Cautious: 7314  | Reckless: 2686
#   [Sim #1 | Day 1656] Cautious: 7336  | Reckless: 2664
#   [Sim #1 | Day 1658] Cautious: 7438  | Reckless: 2562
#   [Sim #1 | Day 1660] Cautious: 7452  | Reckless: 2548
#   [Sim #1 | Day 1662] Cautious: 7462  | Reckless: 2538
#   [Sim #1 | Day 1664] Cautious: 7519  | Reckless: 2481
#   [Sim #1 | Day 1666] Cautious: 7568  | Reckless: 2432
#   [Sim #1 | Day 1668] Cautious: 7258  | Reckless: 2742
#   [Sim #1 | Day 1670] Cautious: 7594  | Reckless: 2406
#   [Sim #1 | Day 1672] Cautious: 7629  | Reckless: 2371
#   [Sim #1 | Day 1674] Cautious: 7764  | Reckless: 2236
#   [Sim #1 | Day 1676] Cautious: 7500  | Reckless: 2500
#   [Sim #1 | Day 1678] Cautious: 7698  | Reckless: 2302
#   [Sim #1 | Day 1680] Cautious: 7795  | Reckless: 2205
#   [Sim #1 | Day 1682] Cautious: 7713  | Reckless: 2287
#   [Sim #1 | Day 1684] Cautious: 7501  | Reckless: 2499
#   [Sim #1 | Day 1686] Cautious: 7843  | Reckless: 2157
#   [Sim #1 | Day 1688] Cautious: 7787  | Reckless: 2213
#   [Sim #1 | Day 1690] Cautious: 7675  | Reckless: 2325
#   [Sim #1 | Day 1692] Cautious: 7274  | Reckless: 2726
#   [Sim #1 | Day 1694] Cautious: 7260  | Reckless: 2740
#   [Sim #1 | Day 1696] Cautious: 7631  | Reckless: 2369
#   [Sim #1 | Day 1698] Cautious: 7646  | Reckless: 2354
#   [Sim #1 | Day 1700] Cautious: 7399  | Reckless: 2601
#   [Sim #1 | Day 1702] Cautious: 7478  | Reckless: 2522
#   [Sim #1 | Day 1704] Cautious: 7717  | Reckless: 2283
#   [Sim #1 | Day 1706] Cautious: 7681  | Reckless: 2319
#   [Sim #1 | Day 1708] Cautious: 7722  | Reckless: 2278
#   [Sim #1 | Day 1710] Cautious: 7439  | Reckless: 2561
#   [Sim #1 | Day 1712] Cautious: 7787  | Reckless: 2213
#   [Sim #1 | Day 1714] Cautious: 7828  | Reckless: 2172
#   [Sim #1 | Day 1716] Cautious: 7771  | Reckless: 2229
#   [Sim #1 | Day 1718] Cautious: 7786  | Reckless: 2214
#   [Sim #1 | Day 1720] Cautious: 7550  | Reckless: 2450
#   [Sim #1 | Day 1722] Cautious: 7756  | Reckless: 2244
#   [Sim #1 | Day 1724] Cautious: 7847  | Reckless: 2153
#   [Sim #1 | Day 1726] Cautious: 7651  | Reckless: 2349
#   [Sim #1 | Day 1728] Cautious: 7657  | Reckless: 2343
#   [Sim #1 | Day 1730] Cautious: 7296  | Reckless: 2704
# ...
#   [Sim #2 | Day 70] Cautious: 5344  | Reckless: 4656
#   [Sim #2 | Day 72] Cautious: 5361  | Reckless: 4639
#   [Sim #2 | Day 74] Cautious: 5401  | Reckless: 4599
#   [Sim #2 | Day 76] Cautious: 5391  | Reckless: 4609
#   [Sim #2 | Day 78] Cautious: 5312  | Reckless: 4688
#   [Sim #2 | Day 80] Cautious: 5279  | Reckless: 4721
#   [Sim #2 | Day 82] Cautious: 5305  | Reckless: 4695
#   [Sim #2 | Day 84] Cautious: 5449  | Reckless: 4551
#   [Sim #2 | Day 86] Cautious: 5344  | Reckless: 4656
#   [Sim #2 | Day 88] Cautious: 5226  | Reckless: 4774
#   [Sim #2 | Day 90] Cautious: 5240  | Reckless: 4760
#   [Sim #2 | Day 92] Cautious: 5238  | Reckless: 4762
#   [Sim #2 | Day 94] Cautious: 5234  | Reckless: 4766
#   [Sim #2 | Day 96] Cautious: 5286  | Reckless: 4714
#   [Sim #2 | Day 98] Cautious: 5345  | Reckless: 4655
#   [Sim #2 | Day 100] Cautious: 5393  | Reckless: 4607
#   [Sim #2 | Day 102] Cautious: 5306  | Reckless: 4694
#   [Sim #2 | Day 104] Cautious: 5347  | Reckless: 4653
#   [Sim #2 | Day 106] Cautious: 5403  | Reckless: 4597
#   [Sim #2 | Day 108] Cautious: 5421  | Reckless: 4579
#   [Sim #2 | Day 110] Cautious: 5465  | Reckless: 4535
#   [Sim #2 | Day 112] Cautious: 5604  | Reckless: 4396
#   [Sim #2 | Day 114] Cautious: 5477  | Reckless: 4523
#   [Sim #2 | Day 116] Cautious: 5474  | Reckless: 4526
#   [Sim #2 | Day 118] Cautious: 5391  | Reckless: 4609
#   [Sim #2 | Day 120] Cautious: 5360  | Reckless: 4640
#   [Sim #2 | Day 122] Cautious: 5420  | Reckless: 4580
#   [Sim #2 | Day 124] Cautious: 5402  | Reckless: 4598
#   [Sim #2 | Day 126] Cautious: 5362  | Reckless: 4638
#   [Sim #2 | Day 128] Cautious: 5307  | Reckless: 4693
#   [Sim #2 | Day 130] Cautious: 5200  | Reckless: 4800
#   [Sim #2 | Day 132] Cautious: 5285  | Reckless: 4715
#   [Sim #2 | Day 134] Cautious: 5343  | Reckless: 4657
#   [Sim #2 | Day 136] Cautious: 5323  | Reckless: 4677
#   [Sim #2 | Day 138] Cautious: 5308  | Reckless: 4692
#   [Sim #2 | Day 140] Cautious: 5272  | Reckless: 4728
#   [Sim #2 | Day 142] Cautious: 5323  | Reckless: 4677
#   [Sim #2 | Day 144] Cautious: 5296  | Reckless: 4704
#   [Sim #2 | Day 146] Cautious: 5304  | Reckless: 4696
#   [Sim #2 | Day 148] Cautious: 5355  | Reckless: 4645
#   [Sim #2 | Day 150] Cautious: 5301  | Reckless: 4699
#   [Sim #2 | Day 152] Cautious: 5317  | Reckless: 4683
#   [Sim #2 | Day 154] Cautious: 5202  | Reckless: 4798
#   [Sim #2 | Day 156] Cautious: 5256  | Reckless: 4744
#   [Sim #2 | Day 158] Cautious: 5237  | Reckless: 4763
#   [Sim #2 | Day 160] Cautious: 5160  | Reckless: 4840
#   [Sim #2 | Day 162] Cautious: 5195  | Reckless: 4805
#   [Sim #2 | Day 164] Cautious: 5170  | Reckless: 4830
#   [Sim #2 | Day 166] Cautious: 5226  | Reckless: 4774
#   [Sim #2 | Day 168] Cautious: 5244  | Reckless: 4756
#   [Sim #2 | Day 170] Cautious: 5186  | Reckless: 4814
#   [Sim #2 | Day 172] Cautious: 5215  | Reckless: 4785
#   [Sim #2 | Day 174] Cautious: 5213  | Reckless: 4787
#   [Sim #2 | Day 176] Cautious: 5221  | Reckless: 4779
#   [Sim #2 | Day 178] Cautious: 5080  | Reckless: 4920
#   [Sim #2 | Day 180] Cautious: 5047  | Reckless: 4953
#   [Sim #2 | Day 182] Cautious: 5033  | Reckless: 4967
#   [Sim #2 | Day 184] Cautious: 5145  | Reckless: 4855
#   [Sim #2 | Day 186] Cautious: 5103  | Reckless: 4897
#   [Sim #2 | Day 188] Cautious: 5094  | Reckless: 4906
#   [Sim #2 | Day 190] Cautious: 5152  | Reckless: 4848
#   [Sim #2 | Day 192] Cautious: 5170  | Reckless: 4830
#   [Sim #2 | Day 194] Cautious: 5163  | Reckless: 4837
#   [Sim #2 | Day 196] Cautious: 5112  | Reckless: 4888
#   [Sim #2 | Day 198] Cautious: 4996  | Reckless: 5004
#   [Sim #2 | Day 200] Cautious: 5042  | Reckless: 4958
#   [Sim #2 | Day 202] Cautious: 5005  | Reckless: 4995
#   [Sim #2 | Day 204] Cautious: 5054  | Reckless: 4946
#   [Sim #2 | Day 206] Cautious: 5045  | Reckless: 4955
#   [Sim #2 | Day 208] Cautious: 5084  | Reckless: 4916
#   [Sim #2 | Day 210] Cautious: 5032  | Reckless: 4968
#   [Sim #2 | Day 212] Cautious: 5054  | Reckless: 4946
#   [Sim #2 | Day 214] Cautious: 5039  | Reckless: 4961
#   [Sim #2 | Day 216] Cautious: 5086  | Reckless: 4914
#   [Sim #2 | Day 218] Cautious: 5061  | Reckless: 4939
#   [Sim #2 | Day 220] Cautious: 5007  | Reckless: 4993
#   [Sim #2 | Day 222] Cautious: 5026  | Reckless: 4974
#   [Sim #2 | Day 224] Cautious: 5023  | Reckless: 4977
#   [Sim #2 | Day 226] Cautious: 4988  | Reckless: 5012
#   [Sim #2 | Day 228] Cautious: 4933  | Reckless: 5067
#   [Sim #2 | Day 230] Cautious: 5008  | Reckless: 4992
#   [Sim #2 | Day 232] Cautious: 4975  | Reckless: 5025
#   [Sim #2 | Day 234] Cautious: 4965  | Reckless: 5035
#   [Sim #2 | Day 236] Cautious: 5000  | Reckless: 5000
#   [Sim #2 | Day 238] Cautious: 5092  | Reckless: 4908
#   [Sim #2 | Day 240] Cautious: 5054  | Reckless: 4946
#   [Sim #2 | Day 242] Cautious: 5126  | Reckless: 4874
#   [Sim #2 | Day 244] Cautious: 5085  | Reckless: 4915
#   [Sim #2 | Day 246] Cautious: 4972  | Reckless: 5028
#   [Sim #2 | Day 248] Cautious: 5046  | Reckless: 4954
#   [Sim #2 | Day 250] Cautious: 5154  | Reckless: 4846
#   [Sim #2 | Day 252] Cautious: 5257  | Reckless: 4743
#   [Sim #2 | Day 254] Cautious: 5352  | Reckless: 4648
#   [Sim #2 | Day 256] Cautious: 5450  | Reckless: 4550
#   [Sim #2 | Day 258] Cautious: 5290  | Reckless: 4710
#   [Sim #2 | Day 260] Cautious: 5271  | Reckless: 4729
#   [Sim #2 | Day 262] Cautious: 5284  | Reckless: 4716
#   [Sim #2 | Day 264] Cautious: 5243  | Reckless: 4757
#   [Sim #2 | Day 266] Cautious: 5358  | Reckless: 4642
#   [Sim #2 | Day 268] Cautious: 5223  | Reckless: 4777
#   [Sim #2 | Day 270] Cautious: 5128  | Reckless: 4872
#   [Sim #2 | Day 272] Cautious: 5143  | Reckless: 4857
#   [Sim #2 | Day 274] Cautious: 5198  | Reckless: 4802
#   [Sim #2 | Day 276] Cautious: 5348  | Reckless: 4652
#   [Sim #2 | Day 278] Cautious: 5104  | Reckless: 4896
#   [Sim #2 | Day 280] Cautious: 5034  | Reckless: 4966
#   [Sim #2 | Day 282] Cautious: 4960  | Reckless: 5040
#   [Sim #2 | Day 284] Cautious: 4934  | Reckless: 5066
#   [Sim #2 | Day 286] Cautious: 4964  | Reckless: 5036
#   [Sim #2 | Day 288] Cautious: 5065  | Reckless: 4935
#   [Sim #2 | Day 290] Cautious: 4789  | Reckless: 5211
#   [Sim #2 | Day 292] Cautious: 4929  | Reckless: 5071
#   [Sim #2 | Day 294] Cautious: 4940  | Reckless: 5060
#   [Sim #2 | Day 296] Cautious: 4949  | Reckless: 5051
#   [Sim #2 | Day 298] Cautious: 4840  | Reckless: 5160
#   [Sim #2 | Day 300] Cautious: 4994  | Reckless: 5006
#   [Sim #2 | Day 302] Cautious: 4926  | Reckless: 5074
#   [Sim #2 | Day 304] Cautious: 4893  | Reckless: 5107
#   [Sim #2 | Day 306] Cautious: 4871  | Reckless: 5129
#   [Sim #2 | Day 308] Cautious: 4775  | Reckless: 5225
#   [Sim #2 | Day 310] Cautious: 4691  | Reckless: 5309
#   [Sim #2 | Day 312] Cautious: 4607  | Reckless: 5393
#   [Sim #2 | Day 314] Cautious: 4436  | Reckless: 5564
#   [Sim #2 | Day 316] Cautious: 4531  | Reckless: 5469
#   [Sim #2 | Day 318] Cautious: 4666  | Reckless: 5334
#   [Sim #2 | Day 320] Cautious: 4657  | Reckless: 5343
#   [Sim #2 | Day 322] Cautious: 4721  | Reckless: 5279
#   [Sim #2 | Day 324] Cautious: 4682  | Reckless: 5318
#   [Sim #2 | Day 326] Cautious: 4629  | Reckless: 5371
#   [Sim #2 | Day 328] Cautious: 4912  | Reckless: 5088
#   [Sim #2 | Day 330] Cautious: 4718  | Reckless: 5282
#   [Sim #2 | Day 332] Cautious: 4791  | Reckless: 5209
#   [Sim #2 | Day 334] Cautious: 4860  | Reckless: 5140
#   [Sim #2 | Day 336] Cautious: 4967  | Reckless: 5033
#   [Sim #2 | Day 338] Cautious: 4946  | Reckless: 5054
#   [Sim #2 | Day 340] Cautious: 4898  | Reckless: 5102
#   [Sim #2 | Day 342] Cautious: 5000  | Reckless: 5000
#   [Sim #2 | Day 344] Cautious: 4896  | Reckless: 5104
#   [Sim #2 | Day 346] Cautious: 5006  | Reckless: 4994
#   [Sim #2 | Day 348] Cautious: 4853  | Reckless: 5147
#   [Sim #2 | Day 350] Cautious: 4888  | Reckless: 5112
#   [Sim #2 | Day 352] Cautious: 4900  | Reckless: 5100
#   [Sim #2 | Day 354] Cautious: 4896  | Reckless: 5104
#   [Sim #2 | Day 356] Cautious: 4874  | Reckless: 5126
#   [Sim #2 | Day 358] Cautious: 5042  | Reckless: 4958
#   [Sim #2 | Day 360] Cautious: 4884  | Reckless: 5116
#   [Sim #2 | Day 362] Cautious: 4853  | Reckless: 5147
#   [Sim #2 | Day 364] Cautious: 5054  | Reckless: 4946
#   [Sim #2 | Day 366] Cautious: 4918  | Reckless: 5082
#   [Sim #2 | Day 368] Cautious: 4979  | Reckless: 5021
#   [Sim #2 | Day 370] Cautious: 4846  | Reckless: 5154
#   [Sim #2 | Day 372] Cautious: 4966  | Reckless: 5034
#   [Sim #2 | Day 374] Cautious: 5012  | Reckless: 4988
#   [Sim #2 | Day 376] Cautious: 4753  | Reckless: 5247
#   [Sim #2 | Day 378] Cautious: 4845  | Reckless: 5155
#   [Sim #2 | Day 380] Cautious: 5062  | Reckless: 4938
#   [Sim #2 | Day 382] Cautious: 4868  | Reckless: 5132
#   [Sim #2 | Day 384] Cautious: 4909  | Reckless: 5091
#   [Sim #2 | Day 386] Cautious: 4743  | Reckless: 5257
#   [Sim #2 | Day 388] Cautious: 4925  | Reckless: 5075
#   [Sim #2 | Day 390] Cautious: 4838  | Reckless: 5162
#   [Sim #2 | Day 392] Cautious: 4927  | Reckless: 5073
#   [Sim #2 | Day 394] Cautious: 4909  | Reckless: 5091
#   [Sim #2 | Day 396] Cautious: 4883  | Reckless: 5117
#   [Sim #2 | Day 398] Cautious: 5084  | Reckless: 4916
#   [Sim #2 | Day 400] Cautious: 4982  | Reckless: 5018
#   [Sim #2 | Day 402] Cautious: 5021  | Reckless: 4979
#   [Sim #2 | Day 404] Cautious: 5044  | Reckless: 4956
#   [Sim #2 | Day 406] Cautious: 5035  | Reckless: 4965
#   [Sim #2 | Day 408] Cautious: 4984  | Reckless: 5016
#   [Sim #2 | Day 410] Cautious: 4937  | Reckless: 5063
#   [Sim #2 | Day 412] Cautious: 4939  | Reckless: 5061
#   [Sim #2 | Day 414] Cautious: 5075  | Reckless: 4925
#   [Sim #2 | Day 416] Cautious: 5119  | Reckless: 4881
#   [Sim #2 | Day 418] Cautious: 5129  | Reckless: 4871
#   [Sim #2 | Day 420] Cautious: 5294  | Reckless: 4706
#   [Sim #2 | Day 422] Cautious: 5206  | Reckless: 4794
#   [Sim #2 | Day 424] Cautious: 5300  | Reckless: 4700
#   [Sim #2 | Day 426] Cautious: 5276  | Reckless: 4724
#   [Sim #2 | Day 428] Cautious: 5415  | Reckless: 4585
#   [Sim #2 | Day 430] Cautious: 5291  | Reckless: 4709
#   [Sim #2 | Day 432] Cautious: 5252  | Reckless: 4748
#   [Sim #2 | Day 434] Cautious: 5204  | Reckless: 4796
#   [Sim #2 | Day 436] Cautious: 5106  | Reckless: 4894
#   [Sim #2 | Day 438] Cautious: 5258  | Reckless: 4742
#   [Sim #2 | Day 440] Cautious: 5190  | Reckless: 4810
#   [Sim #2 | Day 442] Cautious: 5260  | Reckless: 4740
#   [Sim #2 | Day 444] Cautious: 5375  | Reckless: 4625
#   [Sim #2 | Day 446] Cautious: 5631  | Reckless: 4369
#   [Sim #2 | Day 448] Cautious: 5391  | Reckless: 4609
#   [Sim #2 | Day 450] Cautious: 5448  | Reckless: 4552
#   [Sim #2 | Day 452] Cautious: 5311  | Reckless: 4689
#   [Sim #2 | Day 454] Cautious: 5404  | Reckless: 4596
#   [Sim #2 | Day 456] Cautious: 5571  | Reckless: 4429
#   [Sim #2 | Day 458] Cautious: 5560  | Reckless: 4440
#   [Sim #2 | Day 460] Cautious: 5536  | Reckless: 4464
#   [Sim #2 | Day 462] Cautious: 5416  | Reckless: 4584
#   [Sim #2 | Day 464] Cautious: 5610  | Reckless: 4390
#   [Sim #2 | Day 466] Cautious: 5619  | Reckless: 4381
#   [Sim #2 | Day 468] Cautious: 5593  | Reckless: 4407
#   [Sim #2 | Day 470] Cautious: 5654  | Reckless: 4346
#   [Sim #2 | Day 472] Cautious: 5553  | Reckless: 4447
#   [Sim #2 | Day 474] Cautious: 5601  | Reckless: 4399
#   [Sim #2 | Day 476] Cautious: 5680  | Reckless: 4320
#   [Sim #2 | Day 478] Cautious: 5756  | Reckless: 4244
#   [Sim #2 | Day 480] Cautious: 5835  | Reckless: 4165
#   [Sim #2 | Day 482] Cautious: 5823  | Reckless: 4177
#   [Sim #2 | Day 484] Cautious: 5756  | Reckless: 4244
#   [Sim #2 | Day 486] Cautious: 5855  | Reckless: 4145
#   [Sim #2 | Day 488] Cautious: 5805  | Reckless: 4195
#   [Sim #2 | Day 490] Cautious: 5911  | Reckless: 4089
#   [Sim #2 | Day 492] Cautious: 5938  | Reckless: 4062
#   [Sim #2 | Day 494] Cautious: 5872  | Reckless: 4128
#   [Sim #2 | Day 496] Cautious: 5724  | Reckless: 4276
#   [Sim #2 | Day 498] Cautious: 5793  | Reckless: 4207
#   [Sim #2 | Day 500] Cautious: 5832  | Reckless: 4168
#   [Sim #2 | Day 502] Cautious: 5776  | Reckless: 4224
#   [Sim #2 | Day 504] Cautious: 5871  | Reckless: 4129
#   [Sim #2 | Day 506] Cautious: 5755  | Reckless: 4245
#   [Sim #2 | Day 508] Cautious: 5712  | Reckless: 4288
#   [Sim #2 | Day 510] Cautious: 5724  | Reckless: 4276
#   [Sim #2 | Day 512] Cautious: 5683  | Reckless: 4317
#   [Sim #2 | Day 514] Cautious: 5706  | Reckless: 4294
#   [Sim #2 | Day 516] Cautious: 5849  | Reckless: 4151
#   [Sim #2 | Day 518] Cautious: 5731  | Reckless: 4269
#   [Sim #2 | Day 520] Cautious: 5739  | Reckless: 4261
#   [Sim #2 | Day 522] Cautious: 5727  | Reckless: 4273
#   [Sim #2 | Day 524] Cautious: 5817  | Reckless: 4183
#   [Sim #2 | Day 526] Cautious: 5461  | Reckless: 4539
#   [Sim #2 | Day 528] Cautious: 5617  | Reckless: 4383
#   [Sim #2 | Day 530] Cautious: 5601  | Reckless: 4399
#   [Sim #2 | Day 532] Cautious: 5618  | Reckless: 4382
#   [Sim #2 | Day 534] Cautious: 5675  | Reckless: 4325
#   [Sim #2 | Day 536] Cautious: 5674  | Reckless: 4326
#   [Sim #2 | Day 538] Cautious: 5683  | Reckless: 4317
#   [Sim #2 | Day 540] Cautious: 5690  | Reckless: 4310
#   [Sim #2 | Day 542] Cautious: 5819  | Reckless: 4181
#   [Sim #2 | Day 544] Cautious: 5883  | Reckless: 4117
#   [Sim #2 | Day 546] Cautious: 5905  | Reckless: 4095
#   [Sim #2 | Day 548] Cautious: 5960  | Reckless: 4040
#   [Sim #2 | Day 550] Cautious: 6048  | Reckless: 3952
#   [Sim #2 | Day 552] Cautious: 6071  | Reckless: 3929
#   [Sim #2 | Day 554] Cautious: 6040  | Reckless: 3960
#   [Sim #2 | Day 556] Cautious: 6058  | Reckless: 3942
#   [Sim #2 | Day 558] Cautious: 6114  | Reckless: 3886
#   [Sim #2 | Day 560] Cautious: 6077  | Reckless: 3923
#   [Sim #2 | Day 562] Cautious: 6172  | Reckless: 3828
#   [Sim #2 | Day 564] Cautious: 6117  | Reckless: 3883
#   [Sim #2 | Day 566] Cautious: 6105  | Reckless: 3895
#   [Sim #2 | Day 568] Cautious: 6120  | Reckless: 3880
#   [Sim #2 | Day 570] Cautious: 6234  | Reckless: 3766
#   [Sim #2 | Day 572] Cautious: 6186  | Reckless: 3814
#   [Sim #2 | Day 574] Cautious: 5959  | Reckless: 4041
#   [Sim #2 | Day 576] Cautious: 6056  | Reckless: 3944
#   [Sim #2 | Day 578] Cautious: 6084  | Reckless: 3916
#   [Sim #2 | Day 580] Cautious: 6252  | Reckless: 3748
#   [Sim #2 | Day 582] Cautious: 6006  | Reckless: 3994
#   [Sim #2 | Day 584] Cautious: 6059  | Reckless: 3941
#   [Sim #2 | Day 586] Cautious: 6039  | Reckless: 3961
#   [Sim #2 | Day 588] Cautious: 6254  | Reckless: 3746
#   [Sim #2 | Day 590] Cautious: 6291  | Reckless: 3709
#   [Sim #2 | Day 592] Cautious: 6250  | Reckless: 3750
#   [Sim #2 | Day 594] Cautious: 6411  | Reckless: 3589
#   [Sim #2 | Day 596] Cautious: 6275  | Reckless: 3725
#   [Sim #2 | Day 598] Cautious: 6213  | Reckless: 3787
#   [Sim #2 | Day 600] Cautious: 6247  | Reckless: 3753
#   [Sim #2 | Day 602] Cautious: 6219  | Reckless: 3781
#   [Sim #2 | Day 604] Cautious: 6170  | Reckless: 3830
#   [Sim #2 | Day 606] Cautious: 6290  | Reckless: 3710
#   [Sim #2 | Day 608] Cautious: 6408  | Reckless: 3592
#   [Sim #2 | Day 610] Cautious: 6513  | Reckless: 3487
#   [Sim #2 | Day 612] Cautious: 6397  | Reckless: 3603
#   [Sim #2 | Day 614] Cautious: 6450  | Reckless: 3550
#   [Sim #2 | Day 616] Cautious: 6557  | Reckless: 3443
#   [Sim #2 | Day 618] Cautious: 6279  | Reckless: 3721
#   [Sim #2 | Day 620] Cautious: 6389  | Reckless: 3611
#   [Sim #2 | Day 622] Cautious: 6534  | Reckless: 3466
#   [Sim #2 | Day 624] Cautious: 6400  | Reckless: 3600
#   [Sim #2 | Day 626] Cautious: 6506  | Reckless: 3494
#   [Sim #2 | Day 628] Cautious: 6408  | Reckless: 3592
#   [Sim #2 | Day 630] Cautious: 6530  | Reckless: 3470
#   [Sim #2 | Day 632] Cautious: 6626  | Reckless: 3374
#   [Sim #2 | Day 634] Cautious: 6396  | Reckless: 3604
#   [Sim #2 | Day 636] Cautious: 6517  | Reckless: 3483
#   [Sim #2 | Day 638] Cautious: 6373  | Reckless: 3627
#   [Sim #2 | Day 640] Cautious: 6412  | Reckless: 3588
#   [Sim #2 | Day 642] Cautious: 6626  | Reckless: 3374
#   [Sim #2 | Day 644] Cautious: 6448  | Reckless: 3552
#   [Sim #2 | Day 646] Cautious: 6446  | Reckless: 3554
#   [Sim #2 | Day 648] Cautious: 6398  | Reckless: 3602
#   [Sim #2 | Day 650] Cautious: 6445  | Reckless: 3555
