# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessutton600613-png/GC/blob/main/Untitled134.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
import pickle
import os

# --- 1. Environment Class ---
class Environment:
    def __init__(self, total_sim_steps, days_per_cycle=50):
        self.total_sim_steps, self.days_per_cycle, self.time = total_sim_steps, days_per_cycle, 0
        num_years = max(1, total_sim_steps / (365 * days_per_cycle))
        steps_per_year = 365 * days_per_cycle
        daily_uv_cycle = np.sin(np.linspace(0, 2 * np.pi, days_per_cycle)); daily_uv_cycle[daily_uv_cycle < 0] = 0
        full_uv, full_resources = [], []
        for _ in range(int(np.ceil(num_years))):
            uv_severity = np.random.uniform(0.8, 1.25)
            resource_bounty = np.random.uniform(0.8, 1.25)
            seasonal_cycle = np.sin(np.linspace(0, 2 * np.pi, steps_per_year))
            seasonal_amplitude_mod = (0.225 * seasonal_cycle + 0.725) * uv_severity
            seasonal_resource_mod = (-0.20 * seasonal_cycle + 0.80) * resource_bounty
            year_resources = 1200 * seasonal_resource_mod
            year_uv = [daily_uv_cycle[i % days_per_cycle] * seasonal_amplitude_mod[i] for i in range(steps_per_year)]
            full_uv.extend(year_uv); full_resources.extend(year_uv)
        self.uv_intensity = np.array(full_uv)
        self.external_resources = np.array(full_resources)

    def get_current_uv(self):
        return self.uv_intensity[self.time % len(self.uv_intensity)]
    def get_current_resources(self):
        return self.external_resources[self.time % len(self.external_resources)]
    def step(self):
        self.time += 1

# --- 2. Protoribosome Class ---
class Protoribosome:
    def __init__(self, env, strategy, initial_sequence, initial_mass=100.0):
        self.env, self.strategy, self.rna_sequence = env, strategy, list(initial_sequence)
        self.rna_mass = initial_mass
        self.atp_pool, self.mcyw_peptide_pool, self.other_peptide_pool = 500.0, 50.0, 5.0
        self.internal_ntp_stock, self.internal_aa_stock, self.internal_trp_tyr_cys_stock = 200.0, 200.0, 100.0
        self.rna_damage_level = 0.0

        self.location = 'dark_zone'
        self.status = 'ACTIVE'

        self.metabolic_efficiency = 1.0
        self.uv_damage_rate_per_uv = 1.2
        self.repair_rate, self.repair_atp_cost, self.trp_tyr_cys_for_repair_needed = 0.5, 0.0025, 0.0005
        self.uv_protection_factor, self.damage_tolerance_threshold = 0.01, 3.0
        self.atp_generation_rate_per_mcyw_uv, self.baseline_atp_generation_rate = 0.15, 0.5
        self.baseline_atp_chemosynthesis = 1.5
        self.protein_synthesis_rate, self.protein_synthesis_ntp_cost, self.protein_synthesis_aa_cost, self.protein_synthesis_atp_cost = 0.20, 0.1, 0.1, 0.02
        self.replication_rate, self.replication_ntp_cost, self.replication_atp_cost = 0.05, 1.0, 0.2
        self.rna_degradation_rate, self.atp_degradation_rate, self.peptide_degradation_rate = 0.0005, 0.025, 0.0008
        self.diffusion_rate, self.atp_from_ntp_conversion = 0.30, 0.1
        self.mutation_prob = 0.004
        self.failed_synthesis_penalty_atp = 150.0
        self.growth_rate = 0.1
        self.growth_ntp_cost = 1.0
        self.growth_atp_cost = 0.2

    def get_peptide_type(self):
        codons = ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)]
        if any(c in {'UGU', 'UGC', 'UAU', 'UAC', 'UGG'} for c in codons):
            return "MCYW"
        return "XXXX"

    def has_stop_codon(self):
        return any(c in {'UAA', 'UAG', 'UGA'} for c in ["".join(self.rna_sequence[i:i+3]) for i in range(0, len(self.rna_sequence), 3)])

    def _decide_zone_transition(self):
        if self.location == 'dark_zone' and self.atp_pool < 450:
            self.location = 'light_zone'
        elif self.location == 'light_zone' and self.rna_damage_level > self.damage_tolerance_threshold * 0.75:
            self.location = 'dark_zone'

    def _apply_uv_damage(self, current_uv):
        if self.location == 'dark_zone' or current_uv <= 0:
            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate * 0.1)
            return

        protection = self.mcyw_peptide_pool * self.uv_protection_factor
        effective_uv = current_uv * max(0.01, 1 - protection)
        self.rna_damage_level += effective_uv * self.uv_damage_rate_per_uv

        for i in range(len(self.rna_sequence)):
            if random.random() < self.mutation_prob * effective_uv:
                self.rna_sequence[i] = random.choice("AUGC")

    def _manage_state(self, has_stop_codon_cached):
        if self.atp_pool < 0.1 or self.rna_damage_level >= self.damage_tolerance_threshold:
            self.status = 'INACTIVE'
            return

        if self.strategy == 'cautious' and has_stop_codon_cached:
            self.status = 'ARRESTED'
        elif self.status == 'ARRESTED' and not has_stop_codon_cached:
             self.status = 'ACTIVE'

        if self.status == 'ACTIVE':
            self.metabolic_efficiency = 1.25
        else:
            self.metabolic_efficiency = 1.0

    def _synthesize_protein(self, has_stop_codon_cached):
        if self.status != 'ACTIVE': return

        if self.strategy == 'readthrough' and has_stop_codon_cached:
            self.status = 'INACTIVE'
            return

        units = self.protein_synthesis_rate * self.metabolic_efficiency * 10
        required_ntp = units * self.protein_synthesis_ntp_cost
        required_atp = units * self.protein_synthesis_atp_cost
        required_aa_total = units * self.protein_synthesis_aa_cost

        is_mcyw = self.get_peptide_type() == "MCYW"

        if is_mcyw:
            required_special_aa = required_aa_total * 0.5
            required_general_aa = required_aa_total - required_special_aa
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa or
                self.internal_trp_tyr_cys_stock < required_special_aa):
                return
        else:
            required_general_aa = required_aa_total
            required_special_aa = 0
            if (self.internal_ntp_stock < required_ntp or
                self.atp_pool < required_atp or
                self.internal_aa_stock < required_general_aa):
                return

        self.internal_ntp_stock -= required_ntp
        self.atp_pool -= required_atp
        self.internal_aa_stock -= required_general_aa
        self.internal_trp_tyr_cys_stock -= required_special_aa

        if is_mcyw:
            self.mcyw_peptide_pool += units
        else:
            self.other_peptide_pool += units

    def _replicate_rna(self):
        if self.status != 'ACTIVE' or self.rna_mass < 80: return None

        can_replicate = self.rna_mass * self.replication_rate * self.metabolic_efficiency

        if self.internal_ntp_stock > self.replication_ntp_cost and self.atp_pool > self.replication_atp_cost and can_replicate > 1.0:
            offspring_mass = self.rna_mass * 0.5
            self.rna_mass -= offspring_mass

            self.internal_ntp_stock -= offspring_mass * self.replication_ntp_cost
            self.atp_pool -= offspring_mass * self.replication_atp_cost
            return Protoribosome(self.env, self.strategy, "".join(self.rna_sequence), offspring_mass)
        return None

    def _repair_rna_dna(self, dna_template):
        if self.strategy == 'readthrough': return

        if self.status == 'ACTIVE':
            repair_efficiency = 1.0
        elif self.status == 'ARRESTED':
            repair_efficiency = 0.2
        else:
            return

        if "".join(self.rna_sequence) != dna_template:
            for i in range(len(self.rna_sequence)):
                if self.rna_sequence[i] != dna_template[i]:
                    if random.random() < repair_efficiency:
                        if self.atp_pool >= self.repair_atp_cost and self.internal_trp_tyr_cys_stock >= self.trp_tyr_cys_for_repair_needed:
                            self.atp_pool -= self.repair_atp_cost
                            self.internal_trp_tyr_cys_stock -= self.trp_tyr_cys_for_repair_needed
                            self.rna_sequence[i] = dna_template[i]
                            self.rna_damage_level = max(0, self.rna_damage_level - self.repair_rate)
                    break

    def _diffuse_resources(self):
        if self.status == 'INACTIVE': return
        available = self.env.get_current_resources()
        if available > 0:
            amount = available * self.diffusion_rate
            self.internal_ntp_stock += amount * 0.50
            self.internal_aa_stock += amount * 0.45
            self.internal_trp_tyr_cys_stock += amount * 0.05

    def _grow_mass(self):
        if self.status != 'ACTIVE': return

        potential_growth = self.rna_mass * self.growth_rate * self.metabolic_efficiency
        ntp_cost = potential_growth * self.growth_ntp_cost
        atp_cost = potential_growth * self.growth_atp_cost

        if self.internal_ntp_stock >= ntp_cost and self.atp_pool >= atp_cost:
            self.internal_ntp_stock -= ntp_cost
            self.atp_pool -= atp_cost
            self.rna_mass += potential_growth

    def step(self, current_uv, dna_template):
        if self.status == 'INACTIVE': return None

        self._decide_zone_transition()
        self._apply_uv_damage(current_uv)
        self._repair_rna_dna(dna_template)

        has_stop = self.has_stop_codon()
        self._manage_state(has_stop)

        if self.status == 'INACTIVE': return None

        self._diffuse_resources()
        self._grow_mass()

        self.atp_pool += self.baseline_atp_chemosynthesis
        self.atp_pool *= (1 - self.atp_degradation_rate)

        if self.location == 'light_zone' and current_uv > 0:
            self.atp_pool += (self.atp_generation_rate_per_mcyw_uv * self.mcyw_peptide_pool * current_uv)

        self._synthesize_protein(has_stop)
        if self.status == 'INACTIVE': return None

        return self._replicate_rna()

# --- 3. Colony Class ---
class Colony:
    def __init__(self, env, dna_template, initial_pop_size, steps_per_day):
        self.env = env
        self.dna_template = dna_template
        self.active_population = [Protoribosome(env, 'cautious' if i%2==0 else 'readthrough', dna_template) for i in range(initial_pop_size)]
        self.inactive_population = []
        self.steps_per_day = steps_per_day
        # --- FIX: Reinstated the population cap ---
        self.max_population = 10000

    def step(self, current_step):
        newly_replicated = []
        current_uv = self.env.get_current_uv()

        next_active_population = []
        for protoribosome in self.active_population:
            new_offspring = protoribosome.step(current_uv, self.dna_template)

            if protoribosome.status == 'INACTIVE':
                self.inactive_population.append(protoribosome)
            else:
                next_active_population.append(protoribosome)

            if new_offspring:
                newly_replicated.append(new_offspring)

        self.active_population = next_active_population
        self.active_population.extend(newly_replicated)

        # --- FIX: Enforce the active population cap to maintain performance ---
        if len(self.active_population) > self.max_population:
            random.shuffle(self.active_population)
            self.active_population = self.active_population[:self.max_population]

        # Apply the tidal flush to the inactive list
        if current_step > 0 and current_step % self.steps_per_day == 0:
            self.inactive_population.clear()

    def get_aggregated_data(self):
        data = { 'cautious': 0, 'readthrough': 0, 'in_light_zone': 0, 'arrested': 0, 'total_damage': 0.0 }

        num_active = len(self.active_population)
        if num_active == 0:
            data['inactive'] = len(self.inactive_population)
            return data

        for p in self.active_population:
            if p.strategy == 'cautious':
                data['cautious'] += 1
                if p.status == 'ARRESTED':
                    data['arrested'] += 1
            else:
                data['readthrough'] += 1

            if p.location == 'light_zone':
                data['in_light_zone'] += 1
            data['total_damage'] += p.rna_damage_level

        data['inactive'] = len(self.inactive_population)
        data['avg_damage'] = data['total_damage'] / num_active if num_active > 0 else 0
        return data

# --- 4. Simulation and Plotting ---
def run_and_plot():
    MAX_STEPS = 365 * 20 * 10
    STEPS_PER_DAY = 10

    IDEAL_DNA_TEMPLATE = "AUGUGUUACUGG"

    env = Environment(MAX_STEPS, STEPS_PER_DAY)
    colony = Colony(env, IDEAL_DNA_TEMPLATE, initial_pop_size=150, steps_per_day=STEPS_PER_DAY)

    data = []
    print_interval = 20

    step_count = 0
    while step_count < MAX_STEPS:
        if step_count % print_interval == 0:
            agg_data = colony.get_aggregated_data()
            cautious_pop = agg_data.get('cautious', 0)
            readthrough_pop = agg_data.get('readthrough', 0)
            inactive_pop = agg_data.get('inactive', 0)

            print(f"Simulating step {step_count}... "
                  f"Cautious: {cautious_pop} | "
                  f"Readthrough: {readthrough_pop} | "
                  f"Inactive: {inactive_pop}", flush=True)

            if step_count > 1000 and (cautious_pop == 0 or readthrough_pop == 0):
                print(f"\n--- KNOCKOUT at step {step_count}! ---")
                if cautious_pop == 0: print("Cautious strategy is extinct. Readthrough wins.")
                else: print("Readthrough strategy is extinct. Cautious wins.")
                break

        colony.step(step_count)

        if step_count % STEPS_PER_DAY == 0:
            agg_data = colony.get_aggregated_data()
            log_entry = {'time': env.time, 'uv': env.get_current_uv()}
            log_entry.update(agg_data)
            data.append(log_entry)

        env.step()
        step_count += 1

    if step_count == MAX_STEPS:
        print(f"\n--- MAX STEPS ({MAX_STEPS}) REACHED --- \nSimulation ended in a stalemate.")


    if not data:
        print("No data was logged. Cannot generate plots.")
        return

    results_df = pd.DataFrame(data)

    fig, axs = plt.subplots(4, 1, figsize=(15, 16), sharex=True)
    fig.suptitle('BREAKTHRU FLUSH KNOCKOUT', fontsize=16)
    colors = {'cautious': 'orange', 'readthrough': 'purple', 'inactive': 'grey'}

    axs[0].plot(results_df['time'], results_df['uv'], color='black', alpha=0.2, label='UV Intensity')
    axs[0].set_title('Environmental Conditions'); axs[0].set_ylabel('UV Intensity'); axs[0].legend()

    axs[1].plot(results_df['time'], results_df['cautious'], label='Cautious', color=colors['cautious'])
    axs[1].plot(results_df['time'], results_df['readthrough'], label='Readthrough', color=colors['readthrough'])
    axs[1].set_title('Active Population by Strategy'); axs[1].set_ylabel('Count'); axs[1].legend()
    axs[1].set_yscale('symlog')

    axs[2].stackplot(results_df['time'],
                     results_df['cautious'],
                     results_df['readthrough'],
                     results_df['inactive'],
                     labels=['Cautious', 'Readthrough', 'Inactive'],
                     colors=[colors['cautious'], colors['readthrough'], colors['inactive']])
    axs[2].set_title('Total Population Composition'); axs[2].set_ylabel('Total Count'); axs[2].legend(loc='upper left')

    ax3_twin = axs[3].twinx()
    axs[3].plot(results_df['time'], results_df['in_light_zone'], label='In Light Zone (Risk)', color='red', alpha=0.6)
    axs[3].plot(results_df['time'], results_df['arrested'], label='Arrested (Response)', color='blue', linestyle='--')
    ax3_twin.plot(results_df['time'], results_df['avg_damage'], label='Avg. RNA Damage', color='brown', alpha=0.7)
    axs[3].set_title('Safety & Risk Analysis'); axs[3].set_ylabel('Population Count'); ax3_twin.set_ylabel('Avg. Damage')
    axs[3].legend(loc='upper left'); ax3_twin.legend(loc='upper right')

    for ax in axs:
        ax.grid(True, linestyle=':', linewidth='0.5', color='gray')
        ax.set_xlim(left=0)

    plt.tight_layout(rect=[0, 0, 1, 0.96]); plt.show()

if __name__ == "__main__":
    run_and_plot()
# Out:
# Simulating step 0... Cautious: 75 | Readthrough: 75 | Inactive: 0
# Simulating step 20... Cautious: 1125 | Readthrough: 1123 | Inactive: 1
# Simulating step 40... Cautious: 4965 | Readthrough: 5035 | Inactive: 2
# Simulating step 60... Cautious: 4923 | Readthrough: 5077 | Inactive: 4
# Simulating step 80... Cautious: 4952 | Readthrough: 5048 | Inactive: 4
# Simulating step 100... Cautious: 5037 | Readthrough: 4963 | Inactive: 4
# Simulating step 120... Cautious: 5058 | Readthrough: 4942 | Inactive: 4
# Simulating step 140... Cautious: 5014 | Readthrough: 4986 | Inactive: 4
# Simulating step 160... Cautious: 5031 | Readthrough: 4969 | Inactive: 2
# Simulating step 180... Cautious: 5030 | Readthrough: 4970 | Inactive: 3
# Simulating step 200... Cautious: 5062 | Readthrough: 4938 | Inactive: 6
# Simulating step 220... Cautious: 5081 | Readthrough: 4919 | Inactive: 2
# Simulating step 240... Cautious: 5103 | Readthrough: 4897 | Inactive: 6
# Simulating step 260... Cautious: 5155 | Readthrough: 4845 | Inactive: 8
# Simulating step 280... Cautious: 5133 | Readthrough: 4867 | Inactive: 3
# Simulating step 300... Cautious: 5108 | Readthrough: 4892 | Inactive: 5
# Simulating step 320... Cautious: 5176 | Readthrough: 4824 | Inactive: 7
# Simulating step 340... Cautious: 5131 | Readthrough: 4869 | Inactive: 1
# Simulating step 360... Cautious: 5238 | Readthrough: 4762 | Inactive: 5
# Simulating step 380... Cautious: 5087 | Readthrough: 4913 | Inactive: 7
# Simulating step 400... Cautious: 5158 | Readthrough: 4842 | Inactive: 11
# Simulating step 420... Cautious: 5121 | Readthrough: 4879 | Inactive: 1
# Simulating step 440... Cautious: 5282 | Readthrough: 4718 | Inactive: 6
# Simulating step 460... Cautious: 5351 | Readthrough: 4649 | Inactive: 5
# Simulating step 480... Cautious: 5362 | Readthrough: 4638 | Inactive: 7
# Simulating step 500... Cautious: 5280 | Readthrough: 4720 | Inactive: 4
# Simulating step 520... Cautious: 5258 | Readthrough: 4742 | Inactive: 4
# Simulating step 540... Cautious: 5154 | Readthrough: 4846 | Inactive: 5
# Simulating step 560... Cautious: 5146 | Readthrough: 4854 | Inactive: 10
# Simulating step 580... Cautious: 5114 | Readthrough: 4886 | Inactive: 5
# Simulating step 600... Cautious: 5273 | Readthrough: 4727 | Inactive: 7
# Simulating step 620... Cautious: 5288 | Readthrough: 4712 | Inactive: 6
# Simulating step 640... Cautious: 5252 | Readthrough: 4748 | Inactive: 2
# Simulating step 660... Cautious: 5276 | Readthrough: 4724 | Inactive: 8
# Simulating step 680... Cautious: 5274 | Readthrough: 4726 | Inactive: 4
# Simulating step 700... Cautious: 5298 | Readthrough: 4702 | Inactive: 6
# Simulating step 720... Cautious: 5194 | Readthrough: 4806 | Inactive: 9
# Simulating step 740... Cautious: 5170 | Readthrough: 4830 | Inactive: 7
# Simulating step 760... Cautious: 5285 | Readthrough: 4715 | Inactive: 9
# Simulating step 780... Cautious: 5378 | Readthrough: 4622 | Inactive: 4
# Simulating step 800... Cautious: 5406 | Readthrough: 4594 | Inactive: 10
# Simulating step 820... Cautious: 5375 | Readthrough: 4625 | Inactive: 4
# Simulating step 840... Cautious: 5404 | Readthrough: 4596 | Inactive: 3
# Simulating step 860... Cautious: 5466 | Readthrough: 4534 | Inactive: 3
# Simulating step 880... Cautious: 5506 | Readthrough: 4494 | Inactive: 8
# Simulating step 900... Cautious: 5425 | Readthrough: 4575 | Inactive: 8
# Simulating step 920... Cautious: 5383 | Readthrough: 4617 | Inactive: 5
# Simulating step 940... Cautious: 5406 | Readthrough: 4594 | Inactive: 7
# Simulating step 960... Cautious: 5435 | Readthrough: 4565 | Inactive: 2
# Simulating step 980... Cautious: 5464 | Readthrough: 4536 | Inactive: 4
# Simulating step 1000... Cautious: 5358 | Readthrough: 4642 | Inactive: 4
# Simulating step 1020... Cautious: 5282 | Readthrough: 4718 | Inactive: 5
# Simulating step 1040... Cautious: 5231 | Readthrough: 4769 | Inactive: 10
# Simulating step 1060... Cautious: 5270 | Readthrough: 4730 | Inactive: 11
# Simulating step 1080... Cautious: 5392 | Readthrough: 4608 | Inactive: 7
# Simulating step 1100... Cautious: 5387 | Readthrough: 4613 | Inactive: 6
# Simulating step 1120... Cautious: 5433 | Readthrough: 4567 | Inactive: 2
# Simulating step 1140... Cautious: 5372 | Readthrough: 4628 | Inactive: 3
# Simulating step 1160... Cautious: 5343 | Readthrough: 4657 | Inactive: 4
# Simulating step 1180... Cautious: 5319 | Readthrough: 4681 | Inactive: 8
# Simulating step 1200... Cautious: 5207 | Readthrough: 4793 | Inactive: 2
# Simulating step 1220... Cautious: 5224 | Readthrough: 4776 | Inactive: 3
# Simulating step 1240... Cautious: 5267 | Readthrough: 4733 | Inactive: 5
# Simulating step 1260... Cautious: 5204 | Readthrough: 4796 | Inactive: 4
# Simulating step 1280... Cautious: 5238 | Readthrough: 4762 | Inactive: 2
# Simulating step 1300... Cautious: 5246 | Readthrough: 4754 | Inactive: 3
# Simulating step 1320... Cautious: 5283 | Readthrough: 4717 | Inactive: 6
# Simulating step 1340... Cautious: 5256 | Readthrough: 4744 | Inactive: 6
# Simulating step 1360... Cautious: 5293 | Readthrough: 4707 | Inactive: 7
# Simulating step 1380... Cautious: 5366 | Readthrough: 4634 | Inactive: 3
# Simulating step 1400... Cautious: 5348 | Readthrough: 4652 | Inactive: 9
# Simulating step 1420... Cautious: 5275 | Readthrough: 4725 | Inactive: 7
# Simulating step 1440... Cautious: 5313 | Readthrough: 4687 | Inactive: 1
# Simulating step 1460... Cautious: 5252 | Readthrough: 4748 | Inactive: 4
# Simulating step 1480... Cautious: 5270 | Readthrough: 4730 | Inactive: 4
# Simulating step 1500... Cautious: 5286 | Readthrough: 4714 | Inactive: 4
# Simulating step 1520... Cautious: 5242 | Readthrough: 4758 | Inactive: 3
# Simulating step 1540... Cautious: 5147 | Readthrough: 4853 | Inactive: 4
# Simulating step 1560... Cautious: 5216 | Readthrough: 4784 | Inactive: 4
# Simulating step 1580... Cautious: 5280 | Readthrough: 4720 | Inactive: 0
# Simulating step 1600... Cautious: 5253 | Readthrough: 4747 | Inactive: 4
# Simulating step 1620... Cautious: 5270 | Readthrough: 4730 | Inactive: 2
# Simulating step 1640... Cautious: 5255 | Readthrough: 4745 | Inactive: 3
# Simulating step 1660... Cautious: 5266 | Readthrough: 4734 | Inactive: 10
# Simulating step 1680... Cautious: 5261 | Readthrough: 4739 | Inactive: 5
# Simulating step 1700... Cautious: 5357 | Readthrough: 4643 | Inactive: 3
# Simulating step 1720... Cautious: 5362 | Readthrough: 4638 | Inactive: 4
# Simulating step 1740... Cautious: 5351 | Readthrough: 4649 | Inactive: 4
# Simulating step 1760... Cautious: 5433 | Readthrough: 4567 | Inactive: 6
# Simulating step 1780... Cautious: 5394 | Readthrough: 4606 | Inactive: 7
# Simulating step 1800... Cautious: 5459 | Readthrough: 4541 | Inactive: 5
# Simulating step 1820... Cautious: 5463 | Readthrough: 4537 | Inactive: 4
# Simulating step 1840... Cautious: 5453 | Readthrough: 4547 | Inactive: 2
# Simulating step 1860... Cautious: 5517 | Readthrough: 4483 | Inactive: 6
# Simulating step 1880... Cautious: 5545 | Readthrough: 4455 | Inactive: 3
# Simulating step 1900... Cautious: 5641 | Readthrough: 4359 | Inactive: 1
# Simulating step 1920... Cautious: 5664 | Readthrough: 4336 | Inactive: 3
# Simulating step 1940... Cautious: 5691 | Readthrough: 4309 | Inactive: 3
# Simulating step 1960... Cautious: 5729 | Readthrough: 4271 | Inactive: 1
# Simulating step 1980... Cautious: 5716 | Readthrough: 4284 | Inactive: 2
# Simulating step 2000... Cautious: 5693 | Readthrough: 4307 | Inactive: 6
# Simulating step 2020... Cautious: 5704 | Readthrough: 4296 | Inactive: 5
# Simulating step 2040... Cautious: 5763 | Readthrough: 4237 | Inactive: 2
# Simulating step 2060... Cautious: 5853 | Readthrough: 4147 | Inactive: 0
# Simulating step 2080... Cautious: 5884 | Readthrough: 4116 | Inactive: 1
# Simulating step 2100... Cautious: 5985 | Readthrough: 4015 | Inactive: 6
# Simulating step 2120... Cautious: 5977 | Readthrough: 4023 | Inactive: 3
# Simulating step 2140... Cautious: 6008 | Readthrough: 3992 | Inactive: 1
# Simulating step 2160... Cautious: 6116 | Readthrough: 3884 | Inactive: 4
# Simulating step 2180... Cautious: 6043 | Readthrough: 3957 | Inactive: 0
# Simulating step 2200... Cautious: 6118 | Readthrough: 3882 | Inactive: 4
# Simulating step 2220... Cautious: 6125 | Readthrough: 3875 | Inactive: 4
# Simulating step 2240... Cautious: 6114 | Readthrough: 3886 | Inactive: 3
# Simulating step 2260... Cautious: 6163 | Readthrough: 3837 | Inactive: 2
# Simulating step 2280... Cautious: 6205 | Readthrough: 3795 | Inactive: 2
# Simulating step 2300... Cautious: 6167 | Readthrough: 3833 | Inactive: 2
# Simulating step 2320... Cautious: 6158 | Readthrough: 3842 | Inactive: 4
# Simulating step 2340... Cautious: 6106 | Readthrough: 3894 | Inactive: 2
# Simulating step 2360... Cautious: 6169 | Readthrough: 3831 | Inactive: 3
# Simulating step 2380... Cautious: 6130 | Readthrough: 3870 | Inactive: 1
# Simulating step 2400... Cautious: 6209 | Readthrough: 3791 | Inactive: 2
# Simulating step 2420... Cautious: 6283 | Readthrough: 3717 | Inactive: 3
# Simulating step 2440... Cautious: 6326 | Readthrough: 3674 | Inactive: 1
# Simulating step 2460... Cautious: 6163 | Readthrough: 3837 | Inactive: 0
# Simulating step 2480... Cautious: 6127 | Readthrough: 3873 | Inactive: 0
# Simulating step 2500... Cautious: 6049 | Readthrough: 3951 | Inactive: 2
# Simulating step 2520... Cautious: 6133 | Readthrough: 3867 | Inactive: 3
# Simulating step 2540... Cautious: 6165 | Readthrough: 3835 | Inactive: 1
# Simulating step 2560... Cautious: 6262 | Readthrough: 3738 | Inactive: 0
# Simulating step 2580... Cautious: 6270 | Readthrough: 3730 | Inactive: 1
# Simulating step 2600... Cautious: 6212 | Readthrough: 3788 | Inactive: 0
# Simulating step 2620... Cautious: 6190 | Readthrough: 3810 | Inactive: 0
# Simulating step 2640... Cautious: 6218 | Readthrough: 3782 | Inactive: 2
# Simulating step 2660... Cautious: 6218 | Readthrough: 3782 | Inactive: 3
# Simulating step 2680... Cautious: 6185 | Readthrough: 3815 | Inactive: 1
# Simulating step 2700... Cautious: 6205 | Readthrough: 3795 | Inactive: 3
# Simulating step 2720... Cautious: 6145 | Readthrough: 3855 | Inactive: 3
# Simulating step 2740... Cautious: 6186 | Readthrough: 3814 | Inactive: 2
# Simulating step 2760... Cautious: 6200 | Readthrough: 3800 | Inactive: 4
# Simulating step 2780... Cautious: 6312 | Readthrough: 3688 | Inactive: 2
# Simulating step 2800... Cautious: 6189 | Readthrough: 3811 | Inactive: 6
# Simulating step 2820... Cautious: 6224 | Readthrough: 3776 | Inactive: 1
# Simulating step 2840... Cautious: 6336 | Readthrough: 3664 | Inactive: 2
# Simulating step 2860... Cautious: 6424 | Readthrough: 3576 | Inactive: 2
# Simulating step 2880... Cautious: 6469 | Readthrough: 3531 | Inactive: 1
# Simulating step 2900... Cautious: 6404 | Readthrough: 3596 | Inactive: 2
# Simulating step 2920... Cautious: 6388 | Readthrough: 3612 | Inactive: 4
# Simulating step 2940... Cautious: 6452 | Readthrough: 3548 | Inactive: 1
# Simulating step 2960... Cautious: 6476 | Readthrough: 3524 | Inactive: 2
# Simulating step 2980... Cautious: 6497 | Readthrough: 3503 | Inactive: 3
# Simulating step 3000... Cautious: 6559 | Readthrough: 3441 | Inactive: 2
# Simulating step 3020... Cautious: 6539 | Readthrough: 3461 | Inactive: 2
# Simulating step 3040... Cautious: 6497 | Readthrough: 3503 | Inactive: 3
# Simulating step 3060... Cautious: 6461 | Readthrough: 3539 | Inactive: 1
# Simulating step 3080... Cautious: 6477 | Readthrough: 3523 | Inactive: 5
# Simulating step 3100... Cautious: 6558 | Readthrough: 3442 | Inactive: 1
# Simulating step 3120... Cautious: 6513 | Readthrough: 3487 | Inactive: 0
# Simulating step 3140... Cautious: 6437 | Readthrough: 3563 | Inactive: 3
# Simulating step 3160... Cautious: 6485 | Readthrough: 3515 | Inactive: 2
# Simulating step 3180... Cautious: 6463 | Readthrough: 3537 | Inactive: 1
# Simulating step 3200... Cautious: 6466 | Readthrough: 3534 | Inactive: 3
# Simulating step 3220... Cautious: 6522 | Readthrough: 3478 | Inactive: 2
# Simulating step 3240... Cautious: 6600 | Readthrough: 3400 | Inactive: 3
# Simulating step 3260... Cautious: 6590 | Readthrough: 3410 | Inactive: 1
# Simulating step 3280... Cautious: 6546 | Readthrough: 3454 | Inactive: 3
# Simulating step 3300... Cautious: 6506 | Readthrough: 3494 | Inactive: 3
# Simulating step 3320... Cautious: 6616 | Readthrough: 3384 | Inactive: 2
# Simulating step 3340... Cautious: 6605 | Readthrough: 3395 | Inactive: 2
# Simulating step 3360... Cautious: 6642 | Readthrough: 3358 | Inactive: 2
# Simulating step 3380... Cautious: 6683 | Readthrough: 3317 | Inactive: 1
# Simulating step 3400... Cautious: 6704 | Readthrough: 3296 | Inactive: 6
# Simulating step 3420... Cautious: 6691 | Readthrough: 3309 | Inactive: 2
# Simulating step 3440... Cautious: 6675 | Readthrough: 3325 | Inactive: 1
# Simulating step 3460... Cautious: 6586 | Readthrough: 3414 | Inactive: 2
# Simulating step 3480... Cautious: 6506 | Readthrough: 3494 | Inactive: 0
# Simulating step 3500... Cautious: 6486 | Readthrough: 3514 | Inactive: 3
# Simulating step 3520... Cautious: 6558 | Readthrough: 3442 | Inactive: 2
# Simulating step 3540... Cautious: 6534 | Readthrough: 3466 | Inactive: 3
# Simulating step 3560... Cautious: 6526 | Readthrough: 3474 | Inactive: 4
# Simulating step 3580... Cautious: 6501 | Readthrough: 3499 | Inactive: 3
# Simulating step 3600... Cautious: 6396 | Readthrough: 3604 | Inactive: 6
# Simulating step 3620... Cautious: 6380 | Readthrough: 3620 | Inactive: 4
# Simulating step 3640... Cautious: 6391 | Readthrough: 3609 | Inactive: 3
# Simulating step 3660... Cautious: 6403 | Readthrough: 3597 | Inactive: 4
# Simulating step 3680... Cautious: 6481 | Readthrough: 3519 | Inactive: 8
# Simulating step 3700... Cautious: 6564 | Readthrough: 3436 | Inactive: 4
# Simulating step 3720... Cautious: 6505 | Readthrough: 3495 | Inactive: 5
# Simulating step 3740... Cautious: 6557 | Readthrough: 3443 | Inactive: 10
# Simulating step 3760... Cautious: 6565 | Readthrough: 3435 | Inactive: 5
# Simulating step 3780... Cautious: 6422 | Readthrough: 3578 | Inactive: 4
# Simulating step 3800... Cautious: 6426 | Readthrough: 3574 | Inactive: 6
# Simulating step 3820... Cautious: 6455 | Readthrough: 3545 | Inactive: 4
# Simulating step 3840... Cautious: 6434 | Readthrough: 3566 | Inactive: 4
# Simulating step 3860... Cautious: 6472 | Readthrough: 3528 | Inactive: 8
# Simulating step 3880... Cautious: 6608 | Readthrough: 3392 | Inactive: 7
# Simulating step 3900... Cautious: 6732 | Readthrough: 3268 | Inactive: 9
# Simulating step 3920... Cautious: 6733 | Readthrough: 3267 | Inactive: 7
# Simulating step 3940... Cautious: 6650 | Readthrough: 3350 | Inactive: 3
# Simulating step 3960... Cautious: 6671 | Readthrough: 3329 | Inactive: 5
# Simulating step 3980... Cautious: 6821 | Readthrough: 3179 | Inactive: 8
# Simulating step 4000... Cautious: 6881 | Readthrough: 3119 | Inactive: 4
# Simulating step 4020... Cautious: 6819 | Readthrough: 3181 | Inactive: 10
# Simulating step 4040... Cautious: 6856 | Readthrough: 3144 | Inactive: 9
# Simulating step 4060... Cautious: 6929 | Readthrough: 3071 | Inactive: 6
# Simulating step 4080... Cautious: 6860 | Readthrough: 3140 | Inactive: 12
# Simulating step 4100... Cautious: 6811 | Readthrough: 3189 | Inactive: 9
# Simulating step 4120... Cautious: 6830 | Readthrough: 3170 | Inactive: 5
# Simulating step 4140... Cautious: 6962 | Readthrough: 3038 | Inactive: 15
# Simulating step 4160... Cautious: 6975 | Readthrough: 3025 | Inactive: 5
# Simulating step 4180... Cautious: 7026 | Readthrough: 2974 | Inactive: 3
# Simulating step 4200... Cautious: 7137 | Readthrough: 2863 | Inactive: 6
# Simulating step 4220... Cautious: 7140 | Readthrough: 2860 | Inactive: 4
# Simulating step 4240... Cautious: 7065 | Readthrough: 2935 | Inactive: 13
# Simulating step 4260... Cautious: 7072 | Readthrough: 2928 | Inactive: 7
# Simulating step 4280... Cautious: 7104 | Readthrough: 2896 | Inactive: 9
# Simulating step 4300... Cautious: 7088 | Readthrough: 2912 | Inactive: 4
# Simulating step 4320... Cautious: 7002 | Readthrough: 2998 | Inactive: 10
# Simulating step 4340... Cautious: 6863 | Readthrough: 3137 | Inactive: 6
# Simulating step 4360... Cautious: 6836 | Readthrough: 3164 | Inactive: 13
# Simulating step 4380... Cautious: 6840 | Readthrough: 3160 | Inactive: 11
# Simulating step 4400... Cautious: 6895 | Readthrough: 3105 | Inactive: 14
# Simulating step 4420... Cautious: 6914 | Readthrough: 3086 | Inactive: 10
# Simulating step 4440... Cautious: 7011 | Readthrough: 2989 | Inactive: 8
# Simulating step 4460... Cautious: 7116 | Readthrough: 2884 | Inactive: 13
# Simulating step 4480... Cautious: 7057 | Readthrough: 2943 | Inactive: 8
# Simulating step 4500... Cautious: 7039 | Readthrough: 2961 | Inactive: 12
# Simulating step 4520... Cautious: 7079 | Readthrough: 2921 | Inactive: 9
# Simulating step 4540... Cautious: 7138 | Readthrough: 2862 | Inactive: 10
# Simulating step 4560... Cautious: 7115 | Readthrough: 2885 | Inactive: 14
# Simulating step 4580... Cautious: 7173 | Readthrough: 2827 | Inactive: 10
# Simulating step 4600... Cautious: 7158 | Readthrough: 2842 | Inactive: 14
# Simulating step 4620... Cautious: 7102 | Readthrough: 2898 | Inactive: 9
# Simulating step 4640... Cautious: 7094 | Readthrough: 2906 | Inactive: 11
# Simulating step 4660... Cautious: 7195 | Readthrough: 2805 | Inactive: 19
# Simulating step 4680... Cautious: 7234 | Readthrough: 2766 | Inactive: 8
# Simulating step 4700... Cautious: 7188 | Readthrough: 2812 | Inactive: 27
# Simulating step 4720... Cautious: 7214 | Readthrough: 2786 | Inactive: 9
# Simulating step 4740... Cautious: 7205 | Readthrough: 2795 | Inactive: 28
# Simulating step 4760... Cautious: 7140 | Readthrough: 2860 | Inactive: 28
# Simulating step 4780... Cautious: 7196 | Readthrough: 2804 | Inactive: 32
# Simulating step 4800... Cautious: 7261 | Readthrough: 2739 | Inactive: 30
# Simulating step 4820... Cautious: 7286 | Readthrough: 2714 | Inactive: 16
# Simulating step 4840... Cautious: 7262 | Readthrough: 2738 | Inactive: 17
# Simulating step 4860... Cautious: 7292 | Readthrough: 2708 | Inactive: 17
# Simulating step 4880... Cautious: 7268 | Readthrough: 2732 | Inactive: 24
# Simulating step 4900... Cautious: 7258 | Readthrough: 2742 | Inactive: 25
# Simulating step 4920... Cautious: 7265 | Readthrough: 2735 | Inactive: 20
# Simulating step 4940... Cautious: 7187 | Readthrough: 2813 | Inactive: 28
# Simulating step 4960... Cautious: 7124 | Readthrough: 2876 | Inactive: 21
# Simulating step 4980... Cautious: 7142 | Readthrough: 2858 | Inactive: 29
# Simulating step 5000... Cautious: 7130 | Readthrough: 2870 | Inactive: 25
# Simulating step 5020... Cautious: 7088 | Readthrough: 2912 | Inactive: 17
# Simulating step 5040... Cautious: 7115 | Readthrough: 2885 | Inactive: 28
# Simulating step 5060... Cautious: 7121 | Readthrough: 2879 | Inactive: 27
# Simulating step 5080... Cautious: 7090 | Readthrough: 2910 | Inactive: 16
# Simulating step 5100... Cautious: 7177 | Readthrough: 2823 | Inactive: 30
# Simulating step 5120... Cautious: 7175 | Readthrough: 2825 | Inactive: 15
# Simulating step 5140... Cautious: 7160 | Readthrough: 2840 | Inactive: 29
# Simulating step 5160... Cautious: 7167 | Readthrough: 2833 | Inactive: 17
# Simulating step 5180... Cautious: 7114 | Readthrough: 2886 | Inactive: 5
# Simulating step 5200... Cautious: 7127 | Readthrough: 2873 | Inactive: 28
# Simulating step 5220... Cautious: 7120 | Readthrough: 2880 | Inactive: 5
# Simulating step 5240... Cautious: 7055 | Readthrough: 2945 | Inactive: 35
# Simulating step 5260... Cautious: 6944 | Readthrough: 3056 | Inactive: 23
# Simulating step 5280... Cautious: 6916 | Readthrough: 3084 | Inactive: 9
# Simulating step 5300... Cautious: 6886 | Readthrough: 3114 | Inactive: 2
# Simulating step 5320... Cautious: 6853 | Readthrough: 3147 | Inactive: 15
# Simulating step 5340... Cautious: 6836 | Readthrough: 3164 | Inactive: 5
# Simulating step 5360... Cautious: 6961 | Readthrough: 3039 | Inactive: 24
# Simulating step 5380... Cautious: 6977 | Readthrough: 3023 | Inactive: 13
# Simulating step 5400... Cautious: 6984 | Readthrough: 3016 | Inactive: 20
# Simulating step 5420... Cautious: 7017 | Readthrough: 2983 | Inactive: 20
# Simulating step 5440... Cautious: 6996 | Readthrough: 3004 | Inactive: 11
# Simulating step 5460... Cautious: 7099 | Readthrough: 2901 | Inactive: 33
# Simulating step 5480... Cautious: 7034 | Readthrough: 2966 | Inactive: 8
# Simulating step 5500... Cautious: 7090 | Readthrough: 2910 | Inactive: 9
# Simulating step 5520... Cautious: 7073 | Readthrough: 2927 | Inactive: 15
# Simulating step 5540... Cautious: 7128 | Readthrough: 2872 | Inactive: 9
# Simulating step 5560... Cautious: 7146 | Readthrough: 2854 | Inactive: 8
# Simulating step 5580... Cautious: 7041 | Readthrough: 2959 | Inactive: 13
# Simulating step 5600... Cautious: 6986 | Readthrough: 3014 | Inactive: 9
# Simulating step 5620... Cautious: 7043 | Readthrough: 2957 | Inactive: 9
# Simulating step 5640... Cautious: 7063 | Readthrough: 2937 | Inactive: 11
# Simulating step 5660... Cautious: 7107 | Readthrough: 2893 | Inactive: 2
# Simulating step 5680... Cautious: 7219 | Readthrough: 2781 | Inactive: 23
# Simulating step 5700... Cautious: 7112 | Readthrough: 2888 | Inactive: 11
# Simulating step 5720... Cautious: 7125 | Readthrough: 2875 | Inactive: 10
# Simulating step 5740... Cautious: 7106 | Readthrough: 2894 | Inactive: 1
# Simulating step 5760... Cautious: 6966 | Readthrough: 3034 | Inactive: 9
# Simulating step 5780... Cautious: 6927 | Readthrough: 3073 | Inactive: 8
# Simulating step 5800... Cautious: 6805 | Readthrough: 3195 | Inactive: 5
# Simulating step 5820... Cautious: 6781 | Readthrough: 3219 | Inactive: 10
# Simulating step 5840... Cautious: 6685 | Readthrough: 3315 | Inactive: 15
# Simulating step 5860... Cautious: 6686 | Readthrough: 3314 | Inactive: 4
# Simulating step 5880... Cautious: 6829 | Readthrough: 3171 | Inactive: 10
# Simulating step 5900... Cautious: 6945 | Readthrough: 3055 | Inactive: 6
# Simulating step 5920... Cautious: 7037 | Readthrough: 2963 | Inactive: 5
# Simulating step 5940... Cautious: 7103 | Readthrough: 2897 | Inactive: 4
# Simulating step 5960... Cautious: 7019 | Readthrough: 2981 | Inactive: 8
# Simulating step 5980... Cautious: 6964 | Readthrough: 3036 | Inactive: 2
# Simulating step 6000... Cautious: 6935 | Readthrough: 3065 | Inactive: 4
# Simulating step 6020... Cautious: 6998 | Readthrough: 3002 | Inactive: 7
# Simulating step 6040... Cautious: 6913 | Readthrough: 3087 | Inactive: 2
# Simulating step 6060... Cautious: 6842 | Readthrough: 3158 | Inactive: 4
# Simulating step 6080... Cautious: 6813 | Readthrough: 3187 | Inactive: 4
# Simulating step 6100... Cautious: 6792 | Readthrough: 3208 | Inactive: 4
# Simulating step 6120... Cautious: 6854 | Readthrough: 3146 | Inactive: 3
# Simulating step 6140... Cautious: 6905 | Readthrough: 3095 | Inactive: 3
# Simulating step 6160... Cautious: 6838 | Readthrough: 3162 | Inactive: 3
# Simulating step 6180... Cautious: 6730 | Readthrough: 3270 | Inactive: 2
# Simulating step 6200... Cautious: 6720 | Readthrough: 3280 | Inactive: 2
# Simulating step 6220... Cautious: 6640 | Readthrough: 3360 | Inactive: 2
# Simulating step 6240... Cautious: 6591 | Readthrough: 3409 | Inactive: 3
# Simulating step 6260... Cautious: 6623 | Readthrough: 3377 | Inactive: 4
# Simulating step 6280... Cautious: 6690 | Readthrough: 3310 | Inactive: 5
# Simulating step 6300... Cautious: 6704 | Readthrough: 3296 | Inactive: 4
# Simulating step 6320... Cautious: 6676 | Readthrough: 3324 | Inactive: 8
# Simulating step 6340... Cautious: 6711 | Readthrough: 3289 | Inactive: 3
# Simulating step 6360... Cautious: 6780 | Readthrough: 3220 | Inactive: 4
# Simulating step 6380... Cautious: 6768 | Readthrough: 3232 | Inactive: 3
# Simulating step 6400... Cautious: 6679 | Readthrough: 3321 | Inactive: 4
# Simulating step 6420... Cautious: 6597 | Readthrough: 3403 | Inactive: 3
# Simulating step 6440... Cautious: 6593 | Readthrough: 3407 | Inactive: 4
# Simulating step 6460... Cautious: 6422 | Readthrough: 3578 | Inactive: 6
# Simulating step 6480... Cautious: 6404 | Readthrough: 3596 | Inactive: 3
# Simulating step 6500... Cautious: 6393 | Readthrough: 3607 | Inactive: 3
# Simulating step 6520... Cautious: 6323 | Readthrough: 3677 | Inactive: 3
# Simulating step 6540... Cautious: 6300 | Readthrough: 3700 | Inactive: 2
# Simulating step 6560... Cautious: 6202 | Readthrough: 3798 | Inactive: 5
# Simulating step 6580... Cautious: 6288 | Readthrough: 3712 | Inactive: 5
# Simulating step 6600... Cautious: 6348 | Readthrough: 3652 | Inactive: 3
# Simulating step 6620... Cautious: 6306 | Readthrough: 3694 | Inactive: 3
# Simulating step 6640... Cautious: 6239 | Readthrough: 3761 | Inactive: 4
# Simulating step 6660... Cautious: 6246 | Readthrough: 3754 | Inactive: 7
# Simulating step 6680... Cautious: 6250 | Readthrough: 3750 | Inactive: 4
# Simulating step 6700... Cautious: 6199 | Readthrough: 3801 | Inactive: 2
# Simulating step 6720... Cautious: 6108 | Readthrough: 3892 | Inactive: 7
# Simulating step 6740... Cautious: 6102 | Readthrough: 3898 | Inactive: 0
# Simulating step 6760... Cautious: 6135 | Readthrough: 3865 | Inactive: 3
# Simulating step 6780... Cautious: 6175 | Readthrough: 3825 | Inactive: 5
# Simulating step 6800... Cautious: 6226 | Readthrough: 3774 | Inactive: 4
# Simulating step 6820... Cautious: 6224 | Readthrough: 3776 | Inactive: 3
# Simulating step 6840... Cautious: 6247 | Readthrough: 3753 | Inactive: 5
# Simulating step 6860... Cautious: 6190 | Readthrough: 3810 | Inactive: 8
# Simulating step 6880... Cautious: 6029 | Readthrough: 3971 | Inactive: 15
# Simulating step 6900... Cautious: 6003 | Readthrough: 3997 | Inactive: 5
# Simulating step 6920... Cautious: 5858 | Readthrough: 4142 | Inactive: 7
# Simulating step 6940... Cautious: 5855 | Readthrough: 4145 | Inactive: 6
# Simulating step 6960... Cautious: 5897 | Readthrough: 4103 | Inactive: 15
# Simulating step 6980... Cautious: 5870 | Readthrough: 4130 | Inactive: 9
# Simulating step 7000... Cautious: 5926 | Readthrough: 4074 | Inactive: 12
# Simulating step 7020... Cautious: 5894 | Readthrough: 4106 | Inactive: 9
# Simulating step 7040... Cautious: 5925 | Readthrough: 4075 | Inactive: 14
# Simulating step 7060... Cautious: 5993 | Readthrough: 4007 | Inactive: 4
# Simulating step 7080... Cautious: 5984 | Readthrough: 4016 | Inactive: 14
# Simulating step 7100... Cautious: 5966 | Readthrough: 4034 | Inactive: 29
# Simulating step 7120... Cautious: 5985 | Readthrough: 4015 | Inactive: 22
# Simulating step 7140... Cautious: 5986 | Readthrough: 4014 | Inactive: 32
# Simulating step 7160... Cautious: 5967 | Readthrough: 4033 | Inactive: 27
# Simulating step 7180... Cautious: 6143 | Readthrough: 3857 | Inactive: 19
# Simulating step 7200... Cautious: 6169 | Readthrough: 3831 | Inactive: 20
# Simulating step 7220... Cautious: 6114 | Readthrough: 3886 | Inactive: 37
# Simulating step 7240... Cautious: 6149 | Readthrough: 3851 | Inactive: 31
# Simulating step 7260... Cautious: 6174 | Readthrough: 3826 | Inactive: 31
# Simulating step 7280... Cautious: 6194 | Readthrough: 3806 | Inactive: 22
# Simulating step 7300... Cautious: 6258 | Readthrough: 3742 | Inactive: 25
# Simulating step 7320... Cautious: 6255 | Readthrough: 3745 | Inactive: 17
# Simulating step 7340... Cautious: 6236 | Readthrough: 3764 | Inactive: 21
# Simulating step 7360... Cautious: 6305 | Readthrough: 3695 | Inactive: 28
# Simulating step 7380... Cautious: 6189 | Readthrough: 3811 | Inactive: 27
# Simulating step 7400... Cautious: 6251 | Readthrough: 3749 | Inactive: 21
# Simulating step 7420... Cautious: 6338 | Readthrough: 3662 | Inactive: 20
# Simulating step 7440... Cautious: 6300 | Readthrough: 3700 | Inactive: 30
# Simulating step 7460... Cautious: 6293 | Readthrough: 3707 | Inactive: 26
# Simulating step 7480... Cautious: 6331 | Readthrough: 3669 | Inactive: 31
# Simulating step 7500... Cautious: 6281 | Readthrough: 3719 | Inactive: 31
# Simulating step 7520... Cautious: 6278 | Readthrough: 3722 | Inactive: 57
# Simulating step 7540... Cautious: 6323 | Readthrough: 3677 | Inactive: 32
# Simulating step 7560... Cautious: 6467 | Readthrough: 3533 | Inactive: 65
# Simulating step 7580... Cautious: 6493 | Readthrough: 3507 | Inactive: 47
# Simulating step 7600... Cautious: 6441 | Readthrough: 3559 | Inactive: 2
# Simulating step 7620... Cautious: 6470 | Readthrough: 3530 | Inactive: 41
# Simulating step 7640... Cautious: 6460 | Readthrough: 3540 | Inactive: 36
# Simulating step 7660... Cautious: 6391 | Readthrough: 3609 | Inactive: 56
# Simulating step 7680... Cautious: 6358 | Readthrough: 3642 | Inactive: 29
# Simulating step 7700... Cautious: 6364 | Readthrough: 3636 | Inactive: 69
# Simulating step 7720... Cautious: 6302 | Readthrough: 3698 | Inactive: 60
# Simulating step 7740... Cautious: 6300 | Readthrough: 3700 | Inactive: 3
# Simulating step 7760... Cautious: 6379 | Readthrough: 3621 | Inactive: 21
# Simulating step 7780... Cautious: 6376 | Readthrough: 3624 | Inactive: 33
# Simulating step 7800... Cautious: 6374 | Readthrough: 3626 | Inactive: 57
# Simulating step 7820... Cautious: 6365 | Readthrough: 3635 | Inactive: 33
# Simulating step 7840... Cautious: 6331 | Readthrough: 3669 | Inactive: 21
# Simulating step 7860... Cautious: 6365 | Readthrough: 3635 | Inactive: 61
# Simulating step 7880... Cautious: 6143 | Readthrough: 3857 | Inactive: 31
# Simulating step 7900... Cautious: 6118 | Readthrough: 3882 | Inactive: 58
# Simulating step 7920... Cautious: 6153 | Readthrough: 3847 | Inactive: 44
# Simulating step 7940... Cautious: 6162 | Readthrough: 3838 | Inactive: 36
# Simulating step 7960... Cautious: 6209 | Readthrough: 3791 | Inactive: 67
# Simulating step 7980... Cautious: 6203 | Readthrough: 3797 | Inactive: 46
# Simulating step 8000... Cautious: 6195 | Readthrough: 3805 | Inactive: 77
# Simulating step 8020... Cautious: 6077 | Readthrough: 3923 | Inactive: 81
# Simulating step 8040... Cautious: 6081 | Readthrough: 3919 | Inactive: 32
# Simulating step 8060... Cautious: 6021 | Readthrough: 3979 | Inactive: 81
# Simulating step 8080... Cautious: 5914 | Readthrough: 4086 | Inactive: 52
# Simulating step 8100... Cautious: 5988 | Readthrough: 4012 | Inactive: 65
# Simulating step 8120... Cautious: 5907 | Readthrough: 4093 | Inactive: 61
# Simulating step 8140... Cautious: 5981 | Readthrough: 4019 | Inactive: 30
# Simulating step 8160... Cautious: 6020 | Readthrough: 3980 | Inactive: 76
# Simulating step 8180... Cautious: 6106 | Readthrough: 3894 | Inactive: 40
# Simulating step 8200... Cautious: 6106 | Readthrough: 3894 | Inactive: 67
# Simulating step 8220... Cautious: 6187 | Readthrough: 3813 | Inactive: 63
# Simulating step 8240... Cautious: 6099 | Readthrough: 3901 | Inactive: 52
# Simulating step 8260... Cautious: 6013 | Readthrough: 3987 | Inactive: 54
# Simulating step 8280... Cautious: 5968 | Readthrough: 4032 | Inactive: 38
# Simulating step 8300... Cautious: 6056 | Readthrough: 3944 | Inactive: 65
# Simulating step 8320... Cautious: 6154 | Readthrough: 3846 | Inactive: 62
# Simulating step 8340... Cautious: 6144 | Readthrough: 3856 | Inactive: 28
# Simulating step 8360... Cautious: 6085 | Readthrough: 3915 | Inactive: 56
# Simulating step 8380... Cautious: 5988 | Readthrough: 4012 | Inactive: 67
# Simulating step 8400... Cautious: 5930 | Readthrough: 4070 | Inactive: 67
# Simulating step 8420... Cautious: 5840 | Readthrough: 4160 | Inactive: 75
# Simulating step 8440... Cautious: 5844 | Readthrough: 4156 | Inactive: 26
# Simulating step 8460... Cautious: 5836 | Readthrough: 4164 | Inactive: 72
# Simulating step 8480... Cautious: 5868 | Readthrough: 4132 | Inactive: 74
# Simulating step 8500... Cautious: 5900 | Readthrough: 4100 | Inactive: 81
# Simulating step 8520... Cautious: 5929 | Readthrough: 4071 | Inactive: 89
# Simulating step 8540... Cautious: 5947 | Readthrough: 4053 | Inactive: 35
# Simulating step 8560... Cautious: 6021 | Readthrough: 3979 | Inactive: 94
# Simulating step 8580... Cautious: 5936 | Readthrough: 4064 | Inactive: 50
# Simulating step 8600... Cautious: 5914 | Readthrough: 4086 | Inactive: 83
# Simulating step 8620... Cautious: 5889 | Readthrough: 4111 | Inactive: 68
# Simulating step 8640... Cautious: 5875 | Readthrough: 4125 | Inactive: 36
# Simulating step 8660... Cautious: 5824 | Readthrough: 4176 | Inactive: 93
# Simulating step 8680... Cautious: 5874 | Readthrough: 4126 | Inactive: 58
# Simulating step 8700... Cautious: 5916 | Readthrough: 4084 | Inactive: 64
# Simulating step 8720... Cautious: 5835 | Readthrough: 4165 | Inactive: 26
# Simulating step 8740... Cautious: 5924 | Readthrough: 4076 | Inactive: 53
# Simulating step 8760... Cautious: 5933 | Readthrough: 4067 | Inactive: 81
# Simulating step 8780... Cautious: 5887 | Readthrough: 4113 | Inactive: 74
# Simulating step 8800... Cautious: 5921 | Readthrough: 4079 | Inactive: 32
# Simulating step 8820... Cautious: 5902 | Readthrough: 4098 | Inactive: 4
# Simulating step 8840... Cautious: 6000 | Readthrough: 4000 | Inactive: 45
# Simulating step 8860... Cautious: 6031 | Readthrough: 3969 | Inactive: 27
# Simulating step 8880... Cautious: 6035 | Readthrough: 3965 | Inactive: 57
# Simulating step 8900... Cautious: 6040 | Readthrough: 3960 | Inactive: 37
# Simulating step 8920... Cautious: 6042 | Readthrough: 3958 | Inactive: 100
# Simulating step 8940... Cautious: 5966 | Readthrough: 4034 | Inactive: 59
# Simulating step 8960... Cautious: 5935 | Readthrough: 4065 | Inactive: 79
# Simulating step 8980... Cautious: 5884 | Readthrough: 4116 | Inactive: 38
# Simulating step 9000... Cautious: 5883 | Readthrough: 4117 | Inactive: 6
# Simulating step 9020... Cautious: 5840 | Readthrough: 4160 | Inactive: 31
# Simulating step 9040... Cautious: 6007 | Readthrough: 3993 | Inactive: 30
# Simulating step 9060... Cautious: 6106 | Readthrough: 3894 | Inactive: 48
# Simulating step 9080... Cautious: 6112 | Readthrough: 3888 | Inactive: 13
# Simulating step 9100... Cautious: 6085 | Readthrough: 3915 | Inactive: 43
# Simulating step 9120... Cautious: 6013 | Readthrough: 3987 | Inactive: 20
# Simulating step 9140... Cautious: 5995 | Readthrough: 4005 | Inactive: 33
# Simulating step 9160... Cautious: 6016 | Readthrough: 3984 | Inactive: 42
# Simulating step 9180... Cautious: 6074 | Readthrough: 3926 | Inactive: 9
# Simulating step 9200... Cautious: 6066 | Readthrough: 3934 | Inactive: 2
# Simulating step 9220... Cautious: 6075 | Readthrough: 3925 | Inactive: 23
# Simulating step 9240... Cautious: 6110 | Readthrough: 3890 | Inactive: 14
# Simulating step 9260... Cautious: 6043 | Readthrough: 3957 | Inactive: 33
# Simulating step 9280... Cautious: 5933 | Readthrough: 4067 | Inactive: 14
# Simulating step 9300... Cautious: 6010 | Readthrough: 3990 | Inactive: 9
# Simulating step 9320... Cautious: 6053 | Readthrough: 3947 | Inactive: 6
# Simulating step 9340... Cautious: 6063 | Readthrough: 3937 | Inactive: 18
# Simulating step 9360... Cautious: 6105 | Readthrough: 3895 | Inactive: 7
# Simulating step 9380... Cautious: 6052 | Readthrough: 3948 | Inactive: 14
# Simulating step 9400... Cautious: 6007 | Readthrough: 3993 | Inactive: 14
# Simulating step 9420... Cautious: 5916 | Readthrough: 4084 | Inactive: 7
# Simulating step 9440... Cautious: 5991 | Readthrough: 4009 | Inactive: 6
# Simulating step 9460... Cautious: 6103 | Readthrough: 3897 | Inactive: 9
# Simulating step 9480... Cautious: 6043 | Readthrough: 3957 | Inactive: 7
# Simulating step 9500... Cautious: 6008 | Readthrough: 3992 | Inactive: 15
# Simulating step 9520... Cautious: 6001 | Readthrough: 3999 | Inactive: 1
# Simulating step 9540... Cautious: 5973 | Readthrough: 4027 | Inactive: 1
# Simulating step 9560... Cautious: 5914 | Readthrough: 4086 | Inactive: 7
# Simulating step 9580... Cautious: 5866 | Readthrough: 4134 | Inactive: 14
# Simulating step 9600... Cautious: 5859 | Readthrough: 4141 | Inactive: 3
# Simulating step 9620... Cautious: 5923 | Readthrough: 4077 | Inactive: 5
# Simulating step 9640... Cautious: 5970 | Readthrough: 4030 | Inactive: 2
# Simulating step 9660... Cautious: 5957 | Readthrough: 4043 | Inactive: 3
# Simulating step 9680... Cautious: 5879 | Readthrough: 4121 | Inactive: 8
# Simulating step 9700... Cautious: 5901 | Readthrough: 4099 | Inactive: 1
# Simulating step 9720... Cautious: 5889 | Readthrough: 4111 | Inactive: 1
# Simulating step 9740... Cautious: 5779 | Readthrough: 4221 | Inactive: 5
# Simulating step 9760... Cautious: 5843 | Readthrough: 4157 | Inactive: 6
# Simulating step 9780... Cautious: 5843 | Readthrough: 4157 | Inactive: 6
# Simulating step 9800... Cautious: 5839 | Readthrough: 4161 | Inactive: 5
# Simulating step 9820... Cautious: 5879 | Readthrough: 4121 | Inactive: 8
# Simulating step 9840... Cautious: 5898 | Readthrough: 4102 | Inactive: 1
# Simulating step 9860... Cautious: 5946 | Readthrough: 4054 | Inactive: 2
# Simulating step 9880... Cautious: 6008 | Readthrough: 3992 | Inactive: 3
# Simulating step 9900... Cautious: 6102 | Readthrough: 3898 | Inactive: 1
# Simulating step 9920... Cautious: 6102 | Readthrough: 3898 | Inactive: 1
# Simulating step 9940... Cautious: 6020 | Readthrough: 3980 | Inactive: 3
# Simulating step 9960... Cautious: 6045 | Readthrough: 3955 | Inactive: 4
# Simulating step 9980... Cautious: 6129 | Readthrough: 3871 | Inactive: 5
# Simulating step 10000... Cautious: 6118 | Readthrough: 3882 | Inactive: 2
# Simulating step 10020... Cautious: 6044 | Readthrough: 3956 | Inactive: 2
# Simulating step 10040... Cautious: 5958 | Readthrough: 4042 | Inactive: 0
# Simulating step 10060... Cautious: 5984 | Readthrough: 4016 | Inactive: 2
# Simulating step 10080... Cautious: 6067 | Readthrough: 3933 | Inactive: 3
# Simulating step 10100... Cautious: 6038 | Readthrough: 3962 | Inactive: 0
# Simulating step 10120... Cautious: 5979 | Readthrough: 4021 | Inactive: 3
# Simulating step 10140... Cautious: 6004 | Readthrough: 3996 | Inactive: 0
# Simulating step 10160... Cautious: 6040 | Readthrough: 3960 | Inactive: 8
# Simulating step 10180... Cautious: 6206 | Readthrough: 3794 | Inactive: 5
# Simulating step 10200... Cautious: 6233 | Readthrough: 3767 | Inactive: 1
# Simulating step 10220... Cautious: 6299 | Readthrough: 3701 | Inactive: 0
# Simulating step 10240... Cautious: 6234 | Readthrough: 3766 | Inactive: 4
# Simulating step 10260... Cautious: 6191 | Readthrough: 3809 | Inactive: 3
# Simulating step 10280... Cautious: 6144 | Readthrough: 3856 | Inactive: 3
# Simulating step 10300... Cautious: 6099 | Readthrough: 3901 | Inactive: 1
# Simulating step 10320... Cautious: 6167 | Readthrough: 3833 | Inactive: 3
# Simulating step 10340... Cautious: 6203 | Readthrough: 3797 | Inactive: 3
# Simulating step 10360... Cautious: 6143 | Readthrough: 3857 | Inactive: 0
# Simulating step 10380... Cautious: 6229 | Readthrough: 3771 | Inactive: 3
# Simulating step 10400... Cautious: 6245 | Readthrough: 3755 | Inactive: 5
# Simulating step 10420... Cautious: 6334 | Readthrough: 3666 | Inactive: 4
# Simulating step 10440... Cautious: 6418 | Readthrough: 3582 | Inactive: 4
# Simulating step 10460... Cautious: 6410 | Readthrough: 3590 | Inactive: 7
# Simulating step 10480... Cautious: 6421 | Readthrough: 3579 | Inactive: 5
# Simulating step 10500... Cautious: 6400 | Readthrough: 3600 | Inactive: 8
# Simulating step 10520... Cautious: 6402 | Readthrough: 3598 | Inactive: 9
# Simulating step 10540... Cautious: 6329 | Readthrough: 3671 | Inactive: 4
# Simulating step 10560... Cautious: 6331 | Readthrough: 3669 | Inactive: 5
# Simulating step 10580... Cautious: 6301 | Readthrough: 3699 | Inactive: 5
# Simulating step 10600... Cautious: 6323 | Readthrough: 3677 | Inactive: 6
# Simulating step 10620... Cautious: 6330 | Readthrough: 3670 | Inactive: 6
# Simulating step 10640... Cautious: 6326 | Readthrough: 3674 | Inactive: 4
# Simulating step 10660... Cautious: 6313 | Readthrough: 3687 | Inactive: 1
# Simulating step 10680... Cautious: 6377 | Readthrough: 3623 | Inactive: 10
# Simulating step 10700... Cautious: 6407 | Readthrough: 3593 | Inactive: 6
# Simulating step 10720... Cautious: 6424 | Readthrough: 3576 | Inactive: 8
# Simulating step 10740... Cautious: 6356 | Readthrough: 3644 | Inactive: 8
# Simulating step 10760... Cautious: 6319 | Readthrough: 3681 | Inactive: 2
# Simulating step 10780... Cautious: 6255 | Readthrough: 3745 | Inactive: 14
# Simulating step 10800... Cautious: 6372 | Readthrough: 3628 | Inactive: 8
# Simulating step 10820... Cautious: 6312 | Readthrough: 3688 | Inactive: 15
# Simulating step 10840... Cautious: 6296 | Readthrough: 3704 | Inactive: 19
# Simulating step 10860... Cautious: 6264 | Readthrough: 3736 | Inactive: 27
# Simulating step 10880... Cautious: 6363 | Readthrough: 3637 | Inactive: 26
# Simulating step 10900... Cautious: 6411 | Readthrough: 3589 | Inactive: 19
# Simulating step 10920... Cautious: 6390 | Readthrough: 3610 | Inactive: 16
# Simulating step 10940... Cautious: 6214 | Readthrough: 3786 | Inactive: 14
# Simulating step 10960... Cautious: 6139 | Readthrough: 3861 | Inactive: 26
# Simulating step 10980... Cautious: 6119 | Readthrough: 3881 | Inactive: 68
# Simulating step 11000... Cautious: 6059 | Readthrough: 3941 | Inactive: 21
# Simulating step 11020... Cautious: 6091 | Readthrough: 3909 | Inactive: 71
# Simulating step 11040... Cautious: 6342 | Readthrough: 3658 | Inactive: 43
# Simulating step 11060... Cautious: 6321 | Readthrough: 3679 | Inactive: 26
# Simulating step 11080... Cautious: 6293 | Readthrough: 3707 | Inactive: 2
# Simulating step 11100... Cautious: 6411 | Readthrough: 3589 | Inactive: 25
# Simulating step 11120... Cautious: 6412 | Readthrough: 3588 | Inactive: 77
# Simulating step 11140... Cautious: 6445 | Readthrough: 3555 | Inactive: 44
# Simulating step 11160... Cautious: 6446 | Readthrough: 3554 | Inactive: 69
# Simulating step 11180... Cautious: 6264 | Readthrough: 3736 | Inactive: 65
# Simulating step 11200... Cautious: 6203 | Readthrough: 3797 | Inactive: 21
# Simulating step 11220... Cautious: 6247 | Readthrough: 3753 | Inactive: 77
# Simulating step 11240... Cautious: 6181 | Readthrough: 3819 | Inactive: 50
# Simulating step 11260... Cautious: 6122 | Readthrough: 3878 | Inactive: 93
# Simulating step 11280... Cautious: 6040 | Readthrough: 3960 | Inactive: 69
# Simulating step 11300... Cautious: 6105 | Readthrough: 3895 | Inactive: 37
# Simulating step 11320... Cautious: 6185 | Readthrough: 3815 | Inactive: 78
# Simulating step 11340... Cautious: 6177 | Readthrough: 3823 | Inactive: 82
# Simulating step 11360... Cautious: 6194 | Readthrough: 3806 | Inactive: 92
# Simulating step 11380... Cautious: 6208 | Readthrough: 3792 | Inactive: 89
# Simulating step 11400... Cautious: 6256 | Readthrough: 3744 | Inactive: 101
# Simulating step 11420... Cautious: 6323 | Readthrough: 3677 | Inactive: 95
# Simulating step 11440... Cautious: 6260 | Readthrough: 3740 | Inactive: 63
# Simulating step 11460... Cautious: 6311 | Readthrough: 3689 | Inactive: 107
# Simulating step 11480... Cautious: 6353 | Readthrough: 3647 | Inactive: 104
# Simulating step 11500... Cautious: 6457 | Readthrough: 3543 | Inactive: 83
# Simulating step 11520... Cautious: 6461 | Readthrough: 3539 | Inactive: 90
# Simulating step 11540... Cautious: 6457 | Readthrough: 3543 | Inactive: 59
# Simulating step 11560... Cautious: 6461 | Readthrough: 3539 | Inactive: 93
# Simulating step 11580... Cautious: 6269 | Readthrough: 3731 | Inactive: 88
# Simulating step 11600... Cautious: 6236 | Readthrough: 3764 | Inactive: 32
# Simulating step 11620... Cautious: 6204 | Readthrough: 3796 | Inactive: 95
# Simulating step 11640... Cautious: 6126 | Readthrough: 3874 | Inactive: 206
# Simulating step 11660... Cautious: 6170 | Readthrough: 3830 | Inactive: 170
# Simulating step 11680... Cautious: 6178 | Readthrough: 3822 | Inactive: 60
# Simulating step 11700... Cautious: 6178 | Readthrough: 3822 | Inactive: 116
# Simulating step 11720... Cautious: 6243 | Readthrough: 3757 | Inactive: 111
# Simulating step 11740... Cautious: 6255 | Readthrough: 3745 | Inactive: 193
# Simulating step 11760... Cautious: 6313 | Readthrough: 3687 | Inactive: 177
# Simulating step 11780... Cautious: 6295 | Readthrough: 3705 | Inactive: 61
# Simulating step 11800... Cautious: 6279 | Readthrough: 3721 | Inactive: 169
# Simulating step 11820... Cautious: 6229 | Readthrough: 3771 | Inactive: 106
# Simulating step 11840... Cautious: 6140 | Readthrough: 3860 | Inactive: 171
# Simulating step 11860... Cautious: 6177 | Readthrough: 3823 | Inactive: 167
# Simulating step 11880... Cautious: 6057 | Readthrough: 3943 | Inactive: 61
# Simulating step 11900... Cautious: 6092 | Readthrough: 3908 | Inactive: 167
# Simulating step 11920... Cautious: 6112 | Readthrough: 3888 | Inactive: 106
# Simulating step 11940... Cautious: 6136 | Readthrough: 3864 | Inactive: 198
# Simulating step 11960... Cautious: 6223 | Readthrough: 3777 | Inactive: 198
# Simulating step 11980... Cautious: 6143 | Readthrough: 3857 | Inactive: 68
# Simulating step 12000... Cautious: 5987 | Readthrough: 4013 | Inactive: 216
# Simulating step 12020... Cautious: 5939 | Readthrough: 4061 | Inactive: 130
# Simulating step 12040... Cautious: 5867 | Readthrough: 4133 | Inactive: 243
# Simulating step 12060... Cautious: 5873 | Readthrough: 4127 | Inactive: 207
# Simulating step 12080... Cautious: 5880 | Readthrough: 4120 | Inactive: 125
# Simulating step 12100... Cautious: 5881 | Readthrough: 4119 | Inactive: 205
# Simulating step 12120... Cautious: 5904 | Readthrough: 4096 | Inactive: 124
# Simulating step 12140... Cautious: 5856 | Readthrough: 4144 | Inactive: 138
# Simulating step 12160... Cautious: 5957 | Readthrough: 4043 | Inactive: 124
# Simulating step 12180... Cautious: 5886 | Readthrough: 4114 | Inactive: 111
# Simulating step 12200... Cautious: 5901 | Readthrough: 4099 | Inactive: 38
# Simulating step 12220... Cautious: 6001 | Readthrough: 3999 | Inactive: 111
# Simulating step 12240... Cautious: 6010 | Readthrough: 3990 | Inactive: 73
# Simulating step 12260... Cautious: 6037 | Readthrough: 3963 | Inactive: 112
# Simulating step 12280... Cautious: 6022 | Readthrough: 3978 | Inactive: 131
# Simulating step 12300... Cautious: 6070 | Readthrough: 3930 | Inactive: 58
# Simulating step 12320... Cautious: 6059 | Readthrough: 3941 | Inactive: 131
# Simulating step 12340... Cautious: 5954 | Readthrough: 4046 | Inactive: 97
# Simulating step 12360... Cautious: 5992 | Readthrough: 4008 | Inactive: 136
# Simulating step 12380... Cautious: 6002 | Readthrough: 3998 | Inactive: 130
# Simulating step 12400... Cautious: 5884 | Readthrough: 4116 | Inactive: 51
# Simulating step 12420... Cautious: 5902 | Readthrough: 4098 | Inactive: 137
# Simulating step 12440... Cautious: 5785 | Readthrough: 4215 | Inactive: 121
# Simulating step 12460... Cautious: 5982 | Readthrough: 4018 | Inactive: 37
# Simulating step 12480... Cautious: 5928 | Readthrough: 4072 | Inactive: 121
# Simulating step 12500... Cautious: 5804 | Readthrough: 4196 | Inactive: 46
# Simulating step 12520... Cautious: 5880 | Readthrough: 4120 | Inactive: 130
# Simulating step 12540... Cautious: 5708 | Readthrough: 4292 | Inactive: 100
# Simulating step 12560... Cautious: 5702 | Readthrough: 4298 | Inactive: 7
# Simulating step 12580... Cautious: 5627 | Readthrough: 4373 | Inactive: 30
# Simulating step 12600... Cautious: 5640 | Readthrough: 4360 | Inactive: 44
# Simulating step 12620... Cautious: 5599 | Readthrough: 4401 | Inactive: 55
# Simulating step 12640... Cautious: 5655 | Readthrough: 4345 | Inactive: 138
# Simulating step 12660... Cautious: 5548 | Readthrough: 4452 | Inactive: 52
# Simulating step 12680... Cautious: 5593 | Readthrough: 4407 | Inactive: 33
# Simulating step 12700... Cautious: 5556 | Readthrough: 4444 | Inactive: 47
# Simulating step 12720... Cautious: 5462 | Readthrough: 4538 | Inactive: 65
# Simulating step 12740... Cautious: 5362 | Readthrough: 4638 | Inactive: 99
# Simulating step 12760... Cautious: 5483 | Readthrough: 4517 | Inactive: 48
# Simulating step 12780... Cautious: 5597 | Readthrough: 4403 | Inactive: 177
# Simulating step 12800... Cautious: 5571 | Readthrough: 4429 | Inactive: 84
# Simulating step 12820... Cautious: 5648 | Readthrough: 4352 | Inactive: 54
# Simulating step 12840... Cautious: 5429 | Readthrough: 4571 | Inactive: 35
# Simulating step 12860... Cautious: 5542 | Readthrough: 4458 | Inactive: 77
# Simulating step 12880... Cautious: 5563 | Readthrough: 4437 | Inactive: 39
# Simulating step 12900... Cautious: 5479 | Readthrough: 4521 | Inactive: 51
# Simulating step 12920... Cautious: 5577 | Readthrough: 4423 | Inactive: 58
# Simulating step 12940... Cautious: 5567 | Readthrough: 4433 | Inactive: 45
# Simulating step 12960... Cautious: 5526 | Readthrough: 4474 | Inactive: 62
# Simulating step 12980... Cautious: 5466 | Readthrough: 4534 | Inactive: 78
# Simulating step 13000... Cautious: 5538 | Readthrough: 4462 | Inactive: 30
# ...
# Simulating step 68660... Cautious: 9419 | Readthrough: 581 | Inactive: 0
# Simulating step 68680... Cautious: 9442 | Readthrough: 558 | Inactive: 1
# Simulating step 68700... Cautious: 9498 | Readthrough: 502 | Inactive: 0
# Simulating step 68720... Cautious: 9465 | Readthrough: 535 | Inactive: 0
# Simulating step 68740... Cautious: 9460 | Readthrough: 540 | Inactive: 0
# Simulating step 68760... Cautious: 9490 | Readthrough: 510 | Inactive: 0
# Simulating step 68780... Cautious: 9490 | Readthrough: 510 | Inactive: 0
# Simulating step 68800... Cautious: 9514 | Readthrough: 486 | Inactive: 0
# Simulating step 68820... Cautious: 9550 | Readthrough: 450 | Inactive: 1
# Simulating step 68840... Cautious: 9578 | Readthrough: 422 | Inactive: 0
# Simulating step 68860... Cautious: 9611 | Readthrough: 389 | Inactive: 0
# Simulating step 68880... Cautious: 9642 | Readthrough: 358 | Inactive: 0
# Simulating step 68900... Cautious: 9612 | Readthrough: 388 | Inactive: 0
# Simulating step 68920... Cautious: 9643 | Readthrough: 357 | Inactive: 0
# Simulating step 68940... Cautious: 9640 | Readthrough: 360 | Inactive: 0
# Simulating step 68960... Cautious: 9639 | Readthrough: 361 | Inactive: 0
# Simulating step 68980... Cautious: 9615 | Readthrough: 385 | Inactive: 0
# Simulating step 69000... Cautious: 9579 | Readthrough: 421 | Inactive: 0
# Simulating step 69020... Cautious: 9609 | Readthrough: 391 | Inactive: 0
# Simulating step 69040... Cautious: 9638 | Readthrough: 362 | Inactive: 0
# Simulating step 69060... Cautious: 9640 | Readthrough: 360 | Inactive: 0
# Simulating step 69080... Cautious: 9633 | Readthrough: 367 | Inactive: 0
# Simulating step 69100... Cautious: 9649 | Readthrough: 351 | Inactive: 1
# Simulating step 69120... Cautious: 9596 | Readthrough: 404 | Inactive: 1
# Simulating step 69140... Cautious: 9589 | Readthrough: 411 | Inactive: 0
# Simulating step 69160... Cautious: 9607 | Readthrough: 393 | Inactive: 0
# Simulating step 69180... Cautious: 9606 | Readthrough: 394 | Inactive: 2
# Simulating step 69200... Cautious: 9657 | Readthrough: 343 | Inactive: 3
# Simulating step 69220... Cautious: 9698 | Readthrough: 302 | Inactive: 1
# Simulating step 69240... Cautious: 9688 | Readthrough: 312 | Inactive: 0
# Simulating step 69260... Cautious: 9648 | Readthrough: 352 | Inactive: 0
# Simulating step 69280... Cautious: 9622 | Readthrough: 378 | Inactive: 3
# Simulating step 69300... Cautious: 9638 | Readthrough: 362 | Inactive: 2
# Simulating step 69320... Cautious: 9617 | Readthrough: 383 | Inactive: 3
# Simulating step 69340... Cautious: 9618 | Readthrough: 382 | Inactive: 1
# Simulating step 69360... Cautious: 9653 | Readthrough: 347 | Inactive: 6
# Simulating step 69380... Cautious: 9676 | Readthrough: 324 | Inactive: 10
# Simulating step 69400... Cautious: 9707 | Readthrough: 293 | Inactive: 7
# Simulating step 69420... Cautious: 9708 | Readthrough: 292 | Inactive: 9
# Simulating step 69440... Cautious: 9725 | Readthrough: 275 | Inactive: 9
# Simulating step 69460... Cautious: 9698 | Readthrough: 302 | Inactive: 7
# Simulating step 69480... Cautious: 9704 | Readthrough: 296 | Inactive: 6
# Simulating step 69500... Cautious: 9735 | Readthrough: 265 | Inactive: 5
# Simulating step 69520... Cautious: 9725 | Readthrough: 275 | Inactive: 5
# Simulating step 69540... Cautious: 9741 | Readthrough: 259 | Inactive: 7
# Simulating step 69560... Cautious: 9752 | Readthrough: 248 | Inactive: 3
# Simulating step 69580... Cautious: 9724 | Readthrough: 276 | Inactive: 3
# Simulating step 69600... Cautious: 9732 | Readthrough: 268 | Inactive: 8
# Simulating step 69620... Cautious: 9687 | Readthrough: 313 | Inactive: 7
# Simulating step 69640... Cautious: 9697 | Readthrough: 303 | Inactive: 23
# Simulating step 69660... Cautious: 9667 | Readthrough: 333 | Inactive: 7
# Simulating step 69680... Cautious: 9684 | Readthrough: 316 | Inactive: 4
# Simulating step 69700... Cautious: 9686 | Readthrough: 314 | Inactive: 25
# Simulating step 69720... Cautious: 9672 | Readthrough: 328 | Inactive: 8
# Simulating step 69740... Cautious: 9646 | Readthrough: 354 | Inactive: 20
# Simulating step 69760... Cautious: 9677 | Readthrough: 323 | Inactive: 16
# Simulating step 69780... Cautious: 9654 | Readthrough: 346 | Inactive: 8
# Simulating step 69800... Cautious: 9648 | Readthrough: 352 | Inactive: 5
# Simulating step 69820... Cautious: 9632 | Readthrough: 368 | Inactive: 8
# Simulating step 69840... Cautious: 9645 | Readthrough: 355 | Inactive: 5
# Simulating step 69860... Cautious: 9645 | Readthrough: 355 | Inactive: 12
# Simulating step 69880... Cautious: 9676 | Readthrough: 324 | Inactive: 11
# Simulating step 69900... Cautious: 9669 | Readthrough: 331 | Inactive: 29
# Simulating step 69920... Cautious: 9687 | Readthrough: 313 | Inactive: 10
# Simulating step 69940... Cautious: 9729 | Readthrough: 271 | Inactive: 34
# Simulating step 69960... Cautious: 9693 | Readthrough: 307 | Inactive: 16
# Simulating step 69980... Cautious: 9708 | Readthrough: 292 | Inactive: 24
# Simulating step 70000... Cautious: 9680 | Readthrough: 320 | Inactive: 6
# Simulating step 70020... Cautious: 9686 | Readthrough: 314 | Inactive: 4
# Simulating step 70040... Cautious: 9680 | Readthrough: 320 | Inactive: 3
# Simulating step 70060... Cautious: 9684 | Readthrough: 316 | Inactive: 22
# Simulating step 70080... Cautious: 9647 | Readthrough: 353 | Inactive: 20
# Simulating step 70100... Cautious: 9592 | Readthrough: 408 | Inactive: 19
# Simulating step 70120... Cautious: 9580 | Readthrough: 420 | Inactive: 10
# Simulating step 70140... Cautious: 9560 | Readthrough: 440 | Inactive: 27
# Simulating step 70160... Cautious: 9523 | Readthrough: 477 | Inactive: 24
# Simulating step 70180... Cautious: 9511 | Readthrough: 489 | Inactive: 30
# Simulating step 70200... Cautious: 9474 | Readthrough: 526 | Inactive: 19
# Simulating step 70220... Cautious: 9493 | Readthrough: 507 | Inactive: 18
# Simulating step 70240... Cautious: 9485 | Readthrough: 515 | Inactive: 34
# Simulating step 70260... Cautious: 9459 | Readthrough: 541 | Inactive: 27
# Simulating step 70280... Cautious: 9435 | Readthrough: 565 | Inactive: 40
# Simulating step 70300... Cautious: 9391 | Readthrough: 609 | Inactive: 20
# Simulating step 70320... Cautious: 9355 | Readthrough: 645 | Inactive: 19
# Simulating step 70340... Cautious: 9378 | Readthrough: 622 | Inactive: 39
# Simulating step 70360... Cautious: 9363 | Readthrough: 637 | Inactive: 25
# Simulating step 70380... Cautious: 9356 | Readthrough: 644 | Inactive: 37
# Simulating step 70400... Cautious: 9375 | Readthrough: 625 | Inactive: 29
# Simulating step 70420... Cautious: 9384 | Readthrough: 616 | Inactive: 15
# Simulating step 70440... Cautious: 9439 | Readthrough: 561 | Inactive: 44
# Simulating step 70460... Cautious: 9406 | Readthrough: 594 | Inactive: 25
# Simulating step 70480... Cautious: 9386 | Readthrough: 614 | Inactive: 31
# Simulating step 70500... Cautious: 9373 | Readthrough: 627 | Inactive: 31
# Simulating step 70520... Cautious: 9345 | Readthrough: 655 | Inactive: 1
# Simulating step 70540... Cautious: 9369 | Readthrough: 631 | Inactive: 9
# Simulating step 70560... Cautious: 9368 | Readthrough: 632 | Inactive: 6
# Simulating step 70580... Cautious: 9389 | Readthrough: 611 | Inactive: 33
# Simulating step 70600... Cautious: 9374 | Readthrough: 626 | Inactive: 36
# Simulating step 70620... Cautious: 9346 | Readthrough: 654 | Inactive: 8
# Simulating step 70640... Cautious: 9359 | Readthrough: 641 | Inactive: 39
# Simulating step 70660... Cautious: 9439 | Readthrough: 561 | Inactive: 33
# Simulating step 70680... Cautious: 9422 | Readthrough: 578 | Inactive: 8
# Simulating step 70700... Cautious: 9405 | Readthrough: 595 | Inactive: 27
# Simulating step 70720... Cautious: 9406 | Readthrough: 594 | Inactive: 15
# Simulating step 70740... Cautious: 9432 | Readthrough: 568 | Inactive: 16
# Simulating step 70760... Cautious: 9444 | Readthrough: 556 | Inactive: 16
# Simulating step 70780... Cautious: 9398 | Readthrough: 602 | Inactive: 7
# Simulating step 70800... Cautious: 9495 | Readthrough: 505 | Inactive: 33
# Simulating step 70820... Cautious: 9476 | Readthrough: 524 | Inactive: 24
# Simulating step 70840... Cautious: 9537 | Readthrough: 463 | Inactive: 43
# Simulating step 70860... Cautious: 9519 | Readthrough: 481 | Inactive: 15
# Simulating step 70880... Cautious: 9491 | Readthrough: 509 | Inactive: 13
# Simulating step 70900... Cautious: 9475 | Readthrough: 525 | Inactive: 35
# Simulating step 70920... Cautious: 9456 | Readthrough: 544 | Inactive: 27
# Simulating step 70940... Cautious: 9424 | Readthrough: 576 | Inactive: 23
# Simulating step 70960... Cautious: 9447 | Readthrough: 553 | Inactive: 7
# Simulating step 70980... Cautious: 9473 | Readthrough: 527 | Inactive: 10
# Simulating step 71000... Cautious: 9502 | Readthrough: 498 | Inactive: 15
# Simulating step 71020... Cautious: 9525 | Readthrough: 475 | Inactive: 12
# Simulating step 71040... Cautious: 9540 | Readthrough: 460 | Inactive: 12
# Simulating step 71060... Cautious: 9499 | Readthrough: 501 | Inactive: 6
# Simulating step 71080... Cautious: 9512 | Readthrough: 488 | Inactive: 19
# Simulating step 71100... Cautious: 9495 | Readthrough: 505 | Inactive: 18
# Simulating step 71120... Cautious: 9500 | Readthrough: 500 | Inactive: 21
# Simulating step 71140... Cautious: 9482 | Readthrough: 518 | Inactive: 0
# Simulating step 71160... Cautious: 9497 | Readthrough: 503 | Inactive: 7
# Simulating step 71180... Cautious: 9478 | Readthrough: 522 | Inactive: 12
# Simulating step 71200... Cautious: 9463 | Readthrough: 537 | Inactive: 21
# Simulating step 71220... Cautious: 9453 | Readthrough: 547 | Inactive: 1
# Simulating step 71240... Cautious: 9446 | Readthrough: 554 | Inactive: 0
# Simulating step 71260... Cautious: 9469 | Readthrough: 531 | Inactive: 6
# Simulating step 71280... Cautious: 9465 | Readthrough: 535 | Inactive: 5
# Simulating step 71300... Cautious: 9419 | Readthrough: 581 | Inactive: 2
# Simulating step 71320... Cautious: 9439 | Readthrough: 561 | Inactive: 5
# Simulating step 71340... Cautious: 9436 | Readthrough: 564 | Inactive: 2
# Simulating step 71360... Cautious: 9395 | Readthrough: 605 | Inactive: 1
# Simulating step 71380... Cautious: 9390 | Readthrough: 610 | Inactive: 1
# Simulating step 71400... Cautious: 9354 | Readthrough: 646 | Inactive: 2
# Simulating step 71420... Cautious: 9348 | Readthrough: 652 | Inactive: 3
# Simulating step 71440... Cautious: 9365 | Readthrough: 635 | Inactive: 0
# Simulating step 71460... Cautious: 9360 | Readthrough: 640 | Inactive: 4
# Simulating step 71480... Cautious: 9372 | Readthrough: 628 | Inactive: 0
# Simulating step 71500... Cautious: 9318 | Readthrough: 682 | Inactive: 4
# Simulating step 71520... Cautious: 9263 | Readthrough: 737 | Inactive: 5
# Simulating step 71540... Cautious: 9310 | Readthrough: 690 | Inactive: 1
# Simulating step 71560... Cautious: 9277 | Readthrough: 723 | Inactive: 2
# Simulating step 71580... Cautious: 9199 | Readthrough: 801 | Inactive: 0
# Simulating step 71600... Cautious: 9166 | Readthrough: 834 | Inactive: 4
# Simulating step 71620... Cautious: 9207 | Readthrough: 793 | Inactive: 0
# Simulating step 71640... Cautious: 9196 | Readthrough: 804 | Inactive: 0
# Simulating step 71660... Cautious: 9244 | Readthrough: 756 | Inactive: 1
# Simulating step 71680... Cautious: 9237 | Readthrough: 763 | Inactive: 0
# Simulating step 71700... Cautious: 9262 | Readthrough: 738 | Inactive: 1
# Simulating step 71720... Cautious: 9278 | Readthrough: 722 | Inactive: 0
# Simulating step 71740... Cautious: 9269 | Readthrough: 731 | Inactive: 1
# Simulating step 71760... Cautious: 9238 | Readthrough: 762 | Inactive: 0
# Simulating step 71780... Cautious: 9263 | Readthrough: 737 | Inactive: 0
# Simulating step 71800... Cautious: 9297 | Readthrough: 703 | Inactive: 0
# Simulating step 71820... Cautious: 9261 | Readthrough: 739 | Inactive: 0
# Simulating step 71840... Cautious: 9287 | Readthrough: 713 | Inactive: 0
# Simulating step 71860... Cautious: 9288 | Readthrough: 712 | Inactive: 0
# Simulating step 71880... Cautious: 9291 | Readthrough: 709 | Inactive: 2
# Simulating step 71900... Cautious: 9358 | Readthrough: 642 | Inactive: 0
# Simulating step 71920... Cautious: 9416 | Readthrough: 584 | Inactive: 1
# Simulating step 71940... Cautious: 9439 | Readthrough: 561 | Inactive: 0
# Simulating step 71960... Cautious: 9448 | Readthrough: 552 | Inactive: 0
# Simulating step 71980... Cautious: 9478 | Readthrough: 522 | Inactive: 0
# Simulating step 72000... Cautious: 9439 | Readthrough: 561 | Inactive: 0
# Simulating step 72020... Cautious: 9437 | Readthrough: 563 | Inactive: 0
# Simulating step 72040... Cautious: 9412 | Readthrough: 588 | Inactive: 1
# Simulating step 72060... Cautious: 9432 | Readthrough: 568 | Inactive: 0
# Simulating step 72080... Cautious: 9449 | Readthrough: 551 | Inactive: 0
# Simulating step 72100... Cautious: 9445 | Readthrough: 555 | Inactive: 0
# Simulating step 72120... Cautious: 9423 | Readthrough: 577 | Inactive: 0
# Simulating step 72140... Cautious: 9458 | Readthrough: 542 | Inactive: 0
# Simulating step 72160... Cautious: 9524 | Readthrough: 476 | Inactive: 0
# Simulating step 72180... Cautious: 9521 | Readthrough: 479 | Inactive: 0
# Simulating step 72200... Cautious: 9448 | Readthrough: 552 | Inactive: 1
# Simulating step 72220... Cautious: 9433 | Readthrough: 567 | Inactive: 0
# Simulating step 72240... Cautious: 9456 | Readthrough: 544 | Inactive: 0
# Simulating step 72260... Cautious: 9472 | Readthrough: 528 | Inactive: 1
# Simulating step 72280... Cautious: 9471 | Readthrough: 529 | Inactive: 1
# Simulating step 72300... Cautious: 9432 | Readthrough: 568 | Inactive: 1
# Simulating step 72320... Cautious: 9483 | Readthrough: 517 | Inactive: 0
# Simulating step 72340... Cautious: 9491 | Readthrough: 509 | Inactive: 0
# Simulating step 72360... Cautious: 9468 | Readthrough: 532 | Inactive: 0
# Simulating step 72380... Cautious: 9476 | Readthrough: 524 | Inactive: 0
# Simulating step 72400... Cautious: 9467 | Readthrough: 533 | Inactive: 0
# Simulating step 72420... Cautious: 9401 | Readthrough: 599 | Inactive: 0
# Simulating step 72440... Cautious: 9416 | Readthrough: 584 | Inactive: 0
# Simulating step 72460... Cautious: 9414 | Readthrough: 586 | Inactive: 0
# Simulating step 72480... Cautious: 9408 | Readthrough: 592 | Inactive: 1
# Simulating step 72500... Cautious: 9383 | Readthrough: 617 | Inactive: 0
# Simulating step 72520... Cautious: 9380 | Readthrough: 620 | Inactive: 0
# Simulating step 72540... Cautious: 9366 | Readthrough: 634 | Inactive: 0
# Simulating step 72560... Cautious: 9394 | Readthrough: 606 | Inactive: 0
# Simulating step 72580... Cautious: 9365 | Readthrough: 635 | Inactive: 0
# Simulating step 72600... Cautious: 9346 | Readthrough: 654 | Inactive: 2
# Simulating step 72620... Cautious: 9447 | Readthrough: 553 | Inactive: 0
# Simulating step 72640... Cautious: 9434 | Readthrough: 566 | Inactive: 1
# Simulating step 72660... Cautious: 9438 | Readthrough: 562 | Inactive: 3
# Simulating step 72680... Cautious: 9497 | Readthrough: 503 | Inactive: 2
# Simulating step 72700... Cautious: 9461 | Readthrough: 539 | Inactive: 0
# Simulating step 72720... Cautious: 9455 | Readthrough: 545 | Inactive: 2
# Simulating step 72740... Cautious: 9456 | Readthrough: 544 | Inactive: 1
# Simulating step 72760... Cautious: 9469 | Readthrough: 531 | Inactive: 2
# Simulating step 72780... Cautious: 9477 | Readthrough: 523 | Inactive: 4
# Simulating step 72800... Cautious: 9477 | Readthrough: 523 | Inactive: 5
# Simulating step 72820... Cautious: 9491 | Readthrough: 509 | Inactive: 1
# Simulating step 72840... Cautious: 9464 | Readthrough: 536 | Inactive: 4
# Simulating step 72860... Cautious: 9418 | Readthrough: 582 | Inactive: 2
# Simulating step 72880... Cautious: 9433 | Readthrough: 567 | Inactive: 4
# Simulating step 72900... Cautious: 9474 | Readthrough: 526 | Inactive: 2
# Simulating step 72920... Cautious: 9558 | Readthrough: 442 | Inactive: 10
# Simulating step 72940... Cautious: 9600 | Readthrough: 400 | Inactive: 6
# Simulating step 72960... Cautious: 9578 | Readthrough: 422 | Inactive: 5
# Simulating step 72980... Cautious: 9573 | Readthrough: 427 | Inactive: 12
#
# --- MAX STEPS (73000) REACHED ---
# Simulation ended in a stalemate.
